# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import catboost as cat
import ngboost as ng
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold, train_test_split
from sklearn.ensemble import *
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_log_error, mean_squared_error
import xgboost as xgb
import lightgbm as lgb
import warnings
warnings.filterwarnings(action='ignore')

# %%
train = pd.read_csv(r'C:\Users\Rahul\Desktop\HackerEarth-Machine-Learning-Challenge-Carnival-Wars\train.csv')
test = pd.read_csv(r'C:\Users\Rahul\Desktop\HackerEarth-Machine-Learning-Challenge-Carnival-Wars\test.csv')
sample = pd.read_csv(r'C:\Users\Rahul\Desktop\HackerEarth-Machine-Learning-Challenge-Carnival-Wars\sample_submission.csv')
prd_id = test.Product_id
train.rename({'charges_2 (%)':'charges_2'},inplace=True,axis=1)
test.rename({'charges_2 (%)':'charges_2'},inplace=True,axis=1)

# %%
z = np.copy(test.Product_id)
b = pd.DataFrame(np.copy(train),columns=train.columns)

# %%
train.head()
# Out:
#          Product_id  Stall_no             instock_date  Market_Category  \
# 0  BRAE2NF6JA5GUEXG      37.0  2015-08-22 18:36:12.000                2
# 1  TUNE8SFB6RJN2HSD      38.0  2016-03-27 21:19:13.000               24
# 2  BRAEAR7WZPQGPBZU       9.0  2015-08-18 19:25:22.000              447
# 3  WATDZ2ZQ8JPDHCTJ      50.0  2016-03-28 21:53:01.000               23
# 4  JWSEBUKYQPMBZ3RK       7.0  2016-03-29 22:58:53.000               63
#
#   Customer_name Loyalty_customer Product_Category  Grade  Demand  \
# 0      Lillyann              Yes          Fashion      1      68
# 1         Klynn              Yes          Fashion      0      51
# 2         Ridge              Yes       Child_care      0      10
# 3         Abran              Yes      Educational      2      48
# 4        Dustyn              Yes           Repair      1      35
#
#    Discount_avail  charges_1  charges_2  Minimum_price  Maximum_price  \
# 0             0.0      376.0       11.0         2983.0         4713.0
# 1             0.0      397.0       12.0         7495.0        10352.0
# 2             0.0      250.0        9.0         5752.0         7309.0
# 3             0.0      144.0       13.0         5090.0        20814.0
# 4             1.0      211.0        4.0         2430.0         9261.0
#
#    Selling_Price
# 0    4185.947700
# 1    9271.490256
# 2    6785.701362
# 3   13028.917824
# 4     906.553935

# %%
test.head()
# Out:
#          Product_id  Stall_no             instock_date  Market_Category  \
# 0  SCHE4YSTDVPVZVXW      39.0  2016-01-13 07:45:08.000              205
# 1  ACCEGCATKHNRXUHW      49.0  2015-08-23 20:37:05.000                3
# 2  NKCE6GJ5XVJDXNNZ       1.0  2015-11-14 18:12:39.000              183
# 3  NKCEB8BK3ZXDHDHM       8.0  2015-11-21 04:56:19.000              358
# 4  TOPEFDXSAHRNPF94      33.0  2015-05-06 15:09:46.000              167
#
#   Customer_name Loyalty_customer Product_Category  Grade  Demand  \
# 0        Ivanka              No           Fashion      0      90
# 1         Isaak              Yes          Fashion      0      87
# 2      Analiese              No        Technology      2      55
# 3         Rusty              Yes       Child_care      3      86
# 4        Eloise              No        Technology      0      27
#
#    Discount_avail  charges_1  charges_2  Minimum_price  Maximum_price
# 0               0      380.0       16.0         2576.0           3340
# 1               0      393.0       16.0         1202.0           1955
# 2               0      493.0        9.0         7175.0          15715
# 3               0      303.0       16.0         5404.0          13078
# 4               0      567.0       16.0         4069.0           6244

# %%
sample.head()
# Out:
#          Product_id  Selling_Price
# 0  SCHE4YSTDVPVZVXW    3294.594688
# 1  ACCEGCATKHNRXUHW    1945.603968
# 2  NKCE6GJ5XVJDXNNZ   11871.830880
# 3  NKCEB8BK3ZXDHDHM    9421.143424
# 4  TOPEFDXSAHRNPF94    5717.420625

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6368 entries, 0 to 6367
# Data columns (total 15 columns):
# Product_id          6368 non-null object
# Stall_no            6363 non-null float64
# instock_date        6368 non-null object
# Market_Category     6368 non-null int64
# Customer_name       6157 non-null object
# Loyalty_customer    6368 non-null object
# Product_Category    6368 non-null object
# Grade               6368 non-null int64
# Demand              6368 non-null int64
# Discount_avail      6330 non-null float64
# charges_1           6170 non-null float64
# charges_2           6163 non-null float64
# Minimum_price       6330 non-null float64
# Maximum_price       6025 non-null float64
# Selling_Price       6327 non-null float64
# dtypes: float64(7), int64(3), object(5)
# memory usage: 746.3+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3430 entries, 0 to 3429
# Data columns (total 14 columns):
# Product_id          3430 non-null object
# Stall_no            3429 non-null float64
# instock_date        3430 non-null object
# Market_Category     3430 non-null int64
# Customer_name       3377 non-null object
# Loyalty_customer    3430 non-null object
# Product_Category    3430 non-null object
# Grade               3430 non-null int64
# Demand              3430 non-null int64
# Discount_avail      3430 non-null int64
# charges_1           3394 non-null float64
# charges_2           3425 non-null float64
# Minimum_price       3416 non-null float64
# Maximum_price       3430 non-null int64
# dtypes: float64(4), int64(5), object(5)
# memory usage: 375.2+ KB

# %%
train.describe()
# Out:
#           Stall_no  Market_Category        Grade       Demand  Discount_avail  \
# count  6363.000000      6368.000000  6368.000000  6368.000000     6330.000000
# mean     25.309445       199.340609     0.643687    50.921168        0.140442
# std      14.328980       170.275570     1.025092    29.091922        0.347473
# min       1.000000         0.000000     0.000000     1.000000        0.000000
# 25%      13.000000        55.000000     0.000000    26.000000        0.000000
# 50%      25.000000       132.000000     0.000000    51.000000        0.000000
# 75%      37.000000       403.000000     2.000000    76.000000        0.000000
# max      50.000000       471.000000     3.000000   100.000000        1.000000
#
#          charges_1    charges_2  Minimum_price  Maximum_price  Selling_Price
# count  6170.000000  6163.000000    6330.000000    6025.000000    6327.000000
# mean    264.514100    10.146195    3531.349763    6432.545892    4563.242592
# std     124.483056     4.318339    2194.729604    3716.177364    2979.102408
# min     100.000000     1.000000       1.000000     404.000000   -6062.470000
# 25%     163.000000     7.000000    1879.250000    3918.000000    2450.005280
# 50%     252.000000    10.000000    3157.500000    5634.000000    4210.384640
# 75%     314.000000    14.000000    4697.000000    8126.000000    6167.643252
# max     649.000000    17.000000   17580.000000   58812.000000   22638.325941

# %%
test.describe()
# Out:
#           Stall_no  Market_Category        Grade       Demand  Discount_avail  \
# count  3429.000000      3430.000000  3430.000000  3430.000000     3430.000000
# mean     25.633421       196.693878     0.667638    49.917493        0.146356
# std      14.389747       168.832500     1.045914    28.587214        0.353514
# min       1.000000         0.000000     0.000000     1.000000        0.000000
# 25%      13.000000        55.000000     0.000000    26.000000        0.000000
# 50%      26.000000       124.000000     0.000000    50.000000        0.000000
# 75%      38.000000       358.000000     2.000000    74.000000        0.000000
# max      50.000000       471.000000     3.000000   100.000000        1.000000
#
#          charges_1    charges_2  Minimum_price  Maximum_price
# count  3394.000000  3425.000000    3416.000000    3430.000000
# mean    265.484973    10.436204    3444.206089    6234.062391
# std     125.325455     4.232382    2178.418557    3575.968650
# min     100.000000     1.000000     124.000000     163.000000
# 25%     162.000000     7.000000    1834.000000    3819.000000
# 50%     252.000000    11.000000    3060.500000    5431.000000
# 75%     319.000000    14.000000    4606.500000    7796.500000
# max     648.000000    17.000000   17182.000000   27954.000000

# %%
train.isnull().sum()
# Out:
# Product_id            0
# Stall_no              5
# instock_date          0
# Market_Category       0
# Customer_name       211
# Loyalty_customer      0
# Product_Category      0
# Grade                 0
# Demand                0
# Discount_avail       38
# charges_1           198
# charges_2           205
# Minimum_price        38
# Maximum_price       343
# Selling_Price        41
# dtype: int64

# %%
test.isnull().sum()
# Out:
# Product_id           0
# Stall_no             1
# instock_date         0
# Market_Category      0
# Customer_name       53
# Loyalty_customer     0
# Product_Category     0
# Grade                0
# Demand               0
# Discount_avail       0
# charges_1           36
# charges_2            5
# Minimum_price       14
# Maximum_price        0
# dtype: int64

# %% [markdown]
# ### Label Analysis

# %%
sns.distplot(train.Selling_Price)

# %%
train.drop(index=train[train.Selling_Price<0].index, inplace=True)
train.reset_index(drop=True,inplace=True)

# %%
train.Selling_Price = train.Selling_Price.apply(lambda x: x if x>=0 else x*(-1))

# %%
train.Selling_Price.isnull().sum()
# Out:
# 41

# %% [markdown]
# a = train[train.Selling_Price.isnull()]
# b.dropna(inplace=True)
# l1 = np.log(b.Selling_Price)
#
#
# b.Selling_Price = b.Selling_Price.apply(lambda x: x if x>=0 else x*(-1))
# b[['Discount_avail','charges_1','charges_2','Minimum_price','Maximum_price']] = b[['Discount_avail','charges_1','charges_2','Minimum_price','Maximum_price']].astype('float')
#
# xtrain,xtest,ytrain,ytest = train_test_split(b[['Discount_avail','charges_1','charges_2','Minimum_price','Maximum_price']],b.Selling_Price,test_size=0.3,random_state=8011)
#
# m = lgb.LGBMRegressor(random_state=10070)
# m.fit(xtrain,ytrain)
# i_prd = m.predict(xtest)
# np.sqrt(mean_squared_log_error(ytest,i_prd))
#
# a.drop(columns=['Selling_Price'],inplace=True)
#
# a.Maximum_price.fillna(a.Maximum_price.median(),inplace=True)
# a.Minimum_price.fillna(a.Minimum_price.median(),inplace=True)
# a.Discount_avail.fillna(a.Discount_avail.median(),inplace=True)
# a.charges_2.fillna(a.charges_2.median(),inplace=True)
#
# a['Selling_Price'] = m.predict(a[['Discount_avail','charges_1','charges_2','Minimum_price','Maximum_price']])
# l = a.Selling_Price.index
# for i in l:
#     train.loc[i,'Selling_Price'] = a.loc[i,'Selling_Price']

# %%
train.isnull().sum()
# Out:
# Product_id            0
# Stall_no              5
# instock_date          0
# Market_Category       0
# Customer_name       210
# Loyalty_customer      0
# Product_Category      0
# Grade                 0
# Demand                0
# Discount_avail       38
# charges_1           197
# charges_2           205
# Minimum_price        38
# Maximum_price       342
# Selling_Price        41
# dtype: int64

# %%
#train.isnull().sum()

# %%
train.drop(index = train[train.Selling_Price.isnull()].index, inplace=True)
train.reset_index(drop=True,inplace=True)

# %%
#train.Selling_Price.fillna(train.Selling_Price.mean(),inplace=True)

# %% [markdown]
# ## Feature by Feature Analysis

# %% [markdown]
# ### Product ID

# %%
train.Product_id = train.Product_id.apply(lambda x: [i for i in x][:3])
test.Product_id = test.Product_id.apply(lambda x: [i for i in x][:3])

# %%
train.Product_id = train.Product_id.apply(lambda x: ''.join(x))
test.Product_id = test.Product_id.apply(lambda x: ''.join(x))

# %%
train.Product_id.nunique(), test.Product_id.nunique()
# Out:
# (292, 243)

# %%
z
# Out:
# array(['SCHE4YSTDVPVZVXW', 'ACCEGCATKHNRXUHW', 'NKCE6GJ5XVJDXNNZ', ...,
#        'TUNE8FWQBS7TVVT7', 'NKCEGMUABCRGUZPE', 'RNGE7M92KAQWUBCS'],
#       dtype=object)

# %% [markdown]
# ### Stall no.

# %%
test.Stall_no.nunique()
# Out:
# 50

# %%
train.Stall_no.isnull().sum(), test.Stall_no.isnull().sum()
# Out:
# (5, 1)

# %%
train.Stall_no.fillna(20.0, inplace=True) #20
test.Stall_no.fillna(12.0,inplace=True)   #12

# %%
sns.scatterplot(train.Stall_no,train.Selling_Price)

# %%
sns.distplot(train.Stall_no)

# %%
sns.distplot(test.Stall_no)

# %% [markdown]
# ### In Stock date

# %%
#train['Date'] = train.instock_date.str.split(' ').apply(lambda x: x[0])
#test['Date'] = test.instock_date.str.split(' ').apply(lambda x: x[0])

# %%
#train['Time'] = train.instock_date.str.split(' ').apply(lambda x: x[1])
#test['Time'] = test.instock_date.str.split(' ').apply(lambda x: x[1])

# %%
#train['Hour'] = train.Time.str.split(':').apply(lambda x: x[0])
#test['Hour'] = test.Time.str.split(':').apply(lambda x: x[0])

#train['Minute'] = train.Time.str.split(':').apply(lambda x: x[1])
#test['Minute'] = test.Time.str.split(':').apply(lambda x: x[1])

#train['Second'] = train.Time.str.split(':').apply(lambda x: x[2])
#test['Second'] = test.Time.str.split(':').apply(lambda x: x[2])

# %%
#train.drop(columns=['instock_date','Time'],inplace = True)
#test.drop(columns=['instock_date','Time'],inplace = True)

# %%
train.head()
# Out:
#   Product_id  Stall_no             instock_date  Market_Category  \
# 0        BRA      37.0  2015-08-22 18:36:12.000                2
# 1        TUN      38.0  2016-03-27 21:19:13.000               24
# 2        BRA       9.0  2015-08-18 19:25:22.000              447
# 3        WAT      50.0  2016-03-28 21:53:01.000               23
# 4        JWS       7.0  2016-03-29 22:58:53.000               63
#
#   Customer_name Loyalty_customer Product_Category  Grade  Demand  \
# 0      Lillyann              Yes          Fashion      1      68
# 1         Klynn              Yes          Fashion      0      51
# 2         Ridge              Yes       Child_care      0      10
# 3         Abran              Yes      Educational      2      48
# 4        Dustyn              Yes           Repair      1      35
#
#    Discount_avail  charges_1  charges_2  Minimum_price  Maximum_price  \
# 0             0.0      376.0       11.0         2983.0         4713.0
# 1             0.0      397.0       12.0         7495.0        10352.0
# 2             0.0      250.0        9.0         5752.0         7309.0
# 3             0.0      144.0       13.0         5090.0        20814.0
# 4             1.0      211.0        4.0         2430.0         9261.0
#
#    Selling_Price
# 0    4185.947700
# 1    9271.490256
# 2    6785.701362
# 3   13028.917824
# 4     906.553935

# %% [markdown]
# ### Market Category

# %%
sns.distplot(train.Market_Category)

# %%
sns.distplot(test.Market_Category)

# %%
sns.scatterplot(train.Market_Category,train.Selling_Price)

# %% [markdown]
# ### Customer Name

# %%
train.Customer_name.nunique(),test.Customer_name.nunique()
# Out:
# (5855, 3319)

# %%
#train.drop(columns=['Customer_name'],inplace=True)
#test.drop(columns=['Customer_name'],inplace=True)

# %% [markdown]
# ### Loyalty Customer

# %%
train.Loyalty_customer.value_counts(), test.Loyalty_customer.value_counts()
# Out:
# (Yes    3852
#  No     2461
#  Name: Loyalty_customer, dtype: int64,
#  Yes    2087
#  No     1343
#  Name: Loyalty_customer, dtype: int64)

# %%
sns.boxplot(train.Loyalty_customer,train.Selling_Price)

# %% [markdown]
# ### Product Category

# %%
train.Product_Category.value_counts()
# Out:
# Pet_care       674
# Repair         665
# Child_care     652
# Cosmetics      643
# Hospitality    626
# Organic        618
# Technology     616
# Home_decor     610
# Educational    605
# Fashion        604
# Name: Product_Category, dtype: int64

# %%
test.Product_Category.value_counts()
# Out:
# Educational    355
# Child_care     348
# Cosmetics      348
# Pet_care       346
# Fashion        345
# Repair         345
# Home_decor     340
# Technology     340
# Organic        336
# Hospitality    327
# Name: Product_Category, dtype: int64

# %%
sns.boxplot(train.Product_Category,train.Selling_Price)

# %% [markdown]
# ### Grade

# %%
train.Grade.value_counts()
# Out:
# 0    4339
# 2    1093
# 3     502
# 1     379
# Name: Grade, dtype: int64

# %%
z
# Out:
# array(['SCHE4YSTDVPVZVXW', 'ACCEGCATKHNRXUHW', 'NKCE6GJ5XVJDXNNZ', ...,
#        'TUNE8FWQBS7TVVT7', 'NKCEGMUABCRGUZPE', 'RNGE7M92KAQWUBCS'],
#       dtype=object)

# %%
test.Grade.value_counts()
# Out:
# 0    2335
# 2     595
# 3     300
# 1     200
# Name: Grade, dtype: int64

# %%
sns.boxplot(train.Grade,train.Selling_Price)

# %% [markdown]
# ### Demand

# %%
sns.distplot(train.Demand)

# %%
sns.distplot(test.Demand)

# %%
sns.scatterplot(train.Demand,train.Selling_Price)

# %% [markdown]
# ### Discount Avail

# %%
train.Discount_avail.value_counts()
# Out:
# 0.0    5396
# 1.0     880
# Name: Discount_avail, dtype: int64

# %%
#train.Discount_avail.fillna(1.0,inplace=True)

# %%
train.drop(index = train[train.Discount_avail.isnull()].index, inplace=True)
train.reset_index(drop=True,inplace=True)

# %%
#train.Discount_avail.fillna(0.0,inplace=True)

# %%
test.Discount_avail.value_counts()
# Out:
# 0    2928
# 1     502
# Name: Discount_avail, dtype: int64

# %%
sns.boxplot(train.Discount_avail,train.Selling_Price)

# %% [markdown]
# ### Charges_1

# %%
sns.distplot(train.charges_1)

# %%
sns.distplot(test.charges_1)

# %%
sns.scatterplot(train.charges_1,train.Selling_Price)

# %%
#train.drop(train[train.charges_1.isnull()].index,inplace=True)
#train.reset_index(drop=True,inplace=True)

# %%
#train.charges_1.fillna(train.charges_1.median(),inplace=True)
#test.charges_1.fillna(test.charges_1.median(),inplace=True)
# here also

# %% [markdown]
# ### Charges_2(%)

# %%
sns.distplot(train.charges_2)

# %%
sns.distplot(test.charges_2)

# %%
sns.scatterplot(train.charges_2,train.Selling_Price)

# %%
#train.charges_2.fillna(train.charges_2.median(),inplace=True)
#test.charges_2.fillna(test.charges_2.median(),inplace=True)
## here also

# %% [markdown]
# ### Minimum price

# %%
sns.distplot(np.log(train.Minimum_price))

# %%
sns.distplot(np.log(test.Minimum_price))

# %%
sns.scatterplot(train.Minimum_price,train.Selling_Price)

# %%
#train.Minimum_price.fillna(train.Minimum_price.median(),inplace=True)
#test.Minimum_price.fillna(test.Minimum_price.median(),inplace=True)
## removed already but fillinf with df once

# %% [markdown]
# ### Maximum Price

# %%
sns.distplot(np.log(train.Maximum_price))

# %%
sns.distplot(np.log(test.Maximum_price))

# %%
sns.scatterplot(train.Maximum_price,train.Selling_Price)

# %%
train.drop(index = train[train.Maximum_price==train.Maximum_price.max()].index, inplace=True)
train.reset_index(drop=True,inplace=True)

# %%
#train.Maximum_price.fillna(train.Maximum_price.median(),inplace=True)

# %% [markdown]
# ### Feature  Engg.

# %%
train.head()
# Out:
#   Product_id  Stall_no             instock_date  Market_Category  \
# 0        BRA      37.0  2015-08-22 18:36:12.000                2
# 1        TUN      38.0  2016-03-27 21:19:13.000               24
# 2        BRA       9.0  2015-08-18 19:25:22.000              447
# 3        WAT      50.0  2016-03-28 21:53:01.000               23
# 4        JWS       7.0  2016-03-29 22:58:53.000               63
#
#   Customer_name Loyalty_customer Product_Category  Grade  Demand  \
# 0      Lillyann              Yes          Fashion      1      68
# 1         Klynn              Yes          Fashion      0      51
# 2         Ridge              Yes       Child_care      0      10
# 3         Abran              Yes      Educational      2      48
# 4        Dustyn              Yes           Repair      1      35
#
#    Discount_avail  charges_1  charges_2  Minimum_price  Maximum_price  \
# 0             0.0      376.0       11.0         2983.0         4713.0
# 1             0.0      397.0       12.0         7495.0        10352.0
# 2             0.0      250.0        9.0         5752.0         7309.0
# 3             0.0      144.0       13.0         5090.0        20814.0
# 4             1.0      211.0        4.0         2430.0         9261.0
#
#    Selling_Price
# 0    4185.947700
# 1    9271.490256
# 2    6785.701362
# 3   13028.917824
# 4     906.553935

# %%
#train.drop(train.Minimum_price[np.log(train.Minimum_price)<5].index,inplace=True)
#train.reset_index(drop=True,inplace=True)

# %%
df = pd.concat([train,test],axis=0)
df.reset_index(drop=True,inplace=True)

# %%
df.Maximum_price.fillna(df.Maximum_price.median(),inplace=True)
df.Minimum_price.fillna(df.Minimum_price.median(),inplace=True)
df.charges_2.fillna(df.charges_2.median(),inplace=True)
df.charges_1.fillna(df.charges_1.median(),inplace=True)

# %%
df['Sum'] = ((df.Maximum_price**2) + (df.Minimum_price**2))
df['Mean_price'] = (df.Maximum_price + df.Minimum_price)/2
df['Mean_price_charged'] = (df.Maximum_price + df.Minimum_price) - df.charges_1
#df['Diff_price'] = np.sqrt((df.Maximum_price**2) - (df.Minimum_price**2))
df['Date'] = df.instock_date.str.split(' ').apply(lambda x: x[0])
df.Date = pd.to_datetime(df.Date)
df['Max-price_per-demand'] = df.Maximum_price/df.Demand
df['Min-price_per-demand'] = df.Minimum_price/df.Demand
df['Total-price_per-demand'] = df.Sum/df.Demand

# %%
#df.groupby(['Demand'])[['Minimum_price']].agg(('count','min','max','mean'))
#df['Demand_count_price_count'] = df.groupby(['Grade'])[['Sum']].transform('count')
#df['Demand_min_price_min'] = df.groupby(['Grade'])[['Sum']].transform('min')
#df['Demand_max_price_max'] = df.groupby(['Grade'])[['Sum']].transform('max')
#df['Demand_sum_price_sum'] = df.groupby(['Grade'])[['Sum']].transform('sum')

#df['Demand_max_price_count'] = df.groupby(['Demand'])[['Maximum_price']].transform('count')
#df['Demand_max_price_min'] = df.groupby(['Demand'])[['Maximum_price']].transform('min')
#df['Demand_max_price_max'] = df.groupby(['Demand'])[['Maximum_price']].transform('max')
#df['Demand_max_price_sum'] = df.groupby(['Demand'])[['Maximum_price']].transform('sum')

# %%
df['Weekday'] = df.Date.dt.weekday
df['Day'] = df.Date.dt.day
df['DOY'] = df.Date.dt.dayofyear
df['WOY'] = df.Date.dt.weekofyear
df['DIM'] = df.Date.dt.daysinmonth
df['Month'] = df.Date.dt.month
df['WeekDay_name'] = df.Date.dt.weekday_name

# %%
df['Time'] = df.instock_date.str.split(' ').apply(lambda x: x[1])
#df['Hour'] = df.Time.str.split(':').apply(lambda x: int(x[0]))
df['Minute'] = df.Time.str.split(':').apply(lambda x: int(x[1]))
df['Second'] = df.Time.str.split(':').apply(lambda x: float(x[2]))

#df.Hour = df.Hour + (df.Minute/60) + (df.Second/3600)

# %%
#df['Prd_cat_Max_pr_mean']=df.groupby(['Product_Category'])['Mean_price'].transform('mean')
#df['Prd_cat_Max_pr_max']=df.groupby(['Product_Category'])['Maximum_price'].transform('max')
#df['Prd_cat_Max_pr_min']=df.groupby(['Product_Category'])['Maximum_price'].transform('min')
#df['Prd_cat_Max_pr_count']=df.groupby(['Product_Category'])['Maximum_price'].transform('count')

#df['Prd_cat_Min_pr_mean']=df.groupby(['Product_Category'])['Minimum_price'].transform('mean')
#df['Prd_cat_Min_pr_max']=df.groupby(['Product_Category'])['Minimum_price'].transform('max')
#df['Prd_cat_Min_pr_min']=df.groupby(['Product_Category'])['Minimum_price'].transform('min')
#df['Prd_cat_Min_pr_count']=df.groupby(['Product_Category'])['Minimum_price'].transform('count')

#df['Prd_cat_Max_pr_mean']=df.groupby(['Loyalty_customer'])['Maximum_price'].transform('mean')
#df['Prd_cat_Max_pr_max']=df.groupby(['Loyalty_customer'])['Maximum_price'].transform('max')
#df['Prd_cat_Max_pr_min']=df.groupby(['Loyalty_customer'])['Maximum_price'].transform('min')
#df['Prd_cat_Max_pr_count']=df.groupby(['Loyalty_customer'])['Market_Category'].transform('count')

#df['Stall_cat_Min_pr_mean']=df.groupby(['Stall_no'])['Mean_price'].transform('mean')
#df['Stall_cat_Min_pr_max']=df.groupby(['Stall_no'])['Mean_price'].transform('max')
#df['Stall_cat_Min_pr_min']=df.groupby(['Stall_no'])['Mean_price'].transform('min')
#df['Stall_cat_Min_pr_count']=df.groupby(['Market_Category'])['Loyalty_customer'].transform('count')

#df['Stall_cat_Max_pr_mean']=df.groupby(['Discount_avail'])['Sum'].transform('mean')
#df['Stall_cat_Max_pr_max']=df.groupby(['Discount_avail'])['Sum'].transform('max')
#df['Stall_cat_Max_pr_min']=df.groupby(['Discount_avail'])['Sum'].transform('min')
#df['Stall_cat_Max_pr_count']=df.groupby(['Discount_avail'])['Sum'].transform('count')

# %%
df['Charged_max_price'] = df.Maximum_price-(df.charges_1 + (df.charges_2*df.Maximum_price/100))
df['Charged_min_price'] = df.Minimum_price -(df.charges_1 + (df.charges_2*df.Minimum_price/100))
df['Total-charges'] = df.charges_1 + (df.charges_2/100)
df['Diff_Max_price'] = df.Maximum_price - df.Charged_max_price
df['Diff_Sum_price'] = df.Sum - df['Total-charges']
df['Min-Max_ratio'] = df.Maximum_price/df.Minimum_price
df.Maximum_price = np.log(df.Maximum_price)
df.Minimum_price = np.log(df.Minimum_price)

# %%
df['Prd_cat_Min_pr_mean']=df.groupby(['Product_id'])['Minimum_price'].transform('mean')
df['Prd_cat_Min_pr_max']=df.groupby(['Product_id'])['Minimum_price'].transform('max')
df['Prd_cat_Min_pr_min']=df.groupby(['Product_id'])['Minimum_price'].transform('min')
df['Prd_cat_Min_pr_count']=df.groupby(['Product_id'])['Minimum_price'].transform('count')
df['Prd_cat_Min_pr_median']=df.groupby(['Product_id'])['Minimum_price'].transform('median')


df['Market_Loyal_pr_count']=df.groupby(['Market_Category'])['Loyalty_customer'].transform('count')
df['Product_Loyal_pr_count']=df.groupby(['Product_Category'])['Loyalty_customer'].transform('count')
df['Discount_Loyal_pr_count']=df.groupby(['Discount_avail'])['Loyalty_customer'].transform('count')
df['Id_Loyal_pr_count']=df.groupby(['Product_id'])['Loyalty_customer'].transform('count')

# %%
df['Stall_Cust_count']=df.groupby(['Stall_no'])['Customer_name'].transform('count')

#df['Grade_sum_price_count'] = df.groupby(['Grade'])[['Sum']].transform('count')
#df['Grade_sum_price_min'] = df.groupby(['Grade'])[['Sum']].transform('min')
#df['Grade_sum_price_max'] = df.groupby(['Grade'])[['Sum']].transform('max')
#df['Grade_sum_price_sum'] = df.groupby(['Grade'])[['Sum']].transform('sum')

#df['Disc_sum_price_count'] = df.groupby(['Discount_avail','Grade'])[['Mean_price']].transform('count')
#df['Disc_sum_price_min'] = df.groupby(['Discount_avail'])[['Mean_price']].transform('min')
#df['Disc_sum_price_max'] = df.groupby(['Discount_avail'])[['Mean_price']].transform('max')
#df['Disc_sum_price_sum'] = df.groupby(['Discount_avail','Grade'])[['Mean_price']].transform('sum')

#df = pd.concat([df,pd.get_dummies(df[['Loyalty_customer','Product_Category']].astype('category'))],axis=1)

# %%
le = LabelEncoder()
df.Loyalty_customer = le.fit_transform(df.Loyalty_customer)
df.Product_Category = le.fit_transform(df.Product_Category)
df.WeekDay_name = le.fit_transform(df.WeekDay_name)
df.Product_id = le.fit_transform(df.Product_id)

# %%
df.head()
# Out:
#   Customer_name  Demand  Discount_avail  Grade  Loyalty_customer  \
# 0      Lillyann      68             0.0      1                 1
# 1         Klynn      51             0.0      0                 1
# 2         Ridge      10             0.0      0                 1
# 3         Abran      48             0.0      2                 1
# 4        Dustyn      35             1.0      1                 1
#
#    Market_Category  Maximum_price  Minimum_price  Product_Category  \
# 0                2       8.458080       8.000685                 3
# 1               24       9.244935       8.921991                 3
# 2              447       8.896862       8.657303                 0
# 3               23       9.943381       8.535033                 2
# 4               63       9.133567       7.795647                 8
#
#    Product_id  ...  Prd_cat_Min_pr_mean  Prd_cat_Min_pr_max  \
# 0          39  ...             7.736146            9.125762
# 1         315  ...             8.125481            9.473474
# 2          39  ...             7.736146            9.125762
# 3         333  ...             8.066417            9.772182
# 4         151  ...             8.257437            9.394161
#
#    Prd_cat_Min_pr_min  Prd_cat_Min_pr_count Prd_cat_Min_pr_median  \
# 0            5.497168                   989              7.779049
# 1            5.198497                    33              8.351375
# 2            5.497168                   989              7.779049
# 3            5.147494                   440              8.204312
# 4            7.372118                    28              8.425186
#
#    Market_Loyal_pr_count  Product_Loyal_pr_count  Discount_Loyal_pr_count  \
# 0                     39                     945                     8324
# 1                    321                     945                     8324
# 2                    261                     994                     8324
# 3                    491                     955                     8324
# 4                     59                    1004                     1381
#
#   Id_Loyal_pr_count  Stall_Cust_count
# 0               989               197
# 1                33               182
# 2               989               212
# 3               440               167
# 4                28               180
#
# [5 rows x 48 columns]

# %%
#df.drop(columns=['Loyalty_customer','Product_Category'],inplace=True)

# %% [markdown]
# ### Modelling

# %%
train = df.iloc[:train.shape[0],:]
test = df.iloc[train.shape[0]:,:]
test.reset_index(drop=True,inplace=True)
label = np.log(train.Selling_Price)
test.drop(columns=['Selling_Price','Date','Time','instock_date','Customer_name','Minute','Second'],inplace=True)
train.drop(columns=['Selling_Price','Date','Time','instock_date','Customer_name','Minute','Second'],inplace=True)

# %%
train.shape, test.shape
# Out:
# ((6275, 41), (3430, 41))

# %%
def model(m,train,label,test,folds,rnd_st):
    predicted = pd.DataFrame(np.zeros(shape=(test.shape[0],folds)))
    splitters = KFold(n_splits = folds, random_state=rnd_st)
    tr = []
    te = []
    
    for i,(tr_index,val_index) in enumerate(splitters.split(train,label)):
        xtrain,xval = train.loc[tr_index,:], train.loc[val_index,:]
        ytrain,yval = label.loc[tr_index], label.loc[val_index]
        
        m.fit(xtrain,ytrain)
        tr_pred = m.predict(xtrain)
        val_pred = m.predict(xval)
        l1 = max([0,100-np.sqrt(mean_squared_error(ytrain,tr_pred))])
        l2 = max([0,100-np.sqrt(mean_squared_error(yval,val_pred))])
        
        print(l1,'\t\t\t\t\t',l2)
        tr.append(l1)
        te.append(l2)
        pd.Series(m.feature_importances_,index = train.columns).sort_values(ascending=True).plot.barh()
        predicted.iloc[:,i] = m.predict(test)

    print(np.mean(tr), np.mean(te))
    return(predicted)

# %%
seed = 64792

# %%
plt.figure(figsize=(9,12))
result = np.exp(model(cat.CatBoostRegressor(random_state=seed),train,label,test,9,seed))
# Out:
# Learning rate set to 0.052998
# 0:	learn: 0.8179249	total: 5.79ms	remaining: 5.79s
# 1:	learn: 0.7784262	total: 9.68ms	remaining: 4.83s
# 2:	learn: 0.7413801	total: 13.4ms	remaining: 4.46s
# 3:	learn: 0.7061892	total: 17.3ms	remaining: 4.3s
# 4:	learn: 0.6733168	total: 21ms	remaining: 4.18s
# 5:	learn: 0.6412983	total: 24.8ms	remaining: 4.11s
# 6:	learn: 0.6109030	total: 28.7ms	remaining: 4.08s
# 7:	learn: 0.5821772	total: 32.5ms	remaining: 4.03s
# 8:	learn: 0.5556886	total: 36.3ms	remaining: 4s
# 9:	learn: 0.5302075	total: 40.1ms	remaining: 3.97s
# 10:	learn: 0.5060771	total: 43.8ms	remaining: 3.94s
# 11:	learn: 0.4824311	total: 47.6ms	remaining: 3.92s
# 12:	learn: 0.4605354	total: 51.4ms	remaining: 3.9s
# 13:	learn: 0.4395953	total: 55.1ms	remaining: 3.88s
# 14:	learn: 0.4196452	total: 59.1ms	remaining: 3.88s
# 15:	learn: 0.4009359	total: 62.9ms	remaining: 3.87s
# 16:	learn: 0.3837720	total: 66.9ms	remaining: 3.87s
# 17:	learn: 0.3670942	total: 70.8ms	remaining: 3.86s
# 18:	learn: 0.3514973	total: 74.6ms	remaining: 3.85s
# 19:	learn: 0.3371655	total: 78.4ms	remaining: 3.84s
# 20:	learn: 0.3231991	total: 82.2ms	remaining: 3.83s
# 21:	learn: 0.3103023	total: 85.9ms	remaining: 3.82s
# 22:	learn: 0.2975666	total: 89.8ms	remaining: 3.81s
# 23:	learn: 0.2857092	total: 93.6ms	remaining: 3.81s
# 24:	learn: 0.2741642	total: 97.3ms	remaining: 3.8s
# 25:	learn: 0.2639850	total: 101ms	remaining: 3.79s
# 26:	learn: 0.2537898	total: 105ms	remaining: 3.78s
# 27:	learn: 0.2445636	total: 109ms	remaining: 3.77s
# 28:	learn: 0.2359507	total: 112ms	remaining: 3.76s
# 29:	learn: 0.2271607	total: 116ms	remaining: 3.76s
# 30:	learn: 0.2190359	total: 120ms	remaining: 3.75s
# 31:	learn: 0.2113189	total: 124ms	remaining: 3.74s
# 32:	learn: 0.2043229	total: 128ms	remaining: 3.74s
# 33:	learn: 0.1976364	total: 132ms	remaining: 3.74s
# 34:	learn: 0.1913211	total: 135ms	remaining: 3.73s
# 35:	learn: 0.1851555	total: 139ms	remaining: 3.73s
# 36:	learn: 0.1797382	total: 143ms	remaining: 3.72s
# 37:	learn: 0.1750092	total: 146ms	remaining: 3.69s
# 38:	learn: 0.1699328	total: 150ms	remaining: 3.69s
# 39:	learn: 0.1651524	total: 153ms	remaining: 3.68s
# 40:	learn: 0.1607810	total: 157ms	remaining: 3.68s
# 41:	learn: 0.1565523	total: 161ms	remaining: 3.67s
# 42:	learn: 0.1525153	total: 165ms	remaining: 3.67s
# 43:	learn: 0.1490064	total: 168ms	remaining: 3.66s
# 44:	learn: 0.1456721	total: 173ms	remaining: 3.67s
# 45:	learn: 0.1426349	total: 177ms	remaining: 3.66s
# 46:	learn: 0.1396805	total: 180ms	remaining: 3.66s
# 47:	learn: 0.1370952	total: 184ms	remaining: 3.65s
# 48:	learn: 0.1345808	total: 188ms	remaining: 3.65s
# 49:	learn: 0.1322650	total: 192ms	remaining: 3.64s
# 50:	learn: 0.1299488	total: 195ms	remaining: 3.63s
# 51:	learn: 0.1277984	total: 199ms	remaining: 3.63s
# 52:	learn: 0.1258754	total: 203ms	remaining: 3.62s
# 53:	learn: 0.1238936	total: 207ms	remaining: 3.62s
# 54:	learn: 0.1219438	total: 210ms	remaining: 3.61s
# 55:	learn: 0.1203963	total: 214ms	remaining: 3.61s
# 56:	learn: 0.1189636	total: 218ms	remaining: 3.61s
# 57:	learn: 0.1175574	total: 222ms	remaining: 3.61s
# 58:	learn: 0.1160838	total: 226ms	remaining: 3.6s
# 59:	learn: 0.1147107	total: 230ms	remaining: 3.6s
# 60:	learn: 0.1135115	total: 233ms	remaining: 3.59s
# 61:	learn: 0.1124205	total: 237ms	remaining: 3.59s
# 62:	learn: 0.1112701	total: 241ms	remaining: 3.58s
# 63:	learn: 0.1103299	total: 245ms	remaining: 3.58s
# 64:	learn: 0.1093841	total: 248ms	remaining: 3.57s
# 65:	learn: 0.1085422	total: 252ms	remaining: 3.57s
# 66:	learn: 0.1078123	total: 256ms	remaining: 3.56s
# 67:	learn: 0.1071374	total: 260ms	remaining: 3.56s
# 68:	learn: 0.1064250	total: 263ms	remaining: 3.55s
# 69:	learn: 0.1054131	total: 267ms	remaining: 3.55s
# 70:	learn: 0.1047954	total: 271ms	remaining: 3.54s
# 71:	learn: 0.1041503	total: 275ms	remaining: 3.54s
# 72:	learn: 0.1035141	total: 278ms	remaining: 3.54s
# 73:	learn: 0.1030052	total: 282ms	remaining: 3.53s
# 74:	learn: 0.1026469	total: 286ms	remaining: 3.52s
# 75:	learn: 0.1021482	total: 290ms	remaining: 3.52s
# 76:	learn: 0.1016733	total: 293ms	remaining: 3.52s
# 77:	learn: 0.1011830	total: 297ms	remaining: 3.51s
# 78:	learn: 0.1007324	total: 301ms	remaining: 3.5s
# 79:	learn: 0.1004164	total: 304ms	remaining: 3.5s
# 80:	learn: 0.1000921	total: 308ms	remaining: 3.5s
# 81:	learn: 0.0995523	total: 312ms	remaining: 3.49s
# 82:	learn: 0.0991751	total: 316ms	remaining: 3.49s
# 83:	learn: 0.0988247	total: 319ms	remaining: 3.48s
# 84:	learn: 0.0984703	total: 323ms	remaining: 3.48s
# 85:	learn: 0.0981646	total: 327ms	remaining: 3.47s
# 86:	learn: 0.0978935	total: 331ms	remaining: 3.47s
# 87:	learn: 0.0975966	total: 334ms	remaining: 3.46s
# 88:	learn: 0.0971901	total: 338ms	remaining: 3.46s
# 89:	learn: 0.0969452	total: 342ms	remaining: 3.46s
# 90:	learn: 0.0966751	total: 346ms	remaining: 3.46s
# 91:	learn: 0.0964612	total: 350ms	remaining: 3.45s
# 92:	learn: 0.0961703	total: 353ms	remaining: 3.45s
# 93:	learn: 0.0960161	total: 357ms	remaining: 3.44s
# 94:	learn: 0.0958393	total: 361ms	remaining: 3.44s
# 95:	learn: 0.0956824	total: 365ms	remaining: 3.43s
# 96:	learn: 0.0953188	total: 368ms	remaining: 3.43s
# 97:	learn: 0.0946968	total: 372ms	remaining: 3.42s
# 98:	learn: 0.0945078	total: 376ms	remaining: 3.42s
# 99:	learn: 0.0940756	total: 380ms	remaining: 3.42s
# 100:	learn: 0.0939169	total: 384ms	remaining: 3.41s
# 101:	learn: 0.0933276	total: 387ms	remaining: 3.41s
# 102:	learn: 0.0931812	total: 391ms	remaining: 3.4s
# 103:	learn: 0.0930723	total: 395ms	remaining: 3.4s
# 104:	learn: 0.0927112	total: 398ms	remaining: 3.4s
# 105:	learn: 0.0923383	total: 402ms	remaining: 3.39s
# 106:	learn: 0.0918060	total: 406ms	remaining: 3.39s
# 107:	learn: 0.0917036	total: 410ms	remaining: 3.38s
# 108:	learn: 0.0915744	total: 413ms	remaining: 3.38s
# 109:	learn: 0.0914841	total: 417ms	remaining: 3.38s
# 110:	learn: 0.0913410	total: 421ms	remaining: 3.37s
# 111:	learn: 0.0909994	total: 425ms	remaining: 3.37s
# 112:	learn: 0.0908480	total: 428ms	remaining: 3.36s
# 113:	learn: 0.0907073	total: 432ms	remaining: 3.36s
# 114:	learn: 0.0903826	total: 436ms	remaining: 3.35s
# 115:	learn: 0.0902427	total: 440ms	remaining: 3.35s
# 116:	learn: 0.0901649	total: 443ms	remaining: 3.35s
# 117:	learn: 0.0897603	total: 447ms	remaining: 3.34s
# 118:	learn: 0.0896998	total: 451ms	remaining: 3.34s
# 119:	learn: 0.0891720	total: 455ms	remaining: 3.33s
# 120:	learn: 0.0890617	total: 458ms	remaining: 3.33s
# 121:	learn: 0.0887015	total: 462ms	remaining: 3.33s
# 122:	learn: 0.0885663	total: 466ms	remaining: 3.32s
# 123:	learn: 0.0885065	total: 470ms	remaining: 3.32s
# 124:	learn: 0.0880590	total: 473ms	remaining: 3.31s
# 125:	learn: 0.0875580	total: 477ms	remaining: 3.31s
# 126:	learn: 0.0874319	total: 481ms	remaining: 3.31s
# 127:	learn: 0.0873197	total: 485ms	remaining: 3.3s
# 128:	learn: 0.0866922	total: 489ms	remaining: 3.3s
# 129:	learn: 0.0865689	total: 492ms	remaining: 3.29s
# 130:	learn: 0.0863599	total: 496ms	remaining: 3.29s
# 131:	learn: 0.0857925	total: 500ms	remaining: 3.29s
# 132:	learn: 0.0853748	total: 504ms	remaining: 3.28s
# 133:	learn: 0.0848818	total: 507ms	remaining: 3.28s
# 134:	learn: 0.0846841	total: 511ms	remaining: 3.27s
# 135:	learn: 0.0845398	total: 515ms	remaining: 3.27s
# 136:	learn: 0.0842403	total: 519ms	remaining: 3.27s
# 137:	learn: 0.0839220	total: 523ms	remaining: 3.27s
# 138:	learn: 0.0837811	total: 527ms	remaining: 3.26s
# 139:	learn: 0.0837358	total: 530ms	remaining: 3.26s
# 140:	learn: 0.0834366	total: 535ms	remaining: 3.26s
# 141:	learn: 0.0830482	total: 539ms	remaining: 3.26s
# 142:	learn: 0.0824896	total: 543ms	remaining: 3.25s
# 143:	learn: 0.0820083	total: 547ms	remaining: 3.25s
# 144:	learn: 0.0816268	total: 550ms	remaining: 3.25s
# 145:	learn: 0.0815026	total: 554ms	remaining: 3.24s
# 146:	learn: 0.0813919	total: 558ms	remaining: 3.24s
# 147:	learn: 0.0812749	total: 562ms	remaining: 3.23s
# 148:	learn: 0.0808192	total: 566ms	remaining: 3.23s
# 149:	learn: 0.0805340	total: 569ms	remaining: 3.23s
# 150:	learn: 0.0801153	total: 573ms	remaining: 3.22s
# 151:	learn: 0.0800081	total: 577ms	remaining: 3.22s
# 152:	learn: 0.0799137	total: 581ms	remaining: 3.21s
# 153:	learn: 0.0796201	total: 584ms	remaining: 3.21s
# 154:	learn: 0.0794731	total: 588ms	remaining: 3.21s
# 155:	learn: 0.0792583	total: 592ms	remaining: 3.2s
# 156:	learn: 0.0790658	total: 596ms	remaining: 3.2s
# 157:	learn: 0.0790026	total: 599ms	remaining: 3.19s
# 158:	learn: 0.0789363	total: 603ms	remaining: 3.19s
# 159:	learn: 0.0788415	total: 607ms	remaining: 3.19s
# 160:	learn: 0.0787207	total: 611ms	remaining: 3.18s
# 161:	learn: 0.0785623	total: 615ms	remaining: 3.18s
# 162:	learn: 0.0782248	total: 619ms	remaining: 3.18s
# 163:	learn: 0.0777588	total: 623ms	remaining: 3.18s
# 164:	learn: 0.0775244	total: 628ms	remaining: 3.17s
# 165:	learn: 0.0771873	total: 632ms	remaining: 3.17s
# 166:	learn: 0.0769933	total: 636ms	remaining: 3.17s
# 167:	learn: 0.0767239	total: 639ms	remaining: 3.17s
# 168:	learn: 0.0766320	total: 643ms	remaining: 3.16s
# 169:	learn: 0.0764900	total: 647ms	remaining: 3.16s
# 170:	learn: 0.0763688	total: 651ms	remaining: 3.15s
# 171:	learn: 0.0763328	total: 654ms	remaining: 3.15s
# 172:	learn: 0.0761244	total: 658ms	remaining: 3.15s
# 173:	learn: 0.0756672	total: 662ms	remaining: 3.14s
# 174:	learn: 0.0754703	total: 666ms	remaining: 3.14s
# 175:	learn: 0.0750744	total: 670ms	remaining: 3.13s
# 176:	learn: 0.0746618	total: 673ms	remaining: 3.13s
# 177:	learn: 0.0746141	total: 677ms	remaining: 3.13s
# 178:	learn: 0.0744255	total: 681ms	remaining: 3.12s
# 179:	learn: 0.0742510	total: 685ms	remaining: 3.12s
# 180:	learn: 0.0738334	total: 689ms	remaining: 3.12s
# 181:	learn: 0.0737963	total: 693ms	remaining: 3.11s
# 182:	learn: 0.0733767	total: 697ms	remaining: 3.11s
# 183:	learn: 0.0733391	total: 701ms	remaining: 3.11s
# 184:	learn: 0.0729510	total: 704ms	remaining: 3.1s
# 185:	learn: 0.0727243	total: 708ms	remaining: 3.1s
# 186:	learn: 0.0723126	total: 712ms	remaining: 3.1s
# 187:	learn: 0.0721939	total: 716ms	remaining: 3.09s
# 188:	learn: 0.0720230	total: 720ms	remaining: 3.09s
# 189:	learn: 0.0717144	total: 724ms	remaining: 3.09s
# 190:	learn: 0.0715595	total: 728ms	remaining: 3.08s
# 191:	learn: 0.0711745	total: 732ms	remaining: 3.08s
# 192:	learn: 0.0711491	total: 736ms	remaining: 3.08s
# 193:	learn: 0.0709175	total: 740ms	remaining: 3.07s
# 194:	learn: 0.0705566	total: 744ms	remaining: 3.07s
# 195:	learn: 0.0705011	total: 747ms	remaining: 3.06s
# 196:	learn: 0.0704511	total: 751ms	remaining: 3.06s
# 197:	learn: 0.0703578	total: 755ms	remaining: 3.06s
# 198:	learn: 0.0700652	total: 759ms	remaining: 3.05s
# 199:	learn: 0.0696787	total: 762ms	remaining: 3.05s
# 200:	learn: 0.0695471	total: 766ms	remaining: 3.04s
# 201:	learn: 0.0691925	total: 770ms	remaining: 3.04s
# 202:	learn: 0.0690314	total: 774ms	remaining: 3.04s
# 203:	learn: 0.0689676	total: 777ms	remaining: 3.03s
# 204:	learn: 0.0686098	total: 781ms	remaining: 3.03s
# 205:	learn: 0.0685025	total: 785ms	remaining: 3.02s
# 206:	learn: 0.0682609	total: 789ms	remaining: 3.02s
# 207:	learn: 0.0680301	total: 792ms	remaining: 3.02s
# 208:	learn: 0.0678316	total: 796ms	remaining: 3.01s
# 209:	learn: 0.0676577	total: 800ms	remaining: 3.01s
# 210:	learn: 0.0676050	total: 804ms	remaining: 3.01s
# 211:	learn: 0.0673351	total: 808ms	remaining: 3s
# 212:	learn: 0.0671924	total: 812ms	remaining: 3s
# 213:	learn: 0.0669843	total: 816ms	remaining: 3s
# 214:	learn: 0.0666804	total: 821ms	remaining: 3s
# 215:	learn: 0.0664529	total: 825ms	remaining: 2.99s
# 216:	learn: 0.0662885	total: 829ms	remaining: 2.99s
# 217:	learn: 0.0659573	total: 834ms	remaining: 2.99s
# 218:	learn: 0.0658412	total: 839ms	remaining: 2.99s
# 219:	learn: 0.0657303	total: 844ms	remaining: 2.99s
# 220:	learn: 0.0654137	total: 848ms	remaining: 2.99s
# 221:	learn: 0.0651811	total: 852ms	remaining: 2.98s
# 222:	learn: 0.0649588	total: 856ms	remaining: 2.98s
# 223:	learn: 0.0648969	total: 859ms	remaining: 2.98s
# 224:	learn: 0.0645732	total: 863ms	remaining: 2.97s
# 225:	learn: 0.0645162	total: 867ms	remaining: 2.97s
# 226:	learn: 0.0642111	total: 871ms	remaining: 2.96s
# 227:	learn: 0.0639036	total: 875ms	remaining: 2.96s
# 228:	learn: 0.0637857	total: 878ms	remaining: 2.96s
# 229:	learn: 0.0636986	total: 882ms	remaining: 2.95s
# 230:	learn: 0.0633952	total: 886ms	remaining: 2.95s
# 231:	learn: 0.0631309	total: 890ms	remaining: 2.94s
# 232:	learn: 0.0631057	total: 893ms	remaining: 2.94s
# 233:	learn: 0.0630087	total: 897ms	remaining: 2.94s
# 234:	learn: 0.0629652	total: 901ms	remaining: 2.93s
# 235:	learn: 0.0626732	total: 905ms	remaining: 2.93s
# 236:	learn: 0.0624463	total: 908ms	remaining: 2.92s
# 237:	learn: 0.0622661	total: 912ms	remaining: 2.92s
# 238:	learn: 0.0619856	total: 916ms	remaining: 2.92s
# 239:	learn: 0.0619515	total: 920ms	remaining: 2.91s
# 240:	learn: 0.0618466	total: 923ms	remaining: 2.91s
# 241:	learn: 0.0617419	total: 927ms	remaining: 2.9s
# 242:	learn: 0.0614617	total: 931ms	remaining: 2.9s
# 243:	learn: 0.0612940	total: 935ms	remaining: 2.9s
# 244:	learn: 0.0610242	total: 939ms	remaining: 2.89s
# 245:	learn: 0.0607533	total: 942ms	remaining: 2.89s
# 246:	learn: 0.0606734	total: 946ms	remaining: 2.88s
# 247:	learn: 0.0604582	total: 950ms	remaining: 2.88s
# 248:	learn: 0.0603967	total: 953ms	remaining: 2.88s
# 249:	learn: 0.0601993	total: 957ms	remaining: 2.87s
# 250:	learn: 0.0601692	total: 961ms	remaining: 2.87s
# 251:	learn: 0.0601024	total: 965ms	remaining: 2.86s
# 252:	learn: 0.0598475	total: 968ms	remaining: 2.86s
# 253:	learn: 0.0595986	total: 972ms	remaining: 2.85s
# 254:	learn: 0.0595217	total: 976ms	remaining: 2.85s
# 255:	learn: 0.0593264	total: 980ms	remaining: 2.85s
# 256:	learn: 0.0591719	total: 983ms	remaining: 2.84s
# 257:	learn: 0.0590092	total: 987ms	remaining: 2.84s
# 258:	learn: 0.0588341	total: 991ms	remaining: 2.83s
# 259:	learn: 0.0586870	total: 995ms	remaining: 2.83s
# 260:	learn: 0.0586172	total: 999ms	remaining: 2.83s
# 261:	learn: 0.0585093	total: 1s	remaining: 2.82s
# 262:	learn: 0.0584459	total: 1.01s	remaining: 2.82s
# 263:	learn: 0.0583980	total: 1.01s	remaining: 2.81s
# 264:	learn: 0.0581657	total: 1.01s	remaining: 2.81s
# 265:	learn: 0.0581085	total: 1.02s	remaining: 2.81s
# 266:	learn: 0.0578872	total: 1.02s	remaining: 2.8s
# 267:	learn: 0.0576679	total: 1.02s	remaining: 2.8s
# 268:	learn: 0.0574513	total: 1.03s	remaining: 2.79s
# 269:	learn: 0.0573229	total: 1.03s	remaining: 2.79s
# 270:	learn: 0.0572902	total: 1.04s	remaining: 2.79s
# 271:	learn: 0.0570791	total: 1.04s	remaining: 2.78s
# 272:	learn: 0.0568760	total: 1.04s	remaining: 2.78s
# 273:	learn: 0.0566726	total: 1.05s	remaining: 2.78s
# 274:	learn: 0.0566038	total: 1.05s	remaining: 2.77s
# 275:	learn: 0.0563676	total: 1.05s	remaining: 2.77s
# 276:	learn: 0.0563352	total: 1.06s	remaining: 2.76s
# 277:	learn: 0.0562156	total: 1.06s	remaining: 2.76s
# 278:	learn: 0.0561735	total: 1.07s	remaining: 2.76s
# 279:	learn: 0.0560123	total: 1.07s	remaining: 2.75s
# 280:	learn: 0.0558175	total: 1.07s	remaining: 2.75s
# 281:	learn: 0.0557562	total: 1.08s	remaining: 2.75s
# 282:	learn: 0.0556135	total: 1.08s	remaining: 2.74s
# 283:	learn: 0.0555960	total: 1.08s	remaining: 2.74s
# 284:	learn: 0.0554420	total: 1.09s	remaining: 2.73s
# 285:	learn: 0.0553033	total: 1.09s	remaining: 2.73s
# 286:	learn: 0.0551698	total: 1.1s	remaining: 2.73s
# 287:	learn: 0.0551170	total: 1.1s	remaining: 2.72s
# 288:	learn: 0.0550846	total: 1.1s	remaining: 2.72s
# 289:	learn: 0.0550281	total: 1.11s	remaining: 2.71s
# 290:	learn: 0.0549330	total: 1.11s	remaining: 2.71s
# 291:	learn: 0.0548510	total: 1.11s	remaining: 2.71s
# 292:	learn: 0.0546559	total: 1.12s	remaining: 2.7s
# 293:	learn: 0.0545390	total: 1.12s	remaining: 2.7s
# 294:	learn: 0.0544958	total: 1.13s	remaining: 2.69s
# 295:	learn: 0.0544726	total: 1.13s	remaining: 2.69s
# 296:	learn: 0.0542453	total: 1.13s	remaining: 2.69s
# 297:	learn: 0.0540548	total: 1.14s	remaining: 2.68s
# 298:	learn: 0.0538976	total: 1.14s	remaining: 2.68s
# 299:	learn: 0.0537680	total: 1.15s	remaining: 2.67s
# 300:	learn: 0.0536617	total: 1.15s	remaining: 2.67s
# 301:	learn: 0.0535696	total: 1.15s	remaining: 2.67s
# 302:	learn: 0.0534844	total: 1.16s	remaining: 2.66s
# 303:	learn: 0.0534169	total: 1.16s	remaining: 2.66s
# 304:	learn: 0.0533725	total: 1.16s	remaining: 2.65s
# 305:	learn: 0.0533440	total: 1.17s	remaining: 2.65s
# 306:	learn: 0.0532472	total: 1.17s	remaining: 2.65s
# 307:	learn: 0.0532213	total: 1.18s	remaining: 2.64s
# 308:	learn: 0.0530360	total: 1.18s	remaining: 2.64s
# 309:	learn: 0.0528670	total: 1.18s	remaining: 2.63s
# 310:	learn: 0.0528220	total: 1.19s	remaining: 2.63s
# 311:	learn: 0.0526572	total: 1.19s	remaining: 2.63s
# 312:	learn: 0.0526379	total: 1.19s	remaining: 2.62s
# 313:	learn: 0.0525806	total: 1.2s	remaining: 2.62s
# 314:	learn: 0.0524908	total: 1.2s	remaining: 2.61s
# 315:	learn: 0.0523285	total: 1.21s	remaining: 2.61s
# 316:	learn: 0.0522989	total: 1.21s	remaining: 2.61s
# 317:	learn: 0.0522546	total: 1.21s	remaining: 2.6s
# 318:	learn: 0.0521465	total: 1.22s	remaining: 2.6s
# 319:	learn: 0.0521266	total: 1.22s	remaining: 2.59s
# 320:	learn: 0.0521038	total: 1.22s	remaining: 2.59s
# 321:	learn: 0.0520942	total: 1.23s	remaining: 2.59s
# 322:	learn: 0.0519353	total: 1.23s	remaining: 2.58s
# 323:	learn: 0.0519071	total: 1.24s	remaining: 2.58s
# 324:	learn: 0.0517428	total: 1.24s	remaining: 2.57s
# 325:	learn: 0.0516780	total: 1.24s	remaining: 2.57s
# 326:	learn: 0.0516428	total: 1.25s	remaining: 2.57s
# 327:	learn: 0.0514714	total: 1.25s	remaining: 2.56s
# 328:	learn: 0.0513143	total: 1.25s	remaining: 2.56s
# 329:	learn: 0.0511597	total: 1.26s	remaining: 2.55s
# 330:	learn: 0.0510103	total: 1.26s	remaining: 2.55s
# 331:	learn: 0.0509990	total: 1.26s	remaining: 2.55s
# 332:	learn: 0.0508469	total: 1.27s	remaining: 2.54s
# 333:	learn: 0.0506948	total: 1.27s	remaining: 2.54s
# 334:	learn: 0.0506702	total: 1.28s	remaining: 2.54s
# 335:	learn: 0.0505274	total: 1.28s	remaining: 2.53s
# 336:	learn: 0.0505016	total: 1.28s	remaining: 2.53s
# 337:	learn: 0.0504666	total: 1.29s	remaining: 2.52s
# 338:	learn: 0.0503096	total: 1.29s	remaining: 2.52s
# 339:	learn: 0.0501920	total: 1.29s	remaining: 2.52s
# 340:	learn: 0.0500708	total: 1.3s	remaining: 2.51s
# 341:	learn: 0.0500265	total: 1.3s	remaining: 2.51s
# 342:	learn: 0.0498950	total: 1.31s	remaining: 2.5s
# 343:	learn: 0.0498582	total: 1.31s	remaining: 2.5s
# 344:	learn: 0.0497190	total: 1.31s	remaining: 2.5s
# 345:	learn: 0.0496918	total: 1.32s	remaining: 2.49s
# 346:	learn: 0.0495502	total: 1.32s	remaining: 2.49s
# 347:	learn: 0.0495067	total: 1.32s	remaining: 2.48s
# 348:	learn: 0.0493654	total: 1.33s	remaining: 2.48s
# 349:	learn: 0.0492032	total: 1.33s	remaining: 2.48s
# 350:	learn: 0.0490792	total: 1.34s	remaining: 2.47s
# 351:	learn: 0.0490320	total: 1.34s	remaining: 2.47s
# 352:	learn: 0.0490059	total: 1.34s	remaining: 2.46s
# 353:	learn: 0.0489720	total: 1.35s	remaining: 2.46s
# 354:	learn: 0.0488899	total: 1.35s	remaining: 2.46s
# 355:	learn: 0.0487376	total: 1.35s	remaining: 2.45s
# 356:	learn: 0.0487052	total: 1.36s	remaining: 2.45s
# 357:	learn: 0.0486803	total: 1.36s	remaining: 2.44s
# 358:	learn: 0.0486700	total: 1.37s	remaining: 2.44s
# 359:	learn: 0.0486100	total: 1.37s	remaining: 2.44s
# 360:	learn: 0.0485673	total: 1.37s	remaining: 2.43s
# 361:	learn: 0.0484292	total: 1.38s	remaining: 2.43s
# 362:	learn: 0.0483148	total: 1.38s	remaining: 2.42s
# 363:	learn: 0.0481985	total: 1.39s	remaining: 2.42s
# 364:	learn: 0.0481687	total: 1.39s	remaining: 2.42s
# 365:	learn: 0.0481357	total: 1.39s	remaining: 2.41s
# 366:	learn: 0.0479568	total: 1.4s	remaining: 2.41s
# 367:	learn: 0.0479346	total: 1.4s	remaining: 2.4s
# 368:	learn: 0.0478201	total: 1.4s	remaining: 2.4s
# 369:	learn: 0.0477253	total: 1.41s	remaining: 2.4s
# 370:	learn: 0.0476854	total: 1.41s	remaining: 2.39s
# 371:	learn: 0.0476403	total: 1.42s	remaining: 2.39s
# 372:	learn: 0.0475859	total: 1.42s	remaining: 2.39s
# 373:	learn: 0.0475463	total: 1.42s	remaining: 2.38s
# 374:	learn: 0.0475092	total: 1.43s	remaining: 2.38s
# 375:	learn: 0.0474634	total: 1.43s	remaining: 2.37s
# 376:	learn: 0.0474465	total: 1.43s	remaining: 2.37s
# 377:	learn: 0.0472698	total: 1.44s	remaining: 2.37s
# 378:	learn: 0.0472520	total: 1.44s	remaining: 2.36s
# 379:	learn: 0.0472240	total: 1.45s	remaining: 2.36s
# 380:	learn: 0.0472008	total: 1.45s	remaining: 2.36s
# 381:	learn: 0.0471533	total: 1.46s	remaining: 2.35s
# 382:	learn: 0.0471443	total: 1.46s	remaining: 2.35s
# 383:	learn: 0.0470197	total: 1.46s	remaining: 2.35s
# 384:	learn: 0.0469386	total: 1.47s	remaining: 2.34s
# 385:	learn: 0.0469143	total: 1.47s	remaining: 2.34s
# 386:	learn: 0.0468784	total: 1.48s	remaining: 2.34s
# 387:	learn: 0.0468458	total: 1.48s	remaining: 2.33s
# 388:	learn: 0.0468260	total: 1.48s	remaining: 2.33s
# 389:	learn: 0.0466976	total: 1.49s	remaining: 2.33s
# 390:	learn: 0.0465813	total: 1.49s	remaining: 2.32s
# 391:	learn: 0.0465442	total: 1.5s	remaining: 2.32s
# 392:	learn: 0.0464989	total: 1.5s	remaining: 2.32s
# 393:	learn: 0.0464649	total: 1.5s	remaining: 2.31s
# 394:	learn: 0.0464404	total: 1.51s	remaining: 2.31s
# 395:	learn: 0.0463972	total: 1.51s	remaining: 2.3s
# 396:	learn: 0.0463389	total: 1.51s	remaining: 2.3s
# 397:	learn: 0.0463190	total: 1.52s	remaining: 2.3s
# 398:	learn: 0.0461986	total: 1.52s	remaining: 2.29s
# 399:	learn: 0.0460834	total: 1.53s	remaining: 2.29s
# 400:	learn: 0.0459719	total: 1.53s	remaining: 2.29s
# 401:	learn: 0.0458477	total: 1.53s	remaining: 2.28s
# 402:	learn: 0.0458205	total: 1.54s	remaining: 2.28s
# 403:	learn: 0.0456849	total: 1.54s	remaining: 2.27s
# 404:	learn: 0.0456527	total: 1.54s	remaining: 2.27s
# 405:	learn: 0.0455061	total: 1.55s	remaining: 2.27s
# 406:	learn: 0.0454798	total: 1.55s	remaining: 2.26s
# 407:	learn: 0.0453400	total: 1.56s	remaining: 2.26s
# 408:	learn: 0.0453193	total: 1.56s	remaining: 2.26s
# 409:	learn: 0.0451468	total: 1.57s	remaining: 2.25s
# 410:	learn: 0.0451223	total: 1.57s	remaining: 2.25s
# 411:	learn: 0.0450946	total: 1.57s	remaining: 2.25s
# 412:	learn: 0.0450661	total: 1.58s	remaining: 2.24s
# 413:	learn: 0.0449389	total: 1.58s	remaining: 2.24s
# 414:	learn: 0.0449109	total: 1.58s	remaining: 2.23s
# 415:	learn: 0.0447692	total: 1.59s	remaining: 2.23s
# 416:	learn: 0.0446225	total: 1.59s	remaining: 2.23s
# 417:	learn: 0.0445997	total: 1.6s	remaining: 2.22s
# 418:	learn: 0.0445684	total: 1.6s	remaining: 2.22s
# 419:	learn: 0.0444387	total: 1.6s	remaining: 2.22s
# 420:	learn: 0.0443892	total: 1.61s	remaining: 2.21s
# 421:	learn: 0.0443436	total: 1.61s	remaining: 2.21s
# 422:	learn: 0.0442374	total: 1.62s	remaining: 2.2s
# 423:	learn: 0.0441729	total: 1.62s	remaining: 2.2s
# 424:	learn: 0.0441399	total: 1.62s	remaining: 2.2s
# 425:	learn: 0.0441219	total: 1.63s	remaining: 2.19s
# 426:	learn: 0.0439967	total: 1.63s	remaining: 2.19s
# 427:	learn: 0.0438178	total: 1.63s	remaining: 2.18s
# 428:	learn: 0.0438037	total: 1.64s	remaining: 2.18s
# 429:	learn: 0.0437177	total: 1.64s	remaining: 2.18s
# 430:	learn: 0.0436744	total: 1.65s	remaining: 2.17s
# 431:	learn: 0.0436317	total: 1.65s	remaining: 2.17s
# 432:	learn: 0.0435711	total: 1.65s	remaining: 2.17s
# 433:	learn: 0.0434718	total: 1.66s	remaining: 2.16s
# 434:	learn: 0.0433120	total: 1.66s	remaining: 2.16s
# 435:	learn: 0.0432720	total: 1.66s	remaining: 2.15s
# 436:	learn: 0.0432144	total: 1.67s	remaining: 2.15s
# 437:	learn: 0.0431575	total: 1.67s	remaining: 2.15s
# 438:	learn: 0.0430247	total: 1.68s	remaining: 2.14s
# 439:	learn: 0.0430065	total: 1.68s	remaining: 2.14s
# 440:	learn: 0.0429838	total: 1.68s	remaining: 2.13s
# 441:	learn: 0.0429069	total: 1.69s	remaining: 2.13s
# 442:	learn: 0.0428985	total: 1.69s	remaining: 2.13s
# 443:	learn: 0.0428083	total: 1.7s	remaining: 2.13s
# 444:	learn: 0.0427859	total: 1.7s	remaining: 2.12s
# 445:	learn: 0.0427561	total: 1.7s	remaining: 2.12s
# 446:	learn: 0.0427364	total: 1.71s	remaining: 2.11s
# 447:	learn: 0.0426320	total: 1.71s	remaining: 2.11s
# 448:	learn: 0.0425399	total: 1.72s	remaining: 2.11s
# 449:	learn: 0.0425229	total: 1.72s	remaining: 2.1s
# 450:	learn: 0.0424191	total: 1.72s	remaining: 2.1s
# 451:	learn: 0.0423567	total: 1.73s	remaining: 2.1s
# 452:	learn: 0.0423049	total: 1.73s	remaining: 2.09s
# 453:	learn: 0.0422548	total: 1.74s	remaining: 2.09s
# 454:	learn: 0.0422157	total: 1.74s	remaining: 2.08s
# 455:	learn: 0.0421928	total: 1.74s	remaining: 2.08s
# 456:	learn: 0.0421254	total: 1.75s	remaining: 2.08s
# 457:	learn: 0.0420695	total: 1.75s	remaining: 2.07s
# 458:	learn: 0.0420292	total: 1.75s	remaining: 2.07s
# 459:	learn: 0.0419655	total: 1.76s	remaining: 2.06s
# 460:	learn: 0.0419341	total: 1.76s	remaining: 2.06s
# 461:	learn: 0.0419169	total: 1.77s	remaining: 2.06s
# 462:	learn: 0.0418270	total: 1.77s	remaining: 2.05s
# 463:	learn: 0.0417924	total: 1.77s	remaining: 2.05s
# 464:	learn: 0.0417617	total: 1.78s	remaining: 2.05s
# 465:	learn: 0.0417403	total: 1.78s	remaining: 2.04s
# 466:	learn: 0.0416958	total: 1.79s	remaining: 2.04s
# 467:	learn: 0.0416669	total: 1.79s	remaining: 2.04s
# 468:	learn: 0.0416543	total: 1.79s	remaining: 2.03s
# 469:	learn: 0.0416262	total: 1.8s	remaining: 2.03s
# 470:	learn: 0.0416121	total: 1.8s	remaining: 2.02s
# 471:	learn: 0.0415910	total: 1.81s	remaining: 2.02s
# 472:	learn: 0.0415710	total: 1.81s	remaining: 2.02s
# 473:	learn: 0.0415246	total: 1.81s	remaining: 2.01s
# 474:	learn: 0.0414388	total: 1.82s	remaining: 2.01s
# 475:	learn: 0.0413637	total: 1.82s	remaining: 2s
# 476:	learn: 0.0413495	total: 1.82s	remaining: 2s
# 477:	learn: 0.0412986	total: 1.83s	remaining: 2s
# 478:	learn: 0.0412717	total: 1.83s	remaining: 1.99s
# 479:	learn: 0.0412539	total: 1.84s	remaining: 1.99s
# 480:	learn: 0.0412298	total: 1.84s	remaining: 1.99s
# 481:	learn: 0.0411872	total: 1.84s	remaining: 1.98s
# 482:	learn: 0.0410939	total: 1.85s	remaining: 1.98s
# 483:	learn: 0.0410713	total: 1.85s	remaining: 1.97s
# 484:	learn: 0.0409059	total: 1.86s	remaining: 1.97s
# 485:	learn: 0.0408845	total: 1.86s	remaining: 1.97s
# 486:	learn: 0.0408113	total: 1.86s	remaining: 1.96s
# 487:	learn: 0.0406387	total: 1.87s	remaining: 1.96s
# 488:	learn: 0.0406230	total: 1.87s	remaining: 1.96s
# 489:	learn: 0.0405980	total: 1.87s	remaining: 1.95s
# 490:	learn: 0.0405703	total: 1.88s	remaining: 1.95s
# 491:	learn: 0.0404762	total: 1.88s	remaining: 1.94s
# 492:	learn: 0.0403492	total: 1.89s	remaining: 1.94s
# 493:	learn: 0.0403016	total: 1.89s	remaining: 1.94s
# 494:	learn: 0.0402839	total: 1.89s	remaining: 1.93s
# 495:	learn: 0.0401440	total: 1.9s	remaining: 1.93s
# 496:	learn: 0.0400925	total: 1.9s	remaining: 1.92s
# 497:	learn: 0.0399857	total: 1.91s	remaining: 1.92s
# 498:	learn: 0.0399622	total: 1.91s	remaining: 1.92s
# 499:	learn: 0.0398881	total: 1.91s	remaining: 1.91s
# 500:	learn: 0.0397299	total: 1.92s	remaining: 1.91s
# 501:	learn: 0.0396736	total: 1.92s	remaining: 1.91s
# 502:	learn: 0.0396002	total: 1.92s	remaining: 1.9s
# 503:	learn: 0.0395595	total: 1.93s	remaining: 1.9s
# 504:	learn: 0.0395468	total: 1.93s	remaining: 1.89s
# 505:	learn: 0.0395427	total: 1.94s	remaining: 1.89s
# 506:	learn: 0.0394983	total: 1.94s	remaining: 1.89s
# 507:	learn: 0.0394755	total: 1.94s	remaining: 1.88s
# 508:	learn: 0.0393143	total: 1.95s	remaining: 1.88s
# 509:	learn: 0.0392938	total: 1.95s	remaining: 1.87s
# 510:	learn: 0.0392061	total: 1.95s	remaining: 1.87s
# 511:	learn: 0.0392016	total: 1.96s	remaining: 1.87s
# 512:	learn: 0.0391773	total: 1.96s	remaining: 1.86s
# 513:	learn: 0.0391555	total: 1.97s	remaining: 1.86s
# 514:	learn: 0.0390728	total: 1.97s	remaining: 1.85s
# 515:	learn: 0.0390120	total: 1.97s	remaining: 1.85s
# 516:	learn: 0.0389371	total: 1.98s	remaining: 1.85s
# 517:	learn: 0.0388724	total: 1.98s	remaining: 1.84s
# 518:	learn: 0.0388452	total: 1.98s	remaining: 1.84s
# 519:	learn: 0.0387629	total: 1.99s	remaining: 1.83s
# 520:	learn: 0.0387424	total: 1.99s	remaining: 1.83s
# 521:	learn: 0.0386724	total: 2s	remaining: 1.83s
# 522:	learn: 0.0386686	total: 2s	remaining: 1.82s
# 523:	learn: 0.0386406	total: 2s	remaining: 1.82s
# 524:	learn: 0.0385570	total: 2.01s	remaining: 1.81s
# 525:	learn: 0.0385342	total: 2.01s	remaining: 1.81s
# 526:	learn: 0.0384178	total: 2.01s	remaining: 1.81s
# 527:	learn: 0.0384145	total: 2.02s	remaining: 1.8s
# 528:	learn: 0.0383817	total: 2.02s	remaining: 1.8s
# 529:	learn: 0.0383567	total: 2.02s	remaining: 1.8s
# 530:	learn: 0.0383105	total: 2.03s	remaining: 1.79s
# 531:	learn: 0.0382567	total: 2.03s	remaining: 1.79s
# 532:	learn: 0.0382528	total: 2.04s	remaining: 1.78s
# 533:	learn: 0.0382083	total: 2.04s	remaining: 1.78s
# 534:	learn: 0.0381926	total: 2.04s	remaining: 1.78s
# 535:	learn: 0.0381096	total: 2.05s	remaining: 1.77s
# 536:	learn: 0.0380929	total: 2.05s	remaining: 1.77s
# 537:	learn: 0.0380725	total: 2.06s	remaining: 1.76s
# 538:	learn: 0.0379920	total: 2.06s	remaining: 1.76s
# 539:	learn: 0.0379487	total: 2.06s	remaining: 1.76s
# 540:	learn: 0.0379296	total: 2.07s	remaining: 1.75s
# 541:	learn: 0.0379078	total: 2.07s	remaining: 1.75s
# 542:	learn: 0.0378765	total: 2.07s	remaining: 1.75s
# 543:	learn: 0.0378715	total: 2.08s	remaining: 1.74s
# 544:	learn: 0.0378471	total: 2.08s	remaining: 1.74s
# 545:	learn: 0.0378340	total: 2.08s	remaining: 1.73s
# 546:	learn: 0.0377865	total: 2.09s	remaining: 1.73s
# 547:	learn: 0.0377708	total: 2.09s	remaining: 1.73s
# 548:	learn: 0.0376938	total: 2.1s	remaining: 1.72s
# 549:	learn: 0.0376289	total: 2.1s	remaining: 1.72s
# 550:	learn: 0.0376198	total: 2.11s	remaining: 1.72s
# 551:	learn: 0.0375467	total: 2.11s	remaining: 1.71s
# 552:	learn: 0.0374796	total: 2.11s	remaining: 1.71s
# 553:	learn: 0.0374286	total: 2.12s	remaining: 1.71s
# 554:	learn: 0.0373590	total: 2.12s	remaining: 1.7s
# 555:	learn: 0.0373383	total: 2.13s	remaining: 1.7s
# 556:	learn: 0.0373155	total: 2.13s	remaining: 1.69s
# 557:	learn: 0.0373127	total: 2.13s	remaining: 1.69s
# 558:	learn: 0.0372944	total: 2.14s	remaining: 1.69s
# 559:	learn: 0.0371681	total: 2.14s	remaining: 1.68s
# 560:	learn: 0.0371114	total: 2.15s	remaining: 1.68s
# 561:	learn: 0.0370512	total: 2.15s	remaining: 1.67s
# 562:	learn: 0.0369988	total: 2.15s	remaining: 1.67s
# 563:	learn: 0.0369757	total: 2.16s	remaining: 1.67s
# 564:	learn: 0.0369547	total: 2.16s	remaining: 1.66s
# 565:	learn: 0.0369367	total: 2.16s	remaining: 1.66s
# 566:	learn: 0.0368796	total: 2.17s	remaining: 1.66s
# 567:	learn: 0.0368279	total: 2.17s	remaining: 1.65s
# 568:	learn: 0.0367407	total: 2.17s	remaining: 1.65s
# 569:	learn: 0.0367238	total: 2.18s	remaining: 1.64s
# 570:	learn: 0.0366315	total: 2.18s	remaining: 1.64s
# 571:	learn: 0.0366142	total: 2.19s	remaining: 1.64s
# 572:	learn: 0.0366068	total: 2.19s	remaining: 1.63s
# 573:	learn: 0.0365419	total: 2.19s	remaining: 1.63s
# 574:	learn: 0.0365305	total: 2.2s	remaining: 1.62s
# 575:	learn: 0.0364933	total: 2.2s	remaining: 1.62s
# 576:	learn: 0.0364755	total: 2.21s	remaining: 1.62s
# 577:	learn: 0.0364676	total: 2.21s	remaining: 1.61s
# 578:	learn: 0.0364633	total: 2.21s	remaining: 1.61s
# 579:	learn: 0.0364387	total: 2.22s	remaining: 1.6s
# 580:	learn: 0.0363992	total: 2.22s	remaining: 1.6s
# 581:	learn: 0.0363338	total: 2.22s	remaining: 1.6s
# 582:	learn: 0.0363144	total: 2.23s	remaining: 1.59s
# 583:	learn: 0.0362780	total: 2.23s	remaining: 1.59s
# 584:	learn: 0.0362263	total: 2.23s	remaining: 1.58s
# 585:	learn: 0.0361942	total: 2.24s	remaining: 1.58s
# 586:	learn: 0.0361723	total: 2.24s	remaining: 1.58s
# 587:	learn: 0.0361573	total: 2.25s	remaining: 1.57s
# 588:	learn: 0.0361041	total: 2.25s	remaining: 1.57s
# 589:	learn: 0.0360293	total: 2.25s	remaining: 1.57s
# 590:	learn: 0.0360008	total: 2.26s	remaining: 1.56s
# 591:	learn: 0.0359497	total: 2.26s	remaining: 1.56s
# 592:	learn: 0.0359468	total: 2.27s	remaining: 1.55s
# 593:	learn: 0.0359242	total: 2.27s	remaining: 1.55s
# 594:	learn: 0.0358960	total: 2.27s	remaining: 1.55s
# 595:	learn: 0.0357859	total: 2.28s	remaining: 1.54s
# 596:	learn: 0.0357563	total: 2.28s	remaining: 1.54s
# 597:	learn: 0.0356915	total: 2.29s	remaining: 1.54s
# 598:	learn: 0.0356345	total: 2.29s	remaining: 1.53s
# 599:	learn: 0.0355837	total: 2.29s	remaining: 1.53s
# 600:	learn: 0.0354710	total: 2.3s	remaining: 1.52s
# 601:	learn: 0.0353674	total: 2.3s	remaining: 1.52s
# 602:	learn: 0.0353410	total: 2.3s	remaining: 1.52s
# 603:	learn: 0.0353379	total: 2.31s	remaining: 1.51s
# 604:	learn: 0.0353231	total: 2.31s	remaining: 1.51s
# 605:	learn: 0.0353000	total: 2.31s	remaining: 1.5s
# 606:	learn: 0.0352783	total: 2.32s	remaining: 1.5s
# 607:	learn: 0.0352292	total: 2.32s	remaining: 1.5s
# 608:	learn: 0.0351770	total: 2.33s	remaining: 1.49s
# 609:	learn: 0.0351516	total: 2.33s	remaining: 1.49s
# 610:	learn: 0.0351286	total: 2.33s	remaining: 1.49s
# 611:	learn: 0.0351090	total: 2.34s	remaining: 1.48s
# 612:	learn: 0.0350835	total: 2.34s	remaining: 1.48s
# 613:	learn: 0.0350570	total: 2.35s	remaining: 1.47s
# 614:	learn: 0.0350046	total: 2.35s	remaining: 1.47s
# 615:	learn: 0.0348729	total: 2.35s	remaining: 1.47s
# 616:	learn: 0.0348163	total: 2.36s	remaining: 1.46s
# 617:	learn: 0.0347908	total: 2.36s	remaining: 1.46s
# 618:	learn: 0.0347879	total: 2.36s	remaining: 1.46s
# 619:	learn: 0.0347679	total: 2.37s	remaining: 1.45s
# 620:	learn: 0.0347479	total: 2.37s	remaining: 1.45s
# 621:	learn: 0.0346666	total: 2.38s	remaining: 1.44s
# 622:	learn: 0.0346247	total: 2.38s	remaining: 1.44s
# 623:	learn: 0.0346033	total: 2.38s	remaining: 1.44s
# 624:	learn: 0.0345836	total: 2.39s	remaining: 1.43s
# 625:	learn: 0.0345662	total: 2.39s	remaining: 1.43s
# 626:	learn: 0.0345162	total: 2.4s	remaining: 1.42s
# 627:	learn: 0.0345140	total: 2.4s	remaining: 1.42s
# 628:	learn: 0.0344977	total: 2.4s	remaining: 1.42s
# 629:	learn: 0.0344617	total: 2.41s	remaining: 1.41s
# 630:	learn: 0.0344594	total: 2.41s	remaining: 1.41s
# 631:	learn: 0.0344573	total: 2.41s	remaining: 1.4s
# 632:	learn: 0.0344163	total: 2.42s	remaining: 1.4s
# 633:	learn: 0.0343752	total: 2.42s	remaining: 1.4s
# 634:	learn: 0.0342704	total: 2.42s	remaining: 1.39s
# 635:	learn: 0.0342463	total: 2.43s	remaining: 1.39s
# 636:	learn: 0.0342263	total: 2.43s	remaining: 1.39s
# 637:	learn: 0.0341906	total: 2.44s	remaining: 1.38s
# 638:	learn: 0.0340865	total: 2.44s	remaining: 1.38s
# 639:	learn: 0.0340368	total: 2.44s	remaining: 1.37s
# 640:	learn: 0.0339739	total: 2.45s	remaining: 1.37s
# 641:	learn: 0.0339060	total: 2.45s	remaining: 1.37s
# 642:	learn: 0.0338920	total: 2.45s	remaining: 1.36s
# 643:	learn: 0.0338756	total: 2.46s	remaining: 1.36s
# 644:	learn: 0.0338633	total: 2.46s	remaining: 1.35s
# 645:	learn: 0.0338194	total: 2.46s	remaining: 1.35s
# 646:	learn: 0.0337983	total: 2.47s	remaining: 1.35s
# 647:	learn: 0.0337733	total: 2.47s	remaining: 1.34s
# 648:	learn: 0.0337708	total: 2.48s	remaining: 1.34s
# 649:	learn: 0.0337429	total: 2.48s	remaining: 1.34s
# 650:	learn: 0.0337262	total: 2.49s	remaining: 1.33s
# 651:	learn: 0.0337053	total: 2.49s	remaining: 1.33s
# 652:	learn: 0.0336658	total: 2.49s	remaining: 1.32s
# 653:	learn: 0.0336132	total: 2.5s	remaining: 1.32s
# 654:	learn: 0.0335865	total: 2.5s	remaining: 1.32s
# 655:	learn: 0.0335685	total: 2.5s	remaining: 1.31s
# 656:	learn: 0.0335248	total: 2.51s	remaining: 1.31s
# 657:	learn: 0.0335030	total: 2.51s	remaining: 1.31s
# 658:	learn: 0.0334856	total: 2.52s	remaining: 1.3s
# 659:	learn: 0.0334711	total: 2.52s	remaining: 1.3s
# 660:	learn: 0.0333900	total: 2.52s	remaining: 1.29s
# 661:	learn: 0.0333848	total: 2.53s	remaining: 1.29s
# 662:	learn: 0.0333673	total: 2.53s	remaining: 1.29s
# 663:	learn: 0.0333630	total: 2.54s	remaining: 1.28s
# 664:	learn: 0.0333116	total: 2.54s	remaining: 1.28s
# 665:	learn: 0.0332702	total: 2.54s	remaining: 1.27s
# 666:	learn: 0.0332621	total: 2.55s	remaining: 1.27s
# 667:	learn: 0.0332436	total: 2.55s	remaining: 1.27s
# 668:	learn: 0.0332224	total: 2.55s	remaining: 1.26s
# 669:	learn: 0.0332018	total: 2.56s	remaining: 1.26s
# 670:	learn: 0.0331789	total: 2.56s	remaining: 1.25s
# 671:	learn: 0.0331630	total: 2.56s	remaining: 1.25s
# 672:	learn: 0.0331192	total: 2.57s	remaining: 1.25s
# 673:	learn: 0.0330996	total: 2.57s	remaining: 1.24s
# 674:	learn: 0.0330772	total: 2.58s	remaining: 1.24s
# 675:	learn: 0.0330621	total: 2.58s	remaining: 1.24s
# 676:	learn: 0.0330599	total: 2.58s	remaining: 1.23s
# 677:	learn: 0.0330370	total: 2.59s	remaining: 1.23s
# 678:	learn: 0.0330053	total: 2.59s	remaining: 1.23s
# 679:	learn: 0.0329921	total: 2.6s	remaining: 1.22s
# 680:	learn: 0.0329604	total: 2.6s	remaining: 1.22s
# 681:	learn: 0.0329411	total: 2.6s	remaining: 1.21s
# 682:	learn: 0.0328928	total: 2.61s	remaining: 1.21s
# 683:	learn: 0.0328790	total: 2.61s	remaining: 1.21s
# 684:	learn: 0.0328414	total: 2.62s	remaining: 1.2s
# 685:	learn: 0.0328253	total: 2.62s	remaining: 1.2s
# 686:	learn: 0.0328240	total: 2.62s	remaining: 1.2s
# 687:	learn: 0.0327779	total: 2.63s	remaining: 1.19s
# 688:	learn: 0.0327373	total: 2.63s	remaining: 1.19s
# 689:	learn: 0.0326972	total: 2.63s	remaining: 1.18s
# 690:	learn: 0.0326411	total: 2.64s	remaining: 1.18s
# 691:	learn: 0.0326229	total: 2.64s	remaining: 1.18s
# 692:	learn: 0.0325760	total: 2.65s	remaining: 1.17s
# 693:	learn: 0.0325271	total: 2.65s	remaining: 1.17s
# 694:	learn: 0.0325019	total: 2.65s	remaining: 1.16s
# 695:	learn: 0.0324528	total: 2.66s	remaining: 1.16s
# 696:	learn: 0.0323641	total: 2.66s	remaining: 1.16s
# 697:	learn: 0.0323259	total: 2.67s	remaining: 1.15s
# 698:	learn: 0.0323107	total: 2.67s	remaining: 1.15s
# 699:	learn: 0.0322925	total: 2.67s	remaining: 1.15s
# 700:	learn: 0.0322508	total: 2.68s	remaining: 1.14s
# 701:	learn: 0.0321977	total: 2.68s	remaining: 1.14s
# 702:	learn: 0.0321471	total: 2.68s	remaining: 1.13s
# 703:	learn: 0.0321310	total: 2.69s	remaining: 1.13s
# 704:	learn: 0.0321217	total: 2.69s	remaining: 1.13s
# 705:	learn: 0.0321088	total: 2.69s	remaining: 1.12s
# 706:	learn: 0.0320595	total: 2.7s	remaining: 1.12s
# 707:	learn: 0.0319891	total: 2.7s	remaining: 1.11s
# 708:	learn: 0.0318849	total: 2.71s	remaining: 1.11s
# 709:	learn: 0.0318250	total: 2.71s	remaining: 1.11s
# 710:	learn: 0.0318062	total: 2.71s	remaining: 1.1s
# 711:	learn: 0.0317318	total: 2.72s	remaining: 1.1s
# 712:	learn: 0.0317124	total: 2.72s	remaining: 1.09s
# 713:	learn: 0.0316847	total: 2.73s	remaining: 1.09s
# 714:	learn: 0.0316545	total: 2.73s	remaining: 1.09s
# 715:	learn: 0.0315314	total: 2.73s	remaining: 1.08s
# 716:	learn: 0.0314887	total: 2.74s	remaining: 1.08s
# 717:	learn: 0.0314009	total: 2.74s	remaining: 1.08s
# 718:	learn: 0.0313221	total: 2.75s	remaining: 1.07s
# 719:	learn: 0.0313064	total: 2.75s	remaining: 1.07s
# 720:	learn: 0.0312966	total: 2.75s	remaining: 1.06s
# 721:	learn: 0.0312714	total: 2.76s	remaining: 1.06s
# 722:	learn: 0.0312461	total: 2.76s	remaining: 1.06s
# 723:	learn: 0.0312380	total: 2.76s	remaining: 1.05s
# 724:	learn: 0.0312169	total: 2.77s	remaining: 1.05s
# 725:	learn: 0.0311874	total: 2.77s	remaining: 1.05s
# 726:	learn: 0.0311704	total: 2.78s	remaining: 1.04s
# 727:	learn: 0.0311565	total: 2.78s	remaining: 1.04s
# 728:	learn: 0.0311166	total: 2.78s	remaining: 1.03s
# 729:	learn: 0.0310756	total: 2.79s	remaining: 1.03s
# 730:	learn: 0.0310684	total: 2.79s	remaining: 1.03s
# 731:	learn: 0.0310615	total: 2.79s	remaining: 1.02s
# 732:	learn: 0.0310585	total: 2.8s	remaining: 1.02s
# 733:	learn: 0.0310167	total: 2.8s	remaining: 1.01s
# 734:	learn: 0.0310147	total: 2.81s	remaining: 1.01s
# 735:	learn: 0.0309987	total: 2.81s	remaining: 1.01s
# 736:	learn: 0.0309773	total: 2.81s	remaining: 1s
# 737:	learn: 0.0309355	total: 2.82s	remaining: 1s
# 738:	learn: 0.0308974	total: 2.82s	remaining: 996ms
# 739:	learn: 0.0308955	total: 2.83s	remaining: 993ms
# 740:	learn: 0.0308831	total: 2.83s	remaining: 989ms
# 741:	learn: 0.0308349	total: 2.83s	remaining: 985ms
# 742:	learn: 0.0308211	total: 2.84s	remaining: 981ms
# 743:	learn: 0.0308036	total: 2.84s	remaining: 977ms
# 744:	learn: 0.0307732	total: 2.84s	remaining: 973ms
# 745:	learn: 0.0307214	total: 2.85s	remaining: 970ms
# 746:	learn: 0.0306934	total: 2.85s	remaining: 966ms
# 747:	learn: 0.0306818	total: 2.85s	remaining: 962ms
# 748:	learn: 0.0305856	total: 2.86s	remaining: 958ms
# 749:	learn: 0.0305733	total: 2.86s	remaining: 954ms
# 750:	learn: 0.0304941	total: 2.87s	remaining: 950ms
# 751:	learn: 0.0304767	total: 2.87s	remaining: 947ms
# 752:	learn: 0.0304401	total: 2.87s	remaining: 943ms
# 753:	learn: 0.0303879	total: 2.88s	remaining: 939ms
# 754:	learn: 0.0303618	total: 2.88s	remaining: 935ms
# 755:	learn: 0.0303249	total: 2.88s	remaining: 931ms
# 756:	learn: 0.0302573	total: 2.89s	remaining: 928ms
# 757:	learn: 0.0302259	total: 2.89s	remaining: 924ms
# 758:	learn: 0.0302081	total: 2.9s	remaining: 920ms
# 759:	learn: 0.0301761	total: 2.9s	remaining: 916ms
# 760:	learn: 0.0301627	total: 2.9s	remaining: 912ms
# 761:	learn: 0.0301439	total: 2.91s	remaining: 908ms
# 762:	learn: 0.0301277	total: 2.91s	remaining: 905ms
# 763:	learn: 0.0300930	total: 2.92s	remaining: 901ms
# 764:	learn: 0.0300819	total: 2.92s	remaining: 897ms
# 765:	learn: 0.0300684	total: 2.92s	remaining: 893ms
# 766:	learn: 0.0300479	total: 2.93s	remaining: 889ms
# 767:	learn: 0.0299901	total: 2.93s	remaining: 885ms
# 768:	learn: 0.0299736	total: 2.93s	remaining: 882ms
# 769:	learn: 0.0299617	total: 2.94s	remaining: 878ms
# 770:	learn: 0.0299408	total: 2.94s	remaining: 874ms
# 771:	learn: 0.0298978	total: 2.95s	remaining: 870ms
# 772:	learn: 0.0298834	total: 2.95s	remaining: 866ms
# 773:	learn: 0.0298579	total: 2.95s	remaining: 863ms
# 774:	learn: 0.0298201	total: 2.96s	remaining: 859ms
# 775:	learn: 0.0298060	total: 2.96s	remaining: 855ms
# 776:	learn: 0.0297864	total: 2.96s	remaining: 851ms
# 777:	learn: 0.0297669	total: 2.97s	remaining: 847ms
# 778:	learn: 0.0297503	total: 2.97s	remaining: 843ms
# 779:	learn: 0.0297385	total: 2.98s	remaining: 840ms
# 780:	learn: 0.0297309	total: 2.98s	remaining: 836ms
# 781:	learn: 0.0297132	total: 2.98s	remaining: 832ms
# 782:	learn: 0.0296923	total: 2.99s	remaining: 828ms
# 783:	learn: 0.0295863	total: 2.99s	remaining: 824ms
# 784:	learn: 0.0294997	total: 3s	remaining: 821ms
# 785:	learn: 0.0294265	total: 3s	remaining: 817ms
# 786:	learn: 0.0294118	total: 3s	remaining: 813ms
# 787:	learn: 0.0293845	total: 3.01s	remaining: 809ms
# 788:	learn: 0.0293644	total: 3.01s	remaining: 805ms
# 789:	learn: 0.0293537	total: 3.01s	remaining: 801ms
# 790:	learn: 0.0293470	total: 3.02s	remaining: 797ms
# 791:	learn: 0.0293119	total: 3.02s	remaining: 794ms
# 792:	learn: 0.0292992	total: 3.02s	remaining: 790ms
# 793:	learn: 0.0292619	total: 3.03s	remaining: 786ms
# 794:	learn: 0.0292283	total: 3.03s	remaining: 782ms
# 795:	learn: 0.0292221	total: 3.04s	remaining: 778ms
# 796:	learn: 0.0292098	total: 3.04s	remaining: 775ms
# 797:	learn: 0.0291979	total: 3.04s	remaining: 771ms
# 798:	learn: 0.0291188	total: 3.05s	remaining: 767ms
# 799:	learn: 0.0291169	total: 3.05s	remaining: 763ms
# 800:	learn: 0.0291065	total: 3.06s	remaining: 759ms
# 801:	learn: 0.0290320	total: 3.06s	remaining: 755ms
# 802:	learn: 0.0290080	total: 3.06s	remaining: 752ms
# 803:	learn: 0.0289949	total: 3.07s	remaining: 748ms
# 804:	learn: 0.0289829	total: 3.07s	remaining: 744ms
# 805:	learn: 0.0289699	total: 3.07s	remaining: 740ms
# 806:	learn: 0.0289354	total: 3.08s	remaining: 736ms
# 807:	learn: 0.0289231	total: 3.08s	remaining: 732ms
# 808:	learn: 0.0289129	total: 3.08s	remaining: 729ms
# 809:	learn: 0.0288929	total: 3.09s	remaining: 725ms
# 810:	learn: 0.0288694	total: 3.09s	remaining: 721ms
# 811:	learn: 0.0288519	total: 3.1s	remaining: 717ms
# 812:	learn: 0.0288348	total: 3.1s	remaining: 713ms
# 813:	learn: 0.0288319	total: 3.1s	remaining: 709ms
# 814:	learn: 0.0287397	total: 3.11s	remaining: 706ms
# 815:	learn: 0.0287267	total: 3.11s	remaining: 702ms
# 816:	learn: 0.0287029	total: 3.12s	remaining: 698ms
# 817:	learn: 0.0286798	total: 3.12s	remaining: 694ms
# 818:	learn: 0.0286411	total: 3.12s	remaining: 690ms
# 819:	learn: 0.0286306	total: 3.13s	remaining: 687ms
# 820:	learn: 0.0286162	total: 3.13s	remaining: 683ms
# 821:	learn: 0.0285950	total: 3.13s	remaining: 679ms
# 822:	learn: 0.0285884	total: 3.14s	remaining: 675ms
# 823:	learn: 0.0285078	total: 3.14s	remaining: 671ms
# 824:	learn: 0.0284957	total: 3.15s	remaining: 667ms
# 825:	learn: 0.0284793	total: 3.15s	remaining: 664ms
# 826:	learn: 0.0284649	total: 3.15s	remaining: 660ms
# 827:	learn: 0.0284612	total: 3.16s	remaining: 656ms
# 828:	learn: 0.0284491	total: 3.16s	remaining: 652ms
# 829:	learn: 0.0284367	total: 3.17s	remaining: 648ms
# 830:	learn: 0.0284166	total: 3.17s	remaining: 645ms
# 831:	learn: 0.0283770	total: 3.17s	remaining: 641ms
# 832:	learn: 0.0283637	total: 3.18s	remaining: 637ms
# 833:	learn: 0.0283468	total: 3.18s	remaining: 633ms
# 834:	learn: 0.0283348	total: 3.18s	remaining: 629ms
# 835:	learn: 0.0283284	total: 3.19s	remaining: 625ms
# 836:	learn: 0.0283178	total: 3.19s	remaining: 622ms
# 837:	learn: 0.0283058	total: 3.19s	remaining: 618ms
# 838:	learn: 0.0282992	total: 3.2s	remaining: 614ms
# 839:	learn: 0.0282882	total: 3.2s	remaining: 610ms
# 840:	learn: 0.0282754	total: 3.21s	remaining: 606ms
# 841:	learn: 0.0282689	total: 3.21s	remaining: 602ms
# 842:	learn: 0.0282597	total: 3.21s	remaining: 599ms
# 843:	learn: 0.0281951	total: 3.22s	remaining: 595ms
# 844:	learn: 0.0281820	total: 3.22s	remaining: 591ms
# 845:	learn: 0.0281690	total: 3.23s	remaining: 587ms
# 846:	learn: 0.0281400	total: 3.23s	remaining: 583ms
# 847:	learn: 0.0280649	total: 3.23s	remaining: 580ms
# 848:	learn: 0.0280510	total: 3.24s	remaining: 576ms
# 849:	learn: 0.0280346	total: 3.24s	remaining: 572ms
# 850:	learn: 0.0280032	total: 3.24s	remaining: 568ms
# 851:	learn: 0.0279799	total: 3.25s	remaining: 564ms
# 852:	learn: 0.0279758	total: 3.25s	remaining: 560ms
# 853:	learn: 0.0279605	total: 3.25s	remaining: 557ms
# 854:	learn: 0.0279453	total: 3.26s	remaining: 553ms
# 855:	learn: 0.0279025	total: 3.26s	remaining: 549ms
# 856:	learn: 0.0278883	total: 3.27s	remaining: 545ms
# 857:	learn: 0.0278713	total: 3.27s	remaining: 541ms
# 858:	learn: 0.0278595	total: 3.27s	remaining: 537ms
# 859:	learn: 0.0278303	total: 3.28s	remaining: 534ms
# 860:	learn: 0.0278131	total: 3.28s	remaining: 530ms
# 861:	learn: 0.0277784	total: 3.29s	remaining: 526ms
# 862:	learn: 0.0277501	total: 3.29s	remaining: 522ms
# 863:	learn: 0.0277177	total: 3.29s	remaining: 519ms
# 864:	learn: 0.0276575	total: 3.3s	remaining: 515ms
# 865:	learn: 0.0276302	total: 3.3s	remaining: 511ms
# 866:	learn: 0.0276075	total: 3.31s	remaining: 507ms
# 867:	learn: 0.0275918	total: 3.31s	remaining: 503ms
# 868:	learn: 0.0275801	total: 3.31s	remaining: 499ms
# 869:	learn: 0.0275586	total: 3.32s	remaining: 496ms
# 870:	learn: 0.0275534	total: 3.32s	remaining: 492ms
# 871:	learn: 0.0275275	total: 3.32s	remaining: 488ms
# 872:	learn: 0.0275163	total: 3.33s	remaining: 484ms
# 873:	learn: 0.0275100	total: 3.33s	remaining: 480ms
# 874:	learn: 0.0274783	total: 3.33s	remaining: 477ms
# 875:	learn: 0.0274602	total: 3.34s	remaining: 473ms
# 876:	learn: 0.0274497	total: 3.34s	remaining: 469ms
# 877:	learn: 0.0274375	total: 3.35s	remaining: 465ms
# 878:	learn: 0.0273786	total: 3.35s	remaining: 461ms
# 879:	learn: 0.0273659	total: 3.35s	remaining: 457ms
# 880:	learn: 0.0273461	total: 3.36s	remaining: 454ms
# 881:	learn: 0.0273332	total: 3.36s	remaining: 450ms
# 882:	learn: 0.0273078	total: 3.37s	remaining: 446ms
# 883:	learn: 0.0272698	total: 3.37s	remaining: 442ms
# 884:	learn: 0.0272592	total: 3.37s	remaining: 438ms
# 885:	learn: 0.0272186	total: 3.38s	remaining: 435ms
# 886:	learn: 0.0272078	total: 3.38s	remaining: 431ms
# 887:	learn: 0.0271910	total: 3.38s	remaining: 427ms
# 888:	learn: 0.0271729	total: 3.39s	remaining: 423ms
# 889:	learn: 0.0271105	total: 3.39s	remaining: 419ms
# 890:	learn: 0.0270813	total: 3.4s	remaining: 415ms
# 891:	learn: 0.0270547	total: 3.4s	remaining: 412ms
# 892:	learn: 0.0270478	total: 3.4s	remaining: 408ms
# 893:	learn: 0.0270312	total: 3.42s	remaining: 405ms
# 894:	learn: 0.0270130	total: 3.42s	remaining: 402ms
# 895:	learn: 0.0269767	total: 3.43s	remaining: 398ms
# 896:	learn: 0.0269605	total: 3.43s	remaining: 394ms
# 897:	learn: 0.0269502	total: 3.44s	remaining: 390ms
# 898:	learn: 0.0269379	total: 3.44s	remaining: 387ms
# 899:	learn: 0.0269054	total: 3.44s	remaining: 383ms
# 900:	learn: 0.0268902	total: 3.45s	remaining: 379ms
# 901:	learn: 0.0268528	total: 3.45s	remaining: 375ms
# 902:	learn: 0.0267948	total: 3.46s	remaining: 371ms
# 903:	learn: 0.0267797	total: 3.46s	remaining: 367ms
# 904:	learn: 0.0267558	total: 3.46s	remaining: 364ms
# 905:	learn: 0.0267335	total: 3.47s	remaining: 360ms
# 906:	learn: 0.0267051	total: 3.47s	remaining: 356ms
# 907:	learn: 0.0266697	total: 3.48s	remaining: 352ms
# 908:	learn: 0.0266546	total: 3.48s	remaining: 348ms
# 909:	learn: 0.0266454	total: 3.48s	remaining: 345ms
# 910:	learn: 0.0266358	total: 3.49s	remaining: 341ms
# 911:	learn: 0.0266054	total: 3.49s	remaining: 337ms
# 912:	learn: 0.0265950	total: 3.5s	remaining: 333ms
# 913:	learn: 0.0265843	total: 3.5s	remaining: 329ms
# 914:	learn: 0.0265758	total: 3.5s	remaining: 325ms
# 915:	learn: 0.0265646	total: 3.51s	remaining: 322ms
# 916:	learn: 0.0265423	total: 3.51s	remaining: 318ms
# 917:	learn: 0.0265319	total: 3.52s	remaining: 314ms
# 918:	learn: 0.0264939	total: 3.52s	remaining: 310ms
# 919:	learn: 0.0264831	total: 3.52s	remaining: 306ms
# 920:	learn: 0.0264657	total: 3.53s	remaining: 302ms
# 921:	learn: 0.0264200	total: 3.53s	remaining: 299ms
# 922:	learn: 0.0264173	total: 3.53s	remaining: 295ms
# 923:	learn: 0.0264130	total: 3.54s	remaining: 291ms
# 924:	learn: 0.0264090	total: 3.54s	remaining: 287ms
# 925:	learn: 0.0264051	total: 3.54s	remaining: 283ms
# 926:	learn: 0.0263796	total: 3.55s	remaining: 279ms
# ...
# 694:	learn: 0.0324039	total: 3.15s	remaining: 1.38s
# 695:	learn: 0.0323828	total: 3.16s	remaining: 1.38s
# 696:	learn: 0.0323756	total: 3.16s	remaining: 1.37s
# 697:	learn: 0.0323474	total: 3.17s	remaining: 1.37s
# 698:	learn: 0.0323285	total: 3.17s	remaining: 1.36s
# 699:	learn: 0.0323219	total: 3.17s	remaining: 1.36s
# 700:	learn: 0.0323109	total: 3.18s	remaining: 1.36s
# 701:	learn: 0.0322630	total: 3.19s	remaining: 1.35s
# 702:	learn: 0.0322147	total: 3.19s	remaining: 1.35s
# 703:	learn: 0.0321796	total: 3.19s	remaining: 1.34s
# 704:	learn: 0.0320761	total: 3.2s	remaining: 1.34s
# 705:	learn: 0.0320173	total: 3.2s	remaining: 1.33s
# 706:	learn: 0.0319952	total: 3.21s	remaining: 1.33s
# 707:	learn: 0.0319548	total: 3.21s	remaining: 1.32s
# 708:	learn: 0.0318935	total: 3.22s	remaining: 1.32s
# 709:	learn: 0.0318371	total: 3.22s	remaining: 1.32s
# 710:	learn: 0.0318278	total: 3.23s	remaining: 1.31s
# 711:	learn: 0.0317816	total: 3.23s	remaining: 1.31s
# 712:	learn: 0.0317078	total: 3.24s	remaining: 1.3s
# 713:	learn: 0.0316908	total: 3.24s	remaining: 1.3s
# 714:	learn: 0.0316802	total: 3.25s	remaining: 1.29s
# 715:	learn: 0.0316660	total: 3.25s	remaining: 1.29s
# 716:	learn: 0.0316430	total: 3.25s	remaining: 1.28s
# 717:	learn: 0.0316306	total: 3.26s	remaining: 1.28s
# 718:	learn: 0.0315692	total: 3.26s	remaining: 1.27s
# 719:	learn: 0.0315085	total: 3.27s	remaining: 1.27s
# 720:	learn: 0.0315021	total: 3.27s	remaining: 1.27s
# 721:	learn: 0.0314504	total: 3.28s	remaining: 1.26s
# 722:	learn: 0.0314393	total: 3.28s	remaining: 1.26s
# 723:	learn: 0.0314253	total: 3.29s	remaining: 1.25s
# 724:	learn: 0.0313676	total: 3.29s	remaining: 1.25s
# 725:	learn: 0.0313036	total: 3.3s	remaining: 1.24s
# 726:	learn: 0.0312547	total: 3.3s	remaining: 1.24s
# 727:	learn: 0.0312284	total: 3.31s	remaining: 1.24s
# 728:	learn: 0.0311774	total: 3.31s	remaining: 1.23s
# 729:	learn: 0.0311331	total: 3.32s	remaining: 1.23s
# 730:	learn: 0.0311145	total: 3.32s	remaining: 1.22s
# 731:	learn: 0.0310778	total: 3.33s	remaining: 1.22s
# 732:	learn: 0.0310635	total: 3.33s	remaining: 1.21s
# 733:	learn: 0.0310168	total: 3.33s	remaining: 1.21s
# 734:	learn: 0.0309827	total: 3.34s	remaining: 1.2s
# 735:	learn: 0.0308813	total: 3.34s	remaining: 1.2s
# 736:	learn: 0.0308302	total: 3.35s	remaining: 1.19s
# 737:	learn: 0.0308158	total: 3.35s	remaining: 1.19s
# 738:	learn: 0.0307814	total: 3.36s	remaining: 1.19s
# 739:	learn: 0.0307685	total: 3.36s	remaining: 1.18s
# 740:	learn: 0.0307090	total: 3.37s	remaining: 1.18s
# 741:	learn: 0.0306925	total: 3.37s	remaining: 1.17s
# 742:	learn: 0.0305702	total: 3.38s	remaining: 1.17s
# 743:	learn: 0.0305564	total: 3.38s	remaining: 1.16s
# 744:	learn: 0.0305440	total: 3.39s	remaining: 1.16s
# 745:	learn: 0.0305245	total: 3.39s	remaining: 1.15s
# 746:	learn: 0.0304864	total: 3.4s	remaining: 1.15s
# 747:	learn: 0.0304602	total: 3.4s	remaining: 1.15s
# 748:	learn: 0.0304449	total: 3.4s	remaining: 1.14s
# 749:	learn: 0.0304254	total: 3.41s	remaining: 1.14s
# 750:	learn: 0.0304110	total: 3.42s	remaining: 1.13s
# 751:	learn: 0.0303549	total: 3.42s	remaining: 1.13s
# 752:	learn: 0.0303365	total: 3.42s	remaining: 1.12s
# 753:	learn: 0.0302741	total: 3.43s	remaining: 1.12s
# 754:	learn: 0.0302331	total: 3.43s	remaining: 1.11s
# 755:	learn: 0.0301700	total: 3.44s	remaining: 1.11s
# 756:	learn: 0.0301358	total: 3.44s	remaining: 1.1s
# 757:	learn: 0.0301146	total: 3.45s	remaining: 1.1s
# 758:	learn: 0.0300892	total: 3.45s	remaining: 1.1s
# 759:	learn: 0.0300503	total: 3.46s	remaining: 1.09s
# 760:	learn: 0.0300354	total: 3.46s	remaining: 1.09s
# 761:	learn: 0.0300224	total: 3.47s	remaining: 1.08s
# 762:	learn: 0.0300063	total: 3.47s	remaining: 1.08s
# 763:	learn: 0.0300002	total: 3.48s	remaining: 1.07s
# 764:	learn: 0.0299748	total: 3.48s	remaining: 1.07s
# 765:	learn: 0.0299471	total: 3.48s	remaining: 1.06s
# 766:	learn: 0.0299381	total: 3.49s	remaining: 1.06s
# 767:	learn: 0.0299136	total: 3.49s	remaining: 1.05s
# 768:	learn: 0.0298927	total: 3.5s	remaining: 1.05s
# 769:	learn: 0.0298838	total: 3.5s	remaining: 1.05s
# 770:	learn: 0.0298722	total: 3.51s	remaining: 1.04s
# 771:	learn: 0.0298598	total: 3.51s	remaining: 1.04s
# 772:	learn: 0.0298475	total: 3.52s	remaining: 1.03s
# 773:	learn: 0.0298369	total: 3.52s	remaining: 1.03s
# 774:	learn: 0.0298182	total: 3.53s	remaining: 1.02s
# 775:	learn: 0.0297686	total: 3.53s	remaining: 1.02s
# 776:	learn: 0.0297527	total: 3.54s	remaining: 1.01s
# 777:	learn: 0.0297385	total: 3.54s	remaining: 1.01s
# 778:	learn: 0.0296900	total: 3.54s	remaining: 1s
# 779:	learn: 0.0296401	total: 3.55s	remaining: 1s
# 780:	learn: 0.0295759	total: 3.56s	remaining: 997ms
# 781:	learn: 0.0295605	total: 3.56s	remaining: 992ms
# 782:	learn: 0.0295502	total: 3.56s	remaining: 988ms
# 783:	learn: 0.0295200	total: 3.57s	remaining: 983ms
# 784:	learn: 0.0295088	total: 3.57s	remaining: 979ms
# 785:	learn: 0.0294301	total: 3.58s	remaining: 974ms
# 786:	learn: 0.0294056	total: 3.58s	remaining: 970ms
# 787:	learn: 0.0293623	total: 3.59s	remaining: 965ms
# 788:	learn: 0.0293477	total: 3.59s	remaining: 961ms
# 789:	learn: 0.0293151	total: 3.6s	remaining: 956ms
# 790:	learn: 0.0293038	total: 3.6s	remaining: 952ms
# 791:	learn: 0.0292274	total: 3.61s	remaining: 947ms
# 792:	learn: 0.0292069	total: 3.61s	remaining: 943ms
# 793:	learn: 0.0291822	total: 3.62s	remaining: 938ms
# 794:	learn: 0.0291047	total: 3.62s	remaining: 934ms
# 795:	learn: 0.0290900	total: 3.63s	remaining: 929ms
# 796:	learn: 0.0290744	total: 3.63s	remaining: 925ms
# 797:	learn: 0.0290248	total: 3.63s	remaining: 920ms
# 798:	learn: 0.0290024	total: 3.64s	remaining: 915ms
# 799:	learn: 0.0289731	total: 3.64s	remaining: 911ms
# 800:	learn: 0.0289634	total: 3.65s	remaining: 906ms
# 801:	learn: 0.0289493	total: 3.65s	remaining: 902ms
# 802:	learn: 0.0289419	total: 3.66s	remaining: 897ms
# 803:	learn: 0.0289235	total: 3.66s	remaining: 893ms
# 804:	learn: 0.0288854	total: 3.67s	remaining: 888ms
# 805:	learn: 0.0288378	total: 3.67s	remaining: 884ms
# 806:	learn: 0.0288212	total: 3.68s	remaining: 879ms
# 807:	learn: 0.0288054	total: 3.68s	remaining: 875ms
# 808:	learn: 0.0287893	total: 3.69s	remaining: 870ms
# 809:	learn: 0.0287574	total: 3.69s	remaining: 866ms
# 810:	learn: 0.0287465	total: 3.69s	remaining: 861ms
# 811:	learn: 0.0286998	total: 3.7s	remaining: 856ms
# 812:	learn: 0.0286946	total: 3.7s	remaining: 852ms
# 813:	learn: 0.0286553	total: 3.71s	remaining: 848ms
# 814:	learn: 0.0286369	total: 3.71s	remaining: 843ms
# 815:	learn: 0.0286173	total: 3.72s	remaining: 838ms
# 816:	learn: 0.0286051	total: 3.72s	remaining: 834ms
# 817:	learn: 0.0285820	total: 3.73s	remaining: 829ms
# 818:	learn: 0.0285737	total: 3.73s	remaining: 825ms
# 819:	learn: 0.0285492	total: 3.74s	remaining: 820ms
# 820:	learn: 0.0284907	total: 3.74s	remaining: 816ms
# 821:	learn: 0.0284633	total: 3.75s	remaining: 811ms
# 822:	learn: 0.0284446	total: 3.75s	remaining: 807ms
# 823:	learn: 0.0284310	total: 3.75s	remaining: 802ms
# 824:	learn: 0.0284218	total: 3.76s	remaining: 798ms
# 825:	learn: 0.0283853	total: 3.76s	remaining: 793ms
# 826:	learn: 0.0282938	total: 3.77s	remaining: 789ms
# 827:	learn: 0.0282857	total: 3.77s	remaining: 784ms
# 828:	learn: 0.0282729	total: 3.78s	remaining: 779ms
# 829:	learn: 0.0282173	total: 3.78s	remaining: 775ms
# 830:	learn: 0.0281809	total: 3.79s	remaining: 770ms
# 831:	learn: 0.0281704	total: 3.79s	remaining: 766ms
# 832:	learn: 0.0281462	total: 3.8s	remaining: 761ms
# 833:	learn: 0.0280821	total: 3.8s	remaining: 757ms
# 834:	learn: 0.0280515	total: 3.81s	remaining: 752ms
# 835:	learn: 0.0280314	total: 3.81s	remaining: 748ms
# 836:	learn: 0.0279832	total: 3.82s	remaining: 743ms
# 837:	learn: 0.0279683	total: 3.82s	remaining: 739ms
# 838:	learn: 0.0279325	total: 3.83s	remaining: 734ms
# 839:	learn: 0.0278521	total: 3.83s	remaining: 730ms
# 840:	learn: 0.0278243	total: 3.83s	remaining: 725ms
# 841:	learn: 0.0277801	total: 3.84s	remaining: 720ms
# 842:	learn: 0.0277522	total: 3.84s	remaining: 716ms
# 843:	learn: 0.0277436	total: 3.85s	remaining: 711ms
# 844:	learn: 0.0277177	total: 3.85s	remaining: 707ms
# 845:	learn: 0.0276991	total: 3.86s	remaining: 702ms
# 846:	learn: 0.0276629	total: 3.86s	remaining: 698ms
# 847:	learn: 0.0276552	total: 3.87s	remaining: 693ms
# 848:	learn: 0.0276260	total: 3.87s	remaining: 688ms
# 849:	learn: 0.0276170	total: 3.88s	remaining: 684ms
# 850:	learn: 0.0275780	total: 3.88s	remaining: 679ms
# 851:	learn: 0.0275677	total: 3.88s	remaining: 675ms
# 852:	learn: 0.0275511	total: 3.89s	remaining: 670ms
# 853:	learn: 0.0275057	total: 3.89s	remaining: 666ms
# 854:	learn: 0.0274812	total: 3.9s	remaining: 661ms
# 855:	learn: 0.0274167	total: 3.9s	remaining: 657ms
# 856:	learn: 0.0273841	total: 3.91s	remaining: 652ms
# 857:	learn: 0.0273597	total: 3.91s	remaining: 647ms
# 858:	learn: 0.0273117	total: 3.92s	remaining: 643ms
# 859:	learn: 0.0272577	total: 3.92s	remaining: 638ms
# 860:	learn: 0.0272435	total: 3.92s	remaining: 634ms
# 861:	learn: 0.0272263	total: 3.93s	remaining: 629ms
# 862:	learn: 0.0272193	total: 3.93s	remaining: 625ms
# 863:	learn: 0.0271982	total: 3.94s	remaining: 620ms
# 864:	learn: 0.0271802	total: 3.94s	remaining: 615ms
# 865:	learn: 0.0271714	total: 3.95s	remaining: 611ms
# 866:	learn: 0.0271520	total: 3.95s	remaining: 606ms
# 867:	learn: 0.0271339	total: 3.96s	remaining: 602ms
# 868:	learn: 0.0271180	total: 3.96s	remaining: 597ms
# 869:	learn: 0.0270701	total: 3.97s	remaining: 593ms
# 870:	learn: 0.0270552	total: 3.97s	remaining: 588ms
# 871:	learn: 0.0270465	total: 3.98s	remaining: 584ms
# 872:	learn: 0.0270032	total: 3.98s	remaining: 579ms
# 873:	learn: 0.0269737	total: 3.99s	remaining: 575ms
# 874:	learn: 0.0269589	total: 3.99s	remaining: 570ms
# 875:	learn: 0.0269340	total: 4s	remaining: 566ms
# 876:	learn: 0.0269101	total: 4s	remaining: 561ms
# 877:	learn: 0.0268946	total: 4s	remaining: 556ms
# 878:	learn: 0.0268785	total: 4.01s	remaining: 552ms
# 879:	learn: 0.0268655	total: 4.01s	remaining: 547ms
# 880:	learn: 0.0268425	total: 4.02s	remaining: 543ms
# 881:	learn: 0.0268234	total: 4.02s	remaining: 538ms
# 882:	learn: 0.0267817	total: 4.03s	remaining: 534ms
# 883:	learn: 0.0267704	total: 4.03s	remaining: 529ms
# 884:	learn: 0.0267557	total: 4.04s	remaining: 524ms
# 885:	learn: 0.0267425	total: 4.04s	remaining: 520ms
# 886:	learn: 0.0267338	total: 4.04s	remaining: 515ms
# 887:	learn: 0.0267203	total: 4.05s	remaining: 511ms
# 888:	learn: 0.0267109	total: 4.05s	remaining: 506ms
# 889:	learn: 0.0267020	total: 4.06s	remaining: 502ms
# 890:	learn: 0.0266922	total: 4.06s	remaining: 497ms
# 891:	learn: 0.0266597	total: 4.07s	remaining: 492ms
# 892:	learn: 0.0266470	total: 4.07s	remaining: 488ms
# 893:	learn: 0.0266306	total: 4.08s	remaining: 483ms
# 894:	learn: 0.0266211	total: 4.08s	remaining: 479ms
# 895:	learn: 0.0265907	total: 4.09s	remaining: 474ms
# 896:	learn: 0.0265816	total: 4.09s	remaining: 470ms
# 897:	learn: 0.0265651	total: 4.09s	remaining: 465ms
# 898:	learn: 0.0265504	total: 4.1s	remaining: 461ms
# 899:	learn: 0.0265010	total: 4.1s	remaining: 456ms
# 900:	learn: 0.0264447	total: 4.11s	remaining: 452ms
# 901:	learn: 0.0264291	total: 4.11s	remaining: 447ms
# 902:	learn: 0.0264112	total: 4.12s	remaining: 442ms
# 903:	learn: 0.0263938	total: 4.12s	remaining: 438ms
# 904:	learn: 0.0263790	total: 4.13s	remaining: 433ms
# 905:	learn: 0.0263637	total: 4.13s	remaining: 429ms
# 906:	learn: 0.0263487	total: 4.14s	remaining: 424ms
# 907:	learn: 0.0263155	total: 4.14s	remaining: 420ms
# 908:	learn: 0.0263078	total: 4.15s	remaining: 415ms
# 909:	learn: 0.0262906	total: 4.15s	remaining: 411ms
# 910:	learn: 0.0262777	total: 4.16s	remaining: 406ms
# 911:	learn: 0.0262694	total: 4.16s	remaining: 401ms
# 912:	learn: 0.0262570	total: 4.16s	remaining: 397ms
# 913:	learn: 0.0262504	total: 4.17s	remaining: 392ms
# 914:	learn: 0.0262175	total: 4.17s	remaining: 388ms
# 915:	learn: 0.0262087	total: 4.18s	remaining: 383ms
# 916:	learn: 0.0261934	total: 4.18s	remaining: 379ms
# 917:	learn: 0.0261609	total: 4.19s	remaining: 374ms
# 918:	learn: 0.0261515	total: 4.19s	remaining: 370ms
# 919:	learn: 0.0261450	total: 4.2s	remaining: 365ms
# 920:	learn: 0.0261329	total: 4.2s	remaining: 360ms
# 921:	learn: 0.0261163	total: 4.21s	remaining: 356ms
# 922:	learn: 0.0260999	total: 4.21s	remaining: 351ms
# 923:	learn: 0.0260896	total: 4.21s	remaining: 347ms
# 924:	learn: 0.0260790	total: 4.22s	remaining: 342ms
# 925:	learn: 0.0260687	total: 4.22s	remaining: 338ms
# 926:	learn: 0.0260337	total: 4.23s	remaining: 333ms
# 927:	learn: 0.0260078	total: 4.23s	remaining: 329ms
# 928:	learn: 0.0259958	total: 4.24s	remaining: 324ms
# 929:	learn: 0.0259906	total: 4.24s	remaining: 319ms
# 930:	learn: 0.0259785	total: 4.25s	remaining: 315ms
# 931:	learn: 0.0259694	total: 4.25s	remaining: 310ms
# 932:	learn: 0.0259599	total: 4.26s	remaining: 306ms
# 933:	learn: 0.0259551	total: 4.26s	remaining: 301ms
# 934:	learn: 0.0259489	total: 4.27s	remaining: 297ms
# 935:	learn: 0.0259123	total: 4.27s	remaining: 292ms
# 936:	learn: 0.0259075	total: 4.28s	remaining: 288ms
# 937:	learn: 0.0258926	total: 4.28s	remaining: 283ms
# 938:	learn: 0.0258264	total: 4.29s	remaining: 278ms
# 939:	learn: 0.0257930	total: 4.29s	remaining: 274ms
# 940:	learn: 0.0257668	total: 4.29s	remaining: 269ms
# 941:	learn: 0.0257475	total: 4.3s	remaining: 265ms
# 942:	learn: 0.0257233	total: 4.3s	remaining: 260ms
# 943:	learn: 0.0257070	total: 4.31s	remaining: 256ms
# 944:	learn: 0.0256221	total: 4.31s	remaining: 251ms
# 945:	learn: 0.0256120	total: 4.32s	remaining: 246ms
# 946:	learn: 0.0255142	total: 4.32s	remaining: 242ms
# 947:	learn: 0.0255032	total: 4.33s	remaining: 237ms
# 948:	learn: 0.0254811	total: 4.33s	remaining: 233ms
# 949:	learn: 0.0254531	total: 4.34s	remaining: 228ms
# 950:	learn: 0.0254128	total: 4.34s	remaining: 224ms
# 951:	learn: 0.0254030	total: 4.35s	remaining: 219ms
# 952:	learn: 0.0253680	total: 4.35s	remaining: 215ms
# 953:	learn: 0.0253404	total: 4.36s	remaining: 210ms
# 954:	learn: 0.0253162	total: 4.36s	remaining: 205ms
# 955:	learn: 0.0252825	total: 4.37s	remaining: 201ms
# 956:	learn: 0.0252574	total: 4.37s	remaining: 196ms
# 957:	learn: 0.0252163	total: 4.37s	remaining: 192ms
# 958:	learn: 0.0252050	total: 4.38s	remaining: 187ms
# 959:	learn: 0.0251925	total: 4.38s	remaining: 183ms
# 960:	learn: 0.0251773	total: 4.39s	remaining: 178ms
# 961:	learn: 0.0251634	total: 4.39s	remaining: 174ms
# 962:	learn: 0.0251472	total: 4.4s	remaining: 169ms
# 963:	learn: 0.0251176	total: 4.4s	remaining: 164ms
# 964:	learn: 0.0250750	total: 4.41s	remaining: 160ms
# 965:	learn: 0.0250463	total: 4.41s	remaining: 155ms
# 966:	learn: 0.0250249	total: 4.42s	remaining: 151ms
# 967:	learn: 0.0249963	total: 4.42s	remaining: 146ms
# 968:	learn: 0.0249869	total: 4.43s	remaining: 142ms
# 969:	learn: 0.0249799	total: 4.43s	remaining: 137ms
# 970:	learn: 0.0249685	total: 4.44s	remaining: 133ms
# 971:	learn: 0.0249379	total: 4.44s	remaining: 128ms
# 972:	learn: 0.0249294	total: 4.45s	remaining: 123ms
# 973:	learn: 0.0249219	total: 4.45s	remaining: 119ms
# 974:	learn: 0.0248994	total: 4.46s	remaining: 114ms
# 975:	learn: 0.0248947	total: 4.46s	remaining: 110ms
# 976:	learn: 0.0248775	total: 4.47s	remaining: 105ms
# 977:	learn: 0.0248721	total: 4.47s	remaining: 101ms
# 978:	learn: 0.0248497	total: 4.48s	remaining: 96ms
# 979:	learn: 0.0248282	total: 4.48s	remaining: 91.5ms
# 980:	learn: 0.0247980	total: 4.49s	remaining: 86.9ms
# 981:	learn: 0.0247917	total: 4.49s	remaining: 82.3ms
# 982:	learn: 0.0247712	total: 4.5s	remaining: 77.8ms
# 983:	learn: 0.0247114	total: 4.5s	remaining: 73.2ms
# 984:	learn: 0.0246781	total: 4.5s	remaining: 68.6ms
# 985:	learn: 0.0246378	total: 4.51s	remaining: 64ms
# 986:	learn: 0.0246002	total: 4.51s	remaining: 59.5ms
# 987:	learn: 0.0245859	total: 4.52s	remaining: 54.9ms
# 988:	learn: 0.0245663	total: 4.52s	remaining: 50.3ms
# 989:	learn: 0.0245446	total: 4.53s	remaining: 45.8ms
# 990:	learn: 0.0245297	total: 4.53s	remaining: 41.2ms
# 991:	learn: 0.0245113	total: 4.54s	remaining: 36.6ms
# 992:	learn: 0.0244810	total: 4.54s	remaining: 32ms
# 993:	learn: 0.0244683	total: 4.55s	remaining: 27.5ms
# 994:	learn: 0.0244512	total: 4.55s	remaining: 22.9ms
# 995:	learn: 0.0244104	total: 4.56s	remaining: 18.3ms
# 996:	learn: 0.0243979	total: 4.56s	remaining: 13.7ms
# 997:	learn: 0.0243856	total: 4.57s	remaining: 9.16ms
# 998:	learn: 0.0243723	total: 4.57s	remaining: 4.58ms
# 999:	learn: 0.0243524	total: 4.58s	remaining: 0us
# 99.97564762991954 					 99.93030341915889
# 99.97457625472492 99.92126406256972

# %%
result.head()
# Out:
#               0             1             2             3             4  \
# 0   3291.052161   3262.572257   3268.097279   3271.491438   3274.387358
# 1   1882.466005   1859.607112   1828.211022   1853.588897   1845.400260
# 2  11632.460364  11552.955070  11526.410934  11699.536406  11456.368493
# 3   9435.404199   9447.690752   9393.087929   9426.287773   9407.188925
# 4   5746.180669   5719.948138   5690.322342   5697.638846   5666.085977
#
#               5             6             7             8
# 0   3336.654876   3325.391287   3258.865681   3216.883561
# 1   1831.228667   1839.130892   1872.579163   1855.840582
# 2  11536.608095  11790.177815  11723.795795  11679.518657
# 3   9376.277766   9341.645506   9343.058269   9420.018748
# 4   5665.168846   5705.709055   5719.784524   5669.295775

# %%
result1 = np.mean(result,axis=1)

# %%
sample.head()
# Out:
#          Product_id  Selling_Price
# 0  SCHE4YSTDVPVZVXW    3294.594688
# 1  ACCEGCATKHNRXUHW    1945.603968
# 2  NKCE6GJ5XVJDXNNZ   11871.830880
# 3  NKCEB8BK3ZXDHDHM    9421.143424
# 4  TOPEFDXSAHRNPF94    5717.420625

# %%
final = pd.DataFrame(index = range(len(z)),columns=['Product_id','Selling_Price'])

# %%
final.Product_id = z
final.Selling_Price = result1

# %%
final
# Out:
#             Product_id  Selling_Price
# 0     SCHE4YSTDVPVZVXW    3278.377322
# 1     ACCEGCATKHNRXUHW    1852.005844
# 2     NKCE6GJ5XVJDXNNZ   11621.981292
# 3     NKCEB8BK3ZXDHDHM    9398.962207
# 4     TOPEFDXSAHRNPF94    5697.792686
# 5     ACCE558KZHEPZYMG    9542.082148
# 6     ACCEAZCVAMFHDPY7    5277.618906
# 7     NKCDYNY37JPBGBVM    2542.332384
# 8     NKCEY8KWY33FCUYD    7521.328038
# 9     RNGE4YPTQYRECV9J    4662.377602
# 10    NKCE88AHBHJZREXH    3887.225836
# 11    CLTEJ5ZZGBP4JGGE    7268.028607
# 12    WATE3NWH5FZWAMDA    8095.520835
# 13    CAGE53FSFZVFPFHQ    1740.493113
# 14    PCSEAKVBFFPGCHNZ    3761.756477
# 15    WATDFFH3KJYBTYGG    7441.529605
# 16    NKCDWHFQSCHHYZMP    2753.419290
# 17    RNGEB2PG3Q5RKDW6    3477.730700
# 18    NKCE5UY9HHPZGGUZ    4449.621921
# 19    KTAEHETW3ZCMFMJR    4098.322493
# 20    BRAEBBYRVF9MHJHU    7764.607038
# 21    NKCEAX7HAQ2RJA3Q   10343.486852
# 22    CRTECN2RQZWBSP9W    4977.856929
# 23    WATDEWZ9UHSEHGZG    9716.855475
# 24    PTPEYW8HNV6G9YYR    2846.196455
# 25    ACCEAMGZRRYVAHDC    5028.718579
# 26    SRTEHHXG8MUXTGPA    5926.661255
# 27    SKIE4S4NN4MHYM3Z    4780.913512
# 28    HMBE7G34YHWPWKYN    7290.302093
# 29    LLIEGTMFJBD7ZZZM   13562.944062
# ...                ...            ...
# 3400  CBKEHJUH7WPZEEGK    6351.532059
# 3401  CRTECN2QXZUFSGHZ    5159.706365
# 3402  SWSEBHCPAKWKRDPR    9384.622270
# 3403  ACCEAMGZGAQWYYMV    3934.285688
# 3404  CRTECN2QZGUQPR93    3999.286193
# 3405  SHOEJBSZ8FS9SNJR     449.709740
# 3406  BRAE6ZCHV2ZAA9US    3249.818709
# 3407  SUDEGGB28WWTGFUY    6776.424756
# 3408  ACCEAHRFFKPGUGGX    4891.987243
# 3409  BRAEBBMQZDMZAEBV    1074.477838
# 3410  NKCED6EXXSFZGQP8     324.544870
# 3411  SHTECN9HFVZYP2V9    3413.736361
# 3412  RTREAX3DGDRSSYFT    1389.529819
# 3413  RNGE65FGK2TMUC2A    9333.179529
# 3414  ACCEGZ8EWQ7RMZTZ    6948.505269
# 3415  BRAE4DHZEAPXQVRG    1812.441910
# 3416  CAGECHKFAMZCKPFT     160.422548
# 3417  PCSE6SJG9SMAGGHY    3916.602593
# 3418  SNDE25SG2HRJF9JH    1152.705430
# 3419  NKCEAVZ3FCDEUZHG    5354.788704
# 3420  ACCEG7AG8EUZRRZY    6316.924655
# 3421  SHOECH3WZHFCVZWU    3783.926277
# 3422  TOPEAKYKZKRHPMHX    3762.897164
# 3423  NDNEJRAZNQBZQWQK   12641.919682
# 3424  MUGEBFGFDQYJG5TW    5312.742350
# 3425  BBAE9K7BXFUTDNBK    3946.372440
# 3426  RTRDYPA4PJHCJCGF    9350.544579
# 3427  TUNE8FWQBS7TVVT7    6033.898642
# 3428  NKCEGMUABCRGUZPE    3448.814709
# 3429  RNGE7M92KAQWUBCS    1003.527357
#
# [3430 rows x 2 columns]

# %%
final.to_csv('multi_model_cat6.csv',index=False)
