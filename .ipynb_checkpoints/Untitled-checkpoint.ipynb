# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import catboost as cat
import ngboost as ng
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold, train_test_split
from sklearn.ensemble import *
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_log_error, mean_squared_error
import xgboost as xgb
import lightgbm as lgb
import warnings
warnings.filterwarnings(action='ignore')

# %%
train = pd.read_csv(r'C:\Users\Rahul\Desktop\HackerEarth-Machine-Learning-Challenge-Carnival-Wars\train.csv')
test = pd.read_csv(r'C:\Users\Rahul\Desktop\HackerEarth-Machine-Learning-Challenge-Carnival-Wars\test.csv')
sample = pd.read_csv(r'C:\Users\Rahul\Desktop\HackerEarth-Machine-Learning-Challenge-Carnival-Wars\sample_submission.csv')
prd_id = test.Product_id
train.rename({'charges_2 (%)':'charges_2'},inplace=True,axis=1)
test.rename({'charges_2 (%)':'charges_2'},inplace=True,axis=1)

# %%
z = np.copy(test.Product_id)
b = pd.DataFrame(np.copy(train),columns=train.columns)

# %%
train.head()
# Out:
#          Product_id  Stall_no             instock_date  Market_Category  \
# 0  BRAE2NF6JA5GUEXG      37.0  2015-08-22 18:36:12.000                2
# 1  TUNE8SFB6RJN2HSD      38.0  2016-03-27 21:19:13.000               24
# 2  BRAEAR7WZPQGPBZU       9.0  2015-08-18 19:25:22.000              447
# 3  WATDZ2ZQ8JPDHCTJ      50.0  2016-03-28 21:53:01.000               23
# 4  JWSEBUKYQPMBZ3RK       7.0  2016-03-29 22:58:53.000               63
#
#   Customer_name Loyalty_customer Product_Category  Grade  Demand  \
# 0      Lillyann              Yes          Fashion      1      68
# 1         Klynn              Yes          Fashion      0      51
# 2         Ridge              Yes       Child_care      0      10
# 3         Abran              Yes      Educational      2      48
# 4        Dustyn              Yes           Repair      1      35
#
#    Discount_avail  charges_1  charges_2  Minimum_price  Maximum_price  \
# 0             0.0      376.0       11.0         2983.0         4713.0
# 1             0.0      397.0       12.0         7495.0        10352.0
# 2             0.0      250.0        9.0         5752.0         7309.0
# 3             0.0      144.0       13.0         5090.0        20814.0
# 4             1.0      211.0        4.0         2430.0         9261.0
#
#    Selling_Price
# 0    4185.947700
# 1    9271.490256
# 2    6785.701362
# 3   13028.917824
# 4     906.553935

# %%
test.head()
# Out:
#          Product_id  Stall_no             instock_date  Market_Category  \
# 0  SCHE4YSTDVPVZVXW      39.0  2016-01-13 07:45:08.000              205
# 1  ACCEGCATKHNRXUHW      49.0  2015-08-23 20:37:05.000                3
# 2  NKCE6GJ5XVJDXNNZ       1.0  2015-11-14 18:12:39.000              183
# 3  NKCEB8BK3ZXDHDHM       8.0  2015-11-21 04:56:19.000              358
# 4  TOPEFDXSAHRNPF94      33.0  2015-05-06 15:09:46.000              167
#
#   Customer_name Loyalty_customer Product_Category  Grade  Demand  \
# 0        Ivanka              No           Fashion      0      90
# 1         Isaak              Yes          Fashion      0      87
# 2      Analiese              No        Technology      2      55
# 3         Rusty              Yes       Child_care      3      86
# 4        Eloise              No        Technology      0      27
#
#    Discount_avail  charges_1  charges_2  Minimum_price  Maximum_price
# 0               0      380.0       16.0         2576.0           3340
# 1               0      393.0       16.0         1202.0           1955
# 2               0      493.0        9.0         7175.0          15715
# 3               0      303.0       16.0         5404.0          13078
# 4               0      567.0       16.0         4069.0           6244

# %%
sample.head()
# Out:
#          Product_id  Selling_Price
# 0  SCHE4YSTDVPVZVXW    3294.594688
# 1  ACCEGCATKHNRXUHW    1945.603968
# 2  NKCE6GJ5XVJDXNNZ   11871.830880
# 3  NKCEB8BK3ZXDHDHM    9421.143424
# 4  TOPEFDXSAHRNPF94    5717.420625

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6368 entries, 0 to 6367
# Data columns (total 15 columns):
# Product_id          6368 non-null object
# Stall_no            6363 non-null float64
# instock_date        6368 non-null object
# Market_Category     6368 non-null int64
# Customer_name       6157 non-null object
# Loyalty_customer    6368 non-null object
# Product_Category    6368 non-null object
# Grade               6368 non-null int64
# Demand              6368 non-null int64
# Discount_avail      6330 non-null float64
# charges_1           6170 non-null float64
# charges_2           6163 non-null float64
# Minimum_price       6330 non-null float64
# Maximum_price       6025 non-null float64
# Selling_Price       6327 non-null float64
# dtypes: float64(7), int64(3), object(5)
# memory usage: 746.3+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3430 entries, 0 to 3429
# Data columns (total 14 columns):
# Product_id          3430 non-null object
# Stall_no            3429 non-null float64
# instock_date        3430 non-null object
# Market_Category     3430 non-null int64
# Customer_name       3377 non-null object
# Loyalty_customer    3430 non-null object
# Product_Category    3430 non-null object
# Grade               3430 non-null int64
# Demand              3430 non-null int64
# Discount_avail      3430 non-null int64
# charges_1           3394 non-null float64
# charges_2           3425 non-null float64
# Minimum_price       3416 non-null float64
# Maximum_price       3430 non-null int64
# dtypes: float64(4), int64(5), object(5)
# memory usage: 375.2+ KB

# %%
train.describe()
# Out:
#           Stall_no  Market_Category        Grade       Demand  Discount_avail  \
# count  6363.000000      6368.000000  6368.000000  6368.000000     6330.000000
# mean     25.309445       199.340609     0.643687    50.921168        0.140442
# std      14.328980       170.275570     1.025092    29.091922        0.347473
# min       1.000000         0.000000     0.000000     1.000000        0.000000
# 25%      13.000000        55.000000     0.000000    26.000000        0.000000
# 50%      25.000000       132.000000     0.000000    51.000000        0.000000
# 75%      37.000000       403.000000     2.000000    76.000000        0.000000
# max      50.000000       471.000000     3.000000   100.000000        1.000000
#
#          charges_1    charges_2  Minimum_price  Maximum_price  Selling_Price
# count  6170.000000  6163.000000    6330.000000    6025.000000    6327.000000
# mean    264.514100    10.146195    3531.349763    6432.545892    4563.242592
# std     124.483056     4.318339    2194.729604    3716.177364    2979.102408
# min     100.000000     1.000000       1.000000     404.000000   -6062.470000
# 25%     163.000000     7.000000    1879.250000    3918.000000    2450.005280
# 50%     252.000000    10.000000    3157.500000    5634.000000    4210.384640
# 75%     314.000000    14.000000    4697.000000    8126.000000    6167.643252
# max     649.000000    17.000000   17580.000000   58812.000000   22638.325941

# %%
test.describe()
# Out:
#           Stall_no  Market_Category        Grade       Demand  Discount_avail  \
# count  3429.000000      3430.000000  3430.000000  3430.000000     3430.000000
# mean     25.633421       196.693878     0.667638    49.917493        0.146356
# std      14.389747       168.832500     1.045914    28.587214        0.353514
# min       1.000000         0.000000     0.000000     1.000000        0.000000
# 25%      13.000000        55.000000     0.000000    26.000000        0.000000
# 50%      26.000000       124.000000     0.000000    50.000000        0.000000
# 75%      38.000000       358.000000     2.000000    74.000000        0.000000
# max      50.000000       471.000000     3.000000   100.000000        1.000000
#
#          charges_1    charges_2  Minimum_price  Maximum_price
# count  3394.000000  3425.000000    3416.000000    3430.000000
# mean    265.484973    10.436204    3444.206089    6234.062391
# std     125.325455     4.232382    2178.418557    3575.968650
# min     100.000000     1.000000     124.000000     163.000000
# 25%     162.000000     7.000000    1834.000000    3819.000000
# 50%     252.000000    11.000000    3060.500000    5431.000000
# 75%     319.000000    14.000000    4606.500000    7796.500000
# max     648.000000    17.000000   17182.000000   27954.000000

# %%
train.isnull().sum()
# Out:
# Product_id            0
# Stall_no              5
# instock_date          0
# Market_Category       0
# Customer_name       211
# Loyalty_customer      0
# Product_Category      0
# Grade                 0
# Demand                0
# Discount_avail       38
# charges_1           198
# charges_2           205
# Minimum_price        38
# Maximum_price       343
# Selling_Price        41
# dtype: int64

# %%
test.isnull().sum()
# Out:
# Product_id           0
# Stall_no             1
# instock_date         0
# Market_Category      0
# Customer_name       53
# Loyalty_customer     0
# Product_Category     0
# Grade                0
# Demand               0
# Discount_avail       0
# charges_1           36
# charges_2            5
# Minimum_price       14
# Maximum_price        0
# dtype: int64

# %% [markdown]
# ### Label Analysis

# %%
sns.distplot(train.Selling_Price)

# %%
train.drop(index=train[train.Selling_Price<0].index, inplace=True)
train.reset_index(drop=True,inplace=True)

# %%
train.Selling_Price = train.Selling_Price.apply(lambda x: x if x>=0 else x*(-1))

# %%
train.Selling_Price.isnull().sum()
# Out:
# 41

# %%
#a = train[train.Selling_Price.isnull()]

# %%
#b.dropna(inplace=True)
#l1 = np.log(b.Selling_Price)
#b.Selling_Price = b.Selling_Price.apply(lambda x: x if x>=0 else x*(-1))
#b[['Discount_avail','charges_1','charges_2','Minimum_price','Maximum_price']] = b[['Discount_avail','charges_1','charges_2','Minimum_price','Maximum_price']].astype('float')

# %%
#xtrain,xtest,ytrain,ytest = train_test_split(b[['Discount_avail','charges_1','charges_2','Minimum_price','Maximum_price']],b.Selling_Price,test_size=0.3,random_state=8011)

# %%
#m = lgb.LGBMRegressor(random_state=10070)
#m.fit(xtrain,ytrain)
#i_prd = m.predict(xtest)
#np.sqrt(mean_squared_log_error(ytest,i_prd))

# %%
#a.drop(columns=['Selling_Price'],inplace=True)

# %%
#a.Maximum_price.fillna(a.Maximum_price.median(),inplace=True)
#a.Minimum_price.fillna(a.Minimum_price.median(),inplace=True)
#a.Discount_avail.fillna(a.Discount_avail.median(),inplace=True)
#a.charges_2.fillna(a.charges_2.median(),inplace=True)

# %%
#a['Selling_Price'] = m.predict(a[['Discount_avail','charges_1','charges_2','Minimum_price','Maximum_price']])

# %%
#l = a.Selling_Price.index

# %%
#l

# %%
#for i in l:
    #train.loc[i,'Selling_Price'] = a.loc[i,'Selling_Price']

# %%
#train.isnull().sum()

# %%
train.drop(index = train[train.Selling_Price.isnull()].index, inplace=True)
train.reset_index(drop=True,inplace=True)

# %%
#train.Selling_Price.fillna(train.Selling_Price.mean(),inplace=True)

# %% [markdown]
# ## Feature by Feature Analysis

# %% [markdown]
# ### Product ID

# %%
train.Product_id = train.Product_id.apply(lambda x: [i for i in x][:3])
test.Product_id = test.Product_id.apply(lambda x: [i for i in x][:3])

# %%
train.Product_id = train.Product_id.apply(lambda x: ''.join(x))
test.Product_id = test.Product_id.apply(lambda x: ''.join(x))

# %%
train.Product_id.nunique(), test.Product_id.nunique()
# Out:
# (292, 243)

# %%
z
# Out:
# array(['SCHE4YSTDVPVZVXW', 'ACCEGCATKHNRXUHW', 'NKCE6GJ5XVJDXNNZ', ...,
#        'TUNE8FWQBS7TVVT7', 'NKCEGMUABCRGUZPE', 'RNGE7M92KAQWUBCS'],
#       dtype=object)

# %% [markdown]
# ### Stall no.

# %%
test.Stall_no.nunique()
# Out:
# 50

# %%
train.Stall_no.isnull().sum(), test.Stall_no.isnull().sum()
# Out:
# (5, 1)

# %%
train.Stall_no.fillna(20.0, inplace=True) #20
test.Stall_no.fillna(12.0,inplace=True)   #12

# %%
sns.scatterplot(train.Stall_no,train.Selling_Price)

# %%
sns.distplot(train.Stall_no)

# %%
sns.distplot(test.Stall_no)

# %% [markdown]
# ### In Stock date

# %%
#train['Date'] = train.instock_date.str.split(' ').apply(lambda x: x[0])
#test['Date'] = test.instock_date.str.split(' ').apply(lambda x: x[0])

# %%
#train['Time'] = train.instock_date.str.split(' ').apply(lambda x: x[1])
#test['Time'] = test.instock_date.str.split(' ').apply(lambda x: x[1])

# %%
#train['Hour'] = train.Time.str.split(':').apply(lambda x: x[0])
#test['Hour'] = test.Time.str.split(':').apply(lambda x: x[0])

#train['Minute'] = train.Time.str.split(':').apply(lambda x: x[1])
#test['Minute'] = test.Time.str.split(':').apply(lambda x: x[1])

#train['Second'] = train.Time.str.split(':').apply(lambda x: x[2])
#test['Second'] = test.Time.str.split(':').apply(lambda x: x[2])

# %%
#train.drop(columns=['instock_date','Time'],inplace = True)
#test.drop(columns=['instock_date','Time'],inplace = True)

# %%
train.head()
# Out:
#   Product_id  Stall_no             instock_date  Market_Category  \
# 0        BRA      37.0  2015-08-22 18:36:12.000                2
# 1        TUN      38.0  2016-03-27 21:19:13.000               24
# 2        BRA       9.0  2015-08-18 19:25:22.000              447
# 3        WAT      50.0  2016-03-28 21:53:01.000               23
# 4        JWS       7.0  2016-03-29 22:58:53.000               63
#
#   Customer_name Loyalty_customer Product_Category  Grade  Demand  \
# 0      Lillyann              Yes          Fashion      1      68
# 1         Klynn              Yes          Fashion      0      51
# 2         Ridge              Yes       Child_care      0      10
# 3         Abran              Yes      Educational      2      48
# 4        Dustyn              Yes           Repair      1      35
#
#    Discount_avail  charges_1  charges_2  Minimum_price  Maximum_price  \
# 0             0.0      376.0       11.0         2983.0         4713.0
# 1             0.0      397.0       12.0         7495.0        10352.0
# 2             0.0      250.0        9.0         5752.0         7309.0
# 3             0.0      144.0       13.0         5090.0        20814.0
# 4             1.0      211.0        4.0         2430.0         9261.0
#
#    Selling_Price
# 0    4185.947700
# 1    9271.490256
# 2    6785.701362
# 3   13028.917824
# 4     906.553935

# %% [markdown]
# ### Market Category

# %%
sns.distplot(train.Market_Category)

# %%
sns.distplot(test.Market_Category)

# %%
sns.scatterplot(train.Market_Category,train.Selling_Price)

# %% [markdown]
# ### Customer Name

# %%
train.Customer_name.nunique(),test.Customer_name.nunique()
# Out:
# (5855, 3319)

# %%
#train.drop(columns=['Customer_name'],inplace=True)
#test.drop(columns=['Customer_name'],inplace=True)

# %% [markdown]
# ### Loyalty Customer

# %%
train.Loyalty_customer.value_counts(), test.Loyalty_customer.value_counts()
# Out:
# (Yes    3852
#  No     2461
#  Name: Loyalty_customer, dtype: int64,
#  Yes    2087
#  No     1343
#  Name: Loyalty_customer, dtype: int64)

# %%
sns.boxplot(train.Loyalty_customer,train.Selling_Price)

# %% [markdown]
# ### Product Category

# %%
train.Product_Category.value_counts()
# Out:
# Pet_care       674
# Repair         665
# Child_care     652
# Cosmetics      643
# Hospitality    626
# Organic        618
# Technology     616
# Home_decor     610
# Educational    605
# Fashion        604
# Name: Product_Category, dtype: int64

# %%
test.Product_Category.value_counts()
# Out:
# Educational    355
# Cosmetics      348
# Child_care     348
# Pet_care       346
# Repair         345
# Fashion        345
# Home_decor     340
# Technology     340
# Organic        336
# Hospitality    327
# Name: Product_Category, dtype: int64

# %%
sns.boxplot(train.Product_Category,train.Selling_Price)

# %% [markdown]
# ### Grade

# %%
train.Grade.value_counts()
# Out:
# 0    4339
# 2    1093
# 3     502
# 1     379
# Name: Grade, dtype: int64

# %%
z
# Out:
# array(['SCHE4YSTDVPVZVXW', 'ACCEGCATKHNRXUHW', 'NKCE6GJ5XVJDXNNZ', ...,
#        'TUNE8FWQBS7TVVT7', 'NKCEGMUABCRGUZPE', 'RNGE7M92KAQWUBCS'],
#       dtype=object)

# %%
test.Grade.value_counts()
# Out:
# 0    2335
# 2     595
# 3     300
# 1     200
# Name: Grade, dtype: int64

# %%
sns.boxplot(train.Grade,train.Selling_Price)

# %% [markdown]
# ### Demand

# %%
sns.distplot(train.Demand)

# %%
sns.distplot(test.Demand)

# %%
sns.scatterplot(train.Demand,train.Selling_Price)

# %% [markdown]
# ### Discount Avail

# %%
train.Discount_avail.value_counts()
# Out:
# 0.0    5396
# 1.0     880
# Name: Discount_avail, dtype: int64

# %%
train.drop(index = train[train.Discount_avail.isnull()].index, inplace=True)
train.reset_index(drop=True,inplace=True)

# %%
train.Discount_avail.fillna(0.0,inplace=True)

# %%
test.Discount_avail.value_counts()
# Out:
# 0    2928
# 1     502
# Name: Discount_avail, dtype: int64

# %%
sns.boxplot(train.Discount_avail,train.Selling_Price)

# %% [markdown]
# ### Charges_1

# %%
sns.distplot(train.charges_1)

# %%
sns.distplot(test.charges_1)

# %%
sns.scatterplot(train.charges_1,train.Selling_Price)

# %%
#train.drop(train[train.charges_1.isnull()].index,inplace=True)
#train.reset_index(drop=True,inplace=True)

# %%
train.charges_1.fillna(train.charges_1.median(),inplace=True)
test.charges_1.fillna(test.charges_1.median(),inplace=True)

# %% [markdown]
# ### Charges_2(%)

# %%
sns.distplot(train.charges_2)

# %%
train.charges_2.value_counts()
# Out:
# 14.0    482
# 7.0     473
# 5.0     468
# 6.0     456
# 9.0     438
# 8.0     430
# 12.0    427
# 11.0    424
# 16.0    422
# 13.0    409
# 17.0    399
# 15.0    386
# 10.0    337
# 3.0     135
# 1.0     135
# 4.0     131
# 2.0     121
# Name: charges_2, dtype: int64

# %%
sns.distplot(test.charges_2)

# %%
sns.scatterplot(train.charges_2,train.Selling_Price)

# %%
train.charges_2.fillna(train.charges_2.median(),inplace=True)
test.charges_2.fillna(test.charges_2.median(),inplace=True)

# %% [markdown]
# ### Minimum price

# %%
sns.distplot(np.log(train.Minimum_price))

# %%
sns.distplot(np.log(test.Minimum_price))

# %%
sns.scatterplot(train.Minimum_price,train.Selling_Price)

# %%
train.Minimum_price.fillna(train.Minimum_price.median(),inplace=True)
test.Minimum_price.fillna(test.Minimum_price.median(),inplace=True)

# %% [markdown]
# ### Maximum Price

# %%
sns.distplot(np.log(train.Maximum_price))

# %%
sns.distplot(np.log(test.Maximum_price))

# %%
sns.scatterplot(train.Maximum_price,train.Selling_Price)

# %%
train.drop(index = train[train.Maximum_price==train.Maximum_price.max()].index, inplace=True)
train.reset_index(drop=True,inplace=True)

# %%
train.Maximum_price.fillna(train.Maximum_price.median(),inplace=True)

# %% [markdown]
# ### Feature  Engg.

# %%
train.head()
# Out:
#   Product_id  Stall_no             instock_date  Market_Category  \
# 0        BRA      37.0  2015-08-22 18:36:12.000                2
# 1        TUN      38.0  2016-03-27 21:19:13.000               24
# 2        BRA       9.0  2015-08-18 19:25:22.000              447
# 3        WAT      50.0  2016-03-28 21:53:01.000               23
# 4        JWS       7.0  2016-03-29 22:58:53.000               63
#
#   Customer_name Loyalty_customer Product_Category  Grade  Demand  \
# 0      Lillyann              Yes          Fashion      1      68
# 1         Klynn              Yes          Fashion      0      51
# 2         Ridge              Yes       Child_care      0      10
# 3         Abran              Yes      Educational      2      48
# 4        Dustyn              Yes           Repair      1      35
#
#    Discount_avail  charges_1  charges_2  Minimum_price  Maximum_price  \
# 0             0.0      376.0       11.0         2983.0         4713.0
# 1             0.0      397.0       12.0         7495.0        10352.0
# 2             0.0      250.0        9.0         5752.0         7309.0
# 3             0.0      144.0       13.0         5090.0        20814.0
# 4             1.0      211.0        4.0         2430.0         9261.0
#
#    Selling_Price
# 0    4185.947700
# 1    9271.490256
# 2    6785.701362
# 3   13028.917824
# 4     906.553935

# %%
#train.drop(train.Minimum_price[np.log(train.Minimum_price)<5].index,inplace=True)
#train.reset_index(drop=True,inplace=True)

# %%
df = pd.concat([train,test],axis=0)
df.reset_index(drop=True,inplace=True)

# %%
df['Sum'] = ((df.Maximum_price**2) + (df.Minimum_price**2))
df['Mean_price'] = (df.Maximum_price + df.Minimum_price)/2
df['Mean_price_charged'] = (df.Maximum_price + df.Minimum_price) - df.charges_1
#df['Diff_price'] = np.sqrt((df.Maximum_price**2) - (df.Minimum_price**2))
df['Date'] = df.instock_date.str.split(' ').apply(lambda x: x[0])
df.Date = pd.to_datetime(df.Date)
df['Max-price_per-demand'] = df.Maximum_price/df.Demand
df['Min-price_per-demand'] = df.Minimum_price/df.Demand
df['Total-price_per-demand'] = df.Sum/df.Demand

# %%
#df.groupby(['Demand'])[['Minimum_price']].agg(('count','min','max','mean'))
#df['Demand_count_price_count'] = df.groupby(['Grade'])[['Sum']].transform('count')
#df['Demand_min_price_min'] = df.groupby(['Grade'])[['Sum']].transform('min')
#df['Demand_max_price_max'] = df.groupby(['Grade'])[['Sum']].transform('max')
#df['Demand_sum_price_sum'] = df.groupby(['Grade'])[['Sum']].transform('sum')

#df['Demand_max_price_count'] = df.groupby(['Demand'])[['Maximum_price']].transform('count')
#df['Demand_max_price_min'] = df.groupby(['Demand'])[['Maximum_price']].transform('min')
#df['Demand_max_price_max'] = df.groupby(['Demand'])[['Maximum_price']].transform('max')
#df['Demand_max_price_sum'] = df.groupby(['Demand'])[['Maximum_price']].transform('sum')

# %%
df['Weekday'] = df.Date.dt.weekday
df['Day'] = df.Date.dt.day
df['DOY'] = df.Date.dt.dayofyear
df['WOY'] = df.Date.dt.weekofyear
df['DIM'] = df.Date.dt.daysinmonth
df['Month'] = df.Date.dt.month
df['WeekDay_name'] = df.Date.dt.weekday_name

# %%
df['Time'] = df.instock_date.str.split(' ').apply(lambda x: x[1])
#df['Hour'] = df.Time.str.split(':').apply(lambda x: int(x[0]))
#df['Minute'] = df.Time.str.split(':').apply(lambda x: int(x[1]))
#df['Second'] = df.Time.str.split(':').apply(lambda x: float(x[2]))

# %%
#df['Prd_cat_Max_pr_mean']=df.groupby(['Product_Category'])['Mean_price'].transform('mean')
#df['Prd_cat_Max_pr_max']=df.groupby(['Product_Category'])['Maximum_price'].transform('max')
#df['Prd_cat_Max_pr_min']=df.groupby(['Product_Category'])['Maximum_price'].transform('min')
#df['Prd_cat_Max_pr_count']=df.groupby(['Product_Category'])['Maximum_price'].transform('count')

#df['Prd_cat_Min_pr_mean']=df.groupby(['Product_Category'])['Minimum_price'].transform('mean')
#df['Prd_cat_Min_pr_max']=df.groupby(['Product_Category'])['Minimum_price'].transform('max')
#df['Prd_cat_Min_pr_min']=df.groupby(['Product_Category'])['Minimum_price'].transform('min')
#df['Prd_cat_Min_pr_count']=df.groupby(['Product_Category'])['Minimum_price'].transform('count')

#df['Prd_cat_Max_pr_mean']=df.groupby(['Loyalty_customer'])['Maximum_price'].transform('mean')
#df['Prd_cat_Max_pr_max']=df.groupby(['Loyalty_customer'])['Maximum_price'].transform('max')
#df['Prd_cat_Max_pr_min']=df.groupby(['Loyalty_customer'])['Maximum_price'].transform('min')
#df['Prd_cat_Max_pr_count']=df.groupby(['Loyalty_customer'])['Market_Category'].transform('count')

#df['Stall_cat_Min_pr_mean']=df.groupby(['Stall_no'])['Mean_price'].transform('mean')
#df['Stall_cat_Min_pr_max']=df.groupby(['Stall_no'])['Mean_price'].transform('max')
#df['Stall_cat_Min_pr_min']=df.groupby(['Stall_no'])['Mean_price'].transform('min')
#df['Stall_cat_Min_pr_count']=df.groupby(['Market_Category'])['Loyalty_customer'].transform('count')

#df['Stall_cat_Max_pr_mean']=df.groupby(['Discount_avail'])['Sum'].transform('mean')
#df['Stall_cat_Max_pr_max']=df.groupby(['Discount_avail'])['Sum'].transform('max')
#df['Stall_cat_Max_pr_min']=df.groupby(['Discount_avail'])['Sum'].transform('min')
#df['Stall_cat_Max_pr_count']=df.groupby(['Discount_avail'])['Sum'].transform('count')

# %%
df['Charged_max_price'] = df.Maximum_price-(df.charges_1 + (df.charges_2*df.Maximum_price/100))
df['Charged_min_price'] = df.Minimum_price -(df.charges_1 + (df.charges_2*df.Minimum_price/100))
df['Total-charges'] = df.charges_1 + (df.charges_2/100)
df['Diff_Max_price'] = df.Maximum_price - df.Charged_max_price
df['Diff_Sum_price'] = df.Sum - df['Total-charges']
df['Min-Max_ratio'] = df.Maximum_price/df.Minimum_price
df.Maximum_price = np.log(df.Maximum_price)
df.Minimum_price = np.log(df.Minimum_price)

# %%
df['Prd_cat_Min_pr_mean']=df.groupby(['Product_id'])['Minimum_price'].transform('mean')
df['Prd_cat_Min_pr_max']=df.groupby(['Product_id'])['Minimum_price'].transform('max')
df['Prd_cat_Min_pr_min']=df.groupby(['Product_id'])['Minimum_price'].transform('min')
df['Prd_cat_Min_pr_count']=df.groupby(['Product_id'])['Minimum_price'].transform('count')

df['Market_Loyal_pr_count']=df.groupby(['Market_Category'])['Loyalty_customer'].transform('count')
df['Product_Loyal_pr_count']=df.groupby(['Product_Category'])['Loyalty_customer'].transform('count')
df['Discount_Loyal_pr_count']=df.groupby(['Discount_avail'])['Loyalty_customer'].transform('count')
df['Id_Loyal_pr_count']=df.groupby(['Product_id'])['Loyalty_customer'].transform('count')

# %%
df['Stall_Cust_count']=df.groupby(['Stall_no'])['Customer_name'].transform('count')

#df['Grade_sum_price_count'] = df.groupby(['Grade'])[['Sum']].transform('count')
#df['Grade_sum_price_min'] = df.groupby(['Grade'])[['Sum']].transform('min')
#df['Grade_sum_price_max'] = df.groupby(['Grade'])[['Sum']].transform('max')
#df['Grade_sum_price_sum'] = df.groupby(['Grade'])[['Sum']].transform('sum')

#df['Disc_sum_price_count'] = df.groupby(['Discount_avail'])[['Mean_price']].transform('count')
#df['Disc_sum_price_min'] = df.groupby(['Discount_avail'])[['Mean_price']].transform('min')
#df['Disc_sum_price_max'] = df.groupby(['Discount_avail'])[['Mean_price']].transform('max')
#df['Disc_sum_price_sum'] = df.groupby(['Discount_avail'])[['Mean_price']].transform('sum')

#df = pd.concat([df,pd.get_dummies(df[['Loyalty_customer','Product_Category']].astype('category'))],axis=1)

# %%
le = LabelEncoder()
df.Loyalty_customer = le.fit_transform(df.Loyalty_customer)
df.Product_Category = le.fit_transform(df.Product_Category)
df.WeekDay_name = le.fit_transform(df.WeekDay_name)
df.Product_id = le.fit_transform(df.Product_id)

# %%
df.head()
# Out:
#   Customer_name  Demand  Discount_avail  Grade  Loyalty_customer  \
# 0      Lillyann      68             0.0      1                 1
# 1         Klynn      51             0.0      0                 1
# 2         Ridge      10             0.0      0                 1
# 3         Abran      48             0.0      2                 1
# 4        Dustyn      35             1.0      1                 1
#
#    Market_Category  Maximum_price  Minimum_price  Product_Category  \
# 0                2       8.458080       8.000685                 3
# 1               24       9.244935       8.921991                 3
# 2              447       8.896862       8.657303                 0
# 3               23       9.943381       8.535033                 2
# 4               63       9.133567       7.795647                 8
#
#    Product_id  ...  Min-Max_ratio  Prd_cat_Min_pr_mean  Prd_cat_Min_pr_max  \
# 0          39  ...       1.579953             7.736183            9.125762
# 1         315  ...       1.381187             8.125481            9.473474
# 2          39  ...       1.270688             7.736183            9.125762
# 3         333  ...       4.089194             8.066417            9.772182
# 4         151  ...       3.811111             8.256612            9.394161
#
#    Prd_cat_Min_pr_min Prd_cat_Min_pr_count  Market_Loyal_pr_count  \
# 0            5.497168                  989                     39
# 1            5.198497                   33                    321
# 2            5.497168                  989                    261
# 3            5.147494                  440                    491
# 4            7.372118                   28                     59
#
#    Product_Loyal_pr_count  Discount_Loyal_pr_count Id_Loyal_pr_count  \
# 0                     945                     8324               989
# 1                     945                     8324                33
# 2                     994                     8324               989
# 3                     955                     8324               440
# 4                    1004                     1381                28
#
#    Stall_Cust_count
# 0               197
# 1               182
# 2               212
# 3               167
# 4               180
#
# [5 rows x 45 columns]

# %%
#df.drop(columns=['Loyalty_customer','Product_Category'],inplace=True)

# %%
df.isnull().sum()
# Out:
# Customer_name               259
# Demand                        0
# Discount_avail                0
# Grade                         0
# Loyalty_customer              0
# Market_Category               0
# Maximum_price                 0
# Minimum_price                 0
# Product_Category              0
# Product_id                    0
# Selling_Price              3430
# Stall_no                      0
# charges_1                     0
# charges_2                     0
# instock_date                  0
# Sum                           0
# Mean_price                    0
# Mean_price_charged            0
# Date                          0
# Max-price_per-demand          0
# Min-price_per-demand          0
# Total-price_per-demand        0
# Weekday                       0
# Day                           0
# DOY                           0
# WOY                           0
# DIM                           0
# Month                         0
# WeekDay_name                  0
# Time                          0
# Charged_max_price             0
# Charged_min_price             0
# Total-charges                 0
# Diff_Max_price                0
# Diff_Sum_price                0
# Min-Max_ratio                 0
# Prd_cat_Min_pr_mean           0
# Prd_cat_Min_pr_max            0
# Prd_cat_Min_pr_min            0
# Prd_cat_Min_pr_count          0
# Market_Loyal_pr_count         0
# Product_Loyal_pr_count        0
# Discount_Loyal_pr_count       0
# Id_Loyal_pr_count             0
# Stall_Cust_count              0
# dtype: int64

# %% [markdown]
# ### Modelling

# %%
train = df.iloc[:train.shape[0],:]
test = df.iloc[train.shape[0]:,:]
test.reset_index(drop=True,inplace=True)
label = np.log(train.Selling_Price)
test.drop(columns=['Selling_Price','Date','Time','instock_date','Customer_name'],inplace=True)
train.drop(columns=['Selling_Price','Date','Time','instock_date','Customer_name'],inplace=True)

# %%
train.shape, test.shape
# Out:
# ((6275, 40), (3430, 40))

# %%
def model(m,train,label,test,folds,rnd_st):
    predicted = pd.DataFrame(np.zeros(shape=(test.shape[0],folds)))
    splitters = KFold(n_splits = folds, random_state=rnd_st)
    tr = []
    te = []
    
    for i,(tr_index,val_index) in enumerate(splitters.split(train,label)):
        xtrain,xval = train.loc[tr_index,:], train.loc[val_index,:]
        ytrain,yval = label.loc[tr_index], label.loc[val_index]
        
        m.fit(xtrain,ytrain)
        tr_pred = m.predict(xtrain)
        val_pred = m.predict(xval)
        l1 = max([0,100-np.sqrt(mean_squared_error(ytrain,tr_pred))])
        l2 = max([0,100-np.sqrt(mean_squared_error(yval,val_pred))])
        
        print(l1,'\t\t\t\t\t',l2)
        tr.append(l1)
        te.append(l2)
        pd.Series(m.feature_importances_,index = train.columns).sort_values(ascending=True).plot.barh()
        predicted.iloc[:,i] = m.predict(test)

    print(np.mean(tr), np.mean(te))
    return(predicted)

# %%
seed = 119990

# %%
plt.figure(figsize=(9,12))
result = np.exp(model(cat.CatBoostRegressor(random_state=seed),train,label,test,9,seed))
# Out:
# Learning rate set to 0.052998
# 0:	learn: 0.8172067	total: 13ms	remaining: 13s
# 1:	learn: 0.7778357	total: 18ms	remaining: 8.98s
# 2:	learn: 0.7409223	total: 22.5ms	remaining: 7.48s
# 3:	learn: 0.7047304	total: 27.1ms	remaining: 6.74s
# 4:	learn: 0.6717191	total: 31.8ms	remaining: 6.33s
# 5:	learn: 0.6403183	total: 36.2ms	remaining: 6s
# 6:	learn: 0.6101820	total: 40.8ms	remaining: 5.78s
# 7:	learn: 0.5812153	total: 44.9ms	remaining: 5.56s
# 8:	learn: 0.5543360	total: 49.3ms	remaining: 5.43s
# 9:	learn: 0.5284802	total: 54.2ms	remaining: 5.37s
# 10:	learn: 0.5038946	total: 59.3ms	remaining: 5.33s
# 11:	learn: 0.4810713	total: 65.1ms	remaining: 5.36s
# 12:	learn: 0.4589171	total: 69.9ms	remaining: 5.31s
# 13:	learn: 0.4378959	total: 73.9ms	remaining: 5.2s
# 14:	learn: 0.4183000	total: 78.9ms	remaining: 5.18s
# 15:	learn: 0.4004893	total: 83.2ms	remaining: 5.12s
# 16:	learn: 0.3824660	total: 87.3ms	remaining: 5.05s
# 17:	learn: 0.3656135	total: 92.6ms	remaining: 5.05s
# 18:	learn: 0.3500018	total: 97.8ms	remaining: 5.05s
# 19:	learn: 0.3347422	total: 102ms	remaining: 5s
# 20:	learn: 0.3210609	total: 106ms	remaining: 4.94s
# 21:	learn: 0.3080982	total: 111ms	remaining: 4.92s
# 22:	learn: 0.2957745	total: 115ms	remaining: 4.87s
# 23:	learn: 0.2836881	total: 119ms	remaining: 4.84s
# 24:	learn: 0.2724990	total: 124ms	remaining: 4.83s
# 25:	learn: 0.2625365	total: 129ms	remaining: 4.82s
# 26:	learn: 0.2530197	total: 134ms	remaining: 4.81s
# 27:	learn: 0.2436737	total: 137ms	remaining: 4.77s
# 28:	learn: 0.2349375	total: 141ms	remaining: 4.73s
# 29:	learn: 0.2266606	total: 145ms	remaining: 4.7s
# 30:	learn: 0.2192341	total: 149ms	remaining: 4.66s
# 31:	learn: 0.2115526	total: 154ms	remaining: 4.66s
# 32:	learn: 0.2044322	total: 158ms	remaining: 4.62s
# 33:	learn: 0.1978805	total: 162ms	remaining: 4.6s
# 34:	learn: 0.1918297	total: 167ms	remaining: 4.59s
# 35:	learn: 0.1859509	total: 172ms	remaining: 4.62s
# 36:	learn: 0.1801114	total: 178ms	remaining: 4.62s
# 37:	learn: 0.1747691	total: 182ms	remaining: 4.61s
# 38:	learn: 0.1697635	total: 187ms	remaining: 4.62s
# 39:	learn: 0.1650334	total: 192ms	remaining: 4.61s
# 40:	learn: 0.1607482	total: 197ms	remaining: 4.6s
# 41:	learn: 0.1567639	total: 201ms	remaining: 4.59s
# 42:	learn: 0.1530331	total: 207ms	remaining: 4.61s
# 43:	learn: 0.1494817	total: 212ms	remaining: 4.61s
# 44:	learn: 0.1461398	total: 217ms	remaining: 4.6s
# 45:	learn: 0.1431849	total: 223ms	remaining: 4.62s
# 46:	learn: 0.1401919	total: 227ms	remaining: 4.59s
# 47:	learn: 0.1373335	total: 231ms	remaining: 4.57s
# 48:	learn: 0.1348165	total: 235ms	remaining: 4.55s
# 49:	learn: 0.1325085	total: 238ms	remaining: 4.53s
# 50:	learn: 0.1304178	total: 243ms	remaining: 4.52s
# 51:	learn: 0.1282960	total: 248ms	remaining: 4.52s
# 52:	learn: 0.1264394	total: 255ms	remaining: 4.55s
# 53:	learn: 0.1244757	total: 260ms	remaining: 4.56s
# 54:	learn: 0.1228719	total: 265ms	remaining: 4.56s
# 55:	learn: 0.1211995	total: 271ms	remaining: 4.56s
# 56:	learn: 0.1195215	total: 275ms	remaining: 4.54s
# 57:	learn: 0.1179390	total: 279ms	remaining: 4.53s
# 58:	learn: 0.1167513	total: 282ms	remaining: 4.5s
# 59:	learn: 0.1155568	total: 287ms	remaining: 4.49s
# 60:	learn: 0.1143705	total: 292ms	remaining: 4.5s
# 61:	learn: 0.1131854	total: 296ms	remaining: 4.48s
# 62:	learn: 0.1120824	total: 300ms	remaining: 4.47s
# 63:	learn: 0.1110130	total: 305ms	remaining: 4.45s
# 64:	learn: 0.1101088	total: 309ms	remaining: 4.44s
# 65:	learn: 0.1092408	total: 313ms	remaining: 4.44s
# 66:	learn: 0.1084502	total: 318ms	remaining: 4.43s
# 67:	learn: 0.1078352	total: 323ms	remaining: 4.42s
# 68:	learn: 0.1071472	total: 327ms	remaining: 4.41s
# 69:	learn: 0.1065357	total: 330ms	remaining: 4.39s
# 70:	learn: 0.1059945	total: 334ms	remaining: 4.37s
# 71:	learn: 0.1053361	total: 339ms	remaining: 4.37s
# 72:	learn: 0.1046989	total: 343ms	remaining: 4.36s
# 73:	learn: 0.1040271	total: 349ms	remaining: 4.37s
# 74:	learn: 0.1034625	total: 353ms	remaining: 4.36s
# 75:	learn: 0.1027195	total: 357ms	remaining: 4.34s
# 76:	learn: 0.1022065	total: 361ms	remaining: 4.32s
# 77:	learn: 0.1017485	total: 364ms	remaining: 4.31s
# 78:	learn: 0.1012099	total: 369ms	remaining: 4.3s
# 79:	learn: 0.1007681	total: 372ms	remaining: 4.28s
# 80:	learn: 0.1003945	total: 376ms	remaining: 4.27s
# 81:	learn: 0.0999360	total: 380ms	remaining: 4.26s
# 82:	learn: 0.0996342	total: 385ms	remaining: 4.25s
# 83:	learn: 0.0991970	total: 388ms	remaining: 4.23s
# 84:	learn: 0.0988352	total: 392ms	remaining: 4.22s
# 85:	learn: 0.0984570	total: 397ms	remaining: 4.21s
# 86:	learn: 0.0981731	total: 401ms	remaining: 4.2s
# 87:	learn: 0.0978825	total: 406ms	remaining: 4.2s
# 88:	learn: 0.0971811	total: 410ms	remaining: 4.2s
# 89:	learn: 0.0968632	total: 416ms	remaining: 4.21s
# 90:	learn: 0.0966004	total: 420ms	remaining: 4.2s
# 91:	learn: 0.0961942	total: 424ms	remaining: 4.19s
# 92:	learn: 0.0954293	total: 429ms	remaining: 4.18s
# 93:	learn: 0.0950179	total: 434ms	remaining: 4.18s
# 94:	learn: 0.0947165	total: 439ms	remaining: 4.18s
# 95:	learn: 0.0944710	total: 445ms	remaining: 4.19s
# 96:	learn: 0.0942829	total: 448ms	remaining: 4.17s
# 97:	learn: 0.0940847	total: 452ms	remaining: 4.16s
# 98:	learn: 0.0938809	total: 457ms	remaining: 4.16s
# 99:	learn: 0.0934628	total: 462ms	remaining: 4.16s
# 100:	learn: 0.0929973	total: 466ms	remaining: 4.15s
# 101:	learn: 0.0928338	total: 471ms	remaining: 4.15s
# 102:	learn: 0.0926441	total: 476ms	remaining: 4.15s
# 103:	learn: 0.0923129	total: 480ms	remaining: 4.14s
# 104:	learn: 0.0919255	total: 486ms	remaining: 4.14s
# 105:	learn: 0.0914661	total: 491ms	remaining: 4.14s
# 106:	learn: 0.0913433	total: 496ms	remaining: 4.14s
# 107:	learn: 0.0911911	total: 501ms	remaining: 4.13s
# 108:	learn: 0.0909338	total: 506ms	remaining: 4.13s
# 109:	learn: 0.0907633	total: 510ms	remaining: 4.13s
# 110:	learn: 0.0903709	total: 514ms	remaining: 4.12s
# 111:	learn: 0.0902706	total: 519ms	remaining: 4.12s
# 112:	learn: 0.0899571	total: 525ms	remaining: 4.12s
# 113:	learn: 0.0898120	total: 530ms	remaining: 4.12s
# 114:	learn: 0.0892170	total: 537ms	remaining: 4.13s
# 115:	learn: 0.0891072	total: 541ms	remaining: 4.13s
# 116:	learn: 0.0889907	total: 545ms	remaining: 4.12s
# 117:	learn: 0.0888829	total: 549ms	remaining: 4.11s
# 118:	learn: 0.0887645	total: 554ms	remaining: 4.1s
# 119:	learn: 0.0886393	total: 558ms	remaining: 4.09s
# 120:	learn: 0.0882152	total: 561ms	remaining: 4.08s
# 121:	learn: 0.0877754	total: 565ms	remaining: 4.07s
# 122:	learn: 0.0876241	total: 569ms	remaining: 4.06s
# 123:	learn: 0.0875062	total: 573ms	remaining: 4.05s
# 124:	learn: 0.0872067	total: 577ms	remaining: 4.04s
# 125:	learn: 0.0870904	total: 581ms	remaining: 4.03s
# 126:	learn: 0.0867193	total: 585ms	remaining: 4.02s
# 127:	learn: 0.0865800	total: 589ms	remaining: 4.01s
# 128:	learn: 0.0864989	total: 594ms	remaining: 4.01s
# 129:	learn: 0.0863825	total: 598ms	remaining: 4s
# 130:	learn: 0.0861312	total: 603ms	remaining: 4s
# 131:	learn: 0.0859757	total: 607ms	remaining: 3.99s
# 132:	learn: 0.0858282	total: 612ms	remaining: 3.99s
# 133:	learn: 0.0856208	total: 616ms	remaining: 3.98s
# 134:	learn: 0.0850966	total: 619ms	remaining: 3.97s
# 135:	learn: 0.0850071	total: 624ms	remaining: 3.96s
# 136:	learn: 0.0848841	total: 629ms	remaining: 3.96s
# 137:	learn: 0.0843788	total: 633ms	remaining: 3.95s
# 138:	learn: 0.0842618	total: 637ms	remaining: 3.94s
# 139:	learn: 0.0839317	total: 640ms	remaining: 3.93s
# 140:	learn: 0.0835338	total: 645ms	remaining: 3.93s
# 141:	learn: 0.0834194	total: 649ms	remaining: 3.92s
# 142:	learn: 0.0833633	total: 653ms	remaining: 3.91s
# 143:	learn: 0.0830440	total: 657ms	remaining: 3.9s
# 144:	learn: 0.0828813	total: 661ms	remaining: 3.9s
# 145:	learn: 0.0828241	total: 665ms	remaining: 3.89s
# 146:	learn: 0.0827522	total: 669ms	remaining: 3.88s
# 147:	learn: 0.0822461	total: 673ms	remaining: 3.88s
# 148:	learn: 0.0819463	total: 678ms	remaining: 3.87s
# 149:	learn: 0.0818287	total: 684ms	remaining: 3.87s
# 150:	learn: 0.0817378	total: 688ms	remaining: 3.87s
# 151:	learn: 0.0813643	total: 693ms	remaining: 3.87s
# 152:	learn: 0.0812618	total: 697ms	remaining: 3.86s
# 153:	learn: 0.0808101	total: 701ms	remaining: 3.85s
# 154:	learn: 0.0805384	total: 705ms	remaining: 3.84s
# 155:	learn: 0.0803036	total: 708ms	remaining: 3.83s
# 156:	learn: 0.0801996	total: 712ms	remaining: 3.82s
# 157:	learn: 0.0801474	total: 716ms	remaining: 3.81s
# 158:	learn: 0.0799817	total: 720ms	remaining: 3.81s
# 159:	learn: 0.0799343	total: 728ms	remaining: 3.82s
# 160:	learn: 0.0797302	total: 733ms	remaining: 3.82s
# 161:	learn: 0.0796472	total: 737ms	remaining: 3.81s
# 162:	learn: 0.0795191	total: 741ms	remaining: 3.81s
# 163:	learn: 0.0793394	total: 746ms	remaining: 3.8s
# 164:	learn: 0.0791988	total: 750ms	remaining: 3.8s
# 165:	learn: 0.0787725	total: 755ms	remaining: 3.79s
# 166:	learn: 0.0787135	total: 760ms	remaining: 3.79s
# 167:	learn: 0.0786442	total: 764ms	remaining: 3.78s
# 168:	learn: 0.0785901	total: 768ms	remaining: 3.77s
# 169:	learn: 0.0785339	total: 772ms	remaining: 3.77s
# 170:	learn: 0.0783234	total: 775ms	remaining: 3.76s
# 171:	learn: 0.0778789	total: 780ms	remaining: 3.75s
# 172:	learn: 0.0773945	total: 784ms	remaining: 3.75s
# 173:	learn: 0.0769485	total: 789ms	remaining: 3.74s
# 174:	learn: 0.0768796	total: 795ms	remaining: 3.75s
# 175:	learn: 0.0766441	total: 799ms	remaining: 3.74s
# 176:	learn: 0.0765518	total: 806ms	remaining: 3.75s
# 177:	learn: 0.0761182	total: 810ms	remaining: 3.74s
# 178:	learn: 0.0760495	total: 816ms	remaining: 3.74s
# 179:	learn: 0.0759123	total: 824ms	remaining: 3.75s
# 180:	learn: 0.0757764	total: 828ms	remaining: 3.75s
# 181:	learn: 0.0755714	total: 833ms	remaining: 3.74s
# 182:	learn: 0.0751970	total: 838ms	remaining: 3.74s
# 183:	learn: 0.0747749	total: 843ms	remaining: 3.74s
# 184:	learn: 0.0746092	total: 848ms	remaining: 3.74s
# 185:	learn: 0.0744872	total: 852ms	remaining: 3.73s
# 186:	learn: 0.0743655	total: 857ms	remaining: 3.73s
# 187:	learn: 0.0743487	total: 861ms	remaining: 3.72s
# 188:	learn: 0.0741524	total: 866ms	remaining: 3.72s
# 189:	learn: 0.0739634	total: 870ms	remaining: 3.71s
# 190:	learn: 0.0739117	total: 874ms	remaining: 3.7s
# 191:	learn: 0.0735748	total: 878ms	remaining: 3.7s
# 192:	learn: 0.0731456	total: 883ms	remaining: 3.69s
# 193:	learn: 0.0728663	total: 887ms	remaining: 3.69s
# 194:	learn: 0.0728218	total: 891ms	remaining: 3.68s
# 195:	learn: 0.0727621	total: 895ms	remaining: 3.67s
# 196:	learn: 0.0726853	total: 899ms	remaining: 3.67s
# 197:	learn: 0.0726328	total: 904ms	remaining: 3.66s
# 198:	learn: 0.0725843	total: 908ms	remaining: 3.65s
# 199:	learn: 0.0722427	total: 912ms	remaining: 3.65s
# 200:	learn: 0.0721031	total: 917ms	remaining: 3.64s
# 201:	learn: 0.0720575	total: 921ms	remaining: 3.64s
# 202:	learn: 0.0717023	total: 925ms	remaining: 3.63s
# 203:	learn: 0.0713724	total: 929ms	remaining: 3.63s
# 204:	learn: 0.0710051	total: 934ms	remaining: 3.62s
# 205:	learn: 0.0708046	total: 941ms	remaining: 3.63s
# 206:	learn: 0.0705565	total: 948ms	remaining: 3.63s
# 207:	learn: 0.0701451	total: 952ms	remaining: 3.62s
# 208:	learn: 0.0699707	total: 956ms	remaining: 3.62s
# 209:	learn: 0.0695637	total: 961ms	remaining: 3.61s
# 210:	learn: 0.0693963	total: 965ms	remaining: 3.61s
# 211:	learn: 0.0692366	total: 969ms	remaining: 3.6s
# 212:	learn: 0.0692151	total: 974ms	remaining: 3.6s
# 213:	learn: 0.0691771	total: 979ms	remaining: 3.6s
# 214:	learn: 0.0690851	total: 983ms	remaining: 3.59s
# 215:	learn: 0.0689269	total: 987ms	remaining: 3.58s
# 216:	learn: 0.0688541	total: 991ms	remaining: 3.58s
# 217:	learn: 0.0684548	total: 996ms	remaining: 3.57s
# 218:	learn: 0.0681472	total: 1s	remaining: 3.57s
# 219:	learn: 0.0680139	total: 1s	remaining: 3.57s
# 220:	learn: 0.0679190	total: 1.01s	remaining: 3.56s
# 221:	learn: 0.0675981	total: 1.01s	remaining: 3.55s
# 222:	learn: 0.0672292	total: 1.02s	remaining: 3.55s
# 223:	learn: 0.0671862	total: 1.02s	remaining: 3.54s
# 224:	learn: 0.0671119	total: 1.03s	remaining: 3.54s
# 225:	learn: 0.0669789	total: 1.03s	remaining: 3.53s
# 226:	learn: 0.0669333	total: 1.03s	remaining: 3.52s
# 227:	learn: 0.0668743	total: 1.04s	remaining: 3.52s
# 228:	learn: 0.0665814	total: 1.04s	remaining: 3.52s
# 229:	learn: 0.0662270	total: 1.05s	remaining: 3.52s
# 230:	learn: 0.0658461	total: 1.05s	remaining: 3.51s
# 231:	learn: 0.0656652	total: 1.06s	remaining: 3.51s
# 232:	learn: 0.0654890	total: 1.06s	remaining: 3.5s
# 233:	learn: 0.0651824	total: 1.07s	remaining: 3.5s
# 234:	learn: 0.0648331	total: 1.07s	remaining: 3.49s
# 235:	learn: 0.0647424	total: 1.08s	remaining: 3.49s
# 236:	learn: 0.0646702	total: 1.08s	remaining: 3.48s
# 237:	learn: 0.0642374	total: 1.09s	remaining: 3.48s
# 238:	learn: 0.0641988	total: 1.09s	remaining: 3.47s
# 239:	learn: 0.0639625	total: 1.09s	remaining: 3.46s
# 240:	learn: 0.0637189	total: 1.1s	remaining: 3.46s
# 241:	learn: 0.0633760	total: 1.1s	remaining: 3.45s
# 242:	learn: 0.0632848	total: 1.11s	remaining: 3.45s
# 243:	learn: 0.0629577	total: 1.11s	remaining: 3.44s
# 244:	learn: 0.0629190	total: 1.11s	remaining: 3.44s
# 245:	learn: 0.0628120	total: 1.12s	remaining: 3.43s
# 246:	learn: 0.0624773	total: 1.13s	remaining: 3.43s
# 247:	learn: 0.0624440	total: 1.13s	remaining: 3.42s
# 248:	learn: 0.0622628	total: 1.13s	remaining: 3.42s
# 249:	learn: 0.0620226	total: 1.14s	remaining: 3.41s
# 250:	learn: 0.0619151	total: 1.14s	remaining: 3.41s
# 251:	learn: 0.0615198	total: 1.15s	remaining: 3.4s
# 252:	learn: 0.0612009	total: 1.15s	remaining: 3.4s
# 253:	learn: 0.0611528	total: 1.15s	remaining: 3.39s
# 254:	learn: 0.0608404	total: 1.16s	remaining: 3.39s
# 255:	learn: 0.0605339	total: 1.16s	remaining: 3.38s
# 256:	learn: 0.0602447	total: 1.17s	remaining: 3.38s
# 257:	learn: 0.0599517	total: 1.17s	remaining: 3.38s
# 258:	learn: 0.0598776	total: 1.18s	remaining: 3.38s
# 259:	learn: 0.0597841	total: 1.18s	remaining: 3.37s
# 260:	learn: 0.0594968	total: 1.19s	remaining: 3.37s
# 261:	learn: 0.0592113	total: 1.2s	remaining: 3.37s
# 262:	learn: 0.0591325	total: 1.2s	remaining: 3.37s
# 263:	learn: 0.0588698	total: 1.21s	remaining: 3.37s
# 264:	learn: 0.0585874	total: 1.21s	remaining: 3.36s
# 265:	learn: 0.0583770	total: 1.22s	remaining: 3.35s
# 266:	learn: 0.0583397	total: 1.22s	remaining: 3.35s
# 267:	learn: 0.0581677	total: 1.22s	remaining: 3.34s
# 268:	learn: 0.0581418	total: 1.23s	remaining: 3.34s
# 269:	learn: 0.0578684	total: 1.23s	remaining: 3.33s
# 270:	learn: 0.0576040	total: 1.24s	remaining: 3.33s
# 271:	learn: 0.0575668	total: 1.24s	remaining: 3.32s
# 272:	learn: 0.0575226	total: 1.24s	remaining: 3.31s
# 273:	learn: 0.0572676	total: 1.25s	remaining: 3.31s
# 274:	learn: 0.0571248	total: 1.25s	remaining: 3.3s
# 275:	learn: 0.0568660	total: 1.26s	remaining: 3.3s
# 276:	learn: 0.0566192	total: 1.26s	remaining: 3.29s
# 277:	learn: 0.0563648	total: 1.26s	remaining: 3.29s
# 278:	learn: 0.0561514	total: 1.27s	remaining: 3.28s
# 279:	learn: 0.0560949	total: 1.27s	remaining: 3.27s
# 280:	learn: 0.0559932	total: 1.28s	remaining: 3.27s
# 281:	learn: 0.0557615	total: 1.28s	remaining: 3.27s
# 282:	learn: 0.0556558	total: 1.29s	remaining: 3.26s
# 283:	learn: 0.0554090	total: 1.29s	remaining: 3.25s
# 284:	learn: 0.0551659	total: 1.29s	remaining: 3.25s
# 285:	learn: 0.0549357	total: 1.3s	remaining: 3.24s
# 286:	learn: 0.0547102	total: 1.3s	remaining: 3.23s
# 287:	learn: 0.0544837	total: 1.31s	remaining: 3.23s
# 288:	learn: 0.0542603	total: 1.31s	remaining: 3.23s
# 289:	learn: 0.0542317	total: 1.32s	remaining: 3.22s
# 290:	learn: 0.0542010	total: 1.32s	remaining: 3.22s
# 291:	learn: 0.0539842	total: 1.32s	remaining: 3.21s
# 292:	learn: 0.0539579	total: 1.33s	remaining: 3.21s
# 293:	learn: 0.0538141	total: 1.33s	remaining: 3.2s
# 294:	learn: 0.0537503	total: 1.34s	remaining: 3.19s
# 295:	learn: 0.0535796	total: 1.34s	remaining: 3.19s
# 296:	learn: 0.0533604	total: 1.34s	remaining: 3.19s
# 297:	learn: 0.0532005	total: 1.35s	remaining: 3.18s
# 298:	learn: 0.0530044	total: 1.35s	remaining: 3.17s
# 299:	learn: 0.0528095	total: 1.36s	remaining: 3.17s
# 300:	learn: 0.0527400	total: 1.36s	remaining: 3.17s
# 301:	learn: 0.0525368	total: 1.37s	remaining: 3.16s
# 302:	learn: 0.0524964	total: 1.37s	remaining: 3.16s
# 303:	learn: 0.0521813	total: 1.38s	remaining: 3.15s
# 304:	learn: 0.0519915	total: 1.38s	remaining: 3.15s
# 305:	learn: 0.0518063	total: 1.39s	remaining: 3.14s
# 306:	learn: 0.0516301	total: 1.39s	remaining: 3.14s
# 307:	learn: 0.0514634	total: 1.39s	remaining: 3.13s
# 308:	learn: 0.0513431	total: 1.4s	remaining: 3.13s
# 309:	learn: 0.0512208	total: 1.4s	remaining: 3.12s
# 310:	learn: 0.0510313	total: 1.41s	remaining: 3.12s
# 311:	learn: 0.0510016	total: 1.41s	remaining: 3.11s
# 312:	learn: 0.0508389	total: 1.42s	remaining: 3.11s
# 313:	learn: 0.0507762	total: 1.42s	remaining: 3.1s
# 314:	learn: 0.0507567	total: 1.42s	remaining: 3.1s
# 315:	learn: 0.0506004	total: 1.43s	remaining: 3.09s
# 316:	learn: 0.0505669	total: 1.43s	remaining: 3.08s
# 317:	learn: 0.0504945	total: 1.44s	remaining: 3.08s
# 318:	learn: 0.0504648	total: 1.44s	remaining: 3.07s
# 319:	learn: 0.0502400	total: 1.44s	remaining: 3.07s
# 320:	learn: 0.0501906	total: 1.45s	remaining: 3.06s
# 321:	learn: 0.0501571	total: 1.45s	remaining: 3.06s
# 322:	learn: 0.0500038	total: 1.46s	remaining: 3.05s
# 323:	learn: 0.0499927	total: 1.46s	remaining: 3.05s
# 324:	learn: 0.0499650	total: 1.47s	remaining: 3.04s
# 325:	learn: 0.0499364	total: 1.47s	remaining: 3.04s
# 326:	learn: 0.0497708	total: 1.47s	remaining: 3.03s
# 327:	learn: 0.0497523	total: 1.48s	remaining: 3.03s
# 328:	learn: 0.0497286	total: 1.48s	remaining: 3.02s
# 329:	learn: 0.0495655	total: 1.49s	remaining: 3.02s
# 330:	learn: 0.0495260	total: 1.49s	remaining: 3.02s
# 331:	learn: 0.0494697	total: 1.5s	remaining: 3.01s
# 332:	learn: 0.0493425	total: 1.5s	remaining: 3.01s
# 333:	learn: 0.0492748	total: 1.5s	remaining: 3s
# 334:	learn: 0.0491414	total: 1.51s	remaining: 3s
# 335:	learn: 0.0490823	total: 1.51s	remaining: 2.99s
# 336:	learn: 0.0490653	total: 1.52s	remaining: 2.98s
# 337:	learn: 0.0490360	total: 1.52s	remaining: 2.98s
# 338:	learn: 0.0488903	total: 1.52s	remaining: 2.97s
# 339:	learn: 0.0488574	total: 1.53s	remaining: 2.97s
# 340:	learn: 0.0487080	total: 1.53s	remaining: 2.96s
# 341:	learn: 0.0486539	total: 1.54s	remaining: 2.96s
# 342:	learn: 0.0485162	total: 1.54s	remaining: 2.96s
# 343:	learn: 0.0484024	total: 1.55s	remaining: 2.95s
# 344:	learn: 0.0483778	total: 1.55s	remaining: 2.95s
# 345:	learn: 0.0482609	total: 1.56s	remaining: 2.94s
# 346:	learn: 0.0482191	total: 1.56s	remaining: 2.94s
# 347:	learn: 0.0481914	total: 1.57s	remaining: 2.94s
# 348:	learn: 0.0481342	total: 1.57s	remaining: 2.93s
# 349:	learn: 0.0479224	total: 1.57s	remaining: 2.93s
# 350:	learn: 0.0478794	total: 1.58s	remaining: 2.92s
# 351:	learn: 0.0477335	total: 1.58s	remaining: 2.92s
# 352:	learn: 0.0476861	total: 1.59s	remaining: 2.91s
# 353:	learn: 0.0475335	total: 1.59s	remaining: 2.91s
# 354:	learn: 0.0474862	total: 1.6s	remaining: 2.9s
# 355:	learn: 0.0474643	total: 1.6s	remaining: 2.9s
# 356:	learn: 0.0473192	total: 1.6s	remaining: 2.89s
# 357:	learn: 0.0473057	total: 1.61s	remaining: 2.88s
# 358:	learn: 0.0472067	total: 1.61s	remaining: 2.88s
# 359:	learn: 0.0470180	total: 1.62s	remaining: 2.88s
# 360:	learn: 0.0469755	total: 1.62s	remaining: 2.87s
# 361:	learn: 0.0469504	total: 1.63s	remaining: 2.87s
# 362:	learn: 0.0468442	total: 1.63s	remaining: 2.86s
# 363:	learn: 0.0468240	total: 1.63s	remaining: 2.86s
# 364:	learn: 0.0466879	total: 1.64s	remaining: 2.85s
# 365:	learn: 0.0466584	total: 1.64s	remaining: 2.85s
# 366:	learn: 0.0464924	total: 1.65s	remaining: 2.84s
# 367:	learn: 0.0464415	total: 1.65s	remaining: 2.84s
# 368:	learn: 0.0463159	total: 1.66s	remaining: 2.83s
# 369:	learn: 0.0462966	total: 1.66s	remaining: 2.83s
# 370:	learn: 0.0461505	total: 1.66s	remaining: 2.82s
# 371:	learn: 0.0461233	total: 1.67s	remaining: 2.82s
# 372:	learn: 0.0459147	total: 1.67s	remaining: 2.81s
# 373:	learn: 0.0458936	total: 1.68s	remaining: 2.81s
# 374:	learn: 0.0458718	total: 1.68s	remaining: 2.8s
# 375:	learn: 0.0458177	total: 1.69s	remaining: 2.8s
# 376:	learn: 0.0457935	total: 1.69s	remaining: 2.79s
# 377:	learn: 0.0456799	total: 1.69s	remaining: 2.79s
# 378:	learn: 0.0456513	total: 1.7s	remaining: 2.78s
# 379:	learn: 0.0455253	total: 1.7s	remaining: 2.78s
# 380:	learn: 0.0454863	total: 1.71s	remaining: 2.77s
# 381:	learn: 0.0453463	total: 1.71s	remaining: 2.77s
# 382:	learn: 0.0453177	total: 1.72s	remaining: 2.77s
# 383:	learn: 0.0451978	total: 1.72s	remaining: 2.76s
# 384:	learn: 0.0450850	total: 1.73s	remaining: 2.76s
# 385:	learn: 0.0450633	total: 1.73s	remaining: 2.75s
# 386:	learn: 0.0449457	total: 1.74s	remaining: 2.75s
# 387:	learn: 0.0448800	total: 1.74s	remaining: 2.75s
# 388:	learn: 0.0447668	total: 1.75s	remaining: 2.74s
# 389:	learn: 0.0447327	total: 1.75s	remaining: 2.74s
# 390:	learn: 0.0447102	total: 1.75s	remaining: 2.73s
# 391:	learn: 0.0445996	total: 1.76s	remaining: 2.73s
# 392:	learn: 0.0445823	total: 1.76s	remaining: 2.72s
# 393:	learn: 0.0445466	total: 1.77s	remaining: 2.72s
# 394:	learn: 0.0443178	total: 1.77s	remaining: 2.71s
# 395:	learn: 0.0442780	total: 1.77s	remaining: 2.71s
# 396:	learn: 0.0441488	total: 1.78s	remaining: 2.7s
# 397:	learn: 0.0440327	total: 1.78s	remaining: 2.69s
# 398:	learn: 0.0439293	total: 1.78s	remaining: 2.69s
# 399:	learn: 0.0439073	total: 1.79s	remaining: 2.69s
# 400:	learn: 0.0438774	total: 1.79s	remaining: 2.68s
# 401:	learn: 0.0438444	total: 1.8s	remaining: 2.68s
# 402:	learn: 0.0437434	total: 1.8s	remaining: 2.67s
# 403:	learn: 0.0436457	total: 1.81s	remaining: 2.67s
# 404:	learn: 0.0436037	total: 1.81s	remaining: 2.66s
# 405:	learn: 0.0435661	total: 1.82s	remaining: 2.66s
# 406:	learn: 0.0434542	total: 1.82s	remaining: 2.66s
# 407:	learn: 0.0434249	total: 1.83s	remaining: 2.65s
# 408:	learn: 0.0433068	total: 1.83s	remaining: 2.65s
# 409:	learn: 0.0432023	total: 1.84s	remaining: 2.65s
# 410:	learn: 0.0431788	total: 1.84s	remaining: 2.64s
# 411:	learn: 0.0430799	total: 1.85s	remaining: 2.64s
# 412:	learn: 0.0429503	total: 1.85s	remaining: 2.63s
# 413:	learn: 0.0428620	total: 1.86s	remaining: 2.63s
# 414:	learn: 0.0427783	total: 1.86s	remaining: 2.62s
# 415:	learn: 0.0426092	total: 1.86s	remaining: 2.62s
# 416:	learn: 0.0425092	total: 1.87s	remaining: 2.61s
# 417:	learn: 0.0424242	total: 1.87s	remaining: 2.61s
# 418:	learn: 0.0423330	total: 1.88s	remaining: 2.6s
# 419:	learn: 0.0421712	total: 1.88s	remaining: 2.6s
# 420:	learn: 0.0421238	total: 1.88s	remaining: 2.59s
# 421:	learn: 0.0420792	total: 1.89s	remaining: 2.59s
# 422:	learn: 0.0419903	total: 1.89s	remaining: 2.58s
# 423:	learn: 0.0419433	total: 1.9s	remaining: 2.58s
# 424:	learn: 0.0418583	total: 1.9s	remaining: 2.57s
# 425:	learn: 0.0418148	total: 1.9s	remaining: 2.56s
# 426:	learn: 0.0417893	total: 1.91s	remaining: 2.56s
# 427:	learn: 0.0416981	total: 1.91s	remaining: 2.55s
# 428:	learn: 0.0416005	total: 1.91s	remaining: 2.55s
# 429:	learn: 0.0415467	total: 1.92s	remaining: 2.54s
# 430:	learn: 0.0415172	total: 1.92s	remaining: 2.54s
# 431:	learn: 0.0414347	total: 1.93s	remaining: 2.53s
# 432:	learn: 0.0413675	total: 1.93s	remaining: 2.53s
# 433:	learn: 0.0413328	total: 1.93s	remaining: 2.52s
# 434:	learn: 0.0413014	total: 1.94s	remaining: 2.52s
# 435:	learn: 0.0412203	total: 1.94s	remaining: 2.51s
# 436:	learn: 0.0412090	total: 1.95s	remaining: 2.5s
# 437:	learn: 0.0411241	total: 1.95s	remaining: 2.5s
# 438:	learn: 0.0410793	total: 1.95s	remaining: 2.5s
# 439:	learn: 0.0410463	total: 1.96s	remaining: 2.49s
# 440:	learn: 0.0410178	total: 1.96s	remaining: 2.48s
# 441:	learn: 0.0409917	total: 1.96s	remaining: 2.48s
# 442:	learn: 0.0409127	total: 1.97s	remaining: 2.48s
# 443:	learn: 0.0407901	total: 1.98s	remaining: 2.48s
# 444:	learn: 0.0407227	total: 1.98s	remaining: 2.47s
# 445:	learn: 0.0406770	total: 1.99s	remaining: 2.47s
# 446:	learn: 0.0406446	total: 1.99s	remaining: 2.46s
# 447:	learn: 0.0406184	total: 2s	remaining: 2.46s
# 448:	learn: 0.0405805	total: 2s	remaining: 2.45s
# 449:	learn: 0.0405008	total: 2s	remaining: 2.45s
# 450:	learn: 0.0404771	total: 2.01s	remaining: 2.44s
# 451:	learn: 0.0403877	total: 2.01s	remaining: 2.44s
# 452:	learn: 0.0403642	total: 2.02s	remaining: 2.44s
# 453:	learn: 0.0402352	total: 2.02s	remaining: 2.43s
# 454:	learn: 0.0401770	total: 2.02s	remaining: 2.43s
# 455:	learn: 0.0401505	total: 2.03s	remaining: 2.42s
# 456:	learn: 0.0401341	total: 2.03s	remaining: 2.42s
# 457:	learn: 0.0401015	total: 2.04s	remaining: 2.41s
# 458:	learn: 0.0400741	total: 2.04s	remaining: 2.41s
# 459:	learn: 0.0400516	total: 2.04s	remaining: 2.4s
# 460:	learn: 0.0399008	total: 2.05s	remaining: 2.4s
# 461:	learn: 0.0397885	total: 2.05s	remaining: 2.39s
# 462:	learn: 0.0397647	total: 2.06s	remaining: 2.39s
# 463:	learn: 0.0396941	total: 2.06s	remaining: 2.38s
# 464:	learn: 0.0396598	total: 2.07s	remaining: 2.38s
# 465:	learn: 0.0395337	total: 2.07s	remaining: 2.37s
# 466:	learn: 0.0395092	total: 2.08s	remaining: 2.37s
# 467:	learn: 0.0394867	total: 2.08s	remaining: 2.36s
# 468:	learn: 0.0394669	total: 2.08s	remaining: 2.36s
# 469:	learn: 0.0394128	total: 2.09s	remaining: 2.35s
# 470:	learn: 0.0393989	total: 2.09s	remaining: 2.35s
# 471:	learn: 0.0392795	total: 2.1s	remaining: 2.35s
# 472:	learn: 0.0392072	total: 2.1s	remaining: 2.34s
# 473:	learn: 0.0391863	total: 2.1s	remaining: 2.33s
# 474:	learn: 0.0391581	total: 2.11s	remaining: 2.33s
# 475:	learn: 0.0390929	total: 2.11s	remaining: 2.33s
# 476:	learn: 0.0390669	total: 2.12s	remaining: 2.32s
# 477:	learn: 0.0390024	total: 2.12s	remaining: 2.32s
# 478:	learn: 0.0389504	total: 2.13s	remaining: 2.31s
# 479:	learn: 0.0389272	total: 2.13s	remaining: 2.31s
# 480:	learn: 0.0388914	total: 2.13s	remaining: 2.3s
# 481:	learn: 0.0388174	total: 2.14s	remaining: 2.3s
# 482:	learn: 0.0387550	total: 2.14s	remaining: 2.29s
# 483:	learn: 0.0386941	total: 2.15s	remaining: 2.29s
# 484:	learn: 0.0386315	total: 2.15s	remaining: 2.28s
# 485:	learn: 0.0385976	total: 2.15s	remaining: 2.28s
# 486:	learn: 0.0385735	total: 2.16s	remaining: 2.28s
# 487:	learn: 0.0385541	total: 2.17s	remaining: 2.27s
# 488:	learn: 0.0385217	total: 2.17s	remaining: 2.27s
# 489:	learn: 0.0384954	total: 2.18s	remaining: 2.26s
# 490:	learn: 0.0384890	total: 2.18s	remaining: 2.26s
# 491:	learn: 0.0384296	total: 2.18s	remaining: 2.25s
# 492:	learn: 0.0383351	total: 2.19s	remaining: 2.25s
# 493:	learn: 0.0383139	total: 2.19s	remaining: 2.25s
# 494:	learn: 0.0382837	total: 2.19s	remaining: 2.24s
# 495:	learn: 0.0382499	total: 2.2s	remaining: 2.23s
# 496:	learn: 0.0382421	total: 2.2s	remaining: 2.23s
# 497:	learn: 0.0382081	total: 2.21s	remaining: 2.23s
# 498:	learn: 0.0380861	total: 2.21s	remaining: 2.22s
# 499:	learn: 0.0380537	total: 2.22s	remaining: 2.22s
# 500:	learn: 0.0380362	total: 2.22s	remaining: 2.21s
# 501:	learn: 0.0379811	total: 2.22s	remaining: 2.21s
# 502:	learn: 0.0379226	total: 2.23s	remaining: 2.2s
# 503:	learn: 0.0379034	total: 2.23s	remaining: 2.2s
# 504:	learn: 0.0378794	total: 2.24s	remaining: 2.19s
# 505:	learn: 0.0378553	total: 2.24s	remaining: 2.19s
# 506:	learn: 0.0378298	total: 2.25s	remaining: 2.18s
# 507:	learn: 0.0377973	total: 2.25s	remaining: 2.18s
# 508:	learn: 0.0377799	total: 2.25s	remaining: 2.17s
# 509:	learn: 0.0377574	total: 2.26s	remaining: 2.17s
# 510:	learn: 0.0376787	total: 2.26s	remaining: 2.16s
# 511:	learn: 0.0376573	total: 2.27s	remaining: 2.16s
# 512:	learn: 0.0376323	total: 2.27s	remaining: 2.15s
# 513:	learn: 0.0375582	total: 2.27s	remaining: 2.15s
# 514:	learn: 0.0375037	total: 2.28s	remaining: 2.14s
# 515:	learn: 0.0374839	total: 2.28s	remaining: 2.14s
# 516:	learn: 0.0373978	total: 2.29s	remaining: 2.13s
# 517:	learn: 0.0373445	total: 2.29s	remaining: 2.13s
# 518:	learn: 0.0373303	total: 2.29s	remaining: 2.13s
# 519:	learn: 0.0372783	total: 2.3s	remaining: 2.12s
# 520:	learn: 0.0372522	total: 2.3s	remaining: 2.12s
# 521:	learn: 0.0371318	total: 2.31s	remaining: 2.11s
# 522:	learn: 0.0370936	total: 2.31s	remaining: 2.1s
# 523:	learn: 0.0369949	total: 2.31s	remaining: 2.1s
# 524:	learn: 0.0369744	total: 2.32s	remaining: 2.1s
# 525:	learn: 0.0369568	total: 2.32s	remaining: 2.09s
# 526:	learn: 0.0369326	total: 2.32s	remaining: 2.09s
# 527:	learn: 0.0369071	total: 2.33s	remaining: 2.08s
# 528:	learn: 0.0368935	total: 2.33s	remaining: 2.08s
# 529:	learn: 0.0368799	total: 2.34s	remaining: 2.07s
# 530:	learn: 0.0368625	total: 2.34s	remaining: 2.07s
# 531:	learn: 0.0367951	total: 2.34s	remaining: 2.06s
# 532:	learn: 0.0367723	total: 2.35s	remaining: 2.06s
# 533:	learn: 0.0367444	total: 2.35s	remaining: 2.05s
# 534:	learn: 0.0366950	total: 2.35s	remaining: 2.05s
# 535:	learn: 0.0366786	total: 2.36s	remaining: 2.04s
# 536:	learn: 0.0366117	total: 2.36s	remaining: 2.04s
# 537:	learn: 0.0365821	total: 2.37s	remaining: 2.03s
# 538:	learn: 0.0365574	total: 2.37s	remaining: 2.03s
# 539:	learn: 0.0364611	total: 2.37s	remaining: 2.02s
# 540:	learn: 0.0364413	total: 2.38s	remaining: 2.02s
# 541:	learn: 0.0364144	total: 2.38s	remaining: 2.01s
# 542:	learn: 0.0363911	total: 2.38s	remaining: 2.01s
# 543:	learn: 0.0363787	total: 2.39s	remaining: 2s
# 544:	learn: 0.0363474	total: 2.39s	remaining: 2s
# 545:	learn: 0.0362472	total: 2.4s	remaining: 1.99s
# 546:	learn: 0.0361969	total: 2.4s	remaining: 1.99s
# 547:	learn: 0.0360818	total: 2.4s	remaining: 1.98s
# 548:	learn: 0.0360629	total: 2.41s	remaining: 1.98s
# 549:	learn: 0.0360081	total: 2.42s	remaining: 1.98s
# 550:	learn: 0.0359915	total: 2.42s	remaining: 1.97s
# 551:	learn: 0.0359777	total: 2.42s	remaining: 1.97s
# 552:	learn: 0.0359298	total: 2.43s	remaining: 1.96s
# 553:	learn: 0.0358785	total: 2.43s	remaining: 1.96s
# 554:	learn: 0.0358634	total: 2.43s	remaining: 1.95s
# 555:	learn: 0.0358364	total: 2.44s	remaining: 1.95s
# 556:	learn: 0.0357820	total: 2.44s	remaining: 1.94s
# 557:	learn: 0.0357568	total: 2.44s	remaining: 1.94s
# 558:	learn: 0.0357056	total: 2.45s	remaining: 1.93s
# 559:	learn: 0.0356769	total: 2.45s	remaining: 1.93s
# 560:	learn: 0.0356326	total: 2.46s	remaining: 1.92s
# 561:	learn: 0.0356209	total: 2.46s	remaining: 1.92s
# 562:	learn: 0.0355042	total: 2.46s	remaining: 1.91s
# 563:	learn: 0.0354599	total: 2.47s	remaining: 1.91s
# 564:	learn: 0.0354490	total: 2.47s	remaining: 1.9s
# 565:	learn: 0.0353740	total: 2.48s	remaining: 1.9s
# 566:	learn: 0.0353298	total: 2.48s	remaining: 1.89s
# 567:	learn: 0.0352712	total: 2.48s	remaining: 1.89s
# 568:	learn: 0.0352263	total: 2.49s	remaining: 1.88s
# 569:	learn: 0.0351962	total: 2.49s	remaining: 1.88s
# 570:	learn: 0.0351729	total: 2.49s	remaining: 1.87s
# 571:	learn: 0.0351537	total: 2.5s	remaining: 1.87s
# 572:	learn: 0.0350600	total: 2.5s	remaining: 1.86s
# 573:	learn: 0.0350466	total: 2.51s	remaining: 1.86s
# 574:	learn: 0.0350048	total: 2.51s	remaining: 1.85s
# 575:	learn: 0.0348964	total: 2.51s	remaining: 1.85s
# 576:	learn: 0.0348797	total: 2.52s	remaining: 1.84s
# 577:	learn: 0.0348059	total: 2.52s	remaining: 1.84s
# 578:	learn: 0.0347912	total: 2.52s	remaining: 1.84s
# 579:	learn: 0.0347667	total: 2.53s	remaining: 1.83s
# 580:	learn: 0.0347619	total: 2.53s	remaining: 1.83s
# 581:	learn: 0.0346595	total: 2.54s	remaining: 1.82s
# 582:	learn: 0.0346164	total: 2.54s	remaining: 1.82s
# 583:	learn: 0.0345751	total: 2.54s	remaining: 1.81s
# 584:	learn: 0.0345511	total: 2.55s	remaining: 1.81s
# 585:	learn: 0.0345334	total: 2.55s	remaining: 1.8s
# 586:	learn: 0.0344526	total: 2.56s	remaining: 1.8s
# 587:	learn: 0.0344279	total: 2.56s	remaining: 1.79s
# 588:	learn: 0.0343624	total: 2.56s	remaining: 1.79s
# 589:	learn: 0.0343421	total: 2.57s	remaining: 1.78s
# 590:	learn: 0.0343292	total: 2.57s	remaining: 1.78s
# 591:	learn: 0.0343254	total: 2.57s	remaining: 1.77s
# 592:	learn: 0.0343079	total: 2.58s	remaining: 1.77s
# 593:	learn: 0.0342685	total: 2.58s	remaining: 1.76s
# 594:	learn: 0.0342570	total: 2.58s	remaining: 1.76s
# 595:	learn: 0.0342350	total: 2.59s	remaining: 1.75s
# 596:	learn: 0.0341808	total: 2.59s	remaining: 1.75s
# 597:	learn: 0.0340662	total: 2.6s	remaining: 1.75s
# 598:	learn: 0.0339838	total: 2.6s	remaining: 1.74s
# 599:	learn: 0.0339452	total: 2.6s	remaining: 1.74s
# 600:	learn: 0.0339274	total: 2.61s	remaining: 1.73s
# 601:	learn: 0.0339071	total: 2.61s	remaining: 1.73s
# 602:	learn: 0.0338889	total: 2.62s	remaining: 1.72s
# 603:	learn: 0.0338158	total: 2.62s	remaining: 1.72s
# 604:	learn: 0.0337386	total: 2.63s	remaining: 1.71s
# 605:	learn: 0.0337175	total: 2.63s	remaining: 1.71s
# 606:	learn: 0.0337057	total: 2.63s	remaining: 1.71s
# 607:	learn: 0.0336611	total: 2.64s	remaining: 1.7s
# 608:	learn: 0.0336114	total: 2.64s	remaining: 1.7s
# 609:	learn: 0.0335986	total: 2.64s	remaining: 1.69s
# 610:	learn: 0.0335875	total: 2.65s	remaining: 1.69s
# 611:	learn: 0.0335025	total: 2.65s	remaining: 1.68s
# 612:	learn: 0.0334913	total: 2.66s	remaining: 1.68s
# 613:	learn: 0.0334782	total: 2.66s	remaining: 1.67s
# 614:	learn: 0.0334544	total: 2.66s	remaining: 1.67s
# 615:	learn: 0.0334322	total: 2.67s	remaining: 1.66s
# 616:	learn: 0.0333930	total: 2.67s	remaining: 1.66s
# 617:	learn: 0.0333714	total: 2.68s	remaining: 1.65s
# 618:	learn: 0.0333313	total: 2.68s	remaining: 1.65s
# 619:	learn: 0.0333155	total: 2.68s	remaining: 1.65s
# 620:	learn: 0.0332310	total: 2.69s	remaining: 1.64s
# 621:	learn: 0.0332196	total: 2.69s	remaining: 1.64s
# 622:	learn: 0.0331669	total: 2.69s	remaining: 1.63s
# 623:	learn: 0.0331153	total: 2.7s	remaining: 1.63s
# 624:	learn: 0.0330427	total: 2.7s	remaining: 1.62s
# 625:	learn: 0.0330321	total: 2.71s	remaining: 1.62s
# 626:	learn: 0.0330177	total: 2.71s	remaining: 1.61s
# 627:	learn: 0.0329678	total: 2.71s	remaining: 1.61s
# 628:	learn: 0.0329532	total: 2.72s	remaining: 1.6s
# 629:	learn: 0.0329044	total: 2.72s	remaining: 1.6s
# 630:	learn: 0.0328873	total: 2.72s	remaining: 1.59s
# 631:	learn: 0.0328436	total: 2.73s	remaining: 1.59s
# 632:	learn: 0.0328054	total: 2.73s	remaining: 1.58s
# 633:	learn: 0.0327804	total: 2.73s	remaining: 1.58s
# 634:	learn: 0.0327163	total: 2.74s	remaining: 1.57s
# 635:	learn: 0.0326475	total: 2.74s	remaining: 1.57s
# 636:	learn: 0.0325626	total: 2.75s	remaining: 1.56s
# 637:	learn: 0.0325140	total: 2.75s	remaining: 1.56s
# 638:	learn: 0.0324213	total: 2.75s	remaining: 1.56s
# 639:	learn: 0.0323344	total: 2.76s	remaining: 1.55s
# 640:	learn: 0.0322874	total: 2.76s	remaining: 1.55s
# 641:	learn: 0.0322752	total: 2.77s	remaining: 1.54s
# 642:	learn: 0.0322623	total: 2.77s	remaining: 1.54s
# 643:	learn: 0.0322535	total: 2.77s	remaining: 1.53s
# 644:	learn: 0.0322350	total: 2.78s	remaining: 1.53s
# 645:	learn: 0.0322152	total: 2.78s	remaining: 1.52s
# 646:	learn: 0.0322044	total: 2.78s	remaining: 1.52s
# 647:	learn: 0.0321645	total: 2.79s	remaining: 1.51s
# 648:	learn: 0.0321393	total: 2.79s	remaining: 1.51s
# 649:	learn: 0.0320956	total: 2.79s	remaining: 1.5s
# 650:	learn: 0.0320571	total: 2.8s	remaining: 1.5s
# 651:	learn: 0.0320191	total: 2.8s	remaining: 1.5s
# 652:	learn: 0.0320079	total: 2.81s	remaining: 1.49s
# 653:	learn: 0.0319701	total: 2.81s	remaining: 1.49s
# 654:	learn: 0.0319520	total: 2.81s	remaining: 1.48s
# 655:	learn: 0.0318556	total: 2.82s	remaining: 1.48s
# 656:	learn: 0.0318428	total: 2.82s	remaining: 1.47s
# 657:	learn: 0.0318092	total: 2.83s	remaining: 1.47s
# 658:	learn: 0.0317861	total: 2.83s	remaining: 1.46s
# 659:	learn: 0.0317546	total: 2.83s	remaining: 1.46s
# 660:	learn: 0.0317170	total: 2.84s	remaining: 1.45s
# 661:	learn: 0.0316806	total: 2.84s	remaining: 1.45s
# 662:	learn: 0.0316292	total: 2.84s	remaining: 1.45s
# 663:	learn: 0.0315920	total: 2.85s	remaining: 1.44s
# 664:	learn: 0.0315712	total: 2.85s	remaining: 1.44s
# 665:	learn: 0.0315384	total: 2.85s	remaining: 1.43s
# 666:	learn: 0.0315253	total: 2.86s	remaining: 1.43s
# 667:	learn: 0.0315140	total: 2.86s	remaining: 1.42s
# 668:	learn: 0.0314996	total: 2.87s	remaining: 1.42s
# 669:	learn: 0.0314338	total: 2.87s	remaining: 1.41s
# 670:	learn: 0.0313983	total: 2.87s	remaining: 1.41s
# 671:	learn: 0.0313603	total: 2.88s	remaining: 1.4s
# 672:	learn: 0.0313397	total: 2.88s	remaining: 1.4s
# 673:	learn: 0.0313098	total: 2.88s	remaining: 1.39s
# 674:	learn: 0.0312999	total: 2.89s	remaining: 1.39s
# 675:	learn: 0.0312927	total: 2.89s	remaining: 1.39s
# 676:	learn: 0.0312792	total: 2.9s	remaining: 1.38s
# 677:	learn: 0.0312589	total: 2.9s	remaining: 1.38s
# 678:	learn: 0.0312423	total: 2.9s	remaining: 1.37s
# 679:	learn: 0.0312193	total: 2.91s	remaining: 1.37s
# 680:	learn: 0.0311694	total: 2.91s	remaining: 1.36s
# 681:	learn: 0.0311000	total: 2.91s	remaining: 1.36s
# 682:	learn: 0.0310610	total: 2.92s	remaining: 1.35s
# 683:	learn: 0.0310472	total: 2.92s	remaining: 1.35s
# 684:	learn: 0.0310084	total: 2.92s	remaining: 1.34s
# 685:	learn: 0.0310012	total: 2.93s	remaining: 1.34s
# 686:	learn: 0.0309737	total: 2.93s	remaining: 1.33s
# 687:	learn: 0.0309084	total: 2.94s	remaining: 1.33s
# 688:	learn: 0.0308949	total: 2.94s	remaining: 1.33s
# 689:	learn: 0.0308659	total: 2.94s	remaining: 1.32s
# 690:	learn: 0.0308366	total: 2.95s	remaining: 1.32s
# 691:	learn: 0.0308162	total: 2.95s	remaining: 1.31s
# 692:	learn: 0.0307636	total: 2.95s	remaining: 1.31s
# 693:	learn: 0.0307273	total: 2.96s	remaining: 1.3s
# 694:	learn: 0.0306666	total: 2.96s	remaining: 1.3s
# 695:	learn: 0.0306538	total: 2.96s	remaining: 1.29s
# 696:	learn: 0.0306230	total: 2.97s	remaining: 1.29s
# 697:	learn: 0.0305845	total: 2.97s	remaining: 1.29s
# 698:	learn: 0.0305652	total: 2.98s	remaining: 1.28s
# 699:	learn: 0.0305053	total: 2.98s	remaining: 1.28s
# 700:	learn: 0.0304558	total: 2.98s	remaining: 1.27s
# 701:	learn: 0.0304350	total: 2.99s	remaining: 1.27s
# 702:	learn: 0.0304208	total: 2.99s	remaining: 1.26s
# 703:	learn: 0.0304099	total: 2.99s	remaining: 1.26s
# 704:	learn: 0.0303959	total: 3s	remaining: 1.25s
# 705:	learn: 0.0303362	total: 3s	remaining: 1.25s
# 706:	learn: 0.0303074	total: 3.01s	remaining: 1.25s
# 707:	learn: 0.0302142	total: 3.01s	remaining: 1.24s
# 708:	learn: 0.0301938	total: 3.01s	remaining: 1.24s
# 709:	learn: 0.0301351	total: 3.02s	remaining: 1.23s
# 710:	learn: 0.0301182	total: 3.02s	remaining: 1.23s
# 711:	learn: 0.0300620	total: 3.02s	remaining: 1.22s
# 712:	learn: 0.0300438	total: 3.03s	remaining: 1.22s
# 713:	learn: 0.0299924	total: 3.03s	remaining: 1.21s
# 714:	learn: 0.0299828	total: 3.04s	remaining: 1.21s
# 715:	learn: 0.0299590	total: 3.04s	remaining: 1.21s
# 716:	learn: 0.0299463	total: 3.04s	remaining: 1.2s
# 717:	learn: 0.0298913	total: 3.05s	remaining: 1.2s
# 718:	learn: 0.0298306	total: 3.05s	remaining: 1.19s
# 719:	learn: 0.0297959	total: 3.05s	remaining: 1.19s
# 720:	learn: 0.0297874	total: 3.06s	remaining: 1.18s
# 721:	learn: 0.0297735	total: 3.06s	remaining: 1.18s
# 722:	learn: 0.0297551	total: 3.06s	remaining: 1.17s
# 723:	learn: 0.0297225	total: 3.07s	remaining: 1.17s
# 724:	learn: 0.0296939	total: 3.07s	remaining: 1.17s
# 725:	learn: 0.0296457	total: 3.08s	remaining: 1.16s
# 726:	learn: 0.0296140	total: 3.08s	remaining: 1.16s
# 727:	learn: 0.0295867	total: 3.08s	remaining: 1.15s
# 728:	learn: 0.0295487	total: 3.09s	remaining: 1.15s
# 729:	learn: 0.0295394	total: 3.09s	remaining: 1.14s
# 730:	learn: 0.0295237	total: 3.09s	remaining: 1.14s
# 731:	learn: 0.0295008	total: 3.1s	remaining: 1.13s
# 732:	learn: 0.0294865	total: 3.1s	remaining: 1.13s
# 733:	learn: 0.0294737	total: 3.1s	remaining: 1.13s
# 734:	learn: 0.0294183	total: 3.11s	remaining: 1.12s
# 735:	learn: 0.0293903	total: 3.11s	remaining: 1.12s
# 736:	learn: 0.0293689	total: 3.12s	remaining: 1.11s
# 737:	learn: 0.0293444	total: 3.12s	remaining: 1.11s
# 738:	learn: 0.0293071	total: 3.12s	remaining: 1.1s
# 739:	learn: 0.0292927	total: 3.13s	remaining: 1.1s
# 740:	learn: 0.0292745	total: 3.13s	remaining: 1.09s
# 741:	learn: 0.0292567	total: 3.13s	remaining: 1.09s
# 742:	learn: 0.0292016	total: 3.14s	remaining: 1.08s
# 743:	learn: 0.0291823	total: 3.14s	remaining: 1.08s
# 744:	learn: 0.0291563	total: 3.15s	remaining: 1.08s
# 745:	learn: 0.0291417	total: 3.15s	remaining: 1.07s
# 746:	learn: 0.0291076	total: 3.15s	remaining: 1.07s
# 747:	learn: 0.0290845	total: 3.16s	remaining: 1.06s
# 748:	learn: 0.0290252	total: 3.16s	remaining: 1.06s
# 749:	learn: 0.0289929	total: 3.16s	remaining: 1.05s
# 750:	learn: 0.0289761	total: 3.17s	remaining: 1.05s
# 751:	learn: 0.0289633	total: 3.17s	remaining: 1.05s
# 752:	learn: 0.0289387	total: 3.17s	remaining: 1.04s
# 753:	learn: 0.0289250	total: 3.18s	remaining: 1.04s
# 754:	learn: 0.0288941	total: 3.18s	remaining: 1.03s
# 755:	learn: 0.0288645	total: 3.19s	remaining: 1.03s
# 756:	learn: 0.0288457	total: 3.19s	remaining: 1.02s
# 757:	learn: 0.0288313	total: 3.19s	remaining: 1.02s
# 758:	learn: 0.0288189	total: 3.2s	remaining: 1.01s
# 759:	learn: 0.0287888	total: 3.2s	remaining: 1.01s
# 760:	learn: 0.0287652	total: 3.21s	remaining: 1.01s
# 761:	learn: 0.0287529	total: 3.21s	remaining: 1s
# 762:	learn: 0.0287252	total: 3.21s	remaining: 998ms
# 763:	learn: 0.0286723	total: 3.22s	remaining: 994ms
# 764:	learn: 0.0286538	total: 3.22s	remaining: 989ms
# 765:	learn: 0.0286076	total: 3.22s	remaining: 985ms
# 766:	learn: 0.0285766	total: 3.23s	remaining: 981ms
# 767:	learn: 0.0285606	total: 3.23s	remaining: 976ms
# 768:	learn: 0.0285337	total: 3.23s	remaining: 972ms
# 769:	learn: 0.0285208	total: 3.24s	remaining: 968ms
# 770:	learn: 0.0285023	total: 3.24s	remaining: 963ms
# 771:	learn: 0.0284940	total: 3.25s	remaining: 959ms
# 772:	learn: 0.0284792	total: 3.25s	remaining: 954ms
# 773:	learn: 0.0284689	total: 3.25s	remaining: 950ms
# 774:	learn: 0.0284286	total: 3.26s	remaining: 946ms
# 775:	learn: 0.0284128	total: 3.26s	remaining: 941ms
# 776:	learn: 0.0284031	total: 3.27s	remaining: 937ms
# 777:	learn: 0.0283796	total: 3.27s	remaining: 933ms
# 778:	learn: 0.0283617	total: 3.27s	remaining: 928ms
# 779:	learn: 0.0283515	total: 3.28s	remaining: 924ms
# 780:	learn: 0.0283289	total: 3.28s	remaining: 920ms
# 781:	learn: 0.0283013	total: 3.28s	remaining: 915ms
# 782:	learn: 0.0282344	total: 3.29s	remaining: 911ms
# 783:	learn: 0.0282043	total: 3.29s	remaining: 907ms
# 784:	learn: 0.0281967	total: 3.29s	remaining: 902ms
# 785:	learn: 0.0281811	total: 3.3s	remaining: 898ms
# 786:	learn: 0.0281711	total: 3.3s	remaining: 894ms
# 787:	learn: 0.0281655	total: 3.31s	remaining: 889ms
# 788:	learn: 0.0281455	total: 3.31s	remaining: 885ms
# 789:	learn: 0.0281304	total: 3.31s	remaining: 881ms
# 790:	learn: 0.0281194	total: 3.32s	remaining: 876ms
# 791:	learn: 0.0280970	total: 3.32s	remaining: 872ms
# 792:	learn: 0.0280637	total: 3.32s	remaining: 868ms
# 793:	learn: 0.0280521	total: 3.33s	remaining: 863ms
# 794:	learn: 0.0280409	total: 3.33s	remaining: 859ms
# 795:	learn: 0.0280284	total: 3.33s	remaining: 855ms
# 796:	learn: 0.0280193	total: 3.34s	remaining: 851ms
# 797:	learn: 0.0280083	total: 3.34s	remaining: 846ms
# 798:	learn: 0.0279934	total: 3.35s	remaining: 842ms
# 799:	learn: 0.0279649	total: 3.35s	remaining: 838ms
# 800:	learn: 0.0279387	total: 3.35s	remaining: 833ms
# 801:	learn: 0.0279040	total: 3.36s	remaining: 829ms
# 802:	learn: 0.0278962	total: 3.36s	remaining: 825ms
# 803:	learn: 0.0278854	total: 3.37s	remaining: 820ms
# 804:	learn: 0.0278712	total: 3.37s	remaining: 816ms
# 805:	learn: 0.0278431	total: 3.37s	remaining: 812ms
# 806:	learn: 0.0278326	total: 3.38s	remaining: 808ms
# 807:	learn: 0.0278165	total: 3.38s	remaining: 803ms
# 808:	learn: 0.0277928	total: 3.38s	remaining: 799ms
# 809:	learn: 0.0277732	total: 3.39s	remaining: 795ms
# 810:	learn: 0.0277598	total: 3.39s	remaining: 790ms
# 811:	learn: 0.0277478	total: 3.4s	remaining: 786ms
# 812:	learn: 0.0277383	total: 3.4s	remaining: 782ms
# 813:	learn: 0.0276993	total: 3.4s	remaining: 778ms
# 814:	learn: 0.0276871	total: 3.41s	remaining: 773ms
# 815:	learn: 0.0276629	total: 3.41s	remaining: 769ms
# 816:	learn: 0.0276359	total: 3.41s	remaining: 765ms
# 817:	learn: 0.0275976	total: 3.42s	remaining: 760ms
# 818:	learn: 0.0275857	total: 3.42s	remaining: 756ms
# 819:	learn: 0.0275705	total: 3.42s	remaining: 752ms
# 820:	learn: 0.0275437	total: 3.43s	remaining: 748ms
# 821:	learn: 0.0275195	total: 3.43s	remaining: 743ms
# 822:	learn: 0.0274908	total: 3.44s	remaining: 739ms
# 823:	learn: 0.0274770	total: 3.44s	remaining: 735ms
# 824:	learn: 0.0274563	total: 3.44s	remaining: 731ms
# 825:	learn: 0.0274433	total: 3.45s	remaining: 726ms
# 826:	learn: 0.0274305	total: 3.45s	remaining: 722ms
# 827:	learn: 0.0274139	total: 3.46s	remaining: 718ms
# 828:	learn: 0.0274023	total: 3.46s	remaining: 714ms
# 829:	learn: 0.0273617	total: 3.46s	remaining: 709ms
# 830:	learn: 0.0273495	total: 3.47s	remaining: 705ms
# 831:	learn: 0.0273274	total: 3.47s	remaining: 701ms
# 832:	learn: 0.0272770	total: 3.47s	remaining: 697ms
# 833:	learn: 0.0272619	total: 3.48s	remaining: 692ms
# 834:	learn: 0.0272206	total: 3.48s	remaining: 688ms
# 835:	learn: 0.0271797	total: 3.48s	remaining: 684ms
# 836:	learn: 0.0271236	total: 3.49s	remaining: 680ms
# 837:	learn: 0.0271149	total: 3.49s	remaining: 675ms
# 838:	learn: 0.0270550	total: 3.5s	remaining: 671ms
# 839:	learn: 0.0270299	total: 3.5s	remaining: 667ms
# 840:	learn: 0.0270122	total: 3.5s	remaining: 663ms
# 841:	learn: 0.0269891	total: 3.51s	remaining: 658ms
# 842:	learn: 0.0269819	total: 3.51s	remaining: 654ms
# 843:	learn: 0.0269634	total: 3.52s	remaining: 650ms
# 844:	learn: 0.0269316	total: 3.52s	remaining: 645ms
# 845:	learn: 0.0269236	total: 3.52s	remaining: 641ms
# 846:	learn: 0.0269124	total: 3.53s	remaining: 637ms
# 847:	learn: 0.0268781	total: 3.53s	remaining: 633ms
# 848:	learn: 0.0268442	total: 3.53s	remaining: 629ms
# 849:	learn: 0.0268161	total: 3.54s	remaining: 624ms
# 850:	learn: 0.0267986	total: 3.54s	remaining: 620ms
# 851:	learn: 0.0267892	total: 3.54s	remaining: 616ms
# 852:	learn: 0.0267619	total: 3.55s	remaining: 612ms
# 853:	learn: 0.0267501	total: 3.55s	remaining: 608ms
# 854:	learn: 0.0267395	total: 3.56s	remaining: 603ms
# 855:	learn: 0.0267239	total: 3.56s	remaining: 599ms
# 856:	learn: 0.0266898	total: 3.56s	remaining: 595ms
# 857:	learn: 0.0266802	total: 3.57s	remaining: 591ms
# 858:	learn: 0.0266616	total: 3.57s	remaining: 586ms
# 859:	learn: 0.0266392	total: 3.58s	remaining: 582ms
# 860:	learn: 0.0266163	total: 3.58s	remaining: 578ms
# 861:	learn: 0.0266062	total: 3.58s	remaining: 574ms
# 862:	learn: 0.0265306	total: 3.59s	remaining: 570ms
# 863:	learn: 0.0265009	total: 3.59s	remaining: 565ms
# 864:	learn: 0.0264262	total: 3.6s	remaining: 561ms
# 865:	learn: 0.0263437	total: 3.6s	remaining: 557ms
# 866:	learn: 0.0262805	total: 3.6s	remaining: 553ms
# 867:	learn: 0.0262645	total: 3.61s	remaining: 549ms
# 868:	learn: 0.0262439	total: 3.61s	remaining: 544ms
# 869:	learn: 0.0262269	total: 3.61s	remaining: 540ms
# 870:	learn: 0.0261914	total: 3.62s	remaining: 536ms
# 871:	learn: 0.0261702	total: 3.62s	remaining: 532ms
# 872:	learn: 0.0261474	total: 3.63s	remaining: 527ms
# 873:	learn: 0.0261364	total: 3.63s	remaining: 523ms
# 874:	learn: 0.0261034	total: 3.63s	remaining: 519ms
# 875:	learn: 0.0260785	total: 3.64s	remaining: 515ms
# 876:	learn: 0.0260547	total: 3.64s	remaining: 511ms
# 877:	learn: 0.0260337	total: 3.64s	remaining: 506ms
# 878:	learn: 0.0260089	total: 3.65s	remaining: 502ms
# 879:	learn: 0.0259992	total: 3.65s	remaining: 498ms
# 880:	learn: 0.0259878	total: 3.65s	remaining: 494ms
# 881:	learn: 0.0259801	total: 3.66s	remaining: 490ms
# 882:	learn: 0.0259547	total: 3.66s	remaining: 485ms
# 883:	learn: 0.0259478	total: 3.67s	remaining: 481ms
# 884:	learn: 0.0259351	total: 3.67s	remaining: 477ms
# 885:	learn: 0.0259198	total: 3.67s	remaining: 473ms
# 886:	learn: 0.0259123	total: 3.68s	remaining: 469ms
# 887:	learn: 0.0258511	total: 3.68s	remaining: 464ms
# 888:	learn: 0.0258433	total: 3.69s	remaining: 460ms
# 889:	learn: 0.0258239	total: 3.69s	remaining: 456ms
# 890:	learn: 0.0258092	total: 3.69s	remaining: 452ms
# 891:	learn: 0.0258020	total: 3.7s	remaining: 448ms
# 892:	learn: 0.0257786	total: 3.7s	remaining: 443ms
# 893:	learn: 0.0257746	total: 3.7s	remaining: 439ms
# 894:	learn: 0.0257678	total: 3.71s	remaining: 435ms
# 895:	learn: 0.0257460	total: 3.71s	remaining: 431ms
# 896:	learn: 0.0257224	total: 3.71s	remaining: 427ms
# 897:	learn: 0.0257075	total: 3.72s	remaining: 422ms
# 898:	learn: 0.0256947	total: 3.72s	remaining: 418ms
# 899:	learn: 0.0256852	total: 3.73s	remaining: 414ms
# 900:	learn: 0.0256792	total: 3.73s	remaining: 410ms
# 901:	learn: 0.0256565	total: 3.73s	remaining: 406ms
# 902:	learn: 0.0256490	total: 3.74s	remaining: 401ms
# 903:	learn: 0.0256256	total: 3.74s	remaining: 397ms
# 904:	learn: 0.0256038	total: 3.74s	remaining: 393ms
# 905:	learn: 0.0255900	total: 3.75s	remaining: 389ms
# 906:	learn: 0.0255608	total: 3.75s	remaining: 385ms
# 907:	learn: 0.0255502	total: 3.76s	remaining: 381ms
# 908:	learn: 0.0255374	total: 3.76s	remaining: 376ms
# 909:	learn: 0.0255252	total: 3.76s	remaining: 372ms
# 910:	learn: 0.0254901	total: 3.77s	remaining: 368ms
# 911:	learn: 0.0254774	total: 3.77s	remaining: 364ms
# 912:	learn: 0.0254393	total: 3.77s	remaining: 360ms
# 913:	learn: 0.0254128	total: 3.78s	remaining: 356ms
# 914:	learn: 0.0254007	total: 3.78s	remaining: 351ms
# 915:	learn: 0.0253907	total: 3.79s	remaining: 347ms
# 916:	learn: 0.0253807	total: 3.79s	remaining: 343ms
# 917:	learn: 0.0253143	total: 3.79s	remaining: 339ms
# 918:	learn: 0.0252987	total: 3.8s	remaining: 335ms
# 919:	learn: 0.0252775	total: 3.8s	remaining: 331ms
# 920:	learn: 0.0252004	total: 3.8s	remaining: 326ms
# 921:	learn: 0.0251876	total: 3.81s	remaining: 322ms
# 922:	learn: 0.0251698	total: 3.81s	remaining: 318ms
# 923:	learn: 0.0251523	total: 3.81s	remaining: 314ms
# 924:	learn: 0.0251276	total: 3.82s	remaining: 310ms
# 925:	learn: 0.0251165	total: 3.82s	remaining: 305ms
# 926:	learn: 0.0250944	total: 3.83s	remaining: 301ms
# ...
# 694:	learn: 0.0330015	total: 3.37s	remaining: 1.48s
# 695:	learn: 0.0329880	total: 3.38s	remaining: 1.47s
# 696:	learn: 0.0329745	total: 3.38s	remaining: 1.47s
# 697:	learn: 0.0329072	total: 3.38s	remaining: 1.46s
# 698:	learn: 0.0328594	total: 3.39s	remaining: 1.46s
# 699:	learn: 0.0327796	total: 3.39s	remaining: 1.45s
# 700:	learn: 0.0327670	total: 3.4s	remaining: 1.45s
# 701:	learn: 0.0327373	total: 3.4s	remaining: 1.44s
# 702:	learn: 0.0327112	total: 3.41s	remaining: 1.44s
# 703:	learn: 0.0326896	total: 3.41s	remaining: 1.43s
# 704:	learn: 0.0326140	total: 3.42s	remaining: 1.43s
# 705:	learn: 0.0325925	total: 3.42s	remaining: 1.42s
# 706:	learn: 0.0325726	total: 3.42s	remaining: 1.42s
# 707:	learn: 0.0325536	total: 3.43s	remaining: 1.41s
# 708:	learn: 0.0325398	total: 3.43s	remaining: 1.41s
# 709:	learn: 0.0325052	total: 3.44s	remaining: 1.4s
# 710:	learn: 0.0324125	total: 3.44s	remaining: 1.4s
# 711:	learn: 0.0323661	total: 3.45s	remaining: 1.4s
# 712:	learn: 0.0323466	total: 3.45s	remaining: 1.39s
# 713:	learn: 0.0322624	total: 3.46s	remaining: 1.39s
# 714:	learn: 0.0322386	total: 3.46s	remaining: 1.38s
# 715:	learn: 0.0322004	total: 3.47s	remaining: 1.38s
# 716:	learn: 0.0321550	total: 3.47s	remaining: 1.37s
# 717:	learn: 0.0321367	total: 3.48s	remaining: 1.36s
# 718:	learn: 0.0321060	total: 3.48s	remaining: 1.36s
# 719:	learn: 0.0320263	total: 3.48s	remaining: 1.35s
# 720:	learn: 0.0320087	total: 3.49s	remaining: 1.35s
# 721:	learn: 0.0319245	total: 3.49s	remaining: 1.34s
# 722:	learn: 0.0319017	total: 3.5s	remaining: 1.34s
# 723:	learn: 0.0318849	total: 3.5s	remaining: 1.33s
# 724:	learn: 0.0318678	total: 3.51s	remaining: 1.33s
# 725:	learn: 0.0317810	total: 3.51s	remaining: 1.32s
# 726:	learn: 0.0317220	total: 3.52s	remaining: 1.32s
# 727:	learn: 0.0316692	total: 3.52s	remaining: 1.32s
# 728:	learn: 0.0316587	total: 3.53s	remaining: 1.31s
# 729:	learn: 0.0316154	total: 3.53s	remaining: 1.31s
# 730:	learn: 0.0316023	total: 3.54s	remaining: 1.3s
# 731:	learn: 0.0315408	total: 3.54s	remaining: 1.3s
# 732:	learn: 0.0315365	total: 3.55s	remaining: 1.29s
# 733:	learn: 0.0314788	total: 3.55s	remaining: 1.29s
# 734:	learn: 0.0314561	total: 3.56s	remaining: 1.28s
# 735:	learn: 0.0314397	total: 3.56s	remaining: 1.28s
# 736:	learn: 0.0314204	total: 3.56s	remaining: 1.27s
# 737:	learn: 0.0313734	total: 3.57s	remaining: 1.27s
# 738:	learn: 0.0312846	total: 3.57s	remaining: 1.26s
# 739:	learn: 0.0312432	total: 3.58s	remaining: 1.26s
# 740:	learn: 0.0312070	total: 3.58s	remaining: 1.25s
# 741:	learn: 0.0311555	total: 3.59s	remaining: 1.25s
# 742:	learn: 0.0311101	total: 3.59s	remaining: 1.24s
# 743:	learn: 0.0310859	total: 3.6s	remaining: 1.24s
# 744:	learn: 0.0310745	total: 3.6s	remaining: 1.23s
# 745:	learn: 0.0309940	total: 3.61s	remaining: 1.23s
# 746:	learn: 0.0309861	total: 3.61s	remaining: 1.22s
# 747:	learn: 0.0309550	total: 3.62s	remaining: 1.22s
# 748:	learn: 0.0309461	total: 3.62s	remaining: 1.21s
# 749:	learn: 0.0309359	total: 3.63s	remaining: 1.21s
# 750:	learn: 0.0309035	total: 3.63s	remaining: 1.2s
# 751:	learn: 0.0308564	total: 3.64s	remaining: 1.2s
# 752:	learn: 0.0308421	total: 3.64s	remaining: 1.2s
# 753:	learn: 0.0308238	total: 3.65s	remaining: 1.19s
# 754:	learn: 0.0308115	total: 3.65s	remaining: 1.19s
# 755:	learn: 0.0307774	total: 3.66s	remaining: 1.18s
# 756:	learn: 0.0307529	total: 3.66s	remaining: 1.18s
# 757:	learn: 0.0306774	total: 3.67s	remaining: 1.17s
# 758:	learn: 0.0306602	total: 3.67s	remaining: 1.17s
# 759:	learn: 0.0306219	total: 3.67s	remaining: 1.16s
# 760:	learn: 0.0305820	total: 3.68s	remaining: 1.16s
# 761:	learn: 0.0305466	total: 3.69s	remaining: 1.15s
# 762:	learn: 0.0305338	total: 3.69s	remaining: 1.15s
# 763:	learn: 0.0305266	total: 3.69s	remaining: 1.14s
# 764:	learn: 0.0305036	total: 3.7s	remaining: 1.14s
# 765:	learn: 0.0304669	total: 3.7s	remaining: 1.13s
# 766:	learn: 0.0304086	total: 3.71s	remaining: 1.13s
# 767:	learn: 0.0303981	total: 3.71s	remaining: 1.12s
# 768:	learn: 0.0303553	total: 3.72s	remaining: 1.12s
# 769:	learn: 0.0303217	total: 3.72s	remaining: 1.11s
# 770:	learn: 0.0303034	total: 3.73s	remaining: 1.11s
# 771:	learn: 0.0302857	total: 3.73s	remaining: 1.1s
# 772:	learn: 0.0302708	total: 3.74s	remaining: 1.1s
# 773:	learn: 0.0302356	total: 3.74s	remaining: 1.09s
# 774:	learn: 0.0301944	total: 3.75s	remaining: 1.09s
# 775:	learn: 0.0301591	total: 3.75s	remaining: 1.08s
# 776:	learn: 0.0301520	total: 3.76s	remaining: 1.08s
# 777:	learn: 0.0300950	total: 3.77s	remaining: 1.07s
# 778:	learn: 0.0300584	total: 3.77s	remaining: 1.07s
# 779:	learn: 0.0300230	total: 3.78s	remaining: 1.06s
# 780:	learn: 0.0299999	total: 3.78s	remaining: 1.06s
# 781:	learn: 0.0299847	total: 3.79s	remaining: 1.05s
# 782:	learn: 0.0299797	total: 3.79s	remaining: 1.05s
# 783:	learn: 0.0299253	total: 3.8s	remaining: 1.05s
# 784:	learn: 0.0299039	total: 3.8s	remaining: 1.04s
# 785:	learn: 0.0298913	total: 3.81s	remaining: 1.04s
# 786:	learn: 0.0298696	total: 3.81s	remaining: 1.03s
# 787:	learn: 0.0298386	total: 3.82s	remaining: 1.03s
# 788:	learn: 0.0298252	total: 3.82s	remaining: 1.02s
# 789:	learn: 0.0297617	total: 3.83s	remaining: 1.02s
# 790:	learn: 0.0297337	total: 3.83s	remaining: 1.01s
# 791:	learn: 0.0297205	total: 3.84s	remaining: 1.01s
# 792:	learn: 0.0297077	total: 3.84s	remaining: 1s
# 793:	learn: 0.0296906	total: 3.85s	remaining: 998ms
# 794:	learn: 0.0296680	total: 3.85s	remaining: 993ms
# 795:	learn: 0.0296234	total: 3.86s	remaining: 989ms
# 796:	learn: 0.0295825	total: 3.86s	remaining: 984ms
# 797:	learn: 0.0295569	total: 3.87s	remaining: 979ms
# 798:	learn: 0.0295410	total: 3.87s	remaining: 974ms
# 799:	learn: 0.0295273	total: 3.88s	remaining: 969ms
# 800:	learn: 0.0295116	total: 3.88s	remaining: 964ms
# 801:	learn: 0.0294992	total: 3.89s	remaining: 960ms
# 802:	learn: 0.0294780	total: 3.89s	remaining: 955ms
# 803:	learn: 0.0294574	total: 3.9s	remaining: 950ms
# 804:	learn: 0.0294552	total: 3.9s	remaining: 945ms
# 805:	learn: 0.0294403	total: 3.9s	remaining: 940ms
# 806:	learn: 0.0293984	total: 3.91s	remaining: 935ms
# 807:	learn: 0.0293728	total: 3.92s	remaining: 930ms
# 808:	learn: 0.0293623	total: 3.92s	remaining: 926ms
# 809:	learn: 0.0293275	total: 3.92s	remaining: 921ms
# 810:	learn: 0.0292824	total: 3.93s	remaining: 916ms
# 811:	learn: 0.0292757	total: 3.93s	remaining: 911ms
# 812:	learn: 0.0292569	total: 3.94s	remaining: 906ms
# 813:	learn: 0.0292516	total: 3.94s	remaining: 901ms
# 814:	learn: 0.0292330	total: 3.95s	remaining: 896ms
# 815:	learn: 0.0292103	total: 3.95s	remaining: 891ms
# 816:	learn: 0.0291796	total: 3.96s	remaining: 886ms
# 817:	learn: 0.0291623	total: 3.96s	remaining: 882ms
# 818:	learn: 0.0291592	total: 3.97s	remaining: 877ms
# 819:	learn: 0.0291355	total: 3.97s	remaining: 872ms
# 820:	learn: 0.0291186	total: 3.98s	remaining: 867ms
# 821:	learn: 0.0290745	total: 3.98s	remaining: 862ms
# 822:	learn: 0.0290492	total: 3.98s	remaining: 857ms
# 823:	learn: 0.0290190	total: 3.99s	remaining: 852ms
# 824:	learn: 0.0289932	total: 4s	remaining: 847ms
# 825:	learn: 0.0289773	total: 4s	remaining: 843ms
# 826:	learn: 0.0289269	total: 4s	remaining: 838ms
# 827:	learn: 0.0288885	total: 4.01s	remaining: 833ms
# 828:	learn: 0.0288390	total: 4.01s	remaining: 828ms
# 829:	learn: 0.0287906	total: 4.02s	remaining: 823ms
# 830:	learn: 0.0287786	total: 4.02s	remaining: 818ms
# 831:	learn: 0.0287634	total: 4.03s	remaining: 813ms
# 832:	learn: 0.0287404	total: 4.03s	remaining: 808ms
# 833:	learn: 0.0287287	total: 4.04s	remaining: 804ms
# 834:	learn: 0.0286815	total: 4.04s	remaining: 799ms
# 835:	learn: 0.0286350	total: 4.05s	remaining: 794ms
# 836:	learn: 0.0285759	total: 4.05s	remaining: 789ms
# 837:	learn: 0.0285680	total: 4.06s	remaining: 784ms
# 838:	learn: 0.0285598	total: 4.06s	remaining: 779ms
# 839:	learn: 0.0285243	total: 4.07s	remaining: 774ms
# 840:	learn: 0.0285147	total: 4.07s	remaining: 769ms
# 841:	learn: 0.0284778	total: 4.07s	remaining: 765ms
# 842:	learn: 0.0284330	total: 4.08s	remaining: 760ms
# 843:	learn: 0.0284039	total: 4.08s	remaining: 755ms
# 844:	learn: 0.0284016	total: 4.09s	remaining: 750ms
# 845:	learn: 0.0283258	total: 4.09s	remaining: 745ms
# 846:	learn: 0.0282692	total: 4.1s	remaining: 741ms
# 847:	learn: 0.0282541	total: 4.11s	remaining: 736ms
# 848:	learn: 0.0282493	total: 4.11s	remaining: 731ms
# 849:	learn: 0.0281953	total: 4.12s	remaining: 726ms
# 850:	learn: 0.0281806	total: 4.12s	remaining: 721ms
# 851:	learn: 0.0281502	total: 4.12s	remaining: 716ms
# 852:	learn: 0.0281352	total: 4.13s	remaining: 712ms
# 853:	learn: 0.0281034	total: 4.13s	remaining: 707ms
# 854:	learn: 0.0280878	total: 4.14s	remaining: 702ms
# 855:	learn: 0.0280604	total: 4.14s	remaining: 697ms
# 856:	learn: 0.0280515	total: 4.15s	remaining: 693ms
# 857:	learn: 0.0280326	total: 4.16s	remaining: 688ms
# 858:	learn: 0.0280242	total: 4.16s	remaining: 683ms
# 859:	learn: 0.0280155	total: 4.17s	remaining: 678ms
# 860:	learn: 0.0279920	total: 4.17s	remaining: 674ms
# 861:	learn: 0.0279631	total: 4.18s	remaining: 669ms
# 862:	learn: 0.0279421	total: 4.18s	remaining: 664ms
# 863:	learn: 0.0279277	total: 4.19s	remaining: 659ms
# 864:	learn: 0.0279154	total: 4.19s	remaining: 654ms
# 865:	learn: 0.0278890	total: 4.2s	remaining: 649ms
# 866:	learn: 0.0278613	total: 4.2s	remaining: 645ms
# 867:	learn: 0.0278548	total: 4.21s	remaining: 640ms
# 868:	learn: 0.0278410	total: 4.21s	remaining: 635ms
# 869:	learn: 0.0278304	total: 4.22s	remaining: 630ms
# 870:	learn: 0.0278054	total: 4.22s	remaining: 625ms
# 871:	learn: 0.0277995	total: 4.23s	remaining: 620ms
# 872:	learn: 0.0277827	total: 4.23s	remaining: 616ms
# 873:	learn: 0.0277662	total: 4.24s	remaining: 611ms
# 874:	learn: 0.0277437	total: 4.24s	remaining: 606ms
# 875:	learn: 0.0277377	total: 4.25s	remaining: 601ms
# 876:	learn: 0.0276645	total: 4.25s	remaining: 596ms
# 877:	learn: 0.0276474	total: 4.25s	remaining: 591ms
# 878:	learn: 0.0276413	total: 4.26s	remaining: 586ms
# 879:	learn: 0.0275851	total: 4.26s	remaining: 581ms
# 880:	learn: 0.0275680	total: 4.27s	remaining: 577ms
# 881:	learn: 0.0275416	total: 4.27s	remaining: 572ms
# 882:	learn: 0.0275231	total: 4.28s	remaining: 567ms
# 883:	learn: 0.0274845	total: 4.28s	remaining: 562ms
# 884:	learn: 0.0274604	total: 4.29s	remaining: 557ms
# 885:	learn: 0.0274546	total: 4.29s	remaining: 552ms
# 886:	learn: 0.0274438	total: 4.29s	remaining: 547ms
# 887:	learn: 0.0274290	total: 4.3s	remaining: 542ms
# 888:	learn: 0.0274235	total: 4.3s	remaining: 537ms
# 889:	learn: 0.0274124	total: 4.31s	remaining: 533ms
# 890:	learn: 0.0273981	total: 4.31s	remaining: 528ms
# 891:	learn: 0.0273796	total: 4.32s	remaining: 523ms
# 892:	learn: 0.0273523	total: 4.32s	remaining: 518ms
# 893:	learn: 0.0273376	total: 4.33s	remaining: 513ms
# 894:	learn: 0.0273317	total: 4.33s	remaining: 508ms
# 895:	learn: 0.0273182	total: 4.34s	remaining: 503ms
# 896:	learn: 0.0273063	total: 4.34s	remaining: 498ms
# 897:	learn: 0.0272844	total: 4.34s	remaining: 494ms
# 898:	learn: 0.0272723	total: 4.35s	remaining: 489ms
# 899:	learn: 0.0272139	total: 4.35s	remaining: 484ms
# 900:	learn: 0.0271970	total: 4.36s	remaining: 479ms
# 901:	learn: 0.0271830	total: 4.36s	remaining: 474ms
# 902:	learn: 0.0271614	total: 4.37s	remaining: 469ms
# 903:	learn: 0.0271421	total: 4.37s	remaining: 464ms
# 904:	learn: 0.0271120	total: 4.38s	remaining: 460ms
# 905:	learn: 0.0270844	total: 4.38s	remaining: 455ms
# 906:	learn: 0.0270823	total: 4.39s	remaining: 450ms
# 907:	learn: 0.0270765	total: 4.39s	remaining: 445ms
# 908:	learn: 0.0270630	total: 4.4s	remaining: 440ms
# 909:	learn: 0.0270437	total: 4.4s	remaining: 435ms
# 910:	learn: 0.0270288	total: 4.41s	remaining: 431ms
# 911:	learn: 0.0270144	total: 4.41s	remaining: 426ms
# 912:	learn: 0.0269963	total: 4.42s	remaining: 421ms
# 913:	learn: 0.0269746	total: 4.42s	remaining: 416ms
# 914:	learn: 0.0269528	total: 4.43s	remaining: 411ms
# 915:	learn: 0.0269370	total: 4.43s	remaining: 406ms
# 916:	learn: 0.0269248	total: 4.44s	remaining: 402ms
# 917:	learn: 0.0269119	total: 4.44s	remaining: 397ms
# 918:	learn: 0.0268584	total: 4.45s	remaining: 392ms
# 919:	learn: 0.0268451	total: 4.45s	remaining: 387ms
# 920:	learn: 0.0268178	total: 4.46s	remaining: 382ms
# 921:	learn: 0.0268091	total: 4.46s	remaining: 377ms
# 922:	learn: 0.0268014	total: 4.47s	remaining: 373ms
# 923:	learn: 0.0267737	total: 4.47s	remaining: 368ms
# 924:	learn: 0.0267507	total: 4.48s	remaining: 363ms
# 925:	learn: 0.0267298	total: 4.48s	remaining: 358ms
# 926:	learn: 0.0267197	total: 4.49s	remaining: 353ms
# 927:	learn: 0.0266997	total: 4.49s	remaining: 348ms
# 928:	learn: 0.0266716	total: 4.5s	remaining: 344ms
# 929:	learn: 0.0266601	total: 4.5s	remaining: 339ms
# 930:	learn: 0.0266347	total: 4.5s	remaining: 334ms
# 931:	learn: 0.0266249	total: 4.51s	remaining: 329ms
# 932:	learn: 0.0266132	total: 4.51s	remaining: 324ms
# 933:	learn: 0.0265837	total: 4.52s	remaining: 319ms
# 934:	learn: 0.0265245	total: 4.52s	remaining: 314ms
# 935:	learn: 0.0265103	total: 4.53s	remaining: 310ms
# 936:	learn: 0.0264979	total: 4.53s	remaining: 305ms
# 937:	learn: 0.0264671	total: 4.54s	remaining: 300ms
# 938:	learn: 0.0264326	total: 4.54s	remaining: 295ms
# 939:	learn: 0.0263949	total: 4.55s	remaining: 290ms
# 940:	learn: 0.0263841	total: 4.55s	remaining: 286ms
# 941:	learn: 0.0263471	total: 4.56s	remaining: 281ms
# 942:	learn: 0.0263441	total: 4.56s	remaining: 276ms
# 943:	learn: 0.0263350	total: 4.57s	remaining: 271ms
# 944:	learn: 0.0263106	total: 4.57s	remaining: 266ms
# 945:	learn: 0.0262895	total: 4.58s	remaining: 261ms
# 946:	learn: 0.0262802	total: 4.58s	remaining: 256ms
# 947:	learn: 0.0262633	total: 4.59s	remaining: 252ms
# 948:	learn: 0.0262499	total: 4.59s	remaining: 247ms
# 949:	learn: 0.0262094	total: 4.59s	remaining: 242ms
# 950:	learn: 0.0261981	total: 4.6s	remaining: 237ms
# 951:	learn: 0.0261775	total: 4.6s	remaining: 232ms
# 952:	learn: 0.0261678	total: 4.61s	remaining: 227ms
# 953:	learn: 0.0261399	total: 4.61s	remaining: 222ms
# 954:	learn: 0.0261284	total: 4.62s	remaining: 218ms
# 955:	learn: 0.0261113	total: 4.62s	remaining: 213ms
# 956:	learn: 0.0261089	total: 4.63s	remaining: 208ms
# 957:	learn: 0.0260956	total: 4.63s	remaining: 203ms
# 958:	learn: 0.0260860	total: 4.64s	remaining: 198ms
# 959:	learn: 0.0260731	total: 4.64s	remaining: 193ms
# 960:	learn: 0.0260542	total: 4.64s	remaining: 189ms
# 961:	learn: 0.0259967	total: 4.65s	remaining: 184ms
# 962:	learn: 0.0259733	total: 4.65s	remaining: 179ms
# 963:	learn: 0.0259690	total: 4.66s	remaining: 174ms
# 964:	learn: 0.0259406	total: 4.66s	remaining: 169ms
# 965:	learn: 0.0258797	total: 4.67s	remaining: 164ms
# 966:	learn: 0.0258665	total: 4.67s	remaining: 159ms
# 967:	learn: 0.0258473	total: 4.68s	remaining: 155ms
# 968:	learn: 0.0258327	total: 4.68s	remaining: 150ms
# 969:	learn: 0.0257931	total: 4.68s	remaining: 145ms
# 970:	learn: 0.0257702	total: 4.69s	remaining: 140ms
# 971:	learn: 0.0257241	total: 4.7s	remaining: 135ms
# 972:	learn: 0.0257173	total: 4.7s	remaining: 130ms
# 973:	learn: 0.0257096	total: 4.7s	remaining: 126ms
# 974:	learn: 0.0256776	total: 4.71s	remaining: 121ms
# 975:	learn: 0.0256602	total: 4.71s	remaining: 116ms
# 976:	learn: 0.0256430	total: 4.72s	remaining: 111ms
# 977:	learn: 0.0256258	total: 4.72s	remaining: 106ms
# 978:	learn: 0.0256008	total: 4.73s	remaining: 101ms
# 979:	learn: 0.0255580	total: 4.73s	remaining: 96.6ms
# 980:	learn: 0.0255503	total: 4.74s	remaining: 91.8ms
# 981:	learn: 0.0255341	total: 4.74s	remaining: 86.9ms
# 982:	learn: 0.0255181	total: 4.75s	remaining: 82.1ms
# 983:	learn: 0.0255056	total: 4.75s	remaining: 77.3ms
# 984:	learn: 0.0254953	total: 4.76s	remaining: 72.4ms
# 985:	learn: 0.0254708	total: 4.76s	remaining: 67.6ms
# 986:	learn: 0.0254480	total: 4.77s	remaining: 62.8ms
# 987:	learn: 0.0254435	total: 4.77s	remaining: 58ms
# 988:	learn: 0.0254290	total: 4.78s	remaining: 53.1ms
# 989:	learn: 0.0254181	total: 4.78s	remaining: 48.3ms
# 990:	learn: 0.0254133	total: 4.79s	remaining: 43.5ms
# 991:	learn: 0.0253975	total: 4.79s	remaining: 38.6ms
# 992:	learn: 0.0253901	total: 4.8s	remaining: 33.8ms
# 993:	learn: 0.0253375	total: 4.8s	remaining: 29ms
# 994:	learn: 0.0253353	total: 4.81s	remaining: 24.2ms
# 995:	learn: 0.0253233	total: 4.81s	remaining: 19.3ms
# 996:	learn: 0.0252936	total: 4.82s	remaining: 14.5ms
# 997:	learn: 0.0252776	total: 4.82s	remaining: 9.66ms
# 998:	learn: 0.0252685	total: 4.83s	remaining: 4.83ms
# 999:	learn: 0.0252510	total: 4.83s	remaining: 0us
# 99.97474897779631 					 99.93101579042079
# 99.97504178940693 99.92204093788337

# %%
result.head()
# Out:
#               0             1             2             3             4  \
# 0   3263.035450   3307.536365   3262.666605   3251.032851   3236.946554
# 1   1897.268197   1920.187623   1898.884050   1865.234449   1857.906111
# 2  11760.596057  11653.840860  11930.113953  12029.894604  11853.554928
# 3   9426.759798   9480.514877   9205.376718   9261.792337   9449.759053
# 4   5701.657172   5748.347325   5842.515037   5765.659053   5817.667165
#
#               5             6             7             8
# 0   3294.007276   3239.532000   3226.890131   3252.084084
# 1   1882.109988   1885.145467   1911.330835   1942.956865
# 2  11904.560259  11904.521205  11989.720756  11758.798564
# 3   9412.812787   9327.877998   9424.886153   9405.630234
# 4   5776.260357   5747.140882   5788.796235   5683.458050

# %%
result1 = np.mean(result,axis=1)

# %%
sample.head()
# Out:
#          Product_id  Selling_Price
# 0  SCHE4YSTDVPVZVXW    3294.594688
# 1  ACCEGCATKHNRXUHW    1945.603968
# 2  NKCE6GJ5XVJDXNNZ   11871.830880
# 3  NKCEB8BK3ZXDHDHM    9421.143424
# 4  TOPEFDXSAHRNPF94    5717.420625

# %%
final = pd.DataFrame(index = range(len(z)),columns=['Product_id','Selling_Price'])

# %%
final.Product_id = z
final.Selling_Price = result1

# %%
final
# Out:
#             Product_id  Selling_Price
# 0     SCHE4YSTDVPVZVXW    3259.303480
# 1     ACCEGCATKHNRXUHW    1895.669287
# 2     NKCE6GJ5XVJDXNNZ   11865.066798
# 3     NKCEB8BK3ZXDHDHM    9377.267773
# 4     TOPEFDXSAHRNPF94    5763.500142
# 5     ACCE558KZHEPZYMG    9694.856397
# 6     ACCEAZCVAMFHDPY7    5322.183653
# 7     NKCDYNY37JPBGBVM    2530.388605
# 8     NKCEY8KWY33FCUYD    7517.923141
# 9     RNGE4YPTQYRECV9J    4643.985456
# 10    NKCE88AHBHJZREXH    3905.509395
# 11    CLTEJ5ZZGBP4JGGE    7469.881797
# 12    WATE3NWH5FZWAMDA    8098.388361
# 13    CAGE53FSFZVFPFHQ    1739.034617
# 14    PCSEAKVBFFPGCHNZ    3811.111248
# 15    WATDFFH3KJYBTYGG    7480.950386
# 16    NKCDWHFQSCHHYZMP    2763.469583
# 17    RNGEB2PG3Q5RKDW6    3441.571372
# 18    NKCE5UY9HHPZGGUZ    4410.487188
# 19    KTAEHETW3ZCMFMJR    4092.919769
# 20    BRAEBBYRVF9MHJHU    7734.819252
# 21    NKCEAX7HAQ2RJA3Q   10261.324642
# 22    CRTECN2RQZWBSP9W    5018.836803
# 23    WATDEWZ9UHSEHGZG    9464.197919
# 24    PTPEYW8HNV6G9YYR    2818.315460
# 25    ACCEAMGZRRYVAHDC    4985.776057
# 26    SRTEHHXG8MUXTGPA    6016.125185
# 27    SKIE4S4NN4MHYM3Z    4898.635355
# 28    HMBE7G34YHWPWKYN    7157.793708
# 29    LLIEGTMFJBD7ZZZM   13733.121875
# ...                ...            ...
# 3400  CBKEHJUH7WPZEEGK    6377.594013
# 3401  CRTECN2QXZUFSGHZ    5158.173312
# 3402  SWSEBHCPAKWKRDPR    9348.956399
# 3403  ACCEAMGZGAQWYYMV    3965.268066
# 3404  CRTECN2QZGUQPR93    3957.621637
# 3405  SHOEJBSZ8FS9SNJR     438.744056
# 3406  BRAE6ZCHV2ZAA9US    3286.774592
# 3407  SUDEGGB28WWTGFUY    6738.320530
# 3408  ACCEAHRFFKPGUGGX    4833.101234
# 3409  BRAEBBMQZDMZAEBV    1074.946140
# 3410  NKCED6EXXSFZGQP8     329.888268
# 3411  SHTECN9HFVZYP2V9    3407.894841
# 3412  RTREAX3DGDRSSYFT    1423.364047
# 3413  RNGE65FGK2TMUC2A    9496.131087
# 3414  ACCEGZ8EWQ7RMZTZ    6883.575394
# 3415  BRAE4DHZEAPXQVRG    1789.859450
# 3416  CAGECHKFAMZCKPFT     158.918019
# 3417  PCSE6SJG9SMAGGHY    3892.526249
# 3418  SNDE25SG2HRJF9JH    1185.776841
# 3419  NKCEAVZ3FCDEUZHG    5375.289002
# 3420  ACCEG7AG8EUZRRZY    6331.311210
# 3421  SHOECH3WZHFCVZWU    3828.468443
# 3422  TOPEAKYKZKRHPMHX    3729.174641
# 3423  NDNEJRAZNQBZQWQK   12862.629854
# 3424  MUGEBFGFDQYJG5TW    5440.069605
# 3425  BBAE9K7BXFUTDNBK    3891.801729
# 3426  RTRDYPA4PJHCJCGF    9434.177911
# 3427  TUNE8FWQBS7TVVT7    5965.952050
# 3428  NKCEGMUABCRGUZPE    3518.928165
# 3429  RNGE7M92KAQWUBCS     999.233420
#
# [3430 rows x 2 columns]

# %%
final.to_csv('multi_model_cat4.csv',index=False)
