# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import catboost as cat
import ngboost as ng
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold, train_test_split
from sklearn.ensemble import *
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_log_error, mean_squared_error
import xgboost as xgb
import lightgbm as lgb
import warnings
warnings.filterwarnings(action='ignore')

# %%
train = pd.read_csv(r'C:\Users\Rahul\Desktop\HackerEarth-Machine-Learning-Challenge-Carnival-Wars\train.csv')
test = pd.read_csv(r'C:\Users\Rahul\Desktop\HackerEarth-Machine-Learning-Challenge-Carnival-Wars\test.csv')
sample = pd.read_csv(r'C:\Users\Rahul\Desktop\HackerEarth-Machine-Learning-Challenge-Carnival-Wars\sample_submission.csv')
prd_id = test.Product_id
train.rename({'charges_2 (%)':'charges_2'},inplace=True,axis=1)
test.rename({'charges_2 (%)':'charges_2'},inplace=True,axis=1)

# %%
z = np.copy(test.Product_id)
b = pd.DataFrame(np.copy(train),columns=train.columns)

# %%
train.head()
# Out:
#          Product_id  Stall_no             instock_date  Market_Category  \
# 0  BRAE2NF6JA5GUEXG      37.0  2015-08-22 18:36:12.000                2
# 1  TUNE8SFB6RJN2HSD      38.0  2016-03-27 21:19:13.000               24
# 2  BRAEAR7WZPQGPBZU       9.0  2015-08-18 19:25:22.000              447
# 3  WATDZ2ZQ8JPDHCTJ      50.0  2016-03-28 21:53:01.000               23
# 4  JWSEBUKYQPMBZ3RK       7.0  2016-03-29 22:58:53.000               63
#
#   Customer_name Loyalty_customer Product_Category  Grade  Demand  \
# 0      Lillyann              Yes          Fashion      1      68
# 1         Klynn              Yes          Fashion      0      51
# 2         Ridge              Yes       Child_care      0      10
# 3         Abran              Yes      Educational      2      48
# 4        Dustyn              Yes           Repair      1      35
#
#    Discount_avail  charges_1  charges_2  Minimum_price  Maximum_price  \
# 0             0.0      376.0       11.0         2983.0         4713.0
# 1             0.0      397.0       12.0         7495.0        10352.0
# 2             0.0      250.0        9.0         5752.0         7309.0
# 3             0.0      144.0       13.0         5090.0        20814.0
# 4             1.0      211.0        4.0         2430.0         9261.0
#
#    Selling_Price
# 0    4185.947700
# 1    9271.490256
# 2    6785.701362
# 3   13028.917824
# 4     906.553935

# %%
test.head()
# Out:
#          Product_id  Stall_no             instock_date  Market_Category  \
# 0  SCHE4YSTDVPVZVXW      39.0  2016-01-13 07:45:08.000              205
# 1  ACCEGCATKHNRXUHW      49.0  2015-08-23 20:37:05.000                3
# 2  NKCE6GJ5XVJDXNNZ       1.0  2015-11-14 18:12:39.000              183
# 3  NKCEB8BK3ZXDHDHM       8.0  2015-11-21 04:56:19.000              358
# 4  TOPEFDXSAHRNPF94      33.0  2015-05-06 15:09:46.000              167
#
#   Customer_name Loyalty_customer Product_Category  Grade  Demand  \
# 0        Ivanka              No           Fashion      0      90
# 1         Isaak              Yes          Fashion      0      87
# 2      Analiese              No        Technology      2      55
# 3         Rusty              Yes       Child_care      3      86
# 4        Eloise              No        Technology      0      27
#
#    Discount_avail  charges_1  charges_2  Minimum_price  Maximum_price
# 0               0      380.0       16.0         2576.0           3340
# 1               0      393.0       16.0         1202.0           1955
# 2               0      493.0        9.0         7175.0          15715
# 3               0      303.0       16.0         5404.0          13078
# 4               0      567.0       16.0         4069.0           6244

# %%
sample.head()
# Out:
#          Product_id  Selling_Price
# 0  SCHE4YSTDVPVZVXW    3294.594688
# 1  ACCEGCATKHNRXUHW    1945.603968
# 2  NKCE6GJ5XVJDXNNZ   11871.830880
# 3  NKCEB8BK3ZXDHDHM    9421.143424
# 4  TOPEFDXSAHRNPF94    5717.420625

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6368 entries, 0 to 6367
# Data columns (total 15 columns):
# Product_id          6368 non-null object
# Stall_no            6363 non-null float64
# instock_date        6368 non-null object
# Market_Category     6368 non-null int64
# Customer_name       6157 non-null object
# Loyalty_customer    6368 non-null object
# Product_Category    6368 non-null object
# Grade               6368 non-null int64
# Demand              6368 non-null int64
# Discount_avail      6330 non-null float64
# charges_1           6170 non-null float64
# charges_2           6163 non-null float64
# Minimum_price       6330 non-null float64
# Maximum_price       6025 non-null float64
# Selling_Price       6327 non-null float64
# dtypes: float64(7), int64(3), object(5)
# memory usage: 746.3+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3430 entries, 0 to 3429
# Data columns (total 14 columns):
# Product_id          3430 non-null object
# Stall_no            3429 non-null float64
# instock_date        3430 non-null object
# Market_Category     3430 non-null int64
# Customer_name       3377 non-null object
# Loyalty_customer    3430 non-null object
# Product_Category    3430 non-null object
# Grade               3430 non-null int64
# Demand              3430 non-null int64
# Discount_avail      3430 non-null int64
# charges_1           3394 non-null float64
# charges_2           3425 non-null float64
# Minimum_price       3416 non-null float64
# Maximum_price       3430 non-null int64
# dtypes: float64(4), int64(5), object(5)
# memory usage: 375.2+ KB

# %%
train.describe()
# Out:
#           Stall_no  Market_Category        Grade       Demand  Discount_avail  \
# count  6363.000000      6368.000000  6368.000000  6368.000000     6330.000000
# mean     25.309445       199.340609     0.643687    50.921168        0.140442
# std      14.328980       170.275570     1.025092    29.091922        0.347473
# min       1.000000         0.000000     0.000000     1.000000        0.000000
# 25%      13.000000        55.000000     0.000000    26.000000        0.000000
# 50%      25.000000       132.000000     0.000000    51.000000        0.000000
# 75%      37.000000       403.000000     2.000000    76.000000        0.000000
# max      50.000000       471.000000     3.000000   100.000000        1.000000
#
#          charges_1    charges_2  Minimum_price  Maximum_price  Selling_Price
# count  6170.000000  6163.000000    6330.000000    6025.000000    6327.000000
# mean    264.514100    10.146195    3531.349763    6432.545892    4563.242592
# std     124.483056     4.318339    2194.729604    3716.177364    2979.102408
# min     100.000000     1.000000       1.000000     404.000000   -6062.470000
# 25%     163.000000     7.000000    1879.250000    3918.000000    2450.005280
# 50%     252.000000    10.000000    3157.500000    5634.000000    4210.384640
# 75%     314.000000    14.000000    4697.000000    8126.000000    6167.643252
# max     649.000000    17.000000   17580.000000   58812.000000   22638.325941

# %%
test.describe()
# Out:
#           Stall_no  Market_Category        Grade       Demand  Discount_avail  \
# count  3429.000000      3430.000000  3430.000000  3430.000000     3430.000000
# mean     25.633421       196.693878     0.667638    49.917493        0.146356
# std      14.389747       168.832500     1.045914    28.587214        0.353514
# min       1.000000         0.000000     0.000000     1.000000        0.000000
# 25%      13.000000        55.000000     0.000000    26.000000        0.000000
# 50%      26.000000       124.000000     0.000000    50.000000        0.000000
# 75%      38.000000       358.000000     2.000000    74.000000        0.000000
# max      50.000000       471.000000     3.000000   100.000000        1.000000
#
#          charges_1    charges_2  Minimum_price  Maximum_price
# count  3394.000000  3425.000000    3416.000000    3430.000000
# mean    265.484973    10.436204    3444.206089    6234.062391
# std     125.325455     4.232382    2178.418557    3575.968650
# min     100.000000     1.000000     124.000000     163.000000
# 25%     162.000000     7.000000    1834.000000    3819.000000
# 50%     252.000000    11.000000    3060.500000    5431.000000
# 75%     319.000000    14.000000    4606.500000    7796.500000
# max     648.000000    17.000000   17182.000000   27954.000000

# %%
train.isnull().sum()
# Out:
# Product_id            0
# Stall_no              5
# instock_date          0
# Market_Category       0
# Customer_name       211
# Loyalty_customer      0
# Product_Category      0
# Grade                 0
# Demand                0
# Discount_avail       38
# charges_1           198
# charges_2           205
# Minimum_price        38
# Maximum_price       343
# Selling_Price        41
# dtype: int64

# %%
test.isnull().sum()
# Out:
# Product_id           0
# Stall_no             1
# instock_date         0
# Market_Category      0
# Customer_name       53
# Loyalty_customer     0
# Product_Category     0
# Grade                0
# Demand               0
# Discount_avail       0
# charges_1           36
# charges_2            5
# Minimum_price       14
# Maximum_price        0
# dtype: int64

# %% [markdown]
# ### Label Analysis

# %%
sns.distplot(train.Selling_Price)

# %%
train.drop(index=train[train.Selling_Price<0].index, inplace=True)
train.reset_index(drop=True,inplace=True)

# %%
train.Selling_Price = train.Selling_Price.apply(lambda x: x if x>=0 else x*(-1))

# %%
train.Selling_Price.isnull().sum()
# Out:
# 41

# %%
#a = train[train.Selling_Price.isnull()]

# %%
#b.dropna(inplace=True)
#l1 = np.log(b.Selling_Price)
#b.Selling_Price = b.Selling_Price.apply(lambda x: x if x>=0 else x*(-1))
#b[['Discount_avail','charges_1','charges_2','Minimum_price','Maximum_price']] = b[['Discount_avail','charges_1','charges_2','Minimum_price','Maximum_price']].astype('float')

# %%
#xtrain,xtest,ytrain,ytest = train_test_split(b[['Discount_avail','charges_1','charges_2','Minimum_price','Maximum_price']],b.Selling_Price,test_size=0.3,random_state=8011)

# %%
#m = lgb.LGBMRegressor(random_state=10070)
#m.fit(xtrain,ytrain)
#i_prd = m.predict(xtest)
#np.sqrt(mean_squared_log_error(ytest,i_prd))

# %%
#a.drop(columns=['Selling_Price'],inplace=True)

# %%
#a.Maximum_price.fillna(a.Maximum_price.median(),inplace=True)
#a.Minimum_price.fillna(a.Minimum_price.median(),inplace=True)
#a.Discount_avail.fillna(a.Discount_avail.median(),inplace=True)
#a.charges_2.fillna(a.charges_2.median(),inplace=True)

# %%
#a['Selling_Price'] = m.predict(a[['Discount_avail','charges_1','charges_2','Minimum_price','Maximum_price']])

# %%
#l = a.Selling_Price.index

# %%
#l

# %%
#for i in l:
    #train.loc[i,'Selling_Price'] = a.loc[i,'Selling_Price']

# %%
#train.isnull().sum()

# %%
train.drop(index = train[train.Selling_Price.isnull()].index, inplace=True)
train.reset_index(drop=True,inplace=True)

# %%
#train.Selling_Price.fillna(train.Selling_Price.mean(),inplace=True)

# %% [markdown]
# ## Feature by Feature Analysis

# %% [markdown]
# ### Product ID

# %%
train.Product_id = train.Product_id.apply(lambda x: [i for i in x][:3])
test.Product_id = test.Product_id.apply(lambda x: [i for i in x][:3])

# %%
train.Product_id = train.Product_id.apply(lambda x: ''.join(x))
test.Product_id = test.Product_id.apply(lambda x: ''.join(x))

# %%
train.Product_id.nunique(), test.Product_id.nunique()
# Out:
# (292, 243)

# %%
z
# Out:
# array(['SCHE4YSTDVPVZVXW', 'ACCEGCATKHNRXUHW', 'NKCE6GJ5XVJDXNNZ', ...,
#        'TUNE8FWQBS7TVVT7', 'NKCEGMUABCRGUZPE', 'RNGE7M92KAQWUBCS'],
#       dtype=object)

# %% [markdown]
# ### Stall no.

# %%
test.Stall_no.nunique()
# Out:
# 50

# %%
train.Stall_no.isnull().sum(), test.Stall_no.isnull().sum()
# Out:
# (5, 1)

# %%
train.Stall_no.fillna(20.0, inplace=True) #20
test.Stall_no.fillna(12.0,inplace=True)   #12

# %%
sns.scatterplot(train.Stall_no,train.Selling_Price)

# %%
sns.distplot(train.Stall_no)

# %%
sns.distplot(test.Stall_no)

# %% [markdown]
# ### In Stock date

# %%
#train['Date'] = train.instock_date.str.split(' ').apply(lambda x: x[0])
#test['Date'] = test.instock_date.str.split(' ').apply(lambda x: x[0])

# %%
#train['Time'] = train.instock_date.str.split(' ').apply(lambda x: x[1])
#test['Time'] = test.instock_date.str.split(' ').apply(lambda x: x[1])

# %%
#train['Hour'] = train.Time.str.split(':').apply(lambda x: x[0])
#test['Hour'] = test.Time.str.split(':').apply(lambda x: x[0])

#train['Minute'] = train.Time.str.split(':').apply(lambda x: x[1])
#test['Minute'] = test.Time.str.split(':').apply(lambda x: x[1])

#train['Second'] = train.Time.str.split(':').apply(lambda x: x[2])
#test['Second'] = test.Time.str.split(':').apply(lambda x: x[2])

# %%
#train.drop(columns=['instock_date','Time'],inplace = True)
#test.drop(columns=['instock_date','Time'],inplace = True)

# %%
train.head()
# Out:
#   Product_id  Stall_no             instock_date  Market_Category  \
# 0        BRA      37.0  2015-08-22 18:36:12.000                2
# 1        TUN      38.0  2016-03-27 21:19:13.000               24
# 2        BRA       9.0  2015-08-18 19:25:22.000              447
# 3        WAT      50.0  2016-03-28 21:53:01.000               23
# 4        JWS       7.0  2016-03-29 22:58:53.000               63
#
#   Customer_name Loyalty_customer Product_Category  Grade  Demand  \
# 0      Lillyann              Yes          Fashion      1      68
# 1         Klynn              Yes          Fashion      0      51
# 2         Ridge              Yes       Child_care      0      10
# 3         Abran              Yes      Educational      2      48
# 4        Dustyn              Yes           Repair      1      35
#
#    Discount_avail  charges_1  charges_2  Minimum_price  Maximum_price  \
# 0             0.0      376.0       11.0         2983.0         4713.0
# 1             0.0      397.0       12.0         7495.0        10352.0
# 2             0.0      250.0        9.0         5752.0         7309.0
# 3             0.0      144.0       13.0         5090.0        20814.0
# 4             1.0      211.0        4.0         2430.0         9261.0
#
#    Selling_Price
# 0    4185.947700
# 1    9271.490256
# 2    6785.701362
# 3   13028.917824
# 4     906.553935

# %% [markdown]
# ### Market Category

# %%
sns.distplot(train.Market_Category)

# %%
sns.distplot(test.Market_Category)

# %%
sns.scatterplot(train.Market_Category,train.Selling_Price)

# %% [markdown]
# ### Customer Name

# %%
train.Customer_name.nunique(),test.Customer_name.nunique()
# Out:
# (5855, 3319)

# %%
#train.drop(columns=['Customer_name'],inplace=True)
#test.drop(columns=['Customer_name'],inplace=True)

# %% [markdown]
# ### Loyalty Customer

# %%
train.Loyalty_customer.value_counts(), test.Loyalty_customer.value_counts()
# Out:
# (Yes    3852
#  No     2461
#  Name: Loyalty_customer, dtype: int64,
#  Yes    2087
#  No     1343
#  Name: Loyalty_customer, dtype: int64)

# %%
sns.boxplot(train.Loyalty_customer,train.Selling_Price)

# %% [markdown]
# ### Product Category

# %%
train.Product_Category.value_counts()
# Out:
# Pet_care       674
# Repair         665
# Child_care     652
# Cosmetics      643
# Hospitality    626
# Organic        618
# Technology     616
# Home_decor     610
# Educational    605
# Fashion        604
# Name: Product_Category, dtype: int64

# %%
test.Product_Category.value_counts()
# Out:
# Educational    355
# Cosmetics      348
# Child_care     348
# Pet_care       346
# Repair         345
# Fashion        345
# Home_decor     340
# Technology     340
# Organic        336
# Hospitality    327
# Name: Product_Category, dtype: int64

# %%
sns.boxplot(train.Product_Category,train.Selling_Price)

# %% [markdown]
# ### Grade

# %%
train.Grade.value_counts()
# Out:
# 0    4339
# 2    1093
# 3     502
# 1     379
# Name: Grade, dtype: int64

# %%
z
# Out:
# array(['SCHE4YSTDVPVZVXW', 'ACCEGCATKHNRXUHW', 'NKCE6GJ5XVJDXNNZ', ...,
#        'TUNE8FWQBS7TVVT7', 'NKCEGMUABCRGUZPE', 'RNGE7M92KAQWUBCS'],
#       dtype=object)

# %%
test.Grade.value_counts()
# Out:
# 0    2335
# 2     595
# 3     300
# 1     200
# Name: Grade, dtype: int64

# %%
sns.boxplot(train.Grade,train.Selling_Price)

# %% [markdown]
# ### Demand

# %%
sns.distplot(train.Demand)

# %%
sns.distplot(test.Demand)

# %%
sns.scatterplot(train.Demand,train.Selling_Price)

# %% [markdown]
# ### Discount Avail

# %%
train.Discount_avail.value_counts()
# Out:
# 0.0    5396
# 1.0     880
# Name: Discount_avail, dtype: int64

# %%
train.drop(index = train[train.Discount_avail.isnull()].index, inplace=True)
train.reset_index(drop=True,inplace=True)

# %%
train.Discount_avail.fillna(0.0,inplace=True)

# %%
test.Discount_avail.value_counts()
# Out:
# 0    2928
# 1     502
# Name: Discount_avail, dtype: int64

# %%
sns.boxplot(train.Discount_avail,train.Selling_Price)

# %% [markdown]
# ### Charges_1

# %%
sns.distplot(train.charges_1)

# %%
sns.distplot(test.charges_1)

# %%
sns.scatterplot(train.charges_1,train.Selling_Price)

# %%
#train.drop(train[train.charges_1.isnull()].index,inplace=True)
#train.reset_index(drop=True,inplace=True)

# %%
train.charges_1.fillna(train.charges_1.median(),inplace=True)
test.charges_1.fillna(test.charges_1.median(),inplace=True)

# %% [markdown]
# ### Charges_2(%)

# %%
sns.distplot(train.charges_2)

# %%
train.charges_2.value_counts()
# Out:
# 14.0    482
# 7.0     473
# 5.0     468
# 6.0     456
# 9.0     438
# 8.0     430
# 12.0    427
# 11.0    424
# 16.0    422
# 13.0    409
# 17.0    399
# 15.0    386
# 10.0    337
# 3.0     135
# 1.0     135
# 4.0     131
# 2.0     121
# Name: charges_2, dtype: int64

# %%
sns.distplot(test.charges_2)

# %%
sns.scatterplot(train.charges_2,train.Selling_Price)

# %%
train.charges_2.fillna(train.charges_2.median(),inplace=True)
test.charges_2.fillna(test.charges_2.median(),inplace=True)

# %% [markdown]
# ### Minimum price

# %%
sns.distplot(np.log(train.Minimum_price))

# %%
sns.distplot(np.log(test.Minimum_price))

# %%
sns.scatterplot(train.Minimum_price,train.Selling_Price)

# %%
train.Minimum_price.fillna(train.Minimum_price.median(),inplace=True)
test.Minimum_price.fillna(test.Minimum_price.median(),inplace=True)

# %% [markdown]
# ### Maximum Price

# %%
sns.distplot(np.log(train.Maximum_price))

# %%
sns.distplot(np.log(test.Maximum_price))

# %%
sns.scatterplot(train.Maximum_price,train.Selling_Price)

# %%
train.drop(index = train[train.Maximum_price==train.Maximum_price.max()].index, inplace=True)
train.reset_index(drop=True,inplace=True)

# %%
train.Maximum_price.fillna(train.Maximum_price.median(),inplace=True)

# %% [markdown]
# ### Feature  Engg.

# %%
train.head()
# Out:
#   Product_id  Stall_no             instock_date  Market_Category  \
# 0        BRA      37.0  2015-08-22 18:36:12.000                2
# 1        TUN      38.0  2016-03-27 21:19:13.000               24
# 2        BRA       9.0  2015-08-18 19:25:22.000              447
# 3        WAT      50.0  2016-03-28 21:53:01.000               23
# 4        JWS       7.0  2016-03-29 22:58:53.000               63
#
#   Customer_name Loyalty_customer Product_Category  Grade  Demand  \
# 0      Lillyann              Yes          Fashion      1      68
# 1         Klynn              Yes          Fashion      0      51
# 2         Ridge              Yes       Child_care      0      10
# 3         Abran              Yes      Educational      2      48
# 4        Dustyn              Yes           Repair      1      35
#
#    Discount_avail  charges_1  charges_2  Minimum_price  Maximum_price  \
# 0             0.0      376.0       11.0         2983.0         4713.0
# 1             0.0      397.0       12.0         7495.0        10352.0
# 2             0.0      250.0        9.0         5752.0         7309.0
# 3             0.0      144.0       13.0         5090.0        20814.0
# 4             1.0      211.0        4.0         2430.0         9261.0
#
#    Selling_Price
# 0    4185.947700
# 1    9271.490256
# 2    6785.701362
# 3   13028.917824
# 4     906.553935

# %%
#train.drop(train.Minimum_price[np.log(train.Minimum_price)<5].index,inplace=True)
#train.reset_index(drop=True,inplace=True)

# %%
df = pd.concat([train,test],axis=0)
df.reset_index(drop=True,inplace=True)

# %%
df['Sum'] = ((df.Maximum_price**2) + (df.Minimum_price**2))
df['Mean_price'] = (df.Maximum_price + df.Minimum_price)/2
df['Mean_price_charged'] = (df.Maximum_price + df.Minimum_price) - df.charges_1
#df['Diff_price'] = np.sqrt((df.Maximum_price**2) - (df.Minimum_price**2))
df['Date'] = df.instock_date.str.split(' ').apply(lambda x: x[0])
df.Date = pd.to_datetime(df.Date)
df['Max-price_per-demand'] = df.Maximum_price/df.Demand
df['Min-price_per-demand'] = df.Minimum_price/df.Demand
df['Total-price_per-demand'] = df.Sum/df.Demand

# %%
#df.groupby(['Demand'])[['Minimum_price']].agg(('count','min','max','mean'))
#df['Demand_min_price_count'] = df.groupby(['Demand'])[['Minimum_price']].transform('count')
#df['Demand_min_price_min'] = df.groupby(['Demand'])[['Minimum_price']].transform('min')
#df['Demand_min_price_max'] = df.groupby(['Demand'])[['Minimum_price']].transform('max')
#df['Demand_min_price_sum'] = df.groupby(['Demand'])[['Minimum_price']].transform('sum')

#df['Demand_max_price_count'] = df.groupby(['Demand'])[['Maximum_price']].transform('count')
#df['Demand_max_price_min'] = df.groupby(['Demand'])[['Maximum_price']].transform('min')
#df['Demand_max_price_max'] = df.groupby(['Demand'])[['Maximum_price']].transform('max')
#df['Demand_max_price_sum'] = df.groupby(['Demand'])[['Maximum_price']].transform('sum')

# %%
df['Weekday'] = df.Date.dt.weekday
df['Day'] = df.Date.dt.day
df['DOY'] = df.Date.dt.dayofyear
df['WOY'] = df.Date.dt.weekofyear
df['DIM'] = df.Date.dt.daysinmonth
df['Month'] = df.Date.dt.month
df['WeekDay_name'] = df.Date.dt.weekday_name

# %%
df['Time'] = df.instock_date.str.split(' ').apply(lambda x: x[1])
#df['Hour'] = df.Time.str.split(':').apply(lambda x: int(x[0]))
#df['Minute'] = df.Time.str.split(':').apply(lambda x: int(x[1]))
#df['Second'] = df.Time.str.split(':').apply(lambda x: float(x[2]))

# %%
#df['Prd_cat_Max_pr_mean']=df.groupby(['Product_Category'])['Mean_price'].transform('mean')
#df['Prd_cat_Max_pr_max']=df.groupby(['Product_Category'])['Maximum_price'].transform('max')
#df['Prd_cat_Max_pr_min']=df.groupby(['Product_Category'])['Maximum_price'].transform('min')
#df['Prd_cat_Max_pr_count']=df.groupby(['Product_Category'])['Maximum_price'].transform('count')

#df['Prd_cat_Min_pr_mean']=df.groupby(['Product_Category'])['Minimum_price'].transform('mean')
#df['Prd_cat_Min_pr_max']=df.groupby(['Product_Category'])['Minimum_price'].transform('max')
#df['Prd_cat_Min_pr_min']=df.groupby(['Product_Category'])['Minimum_price'].transform('min')
#df['Prd_cat_Min_pr_count']=df.groupby(['Product_Category'])['Minimum_price'].transform('count')

#df['Prd_cat_Max_pr_mean']=df.groupby(['Loyalty_customer'])['Maximum_price'].transform('mean')
#df['Prd_cat_Max_pr_max']=df.groupby(['Loyalty_customer'])['Maximum_price'].transform('max')
#df['Prd_cat_Max_pr_min']=df.groupby(['Loyalty_customer'])['Maximum_price'].transform('min')
#df['Prd_cat_Max_pr_count']=df.groupby(['Loyalty_customer'])['Market_Category'].transform('count')

#df['Stall_cat_Min_pr_mean']=df.groupby(['Stall_no'])['Mean_price'].transform('mean')
#df['Stall_cat_Min_pr_max']=df.groupby(['Stall_no'])['Mean_price'].transform('max')
#df['Stall_cat_Min_pr_min']=df.groupby(['Stall_no'])['Mean_price'].transform('min')
#df['Stall_cat_Min_pr_count']=df.groupby(['Market_Category'])['Loyalty_customer'].transform('count')

#df['Stall_cat_Max_pr_mean']=df.groupby(['Discount_avail'])['Sum'].transform('mean')
#df['Stall_cat_Max_pr_max']=df.groupby(['Discount_avail'])['Sum'].transform('max')
#df['Stall_cat_Max_pr_min']=df.groupby(['Discount_avail'])['Sum'].transform('min')
#df['Stall_cat_Max_pr_count']=df.groupby(['Discount_avail'])['Sum'].transform('count')

# %%
df['Charged_max_price'] = df.Maximum_price-(df.charges_1 + (df.charges_2*df.Maximum_price/100))
df['Charged_min_price'] = df.Minimum_price -(df.charges_1 + (df.charges_2*df.Minimum_price/100))
df['Total-charges'] = df.charges_1 + (df.charges_2/100)
df['Diff_Max_price'] = df.Maximum_price - df.Charged_max_price
df['Diff_Sum_price'] = df.Sum - df['Total-charges']
df['Min-Max_ratio'] = df.Maximum_price/df.Minimum_price
df.Maximum_price = np.log(df.Maximum_price)
df.Minimum_price = np.log(df.Minimum_price)

# %%
df['Prd_cat_Min_pr_mean']=df.groupby(['Product_id'])['Minimum_price'].transform('mean')
df['Prd_cat_Min_pr_max']=df.groupby(['Product_id'])['Minimum_price'].transform('max')
df['Prd_cat_Min_pr_min']=df.groupby(['Product_id'])['Minimum_price'].transform('min')
df['Prd_cat_Min_pr_count']=df.groupby(['Product_id'])['Minimum_price'].transform('count')

df['Market_Loyal_pr_count']=df.groupby(['Market_Category'])['Loyalty_customer'].transform('count')
df['Product_Loyal_pr_count']=df.groupby(['Product_Category'])['Loyalty_customer'].transform('count')
df['Discount_Loyal_pr_count']=df.groupby(['Discount_avail'])['Loyalty_customer'].transform('count')
df['Id_Loyal_pr_count']=df.groupby(['Product_id'])['Loyalty_customer'].transform('count')

# %%
df['Stall_Cust_count']=df.groupby(['Stall_no'])['Customer_name'].transform('count')

#df = pd.concat([df,pd.get_dummies(df[['Loyalty_customer','Product_Category']].astype('category'))],axis=1)

# %%
le = LabelEncoder()
df.Loyalty_customer = le.fit_transform(df.Loyalty_customer)
df.Product_Category = le.fit_transform(df.Product_Category)
df.WeekDay_name = le.fit_transform(df.WeekDay_name)
df.Product_id = le.fit_transform(df.Product_id)

# %%
df.head()
# Out:
#   Customer_name  Demand  Discount_avail  Grade  Loyalty_customer  \
# 0      Lillyann      68             0.0      1                 1
# 1         Klynn      51             0.0      0                 1
# 2         Ridge      10             0.0      0                 1
# 3         Abran      48             0.0      2                 1
# 4        Dustyn      35             1.0      1                 1
#
#    Market_Category  Maximum_price  Minimum_price  Product_Category  \
# 0                2       8.458080       8.000685                 3
# 1               24       9.244935       8.921991                 3
# 2              447       8.896862       8.657303                 0
# 3               23       9.943381       8.535033                 2
# 4               63       9.133567       7.795647                 8
#
#    Product_id  ...  Min-Max_ratio  Prd_cat_Min_pr_mean  Prd_cat_Min_pr_max  \
# 0          39  ...       1.579953             7.736183            9.125762
# 1         315  ...       1.381187             8.125481            9.473474
# 2          39  ...       1.270688             7.736183            9.125762
# 3         333  ...       4.089194             8.066417            9.772182
# 4         151  ...       3.811111             8.256612            9.394161
#
#    Prd_cat_Min_pr_min Prd_cat_Min_pr_count  Market_Loyal_pr_count  \
# 0            5.497168                  989                     39
# 1            5.198497                   33                    321
# 2            5.497168                  989                    261
# 3            5.147494                  440                    491
# 4            7.372118                   28                     59
#
#    Product_Loyal_pr_count  Discount_Loyal_pr_count Id_Loyal_pr_count  \
# 0                     945                     8324               989
# 1                     945                     8324                33
# 2                     994                     8324               989
# 3                     955                     8324               440
# 4                    1004                     1381                28
#
#    Stall_Cust_count
# 0               197
# 1               182
# 2               212
# 3               167
# 4               180
#
# [5 rows x 45 columns]

# %%
#df.drop(columns=['Loyalty_customer','Product_Category'],inplace=True)

# %%
df.isnull().sum()
# Out:
# Customer_name               259
# Demand                        0
# Discount_avail                0
# Grade                         0
# Loyalty_customer              0
# Market_Category               0
# Maximum_price                 0
# Minimum_price                 0
# Product_Category              0
# Product_id                    0
# Selling_Price              3430
# Stall_no                      0
# charges_1                     0
# charges_2                     0
# instock_date                  0
# Sum                           0
# Mean_price                    0
# Mean_price_charged            0
# Date                          0
# Max-price_per-demand          0
# Min-price_per-demand          0
# Total-price_per-demand        0
# Weekday                       0
# Day                           0
# DOY                           0
# WOY                           0
# DIM                           0
# Month                         0
# WeekDay_name                  0
# Time                          0
# Charged_max_price             0
# Charged_min_price             0
# Total-charges                 0
# Diff_Max_price                0
# Diff_Sum_price                0
# Min-Max_ratio                 0
# Prd_cat_Min_pr_mean           0
# Prd_cat_Min_pr_max            0
# Prd_cat_Min_pr_min            0
# Prd_cat_Min_pr_count          0
# Market_Loyal_pr_count         0
# Product_Loyal_pr_count        0
# Discount_Loyal_pr_count       0
# Id_Loyal_pr_count             0
# Stall_Cust_count              0
# dtype: int64

# %% [markdown]
# ### Modelling

# %%
train = df.iloc[:train.shape[0],:]
test = df.iloc[train.shape[0]:,:]
test.reset_index(drop=True,inplace=True)
label = np.log(train.Selling_Price)
test.drop(columns=['Selling_Price','Date','Time','instock_date','Customer_name'],inplace=True)
train.drop(columns=['Selling_Price','Date','Time','instock_date','Customer_name'],inplace=True)

# %%
train.shape, test.shape
# Out:
# ((6275, 40), (3430, 40))

# %%
def model(m,train,label,test,folds,rnd_st):
    predicted = pd.DataFrame(np.zeros(shape=(test.shape[0],folds)))
    splitters = KFold(n_splits = folds, random_state=rnd_st)
    tr = []
    te = []
    
    for i,(tr_index,val_index) in enumerate(splitters.split(train,label)):
        xtrain,xval = train.loc[tr_index,:], train.loc[val_index,:]
        ytrain,yval = label.loc[tr_index], label.loc[val_index]
        
        m.fit(xtrain,ytrain)
        tr_pred = m.predict(xtrain)
        val_pred = m.predict(xval)
        l1 = max([0,100-np.sqrt(mean_squared_error(ytrain,tr_pred))])
        l2 = max([0,100-np.sqrt(mean_squared_error(yval,val_pred))])
        
        print(l1,'\t\t\t\t\t',l2)
        tr.append(l1)
        te.append(l2)
        pd.Series(m.feature_importances_,index = train.columns).sort_values(ascending=True).plot.barh()
        predicted.iloc[:,i] = m.predict(test)

    print(np.mean(tr), np.mean(te))
    return(predicted)

# %%
seed = 11999

# %%
plt.figure(figsize=(9,12))
result = np.exp(model(cat.CatBoostRegressor(random_state=seed),train,label,test,9,seed))
# Out:
# Learning rate set to 0.052998
# 0:	learn: 0.8186402	total: 19.1ms	remaining: 19s
# 1:	learn: 0.7808707	total: 23ms	remaining: 11.5s
# 2:	learn: 0.7449040	total: 26.7ms	remaining: 8.88s
# 3:	learn: 0.7091693	total: 31.1ms	remaining: 7.74s
# 4:	learn: 0.6777096	total: 34.8ms	remaining: 6.93s
# 5:	learn: 0.6455609	total: 38.5ms	remaining: 6.38s
# 6:	learn: 0.6156022	total: 42.2ms	remaining: 5.99s
# 7:	learn: 0.5865680	total: 46ms	remaining: 5.7s
# 8:	learn: 0.5596782	total: 49.6ms	remaining: 5.46s
# 9:	learn: 0.5338280	total: 53.3ms	remaining: 5.28s
# 10:	learn: 0.5091615	total: 56.9ms	remaining: 5.12s
# 11:	learn: 0.4860390	total: 60.6ms	remaining: 4.99s
# 12:	learn: 0.4642043	total: 64.3ms	remaining: 4.88s
# 13:	learn: 0.4433613	total: 68ms	remaining: 4.79s
# 14:	learn: 0.4239126	total: 71.7ms	remaining: 4.71s
# 15:	learn: 0.4046682	total: 75.4ms	remaining: 4.64s
# 16:	learn: 0.3874236	total: 79.3ms	remaining: 4.59s
# 17:	learn: 0.3705701	total: 83.1ms	remaining: 4.54s
# 18:	learn: 0.3545501	total: 86.8ms	remaining: 4.48s
# 19:	learn: 0.3391074	total: 90.5ms	remaining: 4.44s
# 20:	learn: 0.3247194	total: 94.4ms	remaining: 4.4s
# 21:	learn: 0.3114635	total: 98.2ms	remaining: 4.36s
# 22:	learn: 0.2986732	total: 102ms	remaining: 4.32s
# 23:	learn: 0.2867290	total: 106ms	remaining: 4.29s
# 24:	learn: 0.2755989	total: 109ms	remaining: 4.27s
# 25:	learn: 0.2648605	total: 113ms	remaining: 4.24s
# 26:	learn: 0.2553825	total: 117ms	remaining: 4.21s
# 27:	learn: 0.2460946	total: 121ms	remaining: 4.18s
# 28:	learn: 0.2366638	total: 124ms	remaining: 4.16s
# 29:	learn: 0.2281370	total: 128ms	remaining: 4.13s
# 30:	learn: 0.2197872	total: 132ms	remaining: 4.11s
# 31:	learn: 0.2117890	total: 135ms	remaining: 4.09s
# 32:	learn: 0.2044731	total: 139ms	remaining: 4.07s
# 33:	learn: 0.1975248	total: 143ms	remaining: 4.05s
# 34:	learn: 0.1911912	total: 146ms	remaining: 4.03s
# 35:	learn: 0.1853740	total: 150ms	remaining: 4.01s
# 36:	learn: 0.1796488	total: 154ms	remaining: 4s
# 37:	learn: 0.1747924	total: 157ms	remaining: 3.98s
# 38:	learn: 0.1699029	total: 161ms	remaining: 3.96s
# 39:	learn: 0.1652710	total: 165ms	remaining: 3.96s
# 40:	learn: 0.1612028	total: 169ms	remaining: 3.95s
# 41:	learn: 0.1570911	total: 173ms	remaining: 3.94s
# 42:	learn: 0.1529344	total: 177ms	remaining: 3.94s
# 43:	learn: 0.1494464	total: 181ms	remaining: 3.93s
# 44:	learn: 0.1459709	total: 185ms	remaining: 3.92s
# 45:	learn: 0.1428790	total: 189ms	remaining: 3.92s
# 46:	learn: 0.1401245	total: 193ms	remaining: 3.91s
# 47:	learn: 0.1373991	total: 197ms	remaining: 3.91s
# 48:	learn: 0.1346635	total: 201ms	remaining: 3.9s
# 49:	learn: 0.1324465	total: 205ms	remaining: 3.89s
# 50:	learn: 0.1301115	total: 208ms	remaining: 3.87s
# 51:	learn: 0.1280136	total: 212ms	remaining: 3.86s
# 52:	learn: 0.1262375	total: 216ms	remaining: 3.86s
# 53:	learn: 0.1243601	total: 219ms	remaining: 3.85s
# 54:	learn: 0.1227440	total: 223ms	remaining: 3.83s
# 55:	learn: 0.1212634	total: 227ms	remaining: 3.82s
# 56:	learn: 0.1194696	total: 231ms	remaining: 3.81s
# 57:	learn: 0.1180371	total: 234ms	remaining: 3.8s
# 58:	learn: 0.1166606	total: 238ms	remaining: 3.79s
# 59:	learn: 0.1153019	total: 242ms	remaining: 3.79s
# 60:	learn: 0.1141814	total: 246ms	remaining: 3.78s
# 61:	learn: 0.1129019	total: 249ms	remaining: 3.77s
# 62:	learn: 0.1117333	total: 253ms	remaining: 3.76s
# 63:	learn: 0.1108431	total: 257ms	remaining: 3.75s
# 64:	learn: 0.1099550	total: 260ms	remaining: 3.74s
# 65:	learn: 0.1090519	total: 264ms	remaining: 3.73s
# 66:	learn: 0.1082596	total: 268ms	remaining: 3.73s
# 67:	learn: 0.1075665	total: 271ms	remaining: 3.72s
# 68:	learn: 0.1070244	total: 275ms	remaining: 3.71s
# 69:	learn: 0.1064256	total: 279ms	remaining: 3.7s
# 70:	learn: 0.1058504	total: 282ms	remaining: 3.69s
# 71:	learn: 0.1053083	total: 286ms	remaining: 3.69s
# 72:	learn: 0.1044262	total: 290ms	remaining: 3.68s
# 73:	learn: 0.1038493	total: 294ms	remaining: 3.67s
# 74:	learn: 0.1033802	total: 297ms	remaining: 3.67s
# 75:	learn: 0.1029791	total: 301ms	remaining: 3.66s
# 76:	learn: 0.1025053	total: 305ms	remaining: 3.65s
# 77:	learn: 0.1015697	total: 309ms	remaining: 3.65s
# 78:	learn: 0.1009603	total: 313ms	remaining: 3.64s
# 79:	learn: 0.1004636	total: 316ms	remaining: 3.64s
# 80:	learn: 0.0999984	total: 320ms	remaining: 3.63s
# 81:	learn: 0.0996373	total: 324ms	remaining: 3.62s
# 82:	learn: 0.0992796	total: 327ms	remaining: 3.62s
# 83:	learn: 0.0989845	total: 331ms	remaining: 3.61s
# 84:	learn: 0.0986119	total: 335ms	remaining: 3.6s
# 85:	learn: 0.0983056	total: 338ms	remaining: 3.6s
# 86:	learn: 0.0980093	total: 342ms	remaining: 3.59s
# 87:	learn: 0.0974630	total: 346ms	remaining: 3.58s
# 88:	learn: 0.0971902	total: 350ms	remaining: 3.58s
# 89:	learn: 0.0968296	total: 354ms	remaining: 3.58s
# 90:	learn: 0.0965877	total: 358ms	remaining: 3.58s
# 91:	learn: 0.0958473	total: 362ms	remaining: 3.57s
# 92:	learn: 0.0955886	total: 366ms	remaining: 3.57s
# 93:	learn: 0.0953558	total: 370ms	remaining: 3.56s
# 94:	learn: 0.0949229	total: 374ms	remaining: 3.56s
# 95:	learn: 0.0944489	total: 378ms	remaining: 3.56s
# 96:	learn: 0.0942356	total: 382ms	remaining: 3.56s
# 97:	learn: 0.0939940	total: 386ms	remaining: 3.55s
# 98:	learn: 0.0934327	total: 390ms	remaining: 3.54s
# 99:	learn: 0.0933027	total: 393ms	remaining: 3.54s
# 100:	learn: 0.0931097	total: 397ms	remaining: 3.53s
# 101:	learn: 0.0925055	total: 401ms	remaining: 3.53s
# 102:	learn: 0.0923574	total: 404ms	remaining: 3.52s
# 103:	learn: 0.0921625	total: 408ms	remaining: 3.52s
# 104:	learn: 0.0915154	total: 412ms	remaining: 3.51s
# 105:	learn: 0.0909250	total: 416ms	remaining: 3.5s
# 106:	learn: 0.0906942	total: 419ms	remaining: 3.5s
# 107:	learn: 0.0902002	total: 423ms	remaining: 3.49s
# 108:	learn: 0.0900951	total: 427ms	remaining: 3.49s
# 109:	learn: 0.0899335	total: 431ms	remaining: 3.48s
# 110:	learn: 0.0897291	total: 435ms	remaining: 3.48s
# 111:	learn: 0.0895973	total: 439ms	remaining: 3.48s
# 112:	learn: 0.0895018	total: 443ms	remaining: 3.47s
# 113:	learn: 0.0889950	total: 447ms	remaining: 3.47s
# 114:	learn: 0.0888361	total: 450ms	remaining: 3.47s
# 115:	learn: 0.0883000	total: 454ms	remaining: 3.46s
# 116:	learn: 0.0880168	total: 458ms	remaining: 3.46s
# 117:	learn: 0.0876555	total: 462ms	remaining: 3.45s
# 118:	learn: 0.0875283	total: 465ms	remaining: 3.44s
# 119:	learn: 0.0874209	total: 469ms	remaining: 3.44s
# 120:	learn: 0.0873367	total: 473ms	remaining: 3.43s
# 121:	learn: 0.0871689	total: 476ms	remaining: 3.43s
# 122:	learn: 0.0867584	total: 480ms	remaining: 3.42s
# 123:	learn: 0.0861943	total: 484ms	remaining: 3.42s
# 124:	learn: 0.0860406	total: 487ms	remaining: 3.41s
# 125:	learn: 0.0859503	total: 491ms	remaining: 3.41s
# 126:	learn: 0.0854438	total: 495ms	remaining: 3.4s
# 127:	learn: 0.0849519	total: 499ms	remaining: 3.4s
# 128:	learn: 0.0844673	total: 502ms	remaining: 3.39s
# 129:	learn: 0.0843652	total: 506ms	remaining: 3.38s
# 130:	learn: 0.0838735	total: 510ms	remaining: 3.38s
# 131:	learn: 0.0837201	total: 513ms	remaining: 3.37s
# 132:	learn: 0.0836464	total: 517ms	remaining: 3.37s
# 133:	learn: 0.0833670	total: 522ms	remaining: 3.37s
# 134:	learn: 0.0831166	total: 526ms	remaining: 3.37s
# 135:	learn: 0.0828129	total: 530ms	remaining: 3.37s
# 136:	learn: 0.0826352	total: 534ms	remaining: 3.36s
# 137:	learn: 0.0825018	total: 538ms	remaining: 3.36s
# 138:	learn: 0.0820260	total: 542ms	remaining: 3.35s
# 139:	learn: 0.0818429	total: 546ms	remaining: 3.35s
# 140:	learn: 0.0816299	total: 551ms	remaining: 3.35s
# 141:	learn: 0.0815421	total: 555ms	remaining: 3.35s
# 142:	learn: 0.0810907	total: 559ms	remaining: 3.35s
# 143:	learn: 0.0806416	total: 562ms	remaining: 3.34s
# 144:	learn: 0.0804590	total: 566ms	remaining: 3.34s
# 145:	learn: 0.0804029	total: 570ms	remaining: 3.34s
# 146:	learn: 0.0803535	total: 574ms	remaining: 3.33s
# 147:	learn: 0.0802829	total: 578ms	remaining: 3.33s
# 148:	learn: 0.0800710	total: 582ms	remaining: 3.32s
# 149:	learn: 0.0799978	total: 586ms	remaining: 3.32s
# 150:	learn: 0.0797293	total: 589ms	remaining: 3.31s
# 151:	learn: 0.0795880	total: 593ms	remaining: 3.31s
# 152:	learn: 0.0793551	total: 597ms	remaining: 3.31s
# 153:	learn: 0.0791899	total: 601ms	remaining: 3.3s
# 154:	learn: 0.0790774	total: 605ms	remaining: 3.3s
# 155:	learn: 0.0786043	total: 609ms	remaining: 3.3s
# 156:	learn: 0.0784872	total: 613ms	remaining: 3.29s
# 157:	learn: 0.0784186	total: 617ms	remaining: 3.29s
# 158:	learn: 0.0779586	total: 621ms	remaining: 3.28s
# 159:	learn: 0.0776156	total: 625ms	remaining: 3.28s
# 160:	learn: 0.0775122	total: 629ms	remaining: 3.27s
# 161:	learn: 0.0773506	total: 632ms	remaining: 3.27s
# 162:	learn: 0.0771890	total: 636ms	remaining: 3.27s
# 163:	learn: 0.0770500	total: 640ms	remaining: 3.26s
# 164:	learn: 0.0767536	total: 643ms	remaining: 3.26s
# 165:	learn: 0.0767098	total: 647ms	remaining: 3.25s
# 166:	learn: 0.0763011	total: 651ms	remaining: 3.25s
# 167:	learn: 0.0759070	total: 654ms	remaining: 3.24s
# 168:	learn: 0.0756396	total: 658ms	remaining: 3.24s
# 169:	learn: 0.0753540	total: 662ms	remaining: 3.23s
# 170:	learn: 0.0749503	total: 666ms	remaining: 3.23s
# 171:	learn: 0.0746742	total: 669ms	remaining: 3.22s
# 172:	learn: 0.0743725	total: 673ms	remaining: 3.22s
# 173:	learn: 0.0740929	total: 677ms	remaining: 3.21s
# 174:	learn: 0.0740243	total: 680ms	remaining: 3.21s
# 175:	learn: 0.0738379	total: 684ms	remaining: 3.2s
# 176:	learn: 0.0736634	total: 688ms	remaining: 3.2s
# 177:	learn: 0.0735774	total: 692ms	remaining: 3.2s
# 178:	learn: 0.0734298	total: 696ms	remaining: 3.19s
# 179:	learn: 0.0733028	total: 700ms	remaining: 3.19s
# 180:	learn: 0.0729923	total: 704ms	remaining: 3.19s
# 181:	learn: 0.0726229	total: 708ms	remaining: 3.18s
# 182:	learn: 0.0722588	total: 712ms	remaining: 3.18s
# 183:	learn: 0.0720664	total: 716ms	remaining: 3.18s
# 184:	learn: 0.0719412	total: 720ms	remaining: 3.17s
# 185:	learn: 0.0715740	total: 724ms	remaining: 3.17s
# 186:	learn: 0.0712015	total: 728ms	remaining: 3.16s
# 187:	learn: 0.0710351	total: 731ms	remaining: 3.16s
# 188:	learn: 0.0709265	total: 736ms	remaining: 3.16s
# 189:	learn: 0.0706528	total: 740ms	remaining: 3.15s
# 190:	learn: 0.0705722	total: 744ms	remaining: 3.15s
# 191:	learn: 0.0702321	total: 748ms	remaining: 3.15s
# 192:	learn: 0.0698908	total: 751ms	remaining: 3.14s
# 193:	learn: 0.0697877	total: 755ms	remaining: 3.14s
# 194:	learn: 0.0695996	total: 759ms	remaining: 3.13s
# 195:	learn: 0.0692776	total: 763ms	remaining: 3.13s
# 196:	learn: 0.0691097	total: 766ms	remaining: 3.12s
# 197:	learn: 0.0686787	total: 770ms	remaining: 3.12s
# 198:	learn: 0.0685987	total: 774ms	remaining: 3.11s
# 199:	learn: 0.0682804	total: 777ms	remaining: 3.11s
# 200:	learn: 0.0680789	total: 781ms	remaining: 3.1s
# 201:	learn: 0.0678129	total: 785ms	remaining: 3.1s
# 202:	learn: 0.0677090	total: 789ms	remaining: 3.1s
# 203:	learn: 0.0676669	total: 792ms	remaining: 3.09s
# 204:	learn: 0.0676141	total: 796ms	remaining: 3.09s
# 205:	learn: 0.0675022	total: 800ms	remaining: 3.08s
# 206:	learn: 0.0674478	total: 803ms	remaining: 3.08s
# 207:	learn: 0.0671800	total: 807ms	remaining: 3.07s
# 208:	learn: 0.0668719	total: 811ms	remaining: 3.07s
# 209:	learn: 0.0667286	total: 815ms	remaining: 3.07s
# 210:	learn: 0.0667043	total: 819ms	remaining: 3.06s
# 211:	learn: 0.0666304	total: 823ms	remaining: 3.06s
# 212:	learn: 0.0665711	total: 827ms	remaining: 3.06s
# 213:	learn: 0.0664055	total: 831ms	remaining: 3.05s
# 214:	learn: 0.0662738	total: 835ms	remaining: 3.05s
# 215:	learn: 0.0659532	total: 839ms	remaining: 3.05s
# 216:	learn: 0.0658303	total: 843ms	remaining: 3.04s
# 217:	learn: 0.0657577	total: 847ms	remaining: 3.04s
# 218:	learn: 0.0654467	total: 851ms	remaining: 3.04s
# 219:	learn: 0.0651469	total: 855ms	remaining: 3.03s
# 220:	learn: 0.0650305	total: 860ms	remaining: 3.03s
# 221:	learn: 0.0647302	total: 864ms	remaining: 3.03s
# 222:	learn: 0.0646700	total: 868ms	remaining: 3.02s
# 223:	learn: 0.0644945	total: 872ms	remaining: 3.02s
# 224:	learn: 0.0641683	total: 876ms	remaining: 3.02s
# 225:	learn: 0.0640644	total: 880ms	remaining: 3.01s
# 226:	learn: 0.0640160	total: 883ms	remaining: 3.01s
# 227:	learn: 0.0639520	total: 887ms	remaining: 3s
# 228:	learn: 0.0636557	total: 891ms	remaining: 3s
# 229:	learn: 0.0635276	total: 895ms	remaining: 3s
# 230:	learn: 0.0632387	total: 899ms	remaining: 2.99s
# 231:	learn: 0.0629551	total: 902ms	remaining: 2.99s
# 232:	learn: 0.0629104	total: 906ms	remaining: 2.98s
# 233:	learn: 0.0626405	total: 910ms	remaining: 2.98s
# 234:	learn: 0.0626225	total: 913ms	remaining: 2.97s
# 235:	learn: 0.0623490	total: 917ms	remaining: 2.97s
# 236:	learn: 0.0622432	total: 921ms	remaining: 2.96s
# 237:	learn: 0.0621999	total: 925ms	remaining: 2.96s
# 238:	learn: 0.0621537	total: 928ms	remaining: 2.96s
# 239:	learn: 0.0620415	total: 933ms	remaining: 2.96s
# 240:	learn: 0.0619106	total: 937ms	remaining: 2.95s
# 241:	learn: 0.0617457	total: 941ms	remaining: 2.95s
# 242:	learn: 0.0616982	total: 945ms	remaining: 2.94s
# 243:	learn: 0.0616117	total: 949ms	remaining: 2.94s
# 244:	learn: 0.0613407	total: 952ms	remaining: 2.94s
# 245:	learn: 0.0611254	total: 956ms	remaining: 2.93s
# 246:	learn: 0.0610063	total: 960ms	remaining: 2.93s
# 247:	learn: 0.0609949	total: 964ms	remaining: 2.92s
# 248:	learn: 0.0608115	total: 968ms	remaining: 2.92s
# 249:	learn: 0.0605710	total: 971ms	remaining: 2.91s
# 250:	learn: 0.0605508	total: 975ms	remaining: 2.91s
# 251:	learn: 0.0604890	total: 979ms	remaining: 2.9s
# 252:	learn: 0.0602337	total: 983ms	remaining: 2.9s
# 253:	learn: 0.0599833	total: 986ms	remaining: 2.9s
# 254:	learn: 0.0599385	total: 990ms	remaining: 2.89s
# 255:	learn: 0.0598447	total: 994ms	remaining: 2.89s
# 256:	learn: 0.0597643	total: 998ms	remaining: 2.88s
# 257:	learn: 0.0597263	total: 1s	remaining: 2.88s
# 258:	learn: 0.0596457	total: 1s	remaining: 2.87s
# 259:	learn: 0.0593988	total: 1.01s	remaining: 2.87s
# 260:	learn: 0.0591604	total: 1.01s	remaining: 2.87s
# 261:	learn: 0.0588417	total: 1.01s	remaining: 2.86s
# 262:	learn: 0.0587334	total: 1.02s	remaining: 2.86s
# 263:	learn: 0.0587059	total: 1.02s	remaining: 2.85s
# 264:	learn: 0.0584648	total: 1.03s	remaining: 2.85s
# 265:	learn: 0.0583918	total: 1.03s	remaining: 2.85s
# 266:	learn: 0.0581604	total: 1.03s	remaining: 2.84s
# 267:	learn: 0.0579989	total: 1.04s	remaining: 2.84s
# 268:	learn: 0.0579616	total: 1.04s	remaining: 2.84s
# 269:	learn: 0.0577316	total: 1.05s	remaining: 2.83s
# 270:	learn: 0.0576835	total: 1.05s	remaining: 2.83s
# 271:	learn: 0.0574576	total: 1.05s	remaining: 2.82s
# 272:	learn: 0.0572186	total: 1.06s	remaining: 2.82s
# 273:	learn: 0.0571815	total: 1.06s	remaining: 2.82s
# 274:	learn: 0.0570089	total: 1.07s	remaining: 2.81s
# 275:	learn: 0.0568403	total: 1.07s	remaining: 2.81s
# 276:	learn: 0.0566368	total: 1.07s	remaining: 2.8s
# 277:	learn: 0.0563406	total: 1.08s	remaining: 2.8s
# 278:	learn: 0.0562823	total: 1.08s	remaining: 2.79s
# 279:	learn: 0.0560821	total: 1.08s	remaining: 2.79s
# 280:	learn: 0.0558864	total: 1.09s	remaining: 2.79s
# 281:	learn: 0.0558496	total: 1.09s	remaining: 2.78s
# 282:	learn: 0.0556539	total: 1.1s	remaining: 2.78s
# 283:	learn: 0.0555349	total: 1.1s	remaining: 2.77s
# 284:	learn: 0.0555003	total: 1.1s	remaining: 2.77s
# 285:	learn: 0.0554338	total: 1.11s	remaining: 2.77s
# 286:	learn: 0.0553988	total: 1.11s	remaining: 2.76s
# 287:	learn: 0.0552034	total: 1.11s	remaining: 2.76s
# 288:	learn: 0.0551020	total: 1.12s	remaining: 2.75s
# 289:	learn: 0.0549708	total: 1.12s	remaining: 2.75s
# 290:	learn: 0.0547857	total: 1.13s	remaining: 2.74s
# 291:	learn: 0.0546639	total: 1.13s	remaining: 2.74s
# 292:	learn: 0.0545220	total: 1.13s	remaining: 2.73s
# 293:	learn: 0.0543465	total: 1.14s	remaining: 2.73s
# 294:	learn: 0.0541522	total: 1.14s	remaining: 2.73s
# 295:	learn: 0.0541101	total: 1.14s	remaining: 2.72s
# 296:	learn: 0.0539420	total: 1.15s	remaining: 2.72s
# 297:	learn: 0.0537718	total: 1.15s	remaining: 2.71s
# 298:	learn: 0.0535030	total: 1.16s	remaining: 2.71s
# 299:	learn: 0.0534586	total: 1.16s	remaining: 2.71s
# 300:	learn: 0.0533042	total: 1.16s	remaining: 2.7s
# 301:	learn: 0.0531413	total: 1.17s	remaining: 2.7s
# 302:	learn: 0.0531076	total: 1.17s	remaining: 2.69s
# 303:	learn: 0.0529466	total: 1.17s	remaining: 2.69s
# 304:	learn: 0.0527674	total: 1.18s	remaining: 2.68s
# 305:	learn: 0.0525602	total: 1.18s	remaining: 2.68s
# 306:	learn: 0.0523771	total: 1.19s	remaining: 2.68s
# 307:	learn: 0.0522197	total: 1.19s	remaining: 2.67s
# 308:	learn: 0.0520560	total: 1.19s	remaining: 2.67s
# 309:	learn: 0.0520408	total: 1.2s	remaining: 2.66s
# 310:	learn: 0.0519701	total: 1.2s	remaining: 2.66s
# 311:	learn: 0.0517868	total: 1.2s	remaining: 2.65s
# 312:	learn: 0.0517339	total: 1.21s	remaining: 2.65s
# 313:	learn: 0.0515550	total: 1.21s	remaining: 2.65s
# 314:	learn: 0.0513873	total: 1.22s	remaining: 2.64s
# 315:	learn: 0.0513007	total: 1.22s	remaining: 2.64s
# 316:	learn: 0.0512217	total: 1.22s	remaining: 2.64s
# 317:	learn: 0.0509494	total: 1.23s	remaining: 2.63s
# 318:	learn: 0.0508567	total: 1.23s	remaining: 2.63s
# 319:	learn: 0.0507822	total: 1.24s	remaining: 2.63s
# 320:	learn: 0.0506666	total: 1.24s	remaining: 2.62s
# 321:	learn: 0.0505455	total: 1.24s	remaining: 2.62s
# 322:	learn: 0.0505227	total: 1.25s	remaining: 2.61s
# 323:	learn: 0.0503852	total: 1.25s	remaining: 2.61s
# 324:	learn: 0.0503576	total: 1.25s	remaining: 2.61s
# 325:	learn: 0.0503199	total: 1.26s	remaining: 2.6s
# 326:	learn: 0.0502040	total: 1.26s	remaining: 2.6s
# 327:	learn: 0.0501320	total: 1.27s	remaining: 2.59s
# 328:	learn: 0.0500176	total: 1.27s	remaining: 2.59s
# 329:	learn: 0.0499341	total: 1.27s	remaining: 2.58s
# 330:	learn: 0.0497967	total: 1.28s	remaining: 2.58s
# 331:	learn: 0.0496451	total: 1.28s	remaining: 2.58s
# 332:	learn: 0.0496257	total: 1.28s	remaining: 2.57s
# 333:	learn: 0.0495933	total: 1.29s	remaining: 2.57s
# 334:	learn: 0.0495649	total: 1.29s	remaining: 2.56s
# 335:	learn: 0.0494622	total: 1.29s	remaining: 2.56s
# 336:	learn: 0.0493747	total: 1.3s	remaining: 2.56s
# 337:	learn: 0.0493145	total: 1.3s	remaining: 2.55s
# 338:	learn: 0.0491843	total: 1.31s	remaining: 2.55s
# 339:	learn: 0.0491492	total: 1.31s	remaining: 2.54s
# 340:	learn: 0.0490361	total: 1.31s	remaining: 2.54s
# 341:	learn: 0.0489085	total: 1.32s	remaining: 2.54s
# 342:	learn: 0.0487840	total: 1.32s	remaining: 2.53s
# 343:	learn: 0.0485742	total: 1.32s	remaining: 2.53s
# 344:	learn: 0.0484560	total: 1.33s	remaining: 2.52s
# 345:	learn: 0.0484307	total: 1.33s	remaining: 2.52s
# 346:	learn: 0.0483134	total: 1.34s	remaining: 2.52s
# 347:	learn: 0.0482705	total: 1.34s	remaining: 2.51s
# 348:	learn: 0.0482297	total: 1.34s	remaining: 2.51s
# 349:	learn: 0.0481865	total: 1.35s	remaining: 2.5s
# 350:	learn: 0.0481320	total: 1.35s	remaining: 2.5s
# 351:	learn: 0.0479689	total: 1.35s	remaining: 2.5s
# 352:	learn: 0.0479489	total: 1.36s	remaining: 2.49s
# 353:	learn: 0.0479154	total: 1.36s	remaining: 2.49s
# 354:	learn: 0.0477261	total: 1.37s	remaining: 2.48s
# 355:	learn: 0.0476989	total: 1.37s	remaining: 2.48s
# 356:	learn: 0.0476343	total: 1.38s	remaining: 2.48s
# 357:	learn: 0.0475079	total: 1.38s	remaining: 2.48s
# 358:	learn: 0.0474842	total: 1.38s	remaining: 2.47s
# 359:	learn: 0.0472480	total: 1.39s	remaining: 2.47s
# 360:	learn: 0.0471386	total: 1.39s	remaining: 2.46s
# 361:	learn: 0.0470554	total: 1.4s	remaining: 2.46s
# 362:	learn: 0.0469978	total: 1.4s	remaining: 2.46s
# 363:	learn: 0.0469708	total: 1.4s	remaining: 2.45s
# 364:	learn: 0.0468746	total: 1.41s	remaining: 2.45s
# 365:	learn: 0.0468292	total: 1.41s	remaining: 2.44s
# 366:	learn: 0.0467915	total: 1.42s	remaining: 2.44s
# 367:	learn: 0.0466705	total: 1.42s	remaining: 2.44s
# 368:	learn: 0.0466254	total: 1.42s	remaining: 2.43s
# 369:	learn: 0.0465167	total: 1.43s	remaining: 2.43s
# 370:	learn: 0.0463025	total: 1.43s	remaining: 2.42s
# 371:	learn: 0.0462127	total: 1.43s	remaining: 2.42s
# 372:	learn: 0.0461731	total: 1.44s	remaining: 2.42s
# 373:	learn: 0.0461257	total: 1.44s	remaining: 2.41s
# 374:	learn: 0.0461040	total: 1.45s	remaining: 2.41s
# 375:	learn: 0.0460938	total: 1.45s	remaining: 2.4s
# 376:	learn: 0.0460786	total: 1.45s	remaining: 2.4s
# 377:	learn: 0.0460446	total: 1.46s	remaining: 2.4s
# 378:	learn: 0.0459879	total: 1.46s	remaining: 2.39s
# 379:	learn: 0.0459310	total: 1.46s	remaining: 2.39s
# 380:	learn: 0.0458165	total: 1.47s	remaining: 2.38s
# 381:	learn: 0.0456917	total: 1.47s	remaining: 2.38s
# 382:	learn: 0.0456073	total: 1.47s	remaining: 2.38s
# 383:	learn: 0.0455130	total: 1.48s	remaining: 2.37s
# 384:	learn: 0.0454025	total: 1.48s	remaining: 2.37s
# 385:	learn: 0.0452331	total: 1.49s	remaining: 2.36s
# 386:	learn: 0.0451145	total: 1.49s	remaining: 2.36s
# 387:	learn: 0.0450953	total: 1.49s	remaining: 2.35s
# 388:	learn: 0.0449963	total: 1.5s	remaining: 2.35s
# 389:	learn: 0.0449137	total: 1.5s	remaining: 2.35s
# 390:	learn: 0.0448827	total: 1.5s	remaining: 2.34s
# 391:	learn: 0.0447848	total: 1.51s	remaining: 2.34s
# 392:	learn: 0.0446711	total: 1.51s	remaining: 2.33s
# 393:	learn: 0.0446024	total: 1.51s	remaining: 2.33s
# 394:	learn: 0.0445849	total: 1.52s	remaining: 2.33s
# 395:	learn: 0.0445703	total: 1.52s	remaining: 2.32s
# 396:	learn: 0.0444167	total: 1.53s	remaining: 2.32s
# 397:	learn: 0.0443159	total: 1.53s	remaining: 2.31s
# 398:	learn: 0.0442589	total: 1.53s	remaining: 2.31s
# 399:	learn: 0.0442384	total: 1.54s	remaining: 2.31s
# 400:	learn: 0.0441378	total: 1.54s	remaining: 2.3s
# 401:	learn: 0.0441263	total: 1.54s	remaining: 2.3s
# 402:	learn: 0.0440341	total: 1.55s	remaining: 2.29s
# 403:	learn: 0.0439919	total: 1.55s	remaining: 2.29s
# 404:	learn: 0.0439770	total: 1.56s	remaining: 2.29s
# 405:	learn: 0.0438786	total: 1.56s	remaining: 2.28s
# 406:	learn: 0.0437141	total: 1.56s	remaining: 2.28s
# 407:	learn: 0.0437046	total: 1.57s	remaining: 2.28s
# 408:	learn: 0.0435600	total: 1.57s	remaining: 2.27s
# 409:	learn: 0.0435200	total: 1.58s	remaining: 2.27s
# 410:	learn: 0.0432707	total: 1.58s	remaining: 2.26s
# 411:	learn: 0.0432183	total: 1.58s	remaining: 2.26s
# 412:	learn: 0.0432060	total: 1.59s	remaining: 2.26s
# 413:	learn: 0.0431973	total: 1.59s	remaining: 2.25s
# 414:	learn: 0.0429724	total: 1.59s	remaining: 2.25s
# 415:	learn: 0.0429111	total: 1.6s	remaining: 2.25s
# 416:	learn: 0.0428936	total: 1.6s	remaining: 2.24s
# 417:	learn: 0.0428596	total: 1.61s	remaining: 2.24s
# 418:	learn: 0.0427084	total: 1.61s	remaining: 2.23s
# 419:	learn: 0.0426527	total: 1.61s	remaining: 2.23s
# 420:	learn: 0.0426210	total: 1.62s	remaining: 2.22s
# 421:	learn: 0.0425271	total: 1.62s	remaining: 2.22s
# 422:	learn: 0.0425147	total: 1.63s	remaining: 2.22s
# 423:	learn: 0.0424992	total: 1.63s	remaining: 2.21s
# 424:	learn: 0.0424459	total: 1.63s	remaining: 2.21s
# 425:	learn: 0.0424124	total: 1.64s	remaining: 2.2s
# 426:	learn: 0.0423190	total: 1.64s	remaining: 2.2s
# 427:	learn: 0.0422916	total: 1.64s	remaining: 2.2s
# 428:	learn: 0.0422716	total: 1.65s	remaining: 2.19s
# 429:	learn: 0.0421702	total: 1.65s	remaining: 2.19s
# 430:	learn: 0.0421314	total: 1.65s	remaining: 2.18s
# 431:	learn: 0.0420168	total: 1.66s	remaining: 2.18s
# 432:	learn: 0.0419849	total: 1.66s	remaining: 2.18s
# 433:	learn: 0.0419487	total: 1.67s	remaining: 2.17s
# 434:	learn: 0.0419275	total: 1.67s	remaining: 2.17s
# 435:	learn: 0.0418435	total: 1.67s	remaining: 2.16s
# 436:	learn: 0.0417483	total: 1.68s	remaining: 2.16s
# 437:	learn: 0.0417278	total: 1.68s	remaining: 2.16s
# 438:	learn: 0.0415803	total: 1.68s	remaining: 2.15s
# 439:	learn: 0.0415538	total: 1.69s	remaining: 2.15s
# 440:	learn: 0.0415277	total: 1.69s	remaining: 2.14s
# 441:	learn: 0.0415016	total: 1.69s	remaining: 2.14s
# 442:	learn: 0.0412806	total: 1.7s	remaining: 2.13s
# 443:	learn: 0.0412393	total: 1.7s	remaining: 2.13s
# 444:	learn: 0.0411582	total: 1.71s	remaining: 2.13s
# 445:	learn: 0.0411325	total: 1.71s	remaining: 2.12s
# 446:	learn: 0.0410931	total: 1.71s	remaining: 2.12s
# 447:	learn: 0.0410275	total: 1.72s	remaining: 2.12s
# 448:	learn: 0.0409084	total: 1.72s	remaining: 2.11s
# 449:	learn: 0.0408300	total: 1.73s	remaining: 2.11s
# 450:	learn: 0.0407402	total: 1.73s	remaining: 2.11s
# 451:	learn: 0.0407188	total: 1.73s	remaining: 2.1s
# 452:	learn: 0.0405677	total: 1.74s	remaining: 2.1s
# 453:	learn: 0.0405390	total: 1.74s	remaining: 2.09s
# 454:	learn: 0.0404636	total: 1.75s	remaining: 2.09s
# 455:	learn: 0.0404462	total: 1.75s	remaining: 2.09s
# 456:	learn: 0.0403671	total: 1.75s	remaining: 2.08s
# 457:	learn: 0.0403524	total: 1.76s	remaining: 2.08s
# 458:	learn: 0.0403424	total: 1.76s	remaining: 2.07s
# 459:	learn: 0.0403193	total: 1.76s	remaining: 2.07s
# 460:	learn: 0.0402956	total: 1.77s	remaining: 2.07s
# 461:	learn: 0.0402734	total: 1.77s	remaining: 2.06s
# 462:	learn: 0.0402016	total: 1.77s	remaining: 2.06s
# 463:	learn: 0.0401793	total: 1.78s	remaining: 2.05s
# 464:	learn: 0.0401319	total: 1.78s	remaining: 2.05s
# 465:	learn: 0.0400996	total: 1.78s	remaining: 2.05s
# 466:	learn: 0.0399909	total: 1.79s	remaining: 2.04s
# 467:	learn: 0.0399674	total: 1.79s	remaining: 2.04s
# 468:	learn: 0.0399317	total: 1.8s	remaining: 2.03s
# 469:	learn: 0.0399202	total: 1.8s	remaining: 2.03s
# 470:	learn: 0.0397569	total: 1.8s	remaining: 2.03s
# 471:	learn: 0.0396128	total: 1.81s	remaining: 2.02s
# 472:	learn: 0.0395927	total: 1.81s	remaining: 2.02s
# 473:	learn: 0.0395195	total: 1.81s	remaining: 2.02s
# 474:	learn: 0.0394325	total: 1.82s	remaining: 2.01s
# 475:	learn: 0.0394126	total: 1.82s	remaining: 2.01s
# 476:	learn: 0.0393087	total: 1.83s	remaining: 2s
# 477:	learn: 0.0392960	total: 1.83s	remaining: 2s
# 478:	learn: 0.0392620	total: 1.83s	remaining: 2s
# 479:	learn: 0.0392002	total: 1.84s	remaining: 1.99s
# 480:	learn: 0.0390773	total: 1.84s	remaining: 1.99s
# 481:	learn: 0.0390527	total: 1.84s	remaining: 1.98s
# 482:	learn: 0.0390205	total: 1.85s	remaining: 1.98s
# 483:	learn: 0.0389989	total: 1.85s	remaining: 1.98s
# 484:	learn: 0.0389875	total: 1.86s	remaining: 1.97s
# 485:	learn: 0.0389798	total: 1.86s	remaining: 1.97s
# 486:	learn: 0.0388310	total: 1.86s	remaining: 1.96s
# 487:	learn: 0.0387735	total: 1.87s	remaining: 1.96s
# 488:	learn: 0.0387538	total: 1.87s	remaining: 1.96s
# 489:	learn: 0.0386787	total: 1.88s	remaining: 1.95s
# 490:	learn: 0.0385904	total: 1.88s	remaining: 1.95s
# 491:	learn: 0.0385248	total: 1.88s	remaining: 1.94s
# 492:	learn: 0.0385157	total: 1.89s	remaining: 1.94s
# 493:	learn: 0.0384346	total: 1.89s	remaining: 1.94s
# 494:	learn: 0.0383778	total: 1.89s	remaining: 1.93s
# 495:	learn: 0.0383561	total: 1.9s	remaining: 1.93s
# 496:	learn: 0.0382613	total: 1.9s	remaining: 1.93s
# 497:	learn: 0.0382444	total: 1.91s	remaining: 1.92s
# 498:	learn: 0.0382208	total: 1.91s	remaining: 1.92s
# 499:	learn: 0.0381761	total: 1.92s	remaining: 1.92s
# 500:	learn: 0.0381423	total: 1.92s	remaining: 1.91s
# 501:	learn: 0.0381205	total: 1.92s	remaining: 1.91s
# 502:	learn: 0.0380892	total: 1.93s	remaining: 1.9s
# 503:	learn: 0.0380619	total: 1.93s	remaining: 1.9s
# 504:	learn: 0.0379244	total: 1.93s	remaining: 1.9s
# 505:	learn: 0.0378970	total: 1.94s	remaining: 1.89s
# 506:	learn: 0.0377994	total: 1.94s	remaining: 1.89s
# 507:	learn: 0.0376985	total: 1.95s	remaining: 1.88s
# 508:	learn: 0.0376804	total: 1.95s	remaining: 1.88s
# 509:	learn: 0.0376553	total: 1.95s	remaining: 1.88s
# 510:	learn: 0.0375564	total: 1.96s	remaining: 1.87s
# 511:	learn: 0.0375421	total: 1.96s	remaining: 1.87s
# 512:	learn: 0.0375215	total: 1.96s	remaining: 1.86s
# 513:	learn: 0.0374946	total: 1.97s	remaining: 1.86s
# 514:	learn: 0.0374313	total: 1.97s	remaining: 1.86s
# 515:	learn: 0.0373714	total: 1.98s	remaining: 1.85s
# 516:	learn: 0.0373523	total: 1.98s	remaining: 1.85s
# 517:	learn: 0.0372615	total: 1.98s	remaining: 1.84s
# 518:	learn: 0.0372410	total: 1.99s	remaining: 1.84s
# 519:	learn: 0.0371717	total: 1.99s	remaining: 1.84s
# 520:	learn: 0.0371458	total: 1.99s	remaining: 1.83s
# 521:	learn: 0.0371355	total: 2s	remaining: 1.83s
# 522:	learn: 0.0371178	total: 2s	remaining: 1.82s
# 523:	learn: 0.0370919	total: 2s	remaining: 1.82s
# 524:	learn: 0.0370778	total: 2.01s	remaining: 1.82s
# 525:	learn: 0.0369866	total: 2.01s	remaining: 1.81s
# 526:	learn: 0.0369600	total: 2.02s	remaining: 1.81s
# 527:	learn: 0.0369514	total: 2.02s	remaining: 1.8s
# 528:	learn: 0.0368874	total: 2.02s	remaining: 1.8s
# 529:	learn: 0.0368710	total: 2.03s	remaining: 1.8s
# 530:	learn: 0.0368062	total: 2.03s	remaining: 1.79s
# 531:	learn: 0.0367931	total: 2.03s	remaining: 1.79s
# 532:	learn: 0.0367330	total: 2.04s	remaining: 1.78s
# 533:	learn: 0.0367127	total: 2.04s	remaining: 1.78s
# 534:	learn: 0.0366486	total: 2.04s	remaining: 1.78s
# 535:	learn: 0.0366308	total: 2.05s	remaining: 1.77s
# 536:	learn: 0.0365975	total: 2.05s	remaining: 1.77s
# 537:	learn: 0.0365806	total: 2.06s	remaining: 1.76s
# 538:	learn: 0.0365653	total: 2.06s	remaining: 1.76s
# 539:	learn: 0.0364746	total: 2.06s	remaining: 1.76s
# 540:	learn: 0.0364447	total: 2.07s	remaining: 1.75s
# 541:	learn: 0.0364238	total: 2.07s	remaining: 1.75s
# 542:	learn: 0.0364025	total: 2.08s	remaining: 1.75s
# 543:	learn: 0.0363819	total: 2.08s	remaining: 1.74s
# 544:	learn: 0.0363673	total: 2.08s	remaining: 1.74s
# 545:	learn: 0.0363171	total: 2.09s	remaining: 1.74s
# 546:	learn: 0.0362961	total: 2.09s	remaining: 1.73s
# 547:	learn: 0.0362678	total: 2.1s	remaining: 1.73s
# 548:	learn: 0.0362469	total: 2.1s	remaining: 1.72s
# 549:	learn: 0.0361410	total: 2.1s	remaining: 1.72s
# 550:	learn: 0.0360759	total: 2.11s	remaining: 1.72s
# 551:	learn: 0.0360608	total: 2.11s	remaining: 1.71s
# 552:	learn: 0.0360303	total: 2.11s	remaining: 1.71s
# 553:	learn: 0.0360214	total: 2.12s	remaining: 1.71s
# 554:	learn: 0.0359982	total: 2.12s	remaining: 1.7s
# 555:	learn: 0.0359290	total: 2.13s	remaining: 1.7s
# 556:	learn: 0.0359049	total: 2.13s	remaining: 1.69s
# 557:	learn: 0.0358381	total: 2.13s	remaining: 1.69s
# 558:	learn: 0.0357429	total: 2.14s	remaining: 1.69s
# 559:	learn: 0.0357044	total: 2.14s	remaining: 1.68s
# 560:	learn: 0.0356972	total: 2.14s	remaining: 1.68s
# 561:	learn: 0.0356931	total: 2.15s	remaining: 1.67s
# 562:	learn: 0.0356298	total: 2.15s	remaining: 1.67s
# 563:	learn: 0.0355758	total: 2.15s	remaining: 1.67s
# 564:	learn: 0.0355256	total: 2.16s	remaining: 1.66s
# 565:	learn: 0.0354543	total: 2.16s	remaining: 1.66s
# 566:	learn: 0.0354198	total: 2.17s	remaining: 1.65s
# 567:	learn: 0.0354012	total: 2.17s	remaining: 1.65s
# 568:	learn: 0.0353834	total: 2.17s	remaining: 1.65s
# 569:	learn: 0.0353646	total: 2.18s	remaining: 1.64s
# 570:	learn: 0.0353407	total: 2.18s	remaining: 1.64s
# 571:	learn: 0.0353132	total: 2.19s	remaining: 1.64s
# 572:	learn: 0.0352988	total: 2.19s	remaining: 1.63s
# 573:	learn: 0.0352326	total: 2.19s	remaining: 1.63s
# 574:	learn: 0.0351937	total: 2.2s	remaining: 1.62s
# 575:	learn: 0.0351261	total: 2.2s	remaining: 1.62s
# 576:	learn: 0.0351131	total: 2.2s	remaining: 1.61s
# 577:	learn: 0.0350910	total: 2.21s	remaining: 1.61s
# 578:	learn: 0.0350703	total: 2.21s	remaining: 1.61s
# 579:	learn: 0.0349911	total: 2.21s	remaining: 1.6s
# 580:	learn: 0.0349321	total: 2.22s	remaining: 1.6s
# 581:	learn: 0.0348526	total: 2.22s	remaining: 1.6s
# 582:	learn: 0.0348377	total: 2.23s	remaining: 1.6s
# 583:	learn: 0.0348241	total: 2.25s	remaining: 1.6s
# 584:	learn: 0.0348053	total: 2.26s	remaining: 1.61s
# 585:	learn: 0.0347629	total: 2.27s	remaining: 1.6s
# 586:	learn: 0.0347475	total: 2.28s	remaining: 1.6s
# 587:	learn: 0.0347320	total: 2.29s	remaining: 1.6s
# 588:	learn: 0.0347229	total: 2.29s	remaining: 1.6s
# 589:	learn: 0.0347112	total: 2.29s	remaining: 1.59s
# 590:	learn: 0.0345523	total: 2.3s	remaining: 1.59s
# 591:	learn: 0.0345360	total: 2.3s	remaining: 1.59s
# 592:	learn: 0.0345228	total: 2.31s	remaining: 1.58s
# 593:	learn: 0.0345081	total: 2.31s	remaining: 1.58s
# 594:	learn: 0.0344910	total: 2.31s	remaining: 1.57s
# 595:	learn: 0.0344778	total: 2.32s	remaining: 1.57s
# 596:	learn: 0.0344141	total: 2.32s	remaining: 1.57s
# 597:	learn: 0.0343558	total: 2.32s	remaining: 1.56s
# 598:	learn: 0.0342939	total: 2.33s	remaining: 1.56s
# 599:	learn: 0.0342340	total: 2.33s	remaining: 1.55s
# 600:	learn: 0.0341811	total: 2.33s	remaining: 1.55s
# 601:	learn: 0.0341738	total: 2.34s	remaining: 1.55s
# 602:	learn: 0.0341587	total: 2.34s	remaining: 1.54s
# 603:	learn: 0.0341429	total: 2.35s	remaining: 1.54s
# 604:	learn: 0.0341325	total: 2.35s	remaining: 1.53s
# 605:	learn: 0.0341103	total: 2.35s	remaining: 1.53s
# 606:	learn: 0.0340984	total: 2.36s	remaining: 1.53s
# 607:	learn: 0.0340418	total: 2.36s	remaining: 1.52s
# 608:	learn: 0.0340297	total: 2.37s	remaining: 1.52s
# 609:	learn: 0.0339404	total: 2.37s	remaining: 1.51s
# 610:	learn: 0.0339253	total: 2.37s	remaining: 1.51s
# 611:	learn: 0.0338718	total: 2.38s	remaining: 1.51s
# 612:	learn: 0.0338177	total: 2.38s	remaining: 1.5s
# 613:	learn: 0.0338023	total: 2.38s	remaining: 1.5s
# 614:	learn: 0.0337364	total: 2.39s	remaining: 1.49s
# 615:	learn: 0.0336983	total: 2.39s	remaining: 1.49s
# 616:	learn: 0.0336752	total: 2.39s	remaining: 1.49s
# 617:	learn: 0.0336644	total: 2.4s	remaining: 1.48s
# 618:	learn: 0.0336592	total: 2.4s	remaining: 1.48s
# 619:	learn: 0.0336512	total: 2.41s	remaining: 1.47s
# 620:	learn: 0.0335762	total: 2.41s	remaining: 1.47s
# 621:	learn: 0.0335582	total: 2.41s	remaining: 1.47s
# 622:	learn: 0.0335474	total: 2.42s	remaining: 1.46s
# 623:	learn: 0.0334836	total: 2.42s	remaining: 1.46s
# 624:	learn: 0.0334302	total: 2.42s	remaining: 1.46s
# 625:	learn: 0.0334149	total: 2.43s	remaining: 1.45s
# 626:	learn: 0.0333814	total: 2.43s	remaining: 1.45s
# 627:	learn: 0.0333569	total: 2.44s	remaining: 1.44s
# 628:	learn: 0.0332989	total: 2.44s	remaining: 1.44s
# 629:	learn: 0.0332851	total: 2.44s	remaining: 1.44s
# 630:	learn: 0.0332364	total: 2.45s	remaining: 1.43s
# 631:	learn: 0.0332246	total: 2.45s	remaining: 1.43s
# 632:	learn: 0.0332092	total: 2.46s	remaining: 1.42s
# 633:	learn: 0.0331929	total: 2.46s	remaining: 1.42s
# 634:	learn: 0.0331271	total: 2.46s	remaining: 1.42s
# 635:	learn: 0.0331082	total: 2.47s	remaining: 1.41s
# 636:	learn: 0.0330445	total: 2.47s	remaining: 1.41s
# 637:	learn: 0.0329916	total: 2.47s	remaining: 1.4s
# 638:	learn: 0.0329779	total: 2.48s	remaining: 1.4s
# 639:	learn: 0.0329630	total: 2.48s	remaining: 1.4s
# 640:	learn: 0.0329401	total: 2.48s	remaining: 1.39s
# 641:	learn: 0.0329074	total: 2.49s	remaining: 1.39s
# 642:	learn: 0.0328968	total: 2.49s	remaining: 1.38s
# 643:	learn: 0.0328792	total: 2.5s	remaining: 1.38s
# 644:	learn: 0.0328204	total: 2.5s	remaining: 1.38s
# 645:	learn: 0.0327712	total: 2.5s	remaining: 1.37s
# 646:	learn: 0.0327370	total: 2.51s	remaining: 1.37s
# 647:	learn: 0.0327221	total: 2.51s	remaining: 1.36s
# 648:	learn: 0.0327006	total: 2.51s	remaining: 1.36s
# 649:	learn: 0.0326896	total: 2.52s	remaining: 1.36s
# 650:	learn: 0.0326387	total: 2.52s	remaining: 1.35s
# 651:	learn: 0.0325479	total: 2.52s	remaining: 1.35s
# 652:	learn: 0.0325219	total: 2.53s	remaining: 1.34s
# 653:	learn: 0.0324946	total: 2.53s	remaining: 1.34s
# 654:	learn: 0.0324718	total: 2.54s	remaining: 1.34s
# 655:	learn: 0.0324574	total: 2.54s	remaining: 1.33s
# 656:	learn: 0.0324394	total: 2.54s	remaining: 1.33s
# 657:	learn: 0.0323946	total: 2.55s	remaining: 1.32s
# 658:	learn: 0.0323405	total: 2.55s	remaining: 1.32s
# 659:	learn: 0.0323222	total: 2.56s	remaining: 1.32s
# 660:	learn: 0.0322925	total: 2.56s	remaining: 1.31s
# 661:	learn: 0.0322703	total: 2.56s	remaining: 1.31s
# 662:	learn: 0.0322354	total: 2.57s	remaining: 1.3s
# 663:	learn: 0.0322277	total: 2.57s	remaining: 1.3s
# 664:	learn: 0.0321172	total: 2.57s	remaining: 1.3s
# 665:	learn: 0.0321063	total: 2.58s	remaining: 1.29s
# 666:	learn: 0.0320934	total: 2.58s	remaining: 1.29s
# 667:	learn: 0.0320671	total: 2.59s	remaining: 1.29s
# 668:	learn: 0.0320550	total: 2.59s	remaining: 1.28s
# 669:	learn: 0.0319638	total: 2.6s	remaining: 1.28s
# 670:	learn: 0.0319508	total: 2.6s	remaining: 1.27s
# 671:	learn: 0.0319302	total: 2.6s	remaining: 1.27s
# 672:	learn: 0.0319236	total: 2.61s	remaining: 1.27s
# 673:	learn: 0.0319022	total: 2.61s	remaining: 1.26s
# 674:	learn: 0.0318855	total: 2.61s	remaining: 1.26s
# 675:	learn: 0.0318409	total: 2.62s	remaining: 1.25s
# 676:	learn: 0.0318232	total: 2.62s	remaining: 1.25s
# 677:	learn: 0.0317762	total: 2.63s	remaining: 1.25s
# 678:	learn: 0.0317376	total: 2.63s	remaining: 1.24s
# 679:	learn: 0.0317242	total: 2.63s	remaining: 1.24s
# 680:	learn: 0.0317120	total: 2.64s	remaining: 1.23s
# 681:	learn: 0.0316257	total: 2.64s	remaining: 1.23s
# 682:	learn: 0.0315752	total: 2.64s	remaining: 1.23s
# 683:	learn: 0.0315624	total: 2.65s	remaining: 1.22s
# 684:	learn: 0.0315235	total: 2.65s	remaining: 1.22s
# 685:	learn: 0.0315040	total: 2.65s	remaining: 1.22s
# 686:	learn: 0.0314842	total: 2.66s	remaining: 1.21s
# 687:	learn: 0.0314674	total: 2.66s	remaining: 1.21s
# 688:	learn: 0.0313879	total: 2.67s	remaining: 1.2s
# 689:	learn: 0.0313522	total: 2.67s	remaining: 1.2s
# 690:	learn: 0.0313164	total: 2.67s	remaining: 1.2s
# 691:	learn: 0.0312625	total: 2.68s	remaining: 1.19s
# 692:	learn: 0.0312361	total: 2.68s	remaining: 1.19s
# 693:	learn: 0.0312152	total: 2.68s	remaining: 1.18s
# 694:	learn: 0.0311842	total: 2.69s	remaining: 1.18s
# 695:	learn: 0.0311204	total: 2.69s	remaining: 1.18s
# 696:	learn: 0.0310817	total: 2.69s	remaining: 1.17s
# 697:	learn: 0.0310717	total: 2.7s	remaining: 1.17s
# 698:	learn: 0.0310355	total: 2.7s	remaining: 1.16s
# 699:	learn: 0.0310327	total: 2.71s	remaining: 1.16s
# 700:	learn: 0.0309974	total: 2.71s	remaining: 1.16s
# 701:	learn: 0.0309463	total: 2.71s	remaining: 1.15s
# 702:	learn: 0.0309284	total: 2.72s	remaining: 1.15s
# 703:	learn: 0.0308952	total: 2.72s	remaining: 1.14s
# 704:	learn: 0.0307494	total: 2.72s	remaining: 1.14s
# 705:	learn: 0.0307405	total: 2.73s	remaining: 1.14s
# 706:	learn: 0.0306977	total: 2.73s	remaining: 1.13s
# 707:	learn: 0.0306421	total: 2.74s	remaining: 1.13s
# 708:	learn: 0.0305206	total: 2.74s	remaining: 1.12s
# 709:	learn: 0.0305092	total: 2.74s	remaining: 1.12s
# 710:	learn: 0.0304640	total: 2.75s	remaining: 1.12s
# 711:	learn: 0.0304460	total: 2.75s	remaining: 1.11s
# 712:	learn: 0.0304273	total: 2.76s	remaining: 1.11s
# 713:	learn: 0.0303736	total: 2.76s	remaining: 1.1s
# 714:	learn: 0.0303466	total: 2.76s	remaining: 1.1s
# 715:	learn: 0.0303186	total: 2.77s	remaining: 1.1s
# 716:	learn: 0.0302763	total: 2.77s	remaining: 1.09s
# 717:	learn: 0.0302583	total: 2.77s	remaining: 1.09s
# 718:	learn: 0.0302274	total: 2.78s	remaining: 1.09s
# 719:	learn: 0.0301958	total: 2.78s	remaining: 1.08s
# 720:	learn: 0.0301514	total: 2.79s	remaining: 1.08s
# 721:	learn: 0.0301105	total: 2.79s	remaining: 1.07s
# 722:	learn: 0.0300888	total: 2.79s	remaining: 1.07s
# 723:	learn: 0.0300671	total: 2.8s	remaining: 1.07s
# 724:	learn: 0.0300448	total: 2.8s	remaining: 1.06s
# 725:	learn: 0.0299591	total: 2.81s	remaining: 1.06s
# 726:	learn: 0.0299139	total: 2.81s	remaining: 1.05s
# 727:	learn: 0.0298977	total: 2.81s	remaining: 1.05s
# 728:	learn: 0.0298605	total: 2.82s	remaining: 1.05s
# 729:	learn: 0.0298397	total: 2.82s	remaining: 1.04s
# 730:	learn: 0.0297931	total: 2.82s	remaining: 1.04s
# 731:	learn: 0.0297600	total: 2.83s	remaining: 1.03s
# 732:	learn: 0.0297503	total: 2.83s	remaining: 1.03s
# 733:	learn: 0.0297385	total: 2.83s	remaining: 1.03s
# 734:	learn: 0.0297218	total: 2.84s	remaining: 1.02s
# 735:	learn: 0.0297134	total: 2.84s	remaining: 1.02s
# 736:	learn: 0.0297013	total: 2.85s	remaining: 1.01s
# 737:	learn: 0.0296582	total: 2.85s	remaining: 1.01s
# 738:	learn: 0.0296251	total: 2.85s	remaining: 1.01s
# 739:	learn: 0.0296166	total: 2.86s	remaining: 1s
# 740:	learn: 0.0295905	total: 2.86s	remaining: 1s
# 741:	learn: 0.0295505	total: 2.87s	remaining: 996ms
# 742:	learn: 0.0295369	total: 2.87s	remaining: 992ms
# 743:	learn: 0.0295165	total: 2.87s	remaining: 988ms
# 744:	learn: 0.0295032	total: 2.88s	remaining: 985ms
# 745:	learn: 0.0294865	total: 2.88s	remaining: 981ms
# 746:	learn: 0.0294723	total: 2.88s	remaining: 977ms
# 747:	learn: 0.0294474	total: 2.89s	remaining: 973ms
# 748:	learn: 0.0293909	total: 2.89s	remaining: 969ms
# 749:	learn: 0.0293754	total: 2.89s	remaining: 965ms
# 750:	learn: 0.0293630	total: 2.9s	remaining: 961ms
# 751:	learn: 0.0293419	total: 2.9s	remaining: 957ms
# 752:	learn: 0.0293047	total: 2.91s	remaining: 953ms
# 753:	learn: 0.0292928	total: 2.91s	remaining: 949ms
# 754:	learn: 0.0292892	total: 2.91s	remaining: 945ms
# 755:	learn: 0.0292476	total: 2.92s	remaining: 941ms
# 756:	learn: 0.0292292	total: 2.92s	remaining: 938ms
# 757:	learn: 0.0291898	total: 2.92s	remaining: 934ms
# 758:	learn: 0.0291878	total: 2.93s	remaining: 930ms
# 759:	learn: 0.0291839	total: 2.93s	remaining: 927ms
# 760:	learn: 0.0291471	total: 2.94s	remaining: 923ms
# 761:	learn: 0.0291141	total: 2.94s	remaining: 919ms
# 762:	learn: 0.0290737	total: 2.95s	remaining: 915ms
# 763:	learn: 0.0290459	total: 2.95s	remaining: 911ms
# 764:	learn: 0.0290286	total: 2.95s	remaining: 907ms
# 765:	learn: 0.0289929	total: 2.96s	remaining: 904ms
# 766:	learn: 0.0289829	total: 2.96s	remaining: 900ms
# 767:	learn: 0.0289725	total: 2.96s	remaining: 896ms
# 768:	learn: 0.0289377	total: 2.97s	remaining: 892ms
# 769:	learn: 0.0289231	total: 2.97s	remaining: 888ms
# 770:	learn: 0.0288875	total: 2.98s	remaining: 884ms
# 771:	learn: 0.0288774	total: 2.98s	remaining: 880ms
# 772:	learn: 0.0288626	total: 2.98s	remaining: 876ms
# 773:	learn: 0.0288186	total: 2.99s	remaining: 872ms
# 774:	learn: 0.0287906	total: 2.99s	remaining: 868ms
# 775:	learn: 0.0287745	total: 3s	remaining: 865ms
# 776:	learn: 0.0286897	total: 3s	remaining: 861ms
# 777:	learn: 0.0286753	total: 3s	remaining: 857ms
# 778:	learn: 0.0286496	total: 3.01s	remaining: 853ms
# 779:	learn: 0.0286364	total: 3.01s	remaining: 849ms
# 780:	learn: 0.0286211	total: 3.01s	remaining: 845ms
# 781:	learn: 0.0286055	total: 3.02s	remaining: 841ms
# 782:	learn: 0.0285912	total: 3.02s	remaining: 837ms
# 783:	learn: 0.0285662	total: 3.02s	remaining: 833ms
# 784:	learn: 0.0285541	total: 3.03s	remaining: 829ms
# 785:	learn: 0.0285401	total: 3.03s	remaining: 826ms
# 786:	learn: 0.0285054	total: 3.04s	remaining: 822ms
# 787:	learn: 0.0284913	total: 3.04s	remaining: 818ms
# 788:	learn: 0.0284691	total: 3.04s	remaining: 814ms
# 789:	learn: 0.0284658	total: 3.05s	remaining: 810ms
# 790:	learn: 0.0284624	total: 3.05s	remaining: 806ms
# 791:	learn: 0.0284487	total: 3.05s	remaining: 802ms
# 792:	learn: 0.0284422	total: 3.06s	remaining: 798ms
# 793:	learn: 0.0284050	total: 3.06s	remaining: 794ms
# 794:	learn: 0.0283893	total: 3.06s	remaining: 790ms
# 795:	learn: 0.0283666	total: 3.07s	remaining: 786ms
# 796:	learn: 0.0283505	total: 3.07s	remaining: 783ms
# 797:	learn: 0.0283356	total: 3.08s	remaining: 779ms
# 798:	learn: 0.0283028	total: 3.08s	remaining: 775ms
# 799:	learn: 0.0282888	total: 3.08s	remaining: 771ms
# 800:	learn: 0.0282330	total: 3.09s	remaining: 767ms
# 801:	learn: 0.0281978	total: 3.09s	remaining: 763ms
# 802:	learn: 0.0281888	total: 3.1s	remaining: 759ms
# 803:	learn: 0.0281679	total: 3.1s	remaining: 756ms
# 804:	learn: 0.0281561	total: 3.1s	remaining: 752ms
# 805:	learn: 0.0281261	total: 3.11s	remaining: 748ms
# 806:	learn: 0.0280987	total: 3.11s	remaining: 745ms
# 807:	learn: 0.0280881	total: 3.12s	remaining: 741ms
# 808:	learn: 0.0280772	total: 3.12s	remaining: 737ms
# 809:	learn: 0.0280487	total: 3.12s	remaining: 733ms
# 810:	learn: 0.0280363	total: 3.13s	remaining: 729ms
# 811:	learn: 0.0280234	total: 3.13s	remaining: 725ms
# 812:	learn: 0.0280137	total: 3.13s	remaining: 721ms
# 813:	learn: 0.0279760	total: 3.14s	remaining: 717ms
# 814:	learn: 0.0279617	total: 3.14s	remaining: 713ms
# 815:	learn: 0.0279275	total: 3.15s	remaining: 709ms
# 816:	learn: 0.0279177	total: 3.15s	remaining: 706ms
# 817:	learn: 0.0279006	total: 3.15s	remaining: 702ms
# 818:	learn: 0.0278722	total: 3.16s	remaining: 698ms
# 819:	learn: 0.0278664	total: 3.16s	remaining: 694ms
# 820:	learn: 0.0278268	total: 3.16s	remaining: 690ms
# 821:	learn: 0.0278141	total: 3.17s	remaining: 686ms
# 822:	learn: 0.0278016	total: 3.17s	remaining: 682ms
# 823:	learn: 0.0277825	total: 3.17s	remaining: 678ms
# 824:	learn: 0.0277725	total: 3.18s	remaining: 674ms
# 825:	learn: 0.0277512	total: 3.18s	remaining: 671ms
# 826:	learn: 0.0276877	total: 3.19s	remaining: 667ms
# 827:	learn: 0.0276810	total: 3.19s	remaining: 663ms
# 828:	learn: 0.0276679	total: 3.19s	remaining: 659ms
# 829:	learn: 0.0276475	total: 3.2s	remaining: 655ms
# 830:	learn: 0.0276303	total: 3.2s	remaining: 651ms
# 831:	learn: 0.0276051	total: 3.21s	remaining: 647ms
# 832:	learn: 0.0275929	total: 3.21s	remaining: 643ms
# 833:	learn: 0.0275856	total: 3.21s	remaining: 639ms
# 834:	learn: 0.0275589	total: 3.22s	remaining: 636ms
# 835:	learn: 0.0275447	total: 3.22s	remaining: 632ms
# 836:	learn: 0.0275319	total: 3.22s	remaining: 628ms
# 837:	learn: 0.0275027	total: 3.23s	remaining: 624ms
# 838:	learn: 0.0274914	total: 3.23s	remaining: 620ms
# 839:	learn: 0.0274705	total: 3.23s	remaining: 616ms
# 840:	learn: 0.0274580	total: 3.24s	remaining: 612ms
# 841:	learn: 0.0273965	total: 3.24s	remaining: 608ms
# 842:	learn: 0.0273812	total: 3.25s	remaining: 604ms
# 843:	learn: 0.0273649	total: 3.25s	remaining: 601ms
# 844:	learn: 0.0273577	total: 3.25s	remaining: 597ms
# 845:	learn: 0.0273501	total: 3.26s	remaining: 593ms
# 846:	learn: 0.0273256	total: 3.26s	remaining: 589ms
# 847:	learn: 0.0273174	total: 3.26s	remaining: 585ms
# 848:	learn: 0.0272949	total: 3.27s	remaining: 582ms
# 849:	learn: 0.0272881	total: 3.27s	remaining: 578ms
# 850:	learn: 0.0272654	total: 3.28s	remaining: 574ms
# 851:	learn: 0.0272516	total: 3.28s	remaining: 570ms
# 852:	learn: 0.0272448	total: 3.29s	remaining: 566ms
# 853:	learn: 0.0272173	total: 3.29s	remaining: 562ms
# 854:	learn: 0.0271993	total: 3.29s	remaining: 558ms
# 855:	learn: 0.0271784	total: 3.3s	remaining: 555ms
# 856:	learn: 0.0271678	total: 3.3s	remaining: 551ms
# 857:	learn: 0.0271406	total: 3.3s	remaining: 547ms
# 858:	learn: 0.0271280	total: 3.31s	remaining: 543ms
# 859:	learn: 0.0270797	total: 3.31s	remaining: 539ms
# 860:	learn: 0.0270336	total: 3.31s	remaining: 535ms
# 861:	learn: 0.0270095	total: 3.32s	remaining: 531ms
# 862:	learn: 0.0269877	total: 3.32s	remaining: 527ms
# 863:	learn: 0.0269051	total: 3.33s	remaining: 524ms
# 864:	learn: 0.0268715	total: 3.33s	remaining: 520ms
# 865:	learn: 0.0268595	total: 3.33s	remaining: 516ms
# 866:	learn: 0.0268297	total: 3.34s	remaining: 512ms
# 867:	learn: 0.0268204	total: 3.34s	remaining: 508ms
# 868:	learn: 0.0268112	total: 3.35s	remaining: 504ms
# 869:	learn: 0.0267888	total: 3.35s	remaining: 500ms
# 870:	learn: 0.0267782	total: 3.35s	remaining: 497ms
# 871:	learn: 0.0267687	total: 3.36s	remaining: 493ms
# 872:	learn: 0.0267598	total: 3.36s	remaining: 489ms
# 873:	learn: 0.0267372	total: 3.36s	remaining: 485ms
# 874:	learn: 0.0267260	total: 3.37s	remaining: 481ms
# 875:	learn: 0.0267000	total: 3.37s	remaining: 477ms
# 876:	learn: 0.0266819	total: 3.37s	remaining: 473ms
# 877:	learn: 0.0266745	total: 3.38s	remaining: 469ms
# 878:	learn: 0.0266188	total: 3.38s	remaining: 466ms
# 879:	learn: 0.0266098	total: 3.38s	remaining: 462ms
# 880:	learn: 0.0266046	total: 3.39s	remaining: 458ms
# 881:	learn: 0.0265975	total: 3.39s	remaining: 454ms
# 882:	learn: 0.0265854	total: 3.4s	remaining: 450ms
# 883:	learn: 0.0265688	total: 3.4s	remaining: 446ms
# 884:	learn: 0.0265359	total: 3.4s	remaining: 442ms
# 885:	learn: 0.0265236	total: 3.41s	remaining: 438ms
# 886:	learn: 0.0265154	total: 3.41s	remaining: 435ms
# 887:	learn: 0.0265098	total: 3.42s	remaining: 431ms
# 888:	learn: 0.0264888	total: 3.42s	remaining: 427ms
# 889:	learn: 0.0264668	total: 3.42s	remaining: 423ms
# 890:	learn: 0.0264578	total: 3.43s	remaining: 419ms
# 891:	learn: 0.0264348	total: 3.43s	remaining: 415ms
# 892:	learn: 0.0264237	total: 3.43s	remaining: 412ms
# 893:	learn: 0.0263569	total: 3.44s	remaining: 408ms
# 894:	learn: 0.0263461	total: 3.44s	remaining: 404ms
# 895:	learn: 0.0263323	total: 3.45s	remaining: 400ms
# 896:	learn: 0.0263187	total: 3.45s	remaining: 397ms
# 897:	learn: 0.0263077	total: 3.46s	remaining: 393ms
# 898:	learn: 0.0262871	total: 3.46s	remaining: 389ms
# 899:	learn: 0.0262743	total: 3.46s	remaining: 385ms
# 900:	learn: 0.0262630	total: 3.47s	remaining: 381ms
# 901:	learn: 0.0262533	total: 3.47s	remaining: 377ms
# 902:	learn: 0.0262443	total: 3.48s	remaining: 373ms
# 903:	learn: 0.0262212	total: 3.48s	remaining: 370ms
# 904:	learn: 0.0262055	total: 3.48s	remaining: 366ms
# 905:	learn: 0.0261963	total: 3.49s	remaining: 362ms
# 906:	learn: 0.0261915	total: 3.49s	remaining: 358ms
# 907:	learn: 0.0261682	total: 3.49s	remaining: 354ms
# 908:	learn: 0.0261419	total: 3.5s	remaining: 350ms
# 909:	learn: 0.0261273	total: 3.5s	remaining: 346ms
# 910:	learn: 0.0261048	total: 3.5s	remaining: 342ms
# 911:	learn: 0.0260949	total: 3.51s	remaining: 339ms
# 912:	learn: 0.0260874	total: 3.51s	remaining: 335ms
# 913:	learn: 0.0260619	total: 3.52s	remaining: 331ms
# 914:	learn: 0.0260340	total: 3.52s	remaining: 327ms
# 915:	learn: 0.0260220	total: 3.52s	remaining: 323ms
# 916:	learn: 0.0260194	total: 3.53s	remaining: 319ms
# 917:	learn: 0.0260083	total: 3.53s	remaining: 315ms
# 918:	learn: 0.0259946	total: 3.54s	remaining: 312ms
# 919:	learn: 0.0259845	total: 3.54s	remaining: 308ms
# 920:	learn: 0.0259761	total: 3.54s	remaining: 304ms
# 921:	learn: 0.0259590	total: 3.55s	remaining: 300ms
# 922:	learn: 0.0259499	total: 3.55s	remaining: 296ms
# 923:	learn: 0.0259349	total: 3.55s	remaining: 292ms
# 924:	learn: 0.0259076	total: 3.56s	remaining: 288ms
# 925:	learn: 0.0258962	total: 3.56s	remaining: 285ms
# 926:	learn: 0.0258824	total: 3.56s	remaining: 281ms
# ...
# 694:	learn: 0.0340691	total: 3.35s	remaining: 1.47s
# 695:	learn: 0.0340614	total: 3.35s	remaining: 1.47s
# 696:	learn: 0.0340320	total: 3.36s	remaining: 1.46s
# 697:	learn: 0.0340100	total: 3.36s	remaining: 1.46s
# 698:	learn: 0.0339933	total: 3.37s	remaining: 1.45s
# 699:	learn: 0.0338600	total: 3.37s	remaining: 1.45s
# 700:	learn: 0.0338530	total: 3.38s	remaining: 1.44s
# 701:	learn: 0.0337813	total: 3.39s	remaining: 1.44s
# 702:	learn: 0.0337613	total: 3.39s	remaining: 1.43s
# 703:	learn: 0.0337399	total: 3.4s	remaining: 1.43s
# 704:	learn: 0.0337203	total: 3.4s	remaining: 1.42s
# 705:	learn: 0.0336461	total: 3.41s	remaining: 1.42s
# 706:	learn: 0.0336120	total: 3.41s	remaining: 1.41s
# 707:	learn: 0.0336049	total: 3.42s	remaining: 1.41s
# 708:	learn: 0.0334872	total: 3.42s	remaining: 1.4s
# 709:	learn: 0.0334726	total: 3.43s	remaining: 1.4s
# 710:	learn: 0.0334529	total: 3.43s	remaining: 1.39s
# 711:	learn: 0.0333858	total: 3.44s	remaining: 1.39s
# 712:	learn: 0.0332804	total: 3.44s	remaining: 1.38s
# 713:	learn: 0.0332627	total: 3.44s	remaining: 1.38s
# 714:	learn: 0.0332048	total: 3.45s	remaining: 1.38s
# 715:	learn: 0.0331904	total: 3.45s	remaining: 1.37s
# 716:	learn: 0.0330865	total: 3.46s	remaining: 1.36s
# 717:	learn: 0.0330731	total: 3.46s	remaining: 1.36s
# 718:	learn: 0.0330062	total: 3.47s	remaining: 1.35s
# 719:	learn: 0.0329362	total: 3.47s	remaining: 1.35s
# 720:	learn: 0.0329257	total: 3.48s	remaining: 1.34s
# 721:	learn: 0.0328462	total: 3.48s	remaining: 1.34s
# 722:	learn: 0.0328146	total: 3.49s	remaining: 1.33s
# 723:	learn: 0.0327929	total: 3.49s	remaining: 1.33s
# 724:	learn: 0.0327740	total: 3.5s	remaining: 1.32s
# 725:	learn: 0.0327507	total: 3.5s	remaining: 1.32s
# 726:	learn: 0.0327141	total: 3.5s	remaining: 1.31s
# 727:	learn: 0.0326948	total: 3.51s	remaining: 1.31s
# 728:	learn: 0.0326759	total: 3.51s	remaining: 1.3s
# 729:	learn: 0.0326677	total: 3.52s	remaining: 1.3s
# 730:	learn: 0.0326566	total: 3.52s	remaining: 1.29s
# 731:	learn: 0.0326479	total: 3.53s	remaining: 1.29s
# 732:	learn: 0.0326212	total: 3.53s	remaining: 1.29s
# 733:	learn: 0.0325915	total: 3.54s	remaining: 1.28s
# 734:	learn: 0.0325309	total: 3.54s	remaining: 1.28s
# 735:	learn: 0.0324796	total: 3.54s	remaining: 1.27s
# 736:	learn: 0.0324662	total: 3.55s	remaining: 1.27s
# 737:	learn: 0.0324483	total: 3.55s	remaining: 1.26s
# 738:	learn: 0.0324280	total: 3.56s	remaining: 1.26s
# 739:	learn: 0.0323850	total: 3.56s	remaining: 1.25s
# 740:	learn: 0.0323623	total: 3.57s	remaining: 1.25s
# 741:	learn: 0.0322900	total: 3.57s	remaining: 1.24s
# 742:	learn: 0.0322553	total: 3.58s	remaining: 1.24s
# 743:	learn: 0.0322305	total: 3.58s	remaining: 1.23s
# 744:	learn: 0.0321503	total: 3.59s	remaining: 1.23s
# 745:	learn: 0.0321181	total: 3.59s	remaining: 1.22s
# 746:	learn: 0.0320736	total: 3.6s	remaining: 1.22s
# 747:	learn: 0.0320638	total: 3.6s	remaining: 1.21s
# 748:	learn: 0.0320519	total: 3.61s	remaining: 1.21s
# 749:	learn: 0.0319918	total: 3.61s	remaining: 1.2s
# 750:	learn: 0.0319290	total: 3.62s	remaining: 1.2s
# 751:	learn: 0.0318713	total: 3.62s	remaining: 1.19s
# 752:	learn: 0.0318362	total: 3.63s	remaining: 1.19s
# 753:	learn: 0.0317504	total: 3.63s	remaining: 1.19s
# 754:	learn: 0.0317155	total: 3.64s	remaining: 1.18s
# 755:	learn: 0.0316596	total: 3.64s	remaining: 1.18s
# 756:	learn: 0.0316294	total: 3.65s	remaining: 1.17s
# 757:	learn: 0.0315716	total: 3.65s	remaining: 1.17s
# 758:	learn: 0.0315484	total: 3.65s	remaining: 1.16s
# 759:	learn: 0.0315254	total: 3.66s	remaining: 1.16s
# 760:	learn: 0.0314719	total: 3.66s	remaining: 1.15s
# 761:	learn: 0.0314577	total: 3.67s	remaining: 1.15s
# 762:	learn: 0.0314350	total: 3.67s	remaining: 1.14s
# 763:	learn: 0.0313838	total: 3.68s	remaining: 1.14s
# 764:	learn: 0.0313302	total: 3.68s	remaining: 1.13s
# 765:	learn: 0.0313134	total: 3.69s	remaining: 1.13s
# 766:	learn: 0.0313070	total: 3.69s	remaining: 1.12s
# 767:	learn: 0.0311703	total: 3.7s	remaining: 1.12s
# 768:	learn: 0.0311558	total: 3.7s	remaining: 1.11s
# 769:	learn: 0.0311318	total: 3.71s	remaining: 1.11s
# 770:	learn: 0.0311063	total: 3.71s	remaining: 1.1s
# 771:	learn: 0.0310908	total: 3.72s	remaining: 1.1s
# 772:	learn: 0.0310803	total: 3.72s	remaining: 1.09s
# 773:	learn: 0.0310739	total: 3.73s	remaining: 1.09s
# 774:	learn: 0.0310456	total: 3.73s	remaining: 1.08s
# 775:	learn: 0.0310399	total: 3.74s	remaining: 1.08s
# 776:	learn: 0.0310267	total: 3.74s	remaining: 1.07s
# 777:	learn: 0.0310059	total: 3.75s	remaining: 1.07s
# 778:	learn: 0.0310003	total: 3.75s	remaining: 1.06s
# 779:	learn: 0.0309833	total: 3.76s	remaining: 1.06s
# 780:	learn: 0.0309248	total: 3.76s	remaining: 1.05s
# 781:	learn: 0.0309152	total: 3.77s	remaining: 1.05s
# 782:	learn: 0.0308523	total: 3.77s	remaining: 1.04s
# 783:	learn: 0.0308330	total: 3.77s	remaining: 1.04s
# 784:	learn: 0.0308182	total: 3.78s	remaining: 1.03s
# 785:	learn: 0.0307751	total: 3.79s	remaining: 1.03s
# 786:	learn: 0.0307663	total: 3.79s	remaining: 1.02s
# 787:	learn: 0.0307532	total: 3.79s	remaining: 1.02s
# 788:	learn: 0.0307303	total: 3.8s	remaining: 1.01s
# 789:	learn: 0.0306563	total: 3.8s	remaining: 1.01s
# 790:	learn: 0.0306429	total: 3.81s	remaining: 1.01s
# 791:	learn: 0.0306245	total: 3.81s	remaining: 1s
# 792:	learn: 0.0306010	total: 3.82s	remaining: 996ms
# 793:	learn: 0.0305958	total: 3.82s	remaining: 992ms
# 794:	learn: 0.0305881	total: 3.83s	remaining: 987ms
# 795:	learn: 0.0305374	total: 3.83s	remaining: 982ms
# 796:	learn: 0.0305192	total: 3.83s	remaining: 977ms
# 797:	learn: 0.0304932	total: 3.84s	remaining: 972ms
# 798:	learn: 0.0304363	total: 3.84s	remaining: 967ms
# 799:	learn: 0.0303819	total: 3.85s	remaining: 962ms
# 800:	learn: 0.0303426	total: 3.85s	remaining: 957ms
# 801:	learn: 0.0302919	total: 3.86s	remaining: 953ms
# 802:	learn: 0.0302778	total: 3.86s	remaining: 948ms
# 803:	learn: 0.0302610	total: 3.87s	remaining: 943ms
# 804:	learn: 0.0302177	total: 3.88s	remaining: 939ms
# 805:	learn: 0.0301937	total: 3.88s	remaining: 935ms
# 806:	learn: 0.0301402	total: 3.89s	remaining: 930ms
# 807:	learn: 0.0300168	total: 3.89s	remaining: 925ms
# 808:	learn: 0.0299877	total: 3.9s	remaining: 921ms
# 809:	learn: 0.0299523	total: 3.9s	remaining: 916ms
# 810:	learn: 0.0299254	total: 3.91s	remaining: 912ms
# 811:	learn: 0.0298860	total: 3.92s	remaining: 907ms
# 812:	learn: 0.0298482	total: 3.92s	remaining: 903ms
# 813:	learn: 0.0298169	total: 3.93s	remaining: 898ms
# 814:	learn: 0.0297957	total: 3.93s	remaining: 893ms
# 815:	learn: 0.0297860	total: 3.94s	remaining: 888ms
# 816:	learn: 0.0297361	total: 3.94s	remaining: 883ms
# 817:	learn: 0.0297231	total: 3.95s	remaining: 879ms
# 818:	learn: 0.0297167	total: 3.95s	remaining: 874ms
# 819:	learn: 0.0296643	total: 3.96s	remaining: 869ms
# 820:	learn: 0.0296162	total: 3.96s	remaining: 864ms
# 821:	learn: 0.0295672	total: 3.97s	remaining: 860ms
# 822:	learn: 0.0295442	total: 3.98s	remaining: 856ms
# 823:	learn: 0.0295289	total: 3.98s	remaining: 851ms
# 824:	learn: 0.0295244	total: 3.99s	remaining: 846ms
# 825:	learn: 0.0295066	total: 4s	remaining: 842ms
# 826:	learn: 0.0294916	total: 4s	remaining: 837ms
# 827:	learn: 0.0294868	total: 4s	remaining: 832ms
# 828:	learn: 0.0294557	total: 4.01s	remaining: 827ms
# 829:	learn: 0.0294112	total: 4.01s	remaining: 823ms
# 830:	learn: 0.0293991	total: 4.02s	remaining: 818ms
# 831:	learn: 0.0293740	total: 4.03s	remaining: 813ms
# 832:	learn: 0.0293317	total: 4.03s	remaining: 809ms
# 833:	learn: 0.0292823	total: 4.04s	remaining: 804ms
# 834:	learn: 0.0292652	total: 4.04s	remaining: 799ms
# 835:	learn: 0.0292486	total: 4.05s	remaining: 795ms
# 836:	learn: 0.0292327	total: 4.05s	remaining: 790ms
# 837:	learn: 0.0292172	total: 4.06s	remaining: 785ms
# 838:	learn: 0.0291877	total: 4.07s	remaining: 780ms
# 839:	learn: 0.0291300	total: 4.07s	remaining: 775ms
# 840:	learn: 0.0290869	total: 4.08s	remaining: 771ms
# 841:	learn: 0.0290748	total: 4.08s	remaining: 766ms
# 842:	learn: 0.0290627	total: 4.09s	remaining: 761ms
# 843:	learn: 0.0290563	total: 4.09s	remaining: 756ms
# 844:	learn: 0.0290454	total: 4.1s	remaining: 752ms
# 845:	learn: 0.0290328	total: 4.1s	remaining: 747ms
# 846:	learn: 0.0290144	total: 4.11s	remaining: 742ms
# 847:	learn: 0.0289919	total: 4.11s	remaining: 738ms
# 848:	learn: 0.0289777	total: 4.12s	remaining: 733ms
# 849:	learn: 0.0289701	total: 4.12s	remaining: 728ms
# 850:	learn: 0.0289557	total: 4.13s	remaining: 723ms
# 851:	learn: 0.0289108	total: 4.13s	remaining: 718ms
# 852:	learn: 0.0288959	total: 4.14s	remaining: 713ms
# 853:	learn: 0.0288646	total: 4.14s	remaining: 709ms
# 854:	learn: 0.0288186	total: 4.15s	remaining: 704ms
# 855:	learn: 0.0287302	total: 4.15s	remaining: 699ms
# 856:	learn: 0.0287162	total: 4.16s	remaining: 694ms
# 857:	learn: 0.0286635	total: 4.17s	remaining: 690ms
# 858:	learn: 0.0286468	total: 4.17s	remaining: 685ms
# 859:	learn: 0.0286044	total: 4.18s	remaining: 680ms
# 860:	learn: 0.0284948	total: 4.18s	remaining: 675ms
# 861:	learn: 0.0284903	total: 4.18s	remaining: 670ms
# 862:	learn: 0.0284790	total: 4.19s	remaining: 665ms
# 863:	learn: 0.0284747	total: 4.2s	remaining: 660ms
# 864:	learn: 0.0284663	total: 4.21s	remaining: 657ms
# 865:	learn: 0.0284589	total: 4.21s	remaining: 652ms
# 866:	learn: 0.0284380	total: 4.22s	remaining: 648ms
# 867:	learn: 0.0283262	total: 4.23s	remaining: 643ms
# 868:	learn: 0.0283190	total: 4.23s	remaining: 638ms
# 869:	learn: 0.0283064	total: 4.24s	remaining: 633ms
# 870:	learn: 0.0282835	total: 4.24s	remaining: 628ms
# 871:	learn: 0.0282281	total: 4.25s	remaining: 624ms
# 872:	learn: 0.0282207	total: 4.25s	remaining: 619ms
# 873:	learn: 0.0282000	total: 4.26s	remaining: 614ms
# 874:	learn: 0.0281852	total: 4.26s	remaining: 609ms
# 875:	learn: 0.0281656	total: 4.27s	remaining: 604ms
# 876:	learn: 0.0281606	total: 4.27s	remaining: 599ms
# 877:	learn: 0.0281413	total: 4.28s	remaining: 595ms
# 878:	learn: 0.0281286	total: 4.28s	remaining: 590ms
# 879:	learn: 0.0281012	total: 4.29s	remaining: 585ms
# 880:	learn: 0.0280886	total: 4.29s	remaining: 580ms
# 881:	learn: 0.0280765	total: 4.3s	remaining: 575ms
# 882:	learn: 0.0280327	total: 4.3s	remaining: 570ms
# 883:	learn: 0.0280195	total: 4.3s	remaining: 565ms
# 884:	learn: 0.0279779	total: 4.31s	remaining: 560ms
# 885:	learn: 0.0279399	total: 4.31s	remaining: 555ms
# 886:	learn: 0.0279257	total: 4.32s	remaining: 550ms
# 887:	learn: 0.0278735	total: 4.32s	remaining: 545ms
# 888:	learn: 0.0278619	total: 4.33s	remaining: 540ms
# 889:	learn: 0.0278261	total: 4.33s	remaining: 536ms
# 890:	learn: 0.0278119	total: 4.34s	remaining: 531ms
# 891:	learn: 0.0277897	total: 4.34s	remaining: 526ms
# 892:	learn: 0.0277800	total: 4.35s	remaining: 521ms
# 893:	learn: 0.0277589	total: 4.35s	remaining: 516ms
# 894:	learn: 0.0277560	total: 4.36s	remaining: 511ms
# 895:	learn: 0.0277046	total: 4.36s	remaining: 506ms
# 896:	learn: 0.0276937	total: 4.36s	remaining: 501ms
# 897:	learn: 0.0276819	total: 4.37s	remaining: 496ms
# 898:	learn: 0.0276467	total: 4.37s	remaining: 491ms
# 899:	learn: 0.0276391	total: 4.38s	remaining: 486ms
# 900:	learn: 0.0275587	total: 4.38s	remaining: 482ms
# 901:	learn: 0.0275520	total: 4.39s	remaining: 477ms
# 902:	learn: 0.0275174	total: 4.39s	remaining: 472ms
# 903:	learn: 0.0274658	total: 4.39s	remaining: 467ms
# 904:	learn: 0.0274564	total: 4.4s	remaining: 462ms
# 905:	learn: 0.0274487	total: 4.41s	remaining: 457ms
# 906:	learn: 0.0274369	total: 4.41s	remaining: 452ms
# 907:	learn: 0.0273717	total: 4.42s	remaining: 447ms
# 908:	learn: 0.0273589	total: 4.42s	remaining: 443ms
# 909:	learn: 0.0273264	total: 4.43s	remaining: 438ms
# 910:	learn: 0.0273187	total: 4.43s	remaining: 433ms
# 911:	learn: 0.0272818	total: 4.43s	remaining: 428ms
# 912:	learn: 0.0272487	total: 4.44s	remaining: 423ms
# 913:	learn: 0.0272386	total: 4.44s	remaining: 418ms
# 914:	learn: 0.0271788	total: 4.45s	remaining: 413ms
# 915:	learn: 0.0271665	total: 4.45s	remaining: 408ms
# 916:	learn: 0.0271549	total: 4.46s	remaining: 404ms
# 917:	learn: 0.0271466	total: 4.46s	remaining: 399ms
# 918:	learn: 0.0271317	total: 4.47s	remaining: 394ms
# 919:	learn: 0.0271187	total: 4.47s	remaining: 389ms
# 920:	learn: 0.0270665	total: 4.47s	remaining: 384ms
# 921:	learn: 0.0270478	total: 4.48s	remaining: 379ms
# 922:	learn: 0.0270410	total: 4.48s	remaining: 374ms
# 923:	learn: 0.0270072	total: 4.49s	remaining: 369ms
# 924:	learn: 0.0269284	total: 4.49s	remaining: 364ms
# 925:	learn: 0.0269117	total: 4.5s	remaining: 360ms
# 926:	learn: 0.0268824	total: 4.5s	remaining: 355ms
# 927:	learn: 0.0267913	total: 4.51s	remaining: 350ms
# 928:	learn: 0.0267783	total: 4.51s	remaining: 345ms
# 929:	learn: 0.0267642	total: 4.52s	remaining: 340ms
# 930:	learn: 0.0267512	total: 4.52s	remaining: 335ms
# 931:	learn: 0.0267408	total: 4.53s	remaining: 330ms
# 932:	learn: 0.0267278	total: 4.53s	remaining: 325ms
# 933:	learn: 0.0266830	total: 4.53s	remaining: 320ms
# 934:	learn: 0.0266450	total: 4.54s	remaining: 316ms
# 935:	learn: 0.0266024	total: 4.54s	remaining: 311ms
# 936:	learn: 0.0265988	total: 4.55s	remaining: 306ms
# 937:	learn: 0.0265873	total: 4.55s	remaining: 301ms
# 938:	learn: 0.0265775	total: 4.56s	remaining: 296ms
# 939:	learn: 0.0265444	total: 4.56s	remaining: 291ms
# 940:	learn: 0.0265279	total: 4.57s	remaining: 286ms
# 941:	learn: 0.0264993	total: 4.57s	remaining: 281ms
# 942:	learn: 0.0264753	total: 4.58s	remaining: 277ms
# 943:	learn: 0.0264600	total: 4.58s	remaining: 272ms
# 944:	learn: 0.0264503	total: 4.58s	remaining: 267ms
# 945:	learn: 0.0264065	total: 4.59s	remaining: 262ms
# 946:	learn: 0.0263815	total: 4.6s	remaining: 257ms
# 947:	learn: 0.0263599	total: 4.6s	remaining: 252ms
# 948:	learn: 0.0263477	total: 4.61s	remaining: 248ms
# 949:	learn: 0.0263288	total: 4.61s	remaining: 243ms
# 950:	learn: 0.0263238	total: 4.62s	remaining: 238ms
# 951:	learn: 0.0263095	total: 4.62s	remaining: 233ms
# 952:	learn: 0.0262947	total: 4.63s	remaining: 228ms
# 953:	learn: 0.0262784	total: 4.63s	remaining: 223ms
# 954:	learn: 0.0262641	total: 4.63s	remaining: 218ms
# 955:	learn: 0.0262469	total: 4.64s	remaining: 214ms
# 956:	learn: 0.0262103	total: 4.64s	remaining: 209ms
# 957:	learn: 0.0261427	total: 4.65s	remaining: 204ms
# 958:	learn: 0.0261293	total: 4.65s	remaining: 199ms
# 959:	learn: 0.0261233	total: 4.66s	remaining: 194ms
# 960:	learn: 0.0261047	total: 4.66s	remaining: 189ms
# 961:	learn: 0.0260822	total: 4.67s	remaining: 184ms
# 962:	learn: 0.0260733	total: 4.67s	remaining: 180ms
# 963:	learn: 0.0260073	total: 4.68s	remaining: 175ms
# 964:	learn: 0.0259735	total: 4.68s	remaining: 170ms
# 965:	learn: 0.0259615	total: 4.69s	remaining: 165ms
# 966:	learn: 0.0259288	total: 4.69s	remaining: 160ms
# 967:	learn: 0.0258957	total: 4.7s	remaining: 155ms
# 968:	learn: 0.0258840	total: 4.7s	remaining: 150ms
# 969:	learn: 0.0258725	total: 4.7s	remaining: 146ms
# 970:	learn: 0.0257976	total: 4.71s	remaining: 141ms
# 971:	learn: 0.0257661	total: 4.71s	remaining: 136ms
# 972:	learn: 0.0257564	total: 4.72s	remaining: 131ms
# 973:	learn: 0.0257185	total: 4.72s	remaining: 126ms
# 974:	learn: 0.0257075	total: 4.73s	remaining: 121ms
# 975:	learn: 0.0256904	total: 4.73s	remaining: 116ms
# 976:	learn: 0.0256820	total: 4.74s	remaining: 112ms
# 977:	learn: 0.0256717	total: 4.74s	remaining: 107ms
# 978:	learn: 0.0256477	total: 4.75s	remaining: 102ms
# 979:	learn: 0.0256377	total: 4.75s	remaining: 97ms
# 980:	learn: 0.0256214	total: 4.76s	remaining: 92.1ms
# 981:	learn: 0.0256067	total: 4.76s	remaining: 87.3ms
# 982:	learn: 0.0255952	total: 4.77s	remaining: 82.5ms
# 983:	learn: 0.0255577	total: 4.77s	remaining: 77.6ms
# 984:	learn: 0.0255423	total: 4.78s	remaining: 72.8ms
# 985:	learn: 0.0255295	total: 4.78s	remaining: 67.9ms
# 986:	learn: 0.0255119	total: 4.79s	remaining: 63.1ms
# 987:	learn: 0.0254749	total: 4.79s	remaining: 58.2ms
# 988:	learn: 0.0254631	total: 4.8s	remaining: 53.4ms
# 989:	learn: 0.0254510	total: 4.8s	remaining: 48.5ms
# 990:	learn: 0.0254337	total: 4.81s	remaining: 43.7ms
# 991:	learn: 0.0254206	total: 4.81s	remaining: 38.8ms
# 992:	learn: 0.0254103	total: 4.82s	remaining: 34ms
# 993:	learn: 0.0253301	total: 4.82s	remaining: 29.1ms
# 994:	learn: 0.0253231	total: 4.83s	remaining: 24.3ms
# 995:	learn: 0.0252963	total: 4.83s	remaining: 19.4ms
# 996:	learn: 0.0252890	total: 4.83s	remaining: 14.6ms
# 997:	learn: 0.0252540	total: 4.84s	remaining: 9.7ms
# 998:	learn: 0.0252271	total: 4.84s	remaining: 4.85ms
# 999:	learn: 0.0252206	total: 4.85s	remaining: 0us
# 99.97477936426327 					 99.93020349600975
# 99.97420542594136 99.92175405079821

# %%
result.head()
# Out:
#               0             1             2             3             4  \
# 0   3304.121179   3195.429103   3276.228027   3294.889269   3288.985941
# 1   1968.746104   1985.899697   1916.815685   1952.406174   1956.017161
# 2  11828.821452  11773.662789  11705.258685  11641.291281  11819.651791
# 3   9376.716132   9321.409572   9241.254455   9235.309632   9243.931934
# 4   5747.891158   5689.558118   5685.568689   5656.877569   5633.838336
#
#               5             6             7             8
# 0   3301.628636   3282.764929   3229.144254   3320.006710
# 1   1994.655815   1960.504660   2002.406609   1990.596200
# 2  11790.550542  11760.864288  11945.205637  11734.401833
# 3   9322.033308   9165.306610   9439.098310   9179.916872
# 4   5655.202942   5730.229710   5657.750779   5634.402053

# %%
result1 = np.mean(result,axis=1)

# %%
sample.head()
# Out:
#          Product_id  Selling_Price
# 0  SCHE4YSTDVPVZVXW    3294.594688
# 1  ACCEGCATKHNRXUHW    1945.603968
# 2  NKCE6GJ5XVJDXNNZ   11871.830880
# 3  NKCEB8BK3ZXDHDHM    9421.143424
# 4  TOPEFDXSAHRNPF94    5717.420625

# %%
final = pd.DataFrame(index = range(len(z)),columns=['Product_id','Selling_Price'])

# %%
final.Product_id = z
final.Selling_Price = result1

# %%
final
# Out:
#             Product_id  Selling_Price
# 0     SCHE4YSTDVPVZVXW    3277.022005
# 1     ACCEGCATKHNRXUHW    1969.783123
# 2     NKCE6GJ5XVJDXNNZ   11777.745367
# 3     NKCEB8BK3ZXDHDHM    9280.552981
# 4     TOPEFDXSAHRNPF94    5676.813262
# 5     ACCE558KZHEPZYMG    9584.611382
# 6     ACCEAZCVAMFHDPY7    5292.225668
# 7     NKCDYNY37JPBGBVM    2564.245689
# 8     NKCEY8KWY33FCUYD    7592.102981
# 9     RNGE4YPTQYRECV9J    4568.996860
# 10    NKCE88AHBHJZREXH    3902.405905
# 11    CLTEJ5ZZGBP4JGGE    7672.654914
# 12    WATE3NWH5FZWAMDA    8248.443407
# 13    CAGE53FSFZVFPFHQ    1738.128037
# 14    PCSEAKVBFFPGCHNZ    3850.520021
# 15    WATDFFH3KJYBTYGG    7482.418523
# 16    NKCDWHFQSCHHYZMP    2707.755305
# 17    RNGEB2PG3Q5RKDW6    3518.737534
# 18    NKCE5UY9HHPZGGUZ    4416.875901
# 19    KTAEHETW3ZCMFMJR    4086.928855
# 20    BRAEBBYRVF9MHJHU    7895.641526
# 21    NKCEAX7HAQ2RJA3Q   10316.468947
# 22    CRTECN2RQZWBSP9W    5113.314701
# 23    WATDEWZ9UHSEHGZG    9527.025244
# 24    PTPEYW8HNV6G9YYR    2836.407802
# 25    ACCEAMGZRRYVAHDC    5093.703454
# 26    SRTEHHXG8MUXTGPA    6029.538881
# 27    SKIE4S4NN4MHYM3Z    4933.676877
# 28    HMBE7G34YHWPWKYN    7376.128823
# 29    LLIEGTMFJBD7ZZZM   13683.196243
# ...                ...            ...
# 3400  CBKEHJUH7WPZEEGK    6320.375077
# 3401  CRTECN2QXZUFSGHZ    5202.656915
# 3402  SWSEBHCPAKWKRDPR    9234.637422
# 3403  ACCEAMGZGAQWYYMV    3952.426456
# 3404  CRTECN2QZGUQPR93    4037.192727
# 3405  SHOEJBSZ8FS9SNJR     446.660413
# 3406  BRAE6ZCHV2ZAA9US    3243.384823
# 3407  SUDEGGB28WWTGFUY    6699.714324
# 3408  ACCEAHRFFKPGUGGX    4893.154381
# 3409  BRAEBBMQZDMZAEBV    1068.469089
# 3410  NKCED6EXXSFZGQP8     322.854277
# 3411  SHTECN9HFVZYP2V9    3373.940302
# 3412  RTREAX3DGDRSSYFT    1383.010794
# 3413  RNGE65FGK2TMUC2A    9359.474563
# 3414  ACCEGZ8EWQ7RMZTZ    6752.530891
# 3415  BRAE4DHZEAPXQVRG    1807.068109
# 3416  CAGECHKFAMZCKPFT     172.461161
# 3417  PCSE6SJG9SMAGGHY    3922.997864
# 3418  SNDE25SG2HRJF9JH    1192.488273
# 3419  NKCEAVZ3FCDEUZHG    5346.862862
# 3420  ACCEG7AG8EUZRRZY    6282.017369
# 3421  SHOECH3WZHFCVZWU    3758.353990
# 3422  TOPEAKYKZKRHPMHX    3700.397697
# 3423  NDNEJRAZNQBZQWQK   12573.011216
# 3424  MUGEBFGFDQYJG5TW    5391.731615
# 3425  BBAE9K7BXFUTDNBK    3908.967986
# 3426  RTRDYPA4PJHCJCGF    9505.184604
# 3427  TUNE8FWQBS7TVVT7    5883.456995
# 3428  NKCEGMUABCRGUZPE    3486.500069
# 3429  RNGE7M92KAQWUBCS     989.372174
#
# [3430 rows x 2 columns]

# %%
final.to_csv('multi_model_cat4.csv',index=False)
